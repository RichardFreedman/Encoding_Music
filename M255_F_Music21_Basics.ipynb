# %%
from music21 import *
import music21 as m21
import requests
# !pip install musescore-scraper
# Out:
# Collecting musescore-scraper
#   Downloading musescore_scraper-2.4.0-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: requests in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from musescore-scraper) (2.27.0)
# Collecting pyppeteer
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 868 kB/s eta 0:00:01
# Collecting PyPDF2
#   Downloading PyPDF2-2.11.1-py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 4.9 MB/s eta 0:00:01
# Requirement already satisfied: svglib in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from musescore-scraper) (1.4.1)
# Requirement already satisfied: reportlab in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from musescore-scraper) (3.6.11)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from PyPDF2->musescore-scraper) (3.10.0.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer->musescore-scraper) (4.8.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer->musescore-scraper) (1.4.4)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp39-cp39-macosx_10_9_x86_64.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.7 MB/s  eta 0:00:01
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer->musescore-scraper) (4.62.3)
# Collecting certifi>=2021
#   Downloading certifi-2022.9.24-py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 18.5 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from pyppeteer->musescore-scraper) (1.26.7)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer->musescore-scraper) (3.6.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from reportlab->musescore-scraper) (9.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from requests->musescore-scraper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from requests->musescore-scraper) (3.1)
# Requirement already satisfied: lxml in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from svglib->musescore-scraper) (4.6.3)
# Requirement already satisfied: cssselect2>=0.2.0 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from svglib->musescore-scraper) (0.6.0)
# Requirement already satisfied: tinycss2>=0.6.0 in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from svglib->musescore-scraper) (1.1.1)
# Requirement already satisfied: webencodings in /Users/rfreedma/opt/anaconda3/lib/python3.9/site-packages (from cssselect2>=0.2.0->svglib->musescore-scraper) (0.5.1)
# Installing collected packages: websockets, pyee, certifi, pyppeteer, PyPDF2, musescore-scraper
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.
# Successfully installed PyPDF2-2.11.1 certifi-2022.9.24 musescore-scraper-2.4.0 pyee-8.2.2 pyppeteer-1.0.2 websockets-10.4

# %%
path = 'https://raw.githubusercontent.com/CRIM-Project/CRIM-online/master/crim/static/mei/MEI_4.0/CRIM_Model_0008.mei'
score = m21.converter.parse(requests.get(path).text)

# %%
import xml.etree.ElementTree as ET
import requests

MEINSURI = 'http://www.music-encoding.org/ns/mei'
MEINS = '{%s}' % MEINSURI


mei_doc = ET.fromstring(requests.get(path).text)
  # Find the title from the MEI file and update the Music21 Score metadata
title = mei_doc.find(f'{MEINS}meiHead//{MEINS}titleStmt/{MEINS}title').text
score.metadata.title = title

mei_doc = ET.fromstring(requests.get(path).text)
  # Find the composer from the MEI file and update the Music21 Score metadata
composer = mei_doc.find(f'{MEINS}meiHead//{MEINS}respStmt/{MEINS}persName').text
score.metadata.composer = composer

# %% [markdown]
# ### View Metadata

# %%
print(score.metadata.composer)
print(score.metadata.title)
# Out:
# Josquin Des Prés
# Ave Maria

# %% [markdown]
# ### All the Notes in the all the Voices

# %%
voice_parts = score.getElementsByClass(m21.stream.Part)
print(voice_parts.show('text'))
# Out:
# {0.0} <music21.stream.Part 0x7fc580c541c0>
#     {0.0} <music21.instrument.Instrument '1: [Superius]: '>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.TrebleClef>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 4/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note C>
#     {8.0} <music21.stream.Measure 2 offset=8.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {16.0} <music21.stream.Measure 3 offset=16.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {24.0} <music21.stream.Measure 4 offset=24.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {32.0} <music21.stream.Measure 5 offset=32.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {40.0} <music21.stream.Measure 6 offset=40.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {48.0} <music21.stream.Measure 7 offset=48.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {56.0} <music21.stream.Measure 8 offset=56.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {64.0} <music21.stream.Measure 9 offset=64.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {72.0} <music21.stream.Measure 10 offset=72.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {2.0} <music21.note.Note G>
#             {4.0} <music21.note.Note C>
#     {80.0} <music21.stream.Measure 11 offset=80.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note B>
#             {3.0} <music21.note.Note A>
#             {4.0} <music21.note.Note B>
#     {88.0} <music21.stream.Measure 12 offset=88.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {96.0} <music21.stream.Measure 13 offset=96.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {104.0} <music21.stream.Measure 14 offset=104.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {112.0} <music21.stream.Measure 15 offset=112.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {120.0} <music21.stream.Measure 16 offset=120.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {128.0} <music21.stream.Measure 17 offset=128.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {136.0} <music21.stream.Measure 18 offset=136.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {144.0} <music21.stream.Measure 19 offset=144.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#             {6.0} <music21.note.Note G>
#     {152.0} <music21.stream.Measure 20 offset=152.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {4.0} <music21.note.Note E>
#             {6.0} <music21.note.Note C>
#     {160.0} <music21.stream.Measure 21 offset=160.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {1.0} <music21.note.Note B>
#             {2.0} <music21.note.Note A>
#             {6.0} <music21.note.Note G>
#     {168.0} <music21.stream.Measure 22 offset=168.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {4.0} <music21.note.Note E>
#     {176.0} <music21.stream.Measure 23 offset=176.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {184.0} <music21.stream.Measure 24 offset=184.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {192.0} <music21.stream.Measure 25 offset=192.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {200.0} <music21.stream.Measure 26 offset=200.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {208.0} <music21.stream.Measure 27 offset=208.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {216.0} <music21.stream.Measure 28 offset=216.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Rest half>
#             {6.0} <music21.note.Note E>
#     {224.0} <music21.stream.Measure 29 offset=224.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {1.0} <music21.note.Note D>
#             {2.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {232.0} <music21.stream.Measure 30 offset=232.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {240.0} <music21.stream.Measure 31 offset=240.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {248.0} <music21.stream.Measure 32 offset=248.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {256.0} <music21.stream.Measure 33 offset=256.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note E>
#             {6.0} <music21.note.Note F>
#     {264.0} <music21.stream.Measure 34 offset=264.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {1.0} <music21.note.Note E>
#             {2.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#     {272.0} <music21.stream.Measure 35 offset=272.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {280.0} <music21.stream.Measure 36 offset=280.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {288.0} <music21.stream.Measure 37 offset=288.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {296.0} <music21.stream.Measure 38 offset=296.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {304.0} <music21.stream.Measure 39 offset=304.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {312.0} <music21.stream.Measure 40 offset=312.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note E>
#     {320.0} <music21.stream.Measure 41 offset=320.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note E>
#     {328.0} <music21.stream.Measure 42 offset=328.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#     {336.0} <music21.stream.Measure 43 offset=336.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note C>
#     {344.0} <music21.stream.Measure 44 offset=344.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note G>
#     {352.0} <music21.stream.Measure 45 offset=352.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note B>
#     {360.0} <music21.stream.Measure 46 offset=360.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note A>
#     {368.0} <music21.stream.Measure 47 offset=368.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note C>
#     {376.0} <music21.stream.Measure 48 offset=376.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note B>
#     {384.0} <music21.stream.Measure 49 offset=384.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {392.0} <music21.stream.Measure 50 offset=392.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {3.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#             {6.0} <music21.note.Note F>
#     {400.0} <music21.stream.Measure 51 offset=400.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {1.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#             {6.0} <music21.note.Note E>
#     {408.0} <music21.stream.Measure 52 offset=408.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {1.0} <music21.note.Note D>
#             {2.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {416.0} <music21.stream.Measure 53 offset=416.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {424.0} <music21.stream.Measure 54 offset=424.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {432.0} <music21.stream.Measure 55 offset=432.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {440.0} <music21.stream.Measure 56 offset=440.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {448.0} <music21.stream.Measure 57 offset=448.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {6.0} <music21.note.Note A>
#             {7.0} <music21.note.Note G>
#     {456.0} <music21.stream.Measure 58 offset=456.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {6.0} <music21.note.Note A>
#     {464.0} <music21.stream.Measure 59 offset=464.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {1.0} <music21.note.Note G>
#             {2.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {472.0} <music21.stream.Measure 60 offset=472.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {480.0} <music21.stream.Measure 61 offset=480.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {488.0} <music21.stream.Measure 62 offset=488.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {496.0} <music21.stream.Measure 63 offset=496.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {504.0} <music21.stream.Measure 64 offset=504.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note D>
#     {512.0} <music21.stream.Measure 65 offset=512.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note C>
#     {520.0} <music21.stream.Measure 66 offset=520.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note B>
#     {528.0} <music21.stream.Measure 67 offset=528.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#     {536.0} <music21.stream.Measure 68 offset=536.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {544.0} <music21.stream.Measure 69 offset=544.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {552.0} <music21.stream.Measure 70 offset=552.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {560.0} <music21.stream.Measure 71 offset=560.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {568.0} <music21.stream.Measure 72 offset=568.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {576.0} <music21.stream.Measure 73 offset=576.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#             {6.0} <music21.note.Note E>
#     {584.0} <music21.stream.Measure 74 offset=584.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {1.0} <music21.note.Note C>
#             {2.0} <music21.note.Note C>
#             {6.0} <music21.note.Note D>
#     {592.0} <music21.stream.Measure 75 offset=592.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {1.0} <music21.note.Note B>
#             {2.0} <music21.note.Note B>
#             {6.0} <music21.note.Note E>
#     {600.0} <music21.stream.Measure 76 offset=600.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {1.0} <music21.note.Note C>
#             {2.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {608.0} <music21.stream.Measure 77 offset=608.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Rest whole>
#     {616.0} <music21.stream.Measure 78 offset=616.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#             {6.0} <music21.note.Note C>
#     {624.0} <music21.stream.Measure 79 offset=624.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note B>
#             {6.0} <music21.note.Note C>
#     {632.0} <music21.stream.Measure 80 offset=632.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#     {640.0} <music21.stream.Measure 81 offset=640.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {648.0} <music21.stream.Measure 82 offset=648.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {656.0} <music21.stream.Measure 83 offset=656.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {664.0} <music21.stream.Measure 84 offset=664.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note B>
#             {6.0} <music21.note.Note B>
#     {672.0} <music21.stream.Measure 85 offset=672.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note B>
#             {6.0} <music21.note.Note A>
#     {680.0} <music21.stream.Measure 86 offset=680.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {2.0} <music21.note.Note G>
#             {4.0} <music21.note.Note F>
#     {688.0} <music21.stream.Measure 87 offset=688.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Rest half>
#             {6.0} <music21.note.Note E>
#     {696.0} <music21.stream.Measure 88 offset=696.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note G>
#     {704.0} <music21.stream.Measure 89 offset=704.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {712.0} <music21.stream.Measure 90 offset=712.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {720.0} <music21.stream.Measure 91 offset=720.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {728.0} <music21.stream.Measure 92 offset=728.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {736.0} <music21.stream.Measure 93 offset=736.0>
#         {0.0} <music21.meter.TimeSignature 3/1>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Rest whole>
#             {8.0} <music21.note.Rest whole>
#     {748.0} <music21.stream.Measure 94 offset=748.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {760.0} <music21.stream.Measure 95 offset=760.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {772.0} <music21.stream.Measure 96 offset=772.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {8.0} <music21.note.Note B>
#     {784.0} <music21.stream.Measure 97 offset=784.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Rest whole>
#     {796.0} <music21.stream.Measure 98 offset=796.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {808.0} <music21.stream.Measure 99 offset=808.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {820.0} <music21.stream.Measure 100 offset=820.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {8.0} <music21.note.Note B>
#     {832.0} <music21.stream.Measure 101 offset=832.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {844.0} <music21.stream.Measure 102 offset=844.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {856.0} <music21.stream.Measure 103 offset=856.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {868.0} <music21.stream.Measure 104 offset=868.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {6.0} <music21.note.Note C>
#             {8.0} <music21.note.Note B>
#             {10.0} <music21.note.Note A>
#     {880.0} <music21.stream.Measure 105 offset=880.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {892.0} <music21.stream.Measure 106 offset=892.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {904.0} <music21.stream.Measure 107 offset=904.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#             {10.0} <music21.note.Note C>
#     {916.0} <music21.stream.Measure 108 offset=916.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note B>
#     {928.0} <music21.stream.Measure 109 offset=928.0>
#         {0.0} <music21.meter.TimeSignature 4/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {936.0} <music21.stream.Measure 110 offset=936.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {944.0} <music21.stream.Measure 111 offset=944.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#     {952.0} <music21.stream.Measure 112 offset=952.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note D>
#     {960.0} <music21.stream.Measure 113 offset=960.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#             {7.0} <music21.note.Note C>
#     {968.0} <music21.stream.Measure 114 offset=968.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note B>
#             {6.0} <music21.note.Note D>
#     {976.0} <music21.stream.Measure 115 offset=976.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {2.0} <music21.note.Note C>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#     {984.0} <music21.stream.Measure 116 offset=984.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {992.0} <music21.stream.Measure 117 offset=992.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1000.0} <music21.stream.Measure 118 offset=1000.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1008.0} <music21.stream.Measure 119 offset=1008.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#     {1016.0} <music21.stream.Measure 120 offset=1016.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note D>
#     {1024.0} <music21.stream.Measure 121 offset=1024.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#             {7.0} <music21.note.Note C>
#     {1032.0} <music21.stream.Measure 122 offset=1032.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note B>
#             {6.0} <music21.note.Note D>
#     {1040.0} <music21.stream.Measure 123 offset=1040.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {2.0} <music21.note.Note C>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#     {1048.0} <music21.stream.Measure 124 offset=1048.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {1056.0} <music21.stream.Measure 125 offset=1056.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1064.0} <music21.stream.Measure 126 offset=1064.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1072.0} <music21.stream.Measure 127 offset=1072.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {1080.0} <music21.stream.Measure 128 offset=1080.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note B>
#     {1088.0} <music21.stream.Measure 129 offset=1088.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {1096.0} <music21.stream.Measure 130 offset=1096.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {1104.0} <music21.stream.Measure 131 offset=1104.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {1112.0} <music21.stream.Measure 132 offset=1112.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1120.0} <music21.stream.Measure 133 offset=1120.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note E>
#     {1128.0} <music21.stream.Measure 134 offset=1128.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {1136.0} <music21.stream.Measure 135 offset=1136.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note D>
#     {1144.0} <music21.stream.Measure 136 offset=1144.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note C>
#     {1152.0} <music21.stream.Measure 137 offset=1152.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note B>
#     {1160.0} <music21.stream.Measure 138 offset=1160.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Rest whole>
#     {1168.0} <music21.stream.Measure 139 offset=1168.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1176.0} <music21.stream.Measure 140 offset=1176.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1184.0} <music21.stream.Measure 141 offset=1184.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1192.0} <music21.stream.Measure 142 offset=1192.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1200.0} <music21.stream.Measure 143 offset=1200.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1208.0} <music21.stream.Measure 144 offset=1208.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {1216.0} <music21.stream.Measure 145 offset=1216.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#     {1224.0} <music21.stream.Measure 146 offset=1224.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {1232.0} <music21.stream.Measure 147 offset=1232.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note E>
#     {1240.0} <music21.stream.Measure 148 offset=1240.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {1248.0} <music21.stream.Measure 149 offset=1248.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1256.0} <music21.stream.Measure 150 offset=1256.0>
#         {0.0} <music21.meter.TimeSignature 8/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#     {1272.0} <music21.stream.Measure 151 offset=1272.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1288.0} <music21.stream.Measure 152 offset=1288.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#         {16.0} <music21.bar.Barline type=final>
# {0.0} <music21.stream.Part 0x7fc580c54e80>
#     {0.0} <music21.instrument.Instrument '2: Altus: '>
#     {0.0} <music21.stream.Measure 1 offset=0.0>
#         {0.0} <music21.clef.Treble8vbClef>
#         {0.0} <music21.key.Key of C major>
#         {0.0} <music21.meter.TimeSignature 4/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {8.0} <music21.stream.Measure 2 offset=8.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {16.0} <music21.stream.Measure 3 offset=16.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note C>
#     {24.0} <music21.stream.Measure 4 offset=24.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {32.0} <music21.stream.Measure 5 offset=32.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {40.0} <music21.stream.Measure 6 offset=40.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {48.0} <music21.stream.Measure 7 offset=48.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {56.0} <music21.stream.Measure 8 offset=56.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {64.0} <music21.stream.Measure 9 offset=64.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {72.0} <music21.stream.Measure 10 offset=72.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note B>
#     {80.0} <music21.stream.Measure 11 offset=80.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {88.0} <music21.stream.Measure 12 offset=88.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {3.0} <music21.note.Note G>
#             {4.0} <music21.note.Note C>
#     {96.0} <music21.stream.Measure 13 offset=96.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note B>
#             {3.0} <music21.note.Note A>
#             {4.0} <music21.note.Note B>
#     {104.0} <music21.stream.Measure 14 offset=104.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {112.0} <music21.stream.Measure 15 offset=112.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {120.0} <music21.stream.Measure 16 offset=120.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {128.0} <music21.stream.Measure 17 offset=128.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {136.0} <music21.stream.Measure 18 offset=136.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {144.0} <music21.stream.Measure 19 offset=144.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {152.0} <music21.stream.Measure 20 offset=152.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {160.0} <music21.stream.Measure 21 offset=160.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {168.0} <music21.stream.Measure 22 offset=168.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Rest whole>
#     {176.0} <music21.stream.Measure 23 offset=176.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {184.0} <music21.stream.Measure 24 offset=184.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {192.0} <music21.stream.Measure 25 offset=192.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note C>
#     {200.0} <music21.stream.Measure 26 offset=200.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#     {208.0} <music21.stream.Measure 27 offset=208.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note G>
#             {7.0} <music21.note.Note F>
#     {216.0} <music21.stream.Measure 28 offset=216.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {1.0} <music21.note.Note D>
#             {2.0} <music21.note.Note C>
#     {224.0} <music21.stream.Measure 29 offset=224.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note F>
#             {4.0} <music21.note.Note G>
#     {232.0} <music21.stream.Measure 30 offset=232.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {240.0} <music21.stream.Measure 31 offset=240.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {248.0} <music21.stream.Measure 32 offset=248.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note F>
#     {256.0} <music21.stream.Measure 33 offset=256.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {6.0} <music21.note.Note A>
#     {264.0} <music21.stream.Measure 34 offset=264.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {2.0} <music21.note.Note G>
#             {4.0} <music21.note.Note F>
#     {272.0} <music21.stream.Measure 35 offset=272.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {280.0} <music21.stream.Measure 36 offset=280.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note A>
#     {288.0} <music21.stream.Measure 37 offset=288.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {6.0} <music21.note.Note C>
#     {296.0} <music21.stream.Measure 38 offset=296.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {1.0} <music21.note.Note B>
#             {2.0} <music21.note.Note B>
#             {6.0} <music21.note.Note A>
#     {304.0} <music21.stream.Measure 39 offset=304.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#     {312.0} <music21.stream.Measure 40 offset=312.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {320.0} <music21.stream.Measure 41 offset=320.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {328.0} <music21.stream.Measure 42 offset=328.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {6.0} <music21.note.Note D>
#             {7.0} <music21.note.Note E>
#     {336.0} <music21.stream.Measure 43 offset=336.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note D>
#             {4.0} <music21.note.Note G>
#     {344.0} <music21.stream.Measure 44 offset=344.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {352.0} <music21.stream.Measure 45 offset=352.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {360.0} <music21.stream.Measure 46 offset=360.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note A>
#     {368.0} <music21.stream.Measure 47 offset=368.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {2.0} <music21.note.Note B>
#             {4.0} <music21.note.Note A>
#     {376.0} <music21.stream.Measure 48 offset=376.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {3.0} <music21.note.Note E>
#             {4.0} <music21.note.Note F>
#             {6.0} <music21.note.Note G>
#     {384.0} <music21.stream.Measure 49 offset=384.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Rest half>
#             {6.0} <music21.note.Note D>
#     {392.0} <music21.stream.Measure 50 offset=392.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note A>
#             {5.0} <music21.note.Note B>
#             {6.0} <music21.note.Note C>
#     {400.0} <music21.stream.Measure 51 offset=400.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {2.0} <music21.note.Note G>
#             {5.0} <music21.note.Note A>
#             {6.0} <music21.note.Note B>
#     {408.0} <music21.stream.Measure 52 offset=408.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {416.0} <music21.stream.Measure 53 offset=416.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {2.0} <music21.note.Note G>
#             {5.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#             {7.0} <music21.note.Note D>
#     {424.0} <music21.stream.Measure 54 offset=424.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Rest whole>
#     {432.0} <music21.stream.Measure 55 offset=432.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note F>
#     {440.0} <music21.stream.Measure 56 offset=440.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note E>
#             {4.0} <music21.note.Note F>
#     {448.0} <music21.stream.Measure 57 offset=448.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {456.0} <music21.stream.Measure 58 offset=456.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {464.0} <music21.stream.Measure 59 offset=464.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {2.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {472.0} <music21.stream.Measure 60 offset=472.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Rest whole>
#     {480.0} <music21.stream.Measure 61 offset=480.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {488.0} <music21.stream.Measure 62 offset=488.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {496.0} <music21.stream.Measure 63 offset=496.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {504.0} <music21.stream.Measure 64 offset=504.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {512.0} <music21.stream.Measure 65 offset=512.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {520.0} <music21.stream.Measure 66 offset=520.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {528.0} <music21.stream.Measure 67 offset=528.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note F>
#     {536.0} <music21.stream.Measure 68 offset=536.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {544.0} <music21.stream.Measure 69 offset=544.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {3.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {552.0} <music21.stream.Measure 70 offset=552.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {3.0} <music21.note.Note B>
#             {4.0} <music21.note.Note C>
#             {6.0} <music21.note.Note D>
#     {560.0} <music21.stream.Measure 71 offset=560.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {1.0} <music21.note.Note B>
#             {2.0} <music21.note.Note B>
#             {6.0} <music21.note.Note C>
#     {568.0} <music21.stream.Measure 72 offset=568.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {1.0} <music21.note.Note A>
#             {2.0} <music21.note.Note A>
#             {6.0} <music21.note.Note G>
#             {7.0} <music21.note.Note F>
#     {576.0} <music21.stream.Measure 73 offset=576.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note B>
#     {584.0} <music21.stream.Measure 74 offset=584.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note A>
#     {592.0} <music21.stream.Measure 75 offset=592.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {600.0} <music21.stream.Measure 76 offset=600.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {608.0} <music21.stream.Measure 77 offset=608.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {616.0} <music21.stream.Measure 78 offset=616.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#             {6.0} <music21.note.Note C>
#     {624.0} <music21.stream.Measure 79 offset=624.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {6.0} <music21.note.Note A>
#     {632.0} <music21.stream.Measure 80 offset=632.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {1.0} <music21.note.Note G>
#             {2.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#     {640.0} <music21.stream.Measure 81 offset=640.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {648.0} <music21.stream.Measure 82 offset=648.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {656.0} <music21.stream.Measure 83 offset=656.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {664.0} <music21.stream.Measure 84 offset=664.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {3.0} <music21.note.Note F>
#             {4.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#     {672.0} <music21.stream.Measure 85 offset=672.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#             {6.0} <music21.note.Note F>
#     {680.0} <music21.stream.Measure 86 offset=680.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {1.0} <music21.note.Note E>
#             {2.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#     {688.0} <music21.stream.Measure 87 offset=688.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {6.0} <music21.note.Note D>
#             {7.0} <music21.note.Note C>
#     {696.0} <music21.stream.Measure 88 offset=696.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note C>
#     {704.0} <music21.stream.Measure 89 offset=704.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {712.0} <music21.stream.Measure 90 offset=712.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {720.0} <music21.stream.Measure 91 offset=720.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {728.0} <music21.stream.Measure 92 offset=728.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {736.0} <music21.stream.Measure 93 offset=736.0>
#         {0.0} <music21.meter.TimeSignature 3/1>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Rest whole>
#             {8.0} <music21.note.Rest whole>
#     {748.0} <music21.stream.Measure 94 offset=748.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note E>
#             {8.0} <music21.note.Note E>
#     {760.0} <music21.stream.Measure 95 offset=760.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#             {8.0} <music21.note.Note D>
#             {10.0} <music21.note.Note C>
#     {772.0} <music21.stream.Measure 96 offset=772.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {8.0} <music21.note.Note B>
#     {784.0} <music21.stream.Measure 97 offset=784.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Rest whole>
#     {796.0} <music21.stream.Measure 98 offset=796.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note E>
#             {8.0} <music21.note.Note E>
#     {808.0} <music21.stream.Measure 99 offset=808.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#             {8.0} <music21.note.Note D>
#             {10.0} <music21.note.Note C>
#     {820.0} <music21.stream.Measure 100 offset=820.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {8.0} <music21.note.Note B>
#     {832.0} <music21.stream.Measure 101 offset=832.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note G>
#     {844.0} <music21.stream.Measure 102 offset=844.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {856.0} <music21.stream.Measure 103 offset=856.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {8.0} <music21.note.Note F>
#     {868.0} <music21.stream.Measure 104 offset=868.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note D>
#     {880.0} <music21.stream.Measure 105 offset=880.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {8.0} <music21.note.Note G>
#     {892.0} <music21.stream.Measure 106 offset=892.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {6.0} <music21.note.Note G>
#             {8.0} <music21.note.Note F>
#             {10.0} <music21.note.Note E>
#     {904.0} <music21.stream.Measure 107 offset=904.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {4.0} <music21.note.Note B>
#             {8.0} <music21.note.Note C>
#     {916.0} <music21.stream.Measure 108 offset=916.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note G>
#     {928.0} <music21.stream.Measure 109 offset=928.0>
#         {0.0} <music21.meter.TimeSignature 4/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {936.0} <music21.stream.Measure 110 offset=936.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {944.0} <music21.stream.Measure 111 offset=944.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {952.0} <music21.stream.Measure 112 offset=952.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
# ...
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {496.0} <music21.stream.Measure 63 offset=496.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#     {504.0} <music21.stream.Measure 64 offset=504.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {2.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {512.0} <music21.stream.Measure 65 offset=512.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {520.0} <music21.stream.Measure 66 offset=520.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {528.0} <music21.stream.Measure 67 offset=528.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {536.0} <music21.stream.Measure 68 offset=536.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {544.0} <music21.stream.Measure 69 offset=544.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {552.0} <music21.stream.Measure 70 offset=552.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note F>
#     {560.0} <music21.stream.Measure 71 offset=560.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {568.0} <music21.stream.Measure 72 offset=568.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {3.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {576.0} <music21.stream.Measure 73 offset=576.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note G>
#     {584.0} <music21.stream.Measure 74 offset=584.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {4.0} <music21.note.Note F>
#     {592.0} <music21.stream.Measure 75 offset=592.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#     {600.0} <music21.stream.Measure 76 offset=600.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {4.0} <music21.note.Note G>
#     {608.0} <music21.stream.Measure 77 offset=608.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {616.0} <music21.stream.Measure 78 offset=616.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {624.0} <music21.stream.Measure 79 offset=624.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {632.0} <music21.stream.Measure 80 offset=632.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {640.0} <music21.stream.Measure 81 offset=640.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#             {6.0} <music21.note.Note C>
#     {648.0} <music21.stream.Measure 82 offset=648.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#             {6.0} <music21.note.Note A>
#     {656.0} <music21.stream.Measure 83 offset=656.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {1.0} <music21.note.Note G>
#             {2.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#     {664.0} <music21.stream.Measure 84 offset=664.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {672.0} <music21.stream.Measure 85 offset=672.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {680.0} <music21.stream.Measure 86 offset=680.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {688.0} <music21.stream.Measure 87 offset=688.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {696.0} <music21.stream.Measure 88 offset=696.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {704.0} <music21.stream.Measure 89 offset=704.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#     {712.0} <music21.stream.Measure 90 offset=712.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note E>
#             {3.0} <music21.note.Note D>
#             {4.0} <music21.note.Note C>
#             {6.0} <music21.note.Note G>
#     {720.0} <music21.stream.Measure 91 offset=720.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {2.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#             {7.0} <music21.note.Note D>
#     {728.0} <music21.stream.Measure 92 offset=728.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {2.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {736.0} <music21.stream.Measure 93 offset=736.0>
#         {0.0} <music21.meter.TimeSignature 3/1>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {748.0} <music21.stream.Measure 94 offset=748.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {760.0} <music21.stream.Measure 95 offset=760.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {8.0} <music21.note.Note F>
#     {772.0} <music21.stream.Measure 96 offset=772.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {784.0} <music21.stream.Measure 97 offset=784.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Rest whole>
#     {796.0} <music21.stream.Measure 98 offset=796.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {808.0} <music21.stream.Measure 99 offset=808.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {8.0} <music21.note.Note F>
#     {820.0} <music21.stream.Measure 100 offset=820.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {832.0} <music21.stream.Measure 101 offset=832.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {844.0} <music21.stream.Measure 102 offset=844.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {856.0} <music21.stream.Measure 103 offset=856.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note D>
#             {8.0} <music21.note.Note D>
#     {868.0} <music21.stream.Measure 104 offset=868.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {8.0} <music21.note.Note G>
#     {880.0} <music21.stream.Measure 105 offset=880.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {8.0} <music21.note.Note C>
#     {892.0} <music21.stream.Measure 106 offset=892.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {8.0} <music21.note.Note A>
#     {904.0} <music21.stream.Measure 107 offset=904.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note B>
#             {4.0} <music21.note.Note G>
#             {8.0} <music21.note.Note A>
#     {916.0} <music21.stream.Measure 108 offset=916.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {4.0} <music21.note.Note G>
#     {928.0} <music21.stream.Measure 109 offset=928.0>
#         {0.0} <music21.meter.TimeSignature 4/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {936.0} <music21.stream.Measure 110 offset=936.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {944.0} <music21.stream.Measure 111 offset=944.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {952.0} <music21.stream.Measure 112 offset=952.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {960.0} <music21.stream.Measure 113 offset=960.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {968.0} <music21.stream.Measure 114 offset=968.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {976.0} <music21.stream.Measure 115 offset=976.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note F>
#     {984.0} <music21.stream.Measure 116 offset=984.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note C>
#     {992.0} <music21.stream.Measure 117 offset=992.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#             {7.0} <music21.note.Note E>
#     {1000.0} <music21.stream.Measure 118 offset=1000.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#     {1008.0} <music21.stream.Measure 119 offset=1008.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {1016.0} <music21.stream.Measure 120 offset=1016.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1024.0} <music21.stream.Measure 121 offset=1024.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1032.0} <music21.stream.Measure 122 offset=1032.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {1040.0} <music21.stream.Measure 123 offset=1040.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note F>
#     {1048.0} <music21.stream.Measure 124 offset=1048.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {4.0} <music21.note.Note C>
#     {1056.0} <music21.stream.Measure 125 offset=1056.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#             {7.0} <music21.note.Note E>
#     {1064.0} <music21.stream.Measure 126 offset=1064.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#     {1072.0} <music21.stream.Measure 127 offset=1072.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {1080.0} <music21.stream.Measure 128 offset=1080.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1088.0} <music21.stream.Measure 129 offset=1088.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {1096.0} <music21.stream.Measure 130 offset=1096.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {3.0} <music21.note.Note E>
#             {4.0} <music21.note.Note D>
#     {1104.0} <music21.stream.Measure 131 offset=1104.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {3.0} <music21.note.Note D>
#             {4.0} <music21.note.Note E>
#             {5.0} <music21.note.Note F>
#             {6.0} <music21.note.Note G>
#     {1112.0} <music21.stream.Measure 132 offset=1112.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#             {2.0} <music21.note.Note E>
#             {4.0} <music21.note.Note F>
#     {1120.0} <music21.stream.Measure 133 offset=1120.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#     {1128.0} <music21.stream.Measure 134 offset=1128.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1136.0} <music21.stream.Measure 135 offset=1136.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1144.0} <music21.stream.Measure 136 offset=1144.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1152.0} <music21.stream.Measure 137 offset=1152.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note G>
#     {1160.0} <music21.stream.Measure 138 offset=1160.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note E>
#             {2.0} <music21.note.Note A>
#             {5.0} <music21.note.Note G>
#             {6.0} <music21.note.Note F>
#             {7.0} <music21.note.Note E>
#     {1168.0} <music21.stream.Measure 139 offset=1168.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {2.0} <music21.note.Note G>
#             {4.0} <music21.note.Note E>
#             {6.0} <music21.note.Note F>
#     {1176.0} <music21.stream.Measure 140 offset=1176.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {1.0} <music21.note.Note E>
#             {2.0} <music21.note.Note D>
#             {3.0} <music21.note.Note C>
#             {4.0} <music21.note.Note D>
#     {1184.0} <music21.stream.Measure 141 offset=1184.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1192.0} <music21.stream.Measure 142 offset=1192.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest breve>
#     {1200.0} <music21.stream.Measure 143 offset=1200.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1208.0} <music21.stream.Measure 144 offset=1208.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#             {4.0} <music21.note.Note G>
#     {1216.0} <music21.stream.Measure 145 offset=1216.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note F>
#             {6.0} <music21.note.Note E>
#             {7.0} <music21.note.Note D>
#     {1224.0} <music21.stream.Measure 146 offset=1224.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1232.0} <music21.stream.Measure 147 offset=1232.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Rest whole>
#             {4.0} <music21.note.Note C>
#     {1240.0} <music21.stream.Measure 148 offset=1240.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#             {4.0} <music21.note.Note G>
#     {1248.0} <music21.stream.Measure 149 offset=1248.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note A>
#     {1256.0} <music21.stream.Measure 150 offset=1256.0>
#         {0.0} <music21.meter.TimeSignature 8/2>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note G>
#     {1272.0} <music21.stream.Measure 151 offset=1272.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#     {1288.0} <music21.stream.Measure 152 offset=1288.0>
#         {0.0} <music21.stream.Voice 1>
#             {0.0} <music21.note.Note C>
#         {16.0} <music21.bar.Barline type=final>
# None

# %% [markdown]
# ### List of Voice Parts
# - list of parts.  Must use `score.getElementsByClass(m21.stream.Part)`

# %%
voice_parts = score.getElementsByClass(m21.stream.Part)
print(voice_parts)

for part in voice_parts:
  print(part.partName)
# Out:
# <music21.stream.iterator.StreamIterator for Score:0x7fc5d1647a00 @:0>
# [Superius]
# Altus
# Tenor
# Bassus

# %% [markdown]
# ### Notes from One Voice Part
# - Define the variable `parts` and then showing where to obtain these with m21
# - Define the variable for your staff by index number (`[0]` is the top voice, `[2]` is the third from the top, etc.
# - The `show` method, with the parameter `text` reveals the **all the notes** found in that part.

# %%
parts = score.getElementsByClass(m21.stream.Part)
print(parts[0].show('text'))
# Out:
# {0.0} <music21.instrument.Instrument '1: [Superius]: '>
# {0.0} <music21.stream.Measure 1 offset=0.0>
#     {0.0} <music21.clef.TrebleClef>
#     {0.0} <music21.key.Key of C major>
#     {0.0} <music21.meter.TimeSignature 4/2>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {4.0} <music21.note.Note C>
# {8.0} <music21.stream.Measure 2 offset=8.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note C>
# {16.0} <music21.stream.Measure 3 offset=16.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note E>
# {24.0} <music21.stream.Measure 4 offset=24.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {32.0} <music21.stream.Measure 5 offset=32.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {40.0} <music21.stream.Measure 6 offset=40.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {48.0} <music21.stream.Measure 7 offset=48.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {56.0} <music21.stream.Measure 8 offset=56.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {64.0} <music21.stream.Measure 9 offset=64.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {4.0} <music21.note.Note G>
# {72.0} <music21.stream.Measure 10 offset=72.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note G>
#         {4.0} <music21.note.Note C>
# {80.0} <music21.stream.Measure 11 offset=80.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B>
#         {3.0} <music21.note.Note A>
#         {4.0} <music21.note.Note B>
# {88.0} <music21.stream.Measure 12 offset=88.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {96.0} <music21.stream.Measure 13 offset=96.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {104.0} <music21.stream.Measure 14 offset=104.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {112.0} <music21.stream.Measure 15 offset=112.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {120.0} <music21.stream.Measure 16 offset=120.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note C>
# {128.0} <music21.stream.Measure 17 offset=128.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note C>
#         {4.0} <music21.note.Note C>
# {136.0} <music21.stream.Measure 18 offset=136.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note E>
# {144.0} <music21.stream.Measure 19 offset=144.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#         {4.0} <music21.note.Note A>
#         {6.0} <music21.note.Note G>
# {152.0} <music21.stream.Measure 20 offset=152.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
#         {4.0} <music21.note.Note E>
#         {6.0} <music21.note.Note C>
# {160.0} <music21.stream.Measure 21 offset=160.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {1.0} <music21.note.Note B>
#         {2.0} <music21.note.Note A>
#         {6.0} <music21.note.Note G>
# {168.0} <music21.stream.Measure 22 offset=168.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
#         {4.0} <music21.note.Note E>
# {176.0} <music21.stream.Measure 23 offset=176.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {184.0} <music21.stream.Measure 24 offset=184.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {192.0} <music21.stream.Measure 25 offset=192.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {200.0} <music21.stream.Measure 26 offset=200.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {4.0} <music21.note.Note G>
# {208.0} <music21.stream.Measure 27 offset=208.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {216.0} <music21.stream.Measure 28 offset=216.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Rest half>
#         {6.0} <music21.note.Note E>
# {224.0} <music21.stream.Measure 29 offset=224.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {1.0} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {232.0} <music21.stream.Measure 30 offset=232.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {240.0} <music21.stream.Measure 31 offset=240.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note C>
# {248.0} <music21.stream.Measure 32 offset=248.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {256.0} <music21.stream.Measure 33 offset=256.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note E>
#         {6.0} <music21.note.Note F>
# {264.0} <music21.stream.Measure 34 offset=264.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note E>
#         {6.0} <music21.note.Note D>
# {272.0} <music21.stream.Measure 35 offset=272.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
# {280.0} <music21.stream.Measure 36 offset=280.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {288.0} <music21.stream.Measure 37 offset=288.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {296.0} <music21.stream.Measure 38 offset=296.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {304.0} <music21.stream.Measure 39 offset=304.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {312.0} <music21.stream.Measure 40 offset=312.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note E>
# {320.0} <music21.stream.Measure 41 offset=320.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note E>
# {328.0} <music21.stream.Measure 42 offset=328.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
#         {6.0} <music21.note.Note E>
# {336.0} <music21.stream.Measure 43 offset=336.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note C>
# {344.0} <music21.stream.Measure 44 offset=344.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {4.0} <music21.note.Note G>
# {352.0} <music21.stream.Measure 45 offset=352.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {4.0} <music21.note.Note B>
# {360.0} <music21.stream.Measure 46 offset=360.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note A>
# {368.0} <music21.stream.Measure 47 offset=368.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {4.0} <music21.note.Note C>
# {376.0} <music21.stream.Measure 48 offset=376.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note B>
# {384.0} <music21.stream.Measure 49 offset=384.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {392.0} <music21.stream.Measure 50 offset=392.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {3.0} <music21.note.Note D>
#         {4.0} <music21.note.Note E>
#         {6.0} <music21.note.Note F>
# {400.0} <music21.stream.Measure 51 offset=400.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
#         {1.0} <music21.note.Note E>
#         {2.0} <music21.note.Note D>
#         {3.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
#         {6.0} <music21.note.Note E>
# {408.0} <music21.stream.Measure 52 offset=408.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {1.0} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {416.0} <music21.stream.Measure 53 offset=416.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {424.0} <music21.stream.Measure 54 offset=424.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note G>
# {432.0} <music21.stream.Measure 55 offset=432.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {440.0} <music21.stream.Measure 56 offset=440.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {448.0} <music21.stream.Measure 57 offset=448.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {6.0} <music21.note.Note A>
#         {7.0} <music21.note.Note G>
# {456.0} <music21.stream.Measure 58 offset=456.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {4.0} <music21.note.Note G>
#         {6.0} <music21.note.Note A>
# {464.0} <music21.stream.Measure 59 offset=464.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {1.0} <music21.note.Note G>
#         {2.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {472.0} <music21.stream.Measure 60 offset=472.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {480.0} <music21.stream.Measure 61 offset=480.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {488.0} <music21.stream.Measure 62 offset=488.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {496.0} <music21.stream.Measure 63 offset=496.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {504.0} <music21.stream.Measure 64 offset=504.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note D>
# {512.0} <music21.stream.Measure 65 offset=512.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note C>
# {520.0} <music21.stream.Measure 66 offset=520.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note B>
# {528.0} <music21.stream.Measure 67 offset=528.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#         {4.0} <music21.note.Note A>
# {536.0} <music21.stream.Measure 68 offset=536.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
# {544.0} <music21.stream.Measure 69 offset=544.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {552.0} <music21.stream.Measure 70 offset=552.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {560.0} <music21.stream.Measure 71 offset=560.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note G>
# {568.0} <music21.stream.Measure 72 offset=568.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {576.0} <music21.stream.Measure 73 offset=576.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note D>
#         {6.0} <music21.note.Note E>
# {584.0} <music21.stream.Measure 74 offset=584.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {1.0} <music21.note.Note C>
#         {2.0} <music21.note.Note C>
#         {6.0} <music21.note.Note D>
# {592.0} <music21.stream.Measure 75 offset=592.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.note.Note B>
#         {2.0} <music21.note.Note B>
#         {6.0} <music21.note.Note E>
# {600.0} <music21.stream.Measure 76 offset=600.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {1.0} <music21.note.Note C>
#         {2.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {608.0} <music21.stream.Measure 77 offset=608.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Rest whole>
# {616.0} <music21.stream.Measure 78 offset=616.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note C>
#         {6.0} <music21.note.Note C>
# {624.0} <music21.stream.Measure 79 offset=624.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note B>
#         {6.0} <music21.note.Note C>
# {632.0} <music21.stream.Measure 80 offset=632.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B>
#         {4.0} <music21.note.Note A>
# {640.0} <music21.stream.Measure 81 offset=640.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
# {648.0} <music21.stream.Measure 82 offset=648.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {656.0} <music21.stream.Measure 83 offset=656.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {664.0} <music21.stream.Measure 84 offset=664.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {4.0} <music21.note.Note B>
#         {6.0} <music21.note.Note B>
# {672.0} <music21.stream.Measure 85 offset=672.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note B>
#         {6.0} <music21.note.Note A>
# {680.0} <music21.stream.Measure 86 offset=680.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {2.0} <music21.note.Note G>
#         {4.0} <music21.note.Note F>
# {688.0} <music21.stream.Measure 87 offset=688.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Rest half>
#         {6.0} <music21.note.Note E>
# {696.0} <music21.stream.Measure 88 offset=696.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {2.0} <music21.note.Note D>
#         {3.0} <music21.note.Note C>
#         {4.0} <music21.note.Note G>
# {704.0} <music21.stream.Measure 89 offset=704.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {712.0} <music21.stream.Measure 90 offset=712.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {720.0} <music21.stream.Measure 91 offset=720.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {728.0} <music21.stream.Measure 92 offset=728.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {736.0} <music21.stream.Measure 93 offset=736.0>
#     {0.0} <music21.meter.TimeSignature 3/1>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Rest whole>
#         {8.0} <music21.note.Rest whole>
# {748.0} <music21.stream.Measure 94 offset=748.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {4.0} <music21.note.Note G>
#         {8.0} <music21.note.Note G>
# {760.0} <music21.stream.Measure 95 offset=760.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {8.0} <music21.note.Note A>
# {772.0} <music21.stream.Measure 96 offset=772.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {8.0} <music21.note.Note B>
# {784.0} <music21.stream.Measure 97 offset=784.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {8.0} <music21.note.Rest whole>
# {796.0} <music21.stream.Measure 98 offset=796.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {4.0} <music21.note.Note G>
#         {8.0} <music21.note.Note G>
# {808.0} <music21.stream.Measure 99 offset=808.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {8.0} <music21.note.Note A>
# {820.0} <music21.stream.Measure 100 offset=820.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {8.0} <music21.note.Note B>
# {832.0} <music21.stream.Measure 101 offset=832.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {8.0} <music21.note.Note G>
# {844.0} <music21.stream.Measure 102 offset=844.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {8.0} <music21.note.Note C>
# {856.0} <music21.stream.Measure 103 offset=856.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {8.0} <music21.note.Note A>
# {868.0} <music21.stream.Measure 104 offset=868.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {6.0} <music21.note.Note C>
#         {8.0} <music21.note.Note B>
#         {10.0} <music21.note.Note A>
# {880.0} <music21.stream.Measure 105 offset=880.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
#         {8.0} <music21.note.Note G>
# {892.0} <music21.stream.Measure 106 offset=892.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {8.0} <music21.note.Note C>
# {904.0} <music21.stream.Measure 107 offset=904.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note E>
#         {10.0} <music21.note.Note C>
# {916.0} <music21.stream.Measure 108 offset=916.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {8.0} <music21.note.Note B>
# {928.0} <music21.stream.Measure 109 offset=928.0>
#     {0.0} <music21.meter.TimeSignature 4/2>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {936.0} <music21.stream.Measure 110 offset=936.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {944.0} <music21.stream.Measure 111 offset=944.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
# {952.0} <music21.stream.Measure 112 offset=952.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note D>
# {960.0} <music21.stream.Measure 113 offset=960.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {6.0} <music21.note.Note D>
#         {7.0} <music21.note.Note C>
# {968.0} <music21.stream.Measure 114 offset=968.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {4.0} <music21.note.Note B>
#         {6.0} <music21.note.Note D>
# {976.0} <music21.stream.Measure 115 offset=976.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#         {4.0} <music21.note.Note A>
# {984.0} <music21.stream.Measure 116 offset=984.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
# {992.0} <music21.stream.Measure 117 offset=992.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1000.0} <music21.stream.Measure 118 offset=1000.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1008.0} <music21.stream.Measure 119 offset=1008.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
# {1016.0} <music21.stream.Measure 120 offset=1016.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note D>
# {1024.0} <music21.stream.Measure 121 offset=1024.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {6.0} <music21.note.Note D>
#         {7.0} <music21.note.Note C>
# {1032.0} <music21.stream.Measure 122 offset=1032.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
#         {4.0} <music21.note.Note B>
#         {6.0} <music21.note.Note D>
# {1040.0} <music21.stream.Measure 123 offset=1040.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {2.0} <music21.note.Note C>
#         {3.0} <music21.note.Note B>
#         {4.0} <music21.note.Note A>
# {1048.0} <music21.stream.Measure 124 offset=1048.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note G>
# {1056.0} <music21.stream.Measure 125 offset=1056.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1064.0} <music21.stream.Measure 126 offset=1064.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1072.0} <music21.stream.Measure 127 offset=1072.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note G>
# {1080.0} <music21.stream.Measure 128 offset=1080.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note A>
#         {4.0} <music21.note.Note B>
# {1088.0} <music21.stream.Measure 129 offset=1088.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {6.0} <music21.note.Note B>
# {1096.0} <music21.stream.Measure 130 offset=1096.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Note D>
# {1104.0} <music21.stream.Measure 131 offset=1104.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
# {1112.0} <music21.stream.Measure 132 offset=1112.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1120.0} <music21.stream.Measure 133 offset=1120.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note E>
# {1128.0} <music21.stream.Measure 134 offset=1128.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note D>
# {1136.0} <music21.stream.Measure 135 offset=1136.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {6.0} <music21.note.Note D>
# {1144.0} <music21.stream.Measure 136 offset=1144.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note C>
# {1152.0} <music21.stream.Measure 137 offset=1152.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {2.0} <music21.note.Note B>
# {1160.0} <music21.stream.Measure 138 offset=1160.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#         {4.0} <music21.note.Rest whole>
# {1168.0} <music21.stream.Measure 139 offset=1168.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1176.0} <music21.stream.Measure 140 offset=1176.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1184.0} <music21.stream.Measure 141 offset=1184.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1192.0} <music21.stream.Measure 142 offset=1192.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest breve>
# {1200.0} <music21.stream.Measure 143 offset=1200.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {1208.0} <music21.stream.Measure 144 offset=1208.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note D>
#         {4.0} <music21.note.Note E>
# {1216.0} <music21.stream.Measure 145 offset=1216.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note F>
# {1224.0} <music21.stream.Measure 146 offset=1224.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
# {1232.0} <music21.stream.Measure 147 offset=1232.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Rest whole>
#         {4.0} <music21.note.Note E>
# {1240.0} <music21.stream.Measure 148 offset=1240.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note E>
#         {4.0} <music21.note.Note D>
# {1248.0} <music21.stream.Measure 149 offset=1248.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {1256.0} <music21.stream.Measure 150 offset=1256.0>
#     {0.0} <music21.meter.TimeSignature 8/2>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note B>
# {1272.0} <music21.stream.Measure 151 offset=1272.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
# {1288.0} <music21.stream.Measure 152 offset=1288.0>
#     {0.0} <music21.stream.Voice 1>
#         {0.0} <music21.note.Note C>
#     {16.0} <music21.bar.Barline type=final>
# None

# %% [markdown]
# ### "Notes" are Pitch Classes
# - looking for all the notes in a given part
# - `[X]` is index of the given part
# - ust include "flat" for reasons that the documentation does not explain

# %%
notes_selected_part = parts[0].flat.getElementsByClass(['Note'])
for note in notes_selected_part:
  print(note)
# Out:
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note E>
# <music21.note.Note F>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.note.Note D>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note C>

# %%
note.show()
# Out:
# ---------------------------------------------------------------------------
# SubConverterException                     Traceback (most recent call last)
# /var/folders/_s/4t2p1z2x0yxcv068dtqj31tw0000gq/T/ipykernel_25359/78521179.py in <cell line: 1>()
# ----> 1 note.show()
#
# ~/opt/anaconda3/envs/intervals/lib/python3.9/site-packages/music21/base.py in show(self, fmt, app, **keywords)
#    2736         scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2737         formatWriter = scClass()
# -> 2738         return formatWriter.show(self,
#    2739                                  regularizedConverterFormat,
#    2740                                  app=app,
#
# ~/opt/anaconda3/envs/intervals/lib/python3.9/site-packages/music21/converter/subConverters.py in show(self, obj, fmt, app, subformats, **keywords)
#     371
#     372             for s in scores:
# --> 373                 fp = helperSubConverter.write(s,
#     374                                               helperFormat,
#     375                                               subformats=helperSubformats,
#
# ~/opt/anaconda3/envs/intervals/lib/python3.9/site-packages/music21/converter/subConverters.py in write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#    1072                 and ('png' in subformats or 'pdf' in subformats)
#    1073                 and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
# -> 1074             outFp = self.runThroughMusescore(xmlFp, subformats, **keywords)
#    1075         elif compress:
#    1076             archiveTools.compressXML(xmlFp,
#
# ~/opt/anaconda3/envs/intervals/lib/python3.9/site-packages/music21/converter/subConverters.py in runThroughMusescore(self, fp, subformats, **keywords)
#     914                 + 'put a link to it in your .music21rc via Environment.')
#     915         if not musescorePath.exists():
# --> 916             raise SubConverterException(
#     917                 "Cannot find a path to the 'mscore' file at "
#     918                 + f'{musescorePath} -- download MuseScore')
#
# SubConverterException: Cannot find a path to the 'mscore' file at /Applications/MuseScore 3.app/Contents/MacOS/mscore -- download MuseScore

# %% [markdown]
# - `[x]` is zero-based index among the results for the length.  So if your number is larger than the number of results, error!
# - Thus `[1]` is the *second note* of that part
# - adding `.measureNumber` tells us the measure in which that note is found

# %%
print(notes_selected_part[1])
print(notes_selected_part[1].measureNumber)
# Out:
# <music21.note.Note C>
# 1

# %% [markdown]
# ## Find Durations
# - looking for **just the half notes** in a given part
# - M21 counts durations by quarter note, so `2.0` is a **half note**
# - Must include "flat" for reasons that the documentation does note explain

# %%
notes_tenor = parts[2].flat.getElementsByClass(['Note'])
for note_tenor in notes_tenor:
  if note_tenor.quarterLength == 2.0:  
    print(note_tenor.measureNumber)
    print(note_tenor.name)
# Out:
# 12
# B
# 14
# A
# 14
# G
# 15
# C
# 21
# C
# 21
# C
# 23
# C
# 23
# G
# 24
# G
# 24
# F
# 28
# C
# 29
# C
# 37
# E
# 37
# F
# 38
# D
# 42
# G
# 44
# B
# 44
# C
# 45
# C
# 45
# E
# 46
# E
# 46
# D
# 47
# D
# 47
# F
# 48
# F
# 48
# E
# 49
# E
# 49
# G
# 50
# G
# 50
# A
# 51
# F
# 51
# G
# 52
# E
# 52
# F
# 60
# B
# 63
# G
# 63
# A
# 64
# B
# 73
# G
# 74
# E
# 75
# B
# 75
# G
# 76
# F
# 76
# E
# 81
# C
# 81
# C
# 82
# B
# 82
# C
# 83
# C
# 83
# B
# 91
# D
# 91
# E
# 92
# B
# 104
# F
# 105
# E
# 105
# D
# 117
# B
# 117
# D
# 118
# D
# 125
# B
# 125
# D
# 126
# D
# 131
# B
# 138
# D
# 140
# C
# 145
# B

# %% [markdown]
# # Rests are not the Same as Notes!
# - now looking for Rests.  "2.0" returns only one result, because there is only one such rest in the tenor for the piece!
# - `parts` are a submodule, and the `getElementsByClass` is a method.  The particular class we're after is `Rest`

# %%
rests_tenor = parts[2].flat.getElementsByClass(['Rest'])

for tenor_rest in rests_tenor:
#   if tenor_rest.quarterLength == 4.0:  
    print(tenor_rest.measureNumber)
    print(tenor_rest.duration.type)
# Out:
# 1
# breve
# 2
# breve
# 3
# breve
# 4
# breve
# 9
# breve
# 10
# breve
# 11
# breve
# 17
# breve
# 18
# breve
# 19
# breve
# 20
# whole
# 25
# breve
# 32
# breve
# 33
# breve
# 34
# breve
# 35
# whole
# 40
# whole
# 55
# breve
# 56
# breve
# 57
# breve
# 58
# breve
# 59
# whole
# 66
# breve
# 67
# whole
# 73
# half
# 78
# breve
# 79
# breve
# 80
# breve
# 85
# breve
# 86
# breve
# 87
# breve
# 88
# whole
# 94
# whole
# 98
# whole
# 111
# breve
# 112
# breve
# 113
# breve
# 120
# breve
# 121
# breve
# 128
# breve
# 129
# whole
# 134
# breve
# 135
# breve
# 136
# whole
# 142
# breve
# 147
# whole

# %% [markdown]
# # Pitch (Note in a particular Octave)
# - here we look for notes in specific octaves, like `C4`.
# - `parts` are a submodule, and the `getElementsByClas`s is a method. The particular class we're after is `Notes`, and then `nameWithOctave`

# %%
notes_tenor = parts[2].flat.getElementsByClass(['Note'])
for note_tenor in notes_tenor:
  if note_tenor.nameWithOctave == 'C4':  
    print(note_tenor.measureNumber)
    print(note_tenor.nameWithOctave)
# Out:
# 5
# C4
# 6
# C4
# 6
# C4
# 8
# C4
# 12
# C4
# 14
# C4
# 15
# C4
# 16
# C4
# 20
# C4
# 21
# C4
# 21
# C4
# 21
# C4
# 23
# C4
# 26
# C4
# 28
# C4
# 29
# C4
# 29
# C4
# 30
# C4
# 31
# C4
# 35
# C4
# 36
# C4
# 44
# C4
# 45
# C4
# 46
# C4
# 53
# C4
# 54
# C4
# 60
# C4
# 61
# C4
# 64
# C4
# 65
# C4
# 68
# C4
# 70
# C4
# 74
# C4
# 77
# C4
# 81
# C4
# 81
# C4
# 81
# C4
# 82
# C4
# 83
# C4
# 91
# C4
# 92
# C4
# 93
# C4
# 94
# C4
# 94
# C4
# 95
# C4
# 97
# C4
# 98
# C4
# 98
# C4
# 99
# C4
# 101
# C4
# 102
# C4
# 105
# C4
# 106
# C4
# 109
# C4
# 110
# C4
# 116
# C4
# 118
# C4
# 124
# C4
# 126
# C4
# 131
# C4
# 132
# C4
# 138
# C4
# 139
# C4
# 140
# C4
# 141
# C4
# 143
# C4
# 146
# C4
# 147
# C4
# 148
# C4
# 149
# C4
# 151
# C4
# 152
# C4

# %% [markdown]
# # Intervals
# -`pitch` is the module (a collection of methods and classes); `Pitch` is the class (data structure)
# - `interval` is part of the `pitch` module (it's a submodule), and has the method `notesToInterval`.
# - Here `Interval` is another class (data structure), and `interval` is another module

# %%
pitch_1 = pitch.Pitch('C5')
pitch_2 = pitch.Pitch('E5')
output_interval = interval.Interval(pitch_1, pitch_2)

# %%
output_interval.name
# Out:
# 'M3'

# %%
output_interval.niceName
# Out:
# 'Major Third'

# %%
output_interval.semitones
# Out:
# 4

# %%
notes_tenor = parts[2].flat.getElementsByClass(['Note'])
out = zip(notes_tenor,notes_tenor[1:])
for item in out:
    pitch1 = pitch.Pitch(item[0].nameWithOctave)
    pitch2 = pitch.Pitch(item[1].nameWithOctave)
    print(interval.Interval(pitch1, pitch2).directedSimpleName)
# Out:
# P4
# P1
# P1
# M2
# M2
# M-3
# P1
# m-2
# M-2
# M-2
# M2
# M-2
# P4
# P1
# m-2
# M-2
# M2
# m2
# P1
# P1
# P1
# P1
# M2
# M2
# M-3
# M3
# M-2
# P4
# P1
# M-2
# M2
# P-5
# m-3
# M-2
# P1
# M-2
# m-2
# M-2
# M-2
# P1
# m-2
# m2
# M2
# M-2
# P1
# P1
# P1
# M2
# M2
# P1
# m2
# P1
# m-2
# P1
# M-2
# M2
# m3
# P1
# P1
# M2
# M-2
# M-2
# m-2
# M-2
# m-3
# m2
# P1
# M2
# M2
# P1
# M-3
# M2
# P1
# M2
# m2
# P1
# m-3
# M2
# P1
# m2
# M2
# P1
# M2
# M-2
# M2
# M-3
# M2
# M-2
# M2
# m-3
# m2
# m-3
# M-2
# P1
# P-4
# P4
# m-2
# m2
# M2
# m-3
# M-2
# M-2
# P1
# P1
# M2
# P1
# M-2
# P4
# m-2
# m2
# M2
# M2
# M-3
# M2
# m-3
# m2
# m-2
# M-2
# M-2
# P1
# M2
# M-3
# M2
# P1
# m-3
# m2
# m-2
# M-2
# M-2
# m-2
# M-3
# P1
# M-2
# m-2
# M-2
# M-2
# P1
# P1
# P1
# M2
# m-3
# m2
# P1
# m-2
# M-2
# M-2
# M6
# P1
# M-2
# m3
# m-2
# M-2
# M-2
# M2
# M2
# P1
# M-2
# M-2
# m-2
# m2
# P1
# P1
# P1
# M2
# P1
# M2
# P1
# M-3
# P1
# P1
# P1
# M2
# P1
# M2
# P1
# M-3
# P1
# P4
# P1
# m-3
# P1
# P4
# M-2
# m-2
# M-2
# M-2
# P1
# P4
# P1
# M2
# m-3
# m2
# m-3
# M-2
# P1
# M2
# P1
# P1
# M2
# M-2
# M-2
# m-2
# P1
# m3
# P1
# M-2
# m-2
# M-2
# M-2
# P5
# P1
# P1
# M2
# M-2
# M-2
# m-2
# P1
# m3
# P1
# M-2
# m-2
# M-2
# M-2
# P1
# M2
# M2
# m2
# m-2
# m2
# M2
# M2
# P1
# P1
# M-2
# M-2
# M2
# P1
# M-2
# P1
# m-2
# m2
# P1
# m-2
# P1
# M-2
# M2
# m2
# P1
# P1
# m-2
# m2
# M2
# M-2
# P1
