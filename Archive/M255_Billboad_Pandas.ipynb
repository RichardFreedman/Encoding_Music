# %% [markdown]
# ____________________
# # Music 255: Beautiful Soup and Billboard
#
# A Notebook for scraping Billboard Chart Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from bs4 import BeautifulSoup

url = "https://www.billboard.com/artist/miles-davis/chart-history/tlp/"  # replace with the URL of the chart you want to scrape

# example of top 100:
# url = 'https://www.billboard.com/charts/hot-100/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

if 'artist' in url:
    chart_data = []
    all_songs = soup.find_all(attrs={'class' : 'o-chart-results-list-row'})
    # iterate over all the songs in the chart
    for this_song in all_songs:
        title = this_song.h3.get_text(strip=True)
        author = this_song.h3.find_next('span').get_text(strip=True)
        this_song_details = this_song.find_all(attrs={'class': 'o-chart-results-list__item'})
        release_date = this_song_details[0].find_next(attrs={'class': 'o-chart-results-list__item'}).get_text(strip=True)
        peak_weeks = this_song_details[1].find_next(attrs={'class': 'o-chart-results-list__item'}).get_text(strip=True)
        peak_date = this_song_details[2].find_next(attrs={'class': 'o-chart-results-list__item'}).get_text(strip=True)
        total_weeks = this_song_details[3].find_next(attrs={'class': 'o-chart-results-list__item'}).get_text(strip=True)
        chart_data.append({
            'title': title,
            'author': author,
            'release_date': release_date,
            'peak_weeks': peak_weeks,
            'peak_date': peak_date,
            'total_weeks': total_weeks,
        })

    df = pd.DataFrame(chart_data)
    df

elif 'charts' in url:

    
    data = []
    for e in soup.find_all(attrs={'class':'o-chart-results-list-row-container'}):
        # spans = e.find_all('span')
        this_week = e.span.get_text(strip=True)
        last_week = e.h3.find_next('span').find_next('span').get_text(strip=True)
        peak_position = e.h3.find_next('span').find_next('span').find_next('span').get_text(strip=True)
        weeks_on_chart = e.h3.find_next('span').find_next('span').find_next('span').find_next('span').get_text(strip=True)
        data.append({
            'title':e.h3.get_text(strip=True),
            'author':e.h3.find_next('span').get_text(strip=True),
            'this_week' : this_week,
            'last_week': last_week,
            'peak_position': peak_position,
            'weeks_on_chart': weeks_on_chart
        })
    df = pd.DataFrame(data)
    df
    
df
# Out:
#                                                 title  \
# 0                                        Bitches Brew
# 1                               The Man With The Horn
# 2                               Seven Steps To Heaven
# 3                                          Live--Evil
# 4                                 You're Under Arrest
# 5                             Miles Davis At Fillmore
# 6                                       On The Corner
# 7                                               Decoy
# 8                                                Tutu
# 9                               Miles Davis In Europe
# 10         My Funny Valentine: Miles Davis In Concert
# 11                                       Quiet Nights
# 12                            Tribute To Jack Johnson
# 13                                     Get Up With It
# 14                                         In Concert
# 15                                        Star People
# 16                                      We Want Miles
# 17                                    In A Silent Way
# 18                                            Agharta
# 19                                            Amandla
# 20                                            Big Fun
# 21                                            Doo-Bop
# 22  Basic Miles - The Classic Performances Of Mile...
# 23                                         Directions
# 24                                       Water Babies
# 25     LIVE In Europe 1967: The Bootleg Series Vol. 1
# 26  Miles at the Fillmore: Miles Davis 1970 - The ...
# 27                             Everything's Beautiful
# 28         The Final Tour: The Bootleg Series, Vol. 6
# 29  Champions: Rare Miles From The Complete Jack J...
#
#                           author release_date peak_weeks peak_date total_weeks
# 0                    Miles Davis     05.16.70   3512 Wks  07.04.70          29
# 1                    Miles Davis     07.25.81   5312 Wks  09.12.81          18
# 2                    Miles Davis     09.14.63   6212 Wks  10.05.63          15
# 3                    Miles Davis     12.25.71  12512 Wks  02.12.72          14
# 4                    Miles Davis     06.01.85  11112 Wks  06.29.85          12
# 5                    Miles Davis     12.12.70  12312 Wks  01.02.71          12
# 6                    Miles Davis     11.18.72  15612 Wks  12.09.72          11
# 7                    Miles Davis     06.30.84  16912 Wks  07.28.84          11
# 8                    Miles Davis     10.25.86  14112 Wks  11.15.86          10
# 9                    Miles Davis     09.26.64  11612 Wks  11.21.64          10
# 10                   Miles Davis     04.24.65  13812 Wks  06.05.65           9
# 11                   Miles Davis     04.11.64   9312 Wks  05.23.64           9
# 12                   Miles Davis     04.24.71  15912 Wks  06.05.71           8
# 13                   Miles Davis     01.04.75  14112 Wks  02.08.75           8
# 14                   Miles Davis     05.05.73  15212 Wks  06.09.73           8
# 15                   Miles Davis     05.21.83  13612 Wks  06.18.83           7
# 16                   Miles Davis     05.29.82  15912 Wks  06.19.82           7
# 17                   Miles Davis     09.06.69  13412 Wks  09.06.69           6
# 18                   Miles Davis     03.13.76  16812 Wks  04.03.76           5
# 19                   Miles Davis     06.17.89  17712 Wks  07.08.89           5
# 20                   Miles Davis     06.08.74  17912 Wks  07.06.74           5
# 21                   Miles Davis     07.25.92  19012 Wks  08.08.92           4
# 22                   Miles Davis     10.13.73  18912 Wks  10.20.73           3
# 23                   Miles Davis     04.11.81  17912 Wks  04.11.81           2
# 24                   Miles Davis     05.07.77  19012 Wks  05.07.77           2
# 25       The Miles Davis Quintet     10.08.11  17112 Wks  10.08.11           1
# 26                   Miles Davis     04.12.14  18912 Wks  04.12.14           1
# 27  Miles Davis & Robert Glasper     06.18.16  15212 Wks  06.18.16           1
# 28   Miles Davis & John Coltrane     04.07.18  18712 Wks  04.07.18           1
# 29                   Miles Davis     07.31.21  16112 Wks  07.31.21           1

# %%
df.to_csv("Miles_Davis_Billboard.csv")
