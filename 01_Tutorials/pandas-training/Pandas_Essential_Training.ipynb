# %% [markdown]
# # Pandas Essential Training
#
# Notebook from the course [Pandas Essential Training](https://www.linkedin.com/learning/pandas-essential-training-24082178) on LinkedIn.

# %% [markdown]
# ## Using pandas

# %%
# %pip install pandas
# Out:
# Found existing installation: pandas 2.0.2
# Uninstalling pandas-2.0.2:
#   Would remove:
#     /usr/local/lib/python3.10/site-packages/pandas-2.0.2.dist-info/*
#     /usr/local/lib/python3.10/site-packages/pandas/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
#  '_pandas_datetime_CAPI',
#  '_pandas_parser_CAPI',
#  '_testing',
#  '_typing',
#  '_version_meson',
#  'annotations',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'from_dummies',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols: 'UsecolsArgType' = None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters: 'Mapping[Hashable, Callable] | None' = None, true_values: 'list | None' = None, false_values: 'list | None' = None, skipinitialspace: 'bool' = False, skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool | lib.NoDefault' = <no_default>, skip_blank_lines: 'bool' = True, parse_dates: 'bool | Sequence[Hashable] | None' = None, infer_datetime_format: 'bool | lib.NoDefault' = <no_default>, keep_date_col: 'bool | lib.NoDefault' = <no_default>, date_parser: 'Callable | lib.NoDefault' = <no_default>, date_format: 'str | dict[Hashable, str] | None' = None, dayfirst: 'bool' = False, cache_dates: 'bool' = True, iterator: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', thousands: 'str | None' = None, decimal: 'str' = '.', lineterminator: 'str | None' = None, quotechar: 'str' = '"', quoting: 'int' = 0, doublequote: 'bool' = True, escapechar: 'str | None' = None, comment: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', dialect: 'str | csv.Dialect | None' = None, on_bad_lines: 'str' = 'error', delim_whitespace: 'bool | lib.NoDefault' = <no_default>, low_memory: 'bool' = True, memory_map: 'bool' = False, float_precision: "Literal['high', 'legacy'] | None" = None, storage_options: 'StorageOptions | None' = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>) -> 'DataFrame | TextFileReader'
#     Read a comma-separated values (csv) file into DataFrame.
#
#     Also supports optionally iterating or breaking of the file
#     into chunks.
#
#     Additional help can be found in the online docs for
#     `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
#     Parameters
#     ----------
#     filepath_or_buffer : str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is
#         expected. A local file could be: file://localhost/path/to/table.csv.
#
#         If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#         By file-like object, we refer to objects with a ``read()`` method, such as
#         a file handle (e.g. via builtin ``open`` function) or ``StringIO``.
#     sep : str, default ','
#         Character or regex pattern to treat as the delimiter. If ``sep=None``, the
#         C engine cannot automatically detect
#         the separator, but the Python parsing engine can, meaning the latter will
#         be used and automatically detect the separator from only the first valid
#         row of the file by Python's builtin sniffer tool, ``csv.Sniffer``.
#         In addition, separators longer than 1 character and different from
#         ``'\s+'`` will be interpreted as regular expressions and will also force
#         the use of the Python parsing engine. Note that regex delimiters are prone
#         to ignoring quoted data. Regex example: ``'\r\t'``.
#     delimiter : str, optional
#         Alias for ``sep``.
#     header : int, Sequence of int, 'infer' or None, default 'infer'
#         Row number(s) containing column labels and marking the start of the
#         data (zero-indexed). Default behavior is to infer the column names: if no ``names``
#         are passed the behavior is identical to ``header=0`` and column
#         names are inferred from the first line of the file, if column
#         names are passed explicitly to ``names`` then the behavior is identical to
#         ``header=None``. Explicitly pass ``header=0`` to be able to
#         replace existing names. The header can be a list of integers that
#         specify row locations for a :class:`~pandas.MultiIndex` on the columns
#         e.g. ``[0, 1, 3]``. Intervening rows that are not specified will be
#         skipped (e.g. 2 in this example is skipped). Note that this
#         parameter ignores commented lines and empty lines if
#         ``skip_blank_lines=True``, so ``header=0`` denotes the first line of
#         data rather than the first line of the file.
#     names : Sequence of Hashable, optional
#         Sequence of column labels to apply. If the file contains a header row,
#         then you should explicitly pass ``header=0`` to override the column names.
#         Duplicates in this list are not allowed.
#     index_col : Hashable, Sequence of Hashable or False, optional
#       Column(s) to use as row label(s), denoted either by column labels or column
#       indices.  If a sequence of labels or indices is given, :class:`~pandas.MultiIndex`
#       will be formed for the row labels.
#
#       Note: ``index_col=False`` can be used to force pandas to *not* use the first
#       column as the index, e.g., when you have a malformed file with delimiters at
#       the end of each line.
#     usecols : Sequence of Hashable or Callable, optional
#         Subset of columns to select, denoted either by column labels or column indices.
#         If list-like, all elements must either
#         be positional (i.e. integer indices into the document columns) or strings
#         that correspond to column names provided either by the user in ``names`` or
#         inferred from the document header row(s). If ``names`` are given, the document
#         header row(s) are not taken into account. For example, a valid list-like
#         ``usecols`` parameter would be ``[0, 1, 2]`` or ``['foo', 'bar', 'baz']``.
#         Element order is ignored, so ``usecols=[0, 1]`` is the same as ``[1, 0]``.
#         To instantiate a :class:`~pandas.DataFrame` from ``data`` with element order
#         preserved use ``pd.read_csv(data, usecols=['foo', 'bar'])[['foo', 'bar']]``
#         for columns in ``['foo', 'bar']`` order or
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['bar', 'foo']]``
#         for ``['bar', 'foo']`` order.
#
#         If callable, the callable function will be evaluated against the column
#         names, returning names where the callable function evaluates to ``True``. An
#         example of a valid callable argument would be ``lambda x: x.upper() in
#         ['AAA', 'BBB', 'DDD']``. Using this parameter results in much faster
#         parsing time and lower memory usage.
#     dtype : dtype or dict of {Hashable : dtype}, optional
#         Data type(s) to apply to either the whole dataset or individual columns.
#         E.g., ``{'a': np.float64, 'b': np.int32, 'c': 'Int64'}``
#         Use ``str`` or ``object`` together with suitable ``na_values`` settings
#         to preserve and not interpret ``dtype``.
#         If ``converters`` are specified, they will be applied INSTEAD
#         of ``dtype`` conversion.
#
#         .. versionadded:: 1.5.0
#
#             Support for ``defaultdict`` was added. Specify a ``defaultdict`` as input where
#             the default determines the ``dtype`` of the columns which are not explicitly
#             listed.
#     engine : {'c', 'python', 'pyarrow'}, optional
#         Parser engine to use. The C and pyarrow engines are faster, while the python engine
#         is currently more feature-complete. Multithreading is currently only supported by
#         the pyarrow engine.
#
#         .. versionadded:: 1.4.0
#
#             The 'pyarrow' engine was added as an *experimental* engine, and some features
#             are unsupported, or may not work correctly, with this engine.
#     converters : dict of {Hashable : Callable}, optional
#         Functions for converting values in specified columns. Keys can either
#         be column labels or column indices.
#     true_values : list, optional
#         Values to consider as ``True`` in addition to case-insensitive variants of 'True'.
#     false_values : list, optional
#         Values to consider as ``False`` in addition to case-insensitive variants of 'False'.
#     skipinitialspace : bool, default False
#         Skip spaces after delimiter.
#     skiprows : int, list of int or Callable, optional
#         Line numbers to skip (0-indexed) or number of lines to skip (``int``)
#         at the start of the file.
#
#         If callable, the callable function will be evaluated against the row
#         indices, returning ``True`` if the row should be skipped and ``False`` otherwise.
#         An example of a valid callable argument would be ``lambda x: x in [0, 2]``.
#     skipfooter : int, default 0
#         Number of lines at bottom of file to skip (Unsupported with ``engine='c'``).
#     nrows : int, optional
#         Number of rows of file to read. Useful for reading pieces of large files.
#     na_values : Hashable, Iterable of Hashable or dict of {Hashable : Iterable}, optional
#         Additional strings to recognize as ``NA``/``NaN``. If ``dict`` passed, specific
#         per-column ``NA`` values.  By default the following values are interpreted as
#         ``NaN``: " ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan",
#         "1.#IND", "1.#QNAN", "<NA>", "N/A", "NA", "NULL", "NaN", "None",
#         "n/a", "nan", "null ".
#
#     keep_default_na : bool, default True
#         Whether or not to include the default ``NaN`` values when parsing the data.
#         Depending on whether ``na_values`` is passed in, the behavior is as follows:
#
#         * If ``keep_default_na`` is ``True``, and ``na_values`` are specified, ``na_values``
#           is appended to the default ``NaN`` values used for parsing.
#         * If ``keep_default_na`` is ``True``, and ``na_values`` are not specified, only
#           the default ``NaN`` values are used for parsing.
#         * If ``keep_default_na`` is ``False``, and ``na_values`` are specified, only
#           the ``NaN`` values specified ``na_values`` are used for parsing.
#         * If ``keep_default_na`` is ``False``, and ``na_values`` are not specified, no
#           strings will be parsed as ``NaN``.
#
#         Note that if ``na_filter`` is passed in as ``False``, the ``keep_default_na`` and
#         ``na_values`` parameters will be ignored.
#     na_filter : bool, default True
#         Detect missing value markers (empty strings and the value of ``na_values``). In
#         data without any ``NA`` values, passing ``na_filter=False`` can improve the
#         performance of reading a large file.
#     verbose : bool, default False
#         Indicate number of ``NA`` values placed in non-numeric columns.
#
#         .. deprecated:: 2.2.0
#     skip_blank_lines : bool, default True
#         If ``True``, skip over blank lines rather than interpreting as ``NaN`` values.
#     parse_dates : bool, list of Hashable, list of lists or dict of {Hashable : list}, default False
#         The behavior is as follows:
#
#         * ``bool``. If ``True`` -> try parsing the index. Note: Automatically set to
#           ``True`` if ``date_format`` or ``date_parser`` arguments have been passed.
#         * ``list`` of ``int`` or names. e.g. If ``[1, 2, 3]`` -> try parsing columns 1, 2, 3
#           each as a separate date column.
#         * ``list`` of ``list``. e.g.  If ``[[1, 3]]`` -> combine columns 1 and 3 and parse
#           as a single date column. Values are joined with a space before parsing.
#         * ``dict``, e.g. ``{'foo' : [1, 3]}`` -> parse columns 1, 3 as date and call
#           result 'foo'. Values are joined with a space before parsing.
#
#         If a column or index cannot be represented as an array of ``datetime``,
#         say because of an unparsable value or a mixture of timezones, the column
#         or index will be returned unaltered as an ``object`` data type. For
#         non-standard ``datetime`` parsing, use :func:`~pandas.to_datetime` after
#         :func:`~pandas.read_csv`.
#
#         Note: A fast-path exists for iso8601-formatted dates.
#     infer_datetime_format : bool, default False
#         If ``True`` and ``parse_dates`` is enabled, pandas will attempt to infer the
#         format of the ``datetime`` strings in the columns, and if it can be inferred,
#         switch to a faster method of parsing them. In some cases this can increase
#         the parsing speed by 5-10x.
#
#         .. deprecated:: 2.0.0
#             A strict version of this argument is now the default, passing it has no effect.
#
#     keep_date_col : bool, default False
#         If ``True`` and ``parse_dates`` specifies combining multiple columns then
#         keep the original columns.
#     date_parser : Callable, optional
#         Function to use for converting a sequence of string columns to an array of
#         ``datetime`` instances. The default uses ``dateutil.parser.parser`` to do the
#         conversion. pandas will try to call ``date_parser`` in three different ways,
#         advancing to the next if an exception occurs: 1) Pass one or more arrays
#         (as defined by ``parse_dates``) as arguments; 2) concatenate (row-wise) the
#         string values from the columns defined by ``parse_dates`` into a single array
#         and pass that; and 3) call ``date_parser`` once for each row using one or
#         more strings (corresponding to the columns defined by ``parse_dates``) as
#         arguments.
#
#         .. deprecated:: 2.0.0
#            Use ``date_format`` instead, or read in as ``object`` and then apply
#            :func:`~pandas.to_datetime` as-needed.
#     date_format : str or dict of column -> format, optional
#         Format to use for parsing dates when used in conjunction with ``parse_dates``.
#         The strftime to parse time, e.g. :const:`"%d/%m/%Y"`. See
#         `strftime documentation
#         <https://docs.python.org/3/library/datetime.html
#         #strftime-and-strptime-behavior>`_ for more information on choices, though
#         note that :const:`"%f"` will parse all the way up to nanoseconds.
#         You can also pass:
#
#         - "ISO8601", to parse any `ISO8601 <https://en.wikipedia.org/wiki/ISO_8601>`_
#             time string (not necessarily in exactly the same format);
#         - "mixed", to infer the format for each element individually. This is risky,
#             and you should probably use it along with `dayfirst`.
#
#         .. versionadded:: 2.0.0
#     dayfirst : bool, default False
#         DD/MM format dates, international and European format.
#     cache_dates : bool, default True
#         If ``True``, use a cache of unique, converted dates to apply the ``datetime``
#         conversion. May produce significant speed-up when parsing duplicate
#         date strings, especially ones with timezone offsets.
#
#     iterator : bool, default False
#         Return ``TextFileReader`` object for iteration or getting chunks with
#         ``get_chunk()``.
#     chunksize : int, optional
#         Number of lines to read from the file per chunk. Passing a value will cause the
#         function to return a ``TextFileReader`` object for iteration.
#         See the `IO Tools docs
#         <https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking>`_
#         for more information on ``iterator`` and ``chunksize``.
#
#     compression : str or dict, default 'infer'
#         For on-the-fly decompression of on-disk data. If 'infer' and 'filepath_or_buffer' is
#         path-like, then detect compression from the following extensions: '.gz',
#         '.bz2', '.zip', '.xz', '.zst', '.tar', '.tar.gz', '.tar.xz' or '.tar.bz2'
#         (otherwise no compression).
#         If using 'zip' or 'tar', the ZIP file must contain only one data file to be read in.
#         Set to ``None`` for no decompression.
#         Can also be a dict with key ``'method'`` set
#         to one of {``'zip'``, ``'gzip'``, ``'bz2'``, ``'zstd'``, ``'xz'``, ``'tar'``} and
#         other key-value pairs are forwarded to
#         ``zipfile.ZipFile``, ``gzip.GzipFile``,
#         ``bz2.BZ2File``, ``zstandard.ZstdDecompressor``, ``lzma.LZMAFile`` or
#         ``tarfile.TarFile``, respectively.
#         As an example, the following could be passed for Zstandard decompression using a
#         custom compression dictionary:
#         ``compression={'method': 'zstd', 'dict_data': my_compression_dict}``.
#
#         .. versionadded:: 1.5.0
#             Added support for `.tar` files.
#
#         .. versionchanged:: 1.4.0 Zstandard support.
#
#     thousands : str (length 1), optional
#         Character acting as the thousands separator in numerical values.
#     decimal : str (length 1), default '.'
#         Character to recognize as decimal point (e.g., use ',' for European data).
#     lineterminator : str (length 1), optional
#         Character used to denote a line break. Only valid with C parser.
#     quotechar : str (length 1), optional
#         Character used to denote the start and end of a quoted item. Quoted
#         items can include the ``delimiter`` and it will be ignored.
#     quoting : {0 or csv.QUOTE_MINIMAL, 1 or csv.QUOTE_ALL, 2 or csv.QUOTE_NONNUMERIC, 3 or csv.QUOTE_NONE}, default csv.QUOTE_MINIMAL
#         Control field quoting behavior per ``csv.QUOTE_*`` constants. Default is
#         ``csv.QUOTE_MINIMAL`` (i.e., 0) which implies that only fields containing special
#         characters are quoted (e.g., characters defined in ``quotechar``, ``delimiter``,
#         or ``lineterminator``.
#     doublequote : bool, default True
#        When ``quotechar`` is specified and ``quoting`` is not ``QUOTE_NONE``, indicate
#        whether or not to interpret two consecutive ``quotechar`` elements INSIDE a
#        field as a single ``quotechar`` element.
#     escapechar : str (length 1), optional
#         Character used to escape other characters.
#     comment : str (length 1), optional
#         Character indicating that the remainder of line should not be parsed.
#         If found at the beginning
#         of a line, the line will be ignored altogether. This parameter must be a
#         single character. Like empty lines (as long as ``skip_blank_lines=True``),
#         fully commented lines are ignored by the parameter ``header`` but not by
#         ``skiprows``. For example, if ``comment='#'``, parsing
#         ``#empty\na,b,c\n1,2,3`` with ``header=0`` will result in ``'a,b,c'`` being
#         treated as the header.
#     encoding : str, optional, default 'utf-8'
#         Encoding to use for UTF when reading/writing (ex. ``'utf-8'``). `List of Python
#         standard encodings
#         <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .
#
#     encoding_errors : str, optional, default 'strict'
#         How encoding errors are treated. `List of possible values
#         <https://docs.python.org/3/library/codecs.html#error-handlers>`_ .
#
#         .. versionadded:: 1.3.0
#
#     dialect : str or csv.Dialect, optional
#         If provided, this parameter will override values (default or not) for the
#         following parameters: ``delimiter``, ``doublequote``, ``escapechar``,
#         ``skipinitialspace``, ``quotechar``, and ``quoting``. If it is necessary to
#         override values, a ``ParserWarning`` will be issued. See ``csv.Dialect``
#         documentation for more details.
#     on_bad_lines : {'error', 'warn', 'skip'} or Callable, default 'error'
#         Specifies what to do upon encountering a bad line (a line with too many fields).
#         Allowed values are :
#
#         - ``'error'``, raise an Exception when a bad line is encountered.
#         - ``'warn'``, raise a warning when a bad line is encountered and skip that line.
#         - ``'skip'``, skip bad lines without raising or warning when they are encountered.
#
#         .. versionadded:: 1.3.0
#
#         .. versionadded:: 1.4.0
#
#             - Callable, function with signature
#               ``(bad_line: list[str]) -> list[str] | None`` that will process a single
#               bad line. ``bad_line`` is a list of strings split by the ``sep``.
#               If the function returns ``None``, the bad line will be ignored.
#               If the function returns a new ``list`` of strings with more elements than
#               expected, a ``ParserWarning`` will be emitted while dropping extra elements.
#               Only supported when ``engine='python'``
#
#         .. versionchanged:: 2.2.0
#
#             - Callable, function with signature
#               as described in `pyarrow documentation
#               <https://arrow.apache.org/docs/python/generated/pyarrow.csv.ParseOptions.html
#               #pyarrow.csv.ParseOptions.invalid_row_handler>`_ when ``engine='pyarrow'``
#
#     delim_whitespace : bool, default False
#         Specifies whether or not whitespace (e.g. ``' '`` or ``'\t'``) will be
#         used as the ``sep`` delimiter. Equivalent to setting ``sep='\s+'``. If this option
#         is set to ``True``, nothing should be passed in for the ``delimiter``
#         parameter.
#
#         .. deprecated:: 2.2.0
#             Use ``sep="\s+"`` instead.
#     low_memory : bool, default True
#         Internally process the file in chunks, resulting in lower memory use
#         while parsing, but possibly mixed type inference.  To ensure no mixed
#         types either set ``False``, or specify the type with the ``dtype`` parameter.
#         Note that the entire file is read into a single :class:`~pandas.DataFrame`
#         regardless, use the ``chunksize`` or ``iterator`` parameter to return the data in
#         chunks. (Only valid with C parser).
#     memory_map : bool, default False
#         If a filepath is provided for ``filepath_or_buffer``, map the file object
#         directly onto memory and access the data directly from there. Using this
#         option can improve performance because there is no longer any I/O overhead.
#     float_precision : {'high', 'legacy', 'round_trip'}, optional
#         Specifies which converter the C engine should use for floating-point
#         values. The options are ``None`` or ``'high'`` for the ordinary converter,
#         ``'legacy'`` for the original lower precision pandas converter, and
#         ``'round_trip'`` for the round-trip converter.
#
#     storage_options : dict, optional
#         Extra options that make sense for a particular storage connection, e.g.
#         host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#         are forwarded to ``urllib.request.Request`` as header options. For other
#         URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#         forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#         details, and for more examples on storage options refer `here
#         <https://pandas.pydata.org/docs/user_guide/io.html?
#         highlight=storage_options#reading-writing-remote-files>`_.
#
#     dtype_backend : {'numpy_nullable', 'pyarrow'}, default 'numpy_nullable'
#         Back-end data type applied to the resultant :class:`DataFrame`
#         (still experimental). Behaviour is as follows:
#
#         * ``"numpy_nullable"``: returns nullable-dtype-backed :class:`DataFrame`
#           (default).
#         * ``"pyarrow"``: returns pyarrow-backed nullable :class:`ArrowDtype`
#           DataFrame.
#
#         .. versionadded:: 2.0
#
#     Returns
#     -------
#     DataFrame or TextFileReader
#         A comma-separated values (csv) file is returned as two-dimensional
#         data structure with labeled axes.
#
#     See Also
#     --------
#     DataFrame.to_csv : Write DataFrame to a comma-separated values (csv) file.
#     read_table : Read general delimited file into DataFrame.
#     read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
#     Examples
#     --------
#     >>> pd.read_csv('data.csv')  # doctest: +SKIP

# %%
pd.DataFrame.groupby?
# Out:
# Signature:
# pd.DataFrame.groupby(
#     self,
#     by=None,
#     axis: 'Axis | lib.NoDefault' = <no_default>,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
#     will be used to determine the groups (the Series' values are first
#     aligned; see ``.align()`` method). If a list or ndarray of length
#     equal to the selected axis is passed (see the `groupby user guide
#     <https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html#splitting-an-object-into-groups>`_),
#     the values are used as-is to determine the groups. A label or list
#     of labels may be passed to group by the columns in ``self``.
#     Notice that a tuple is interpreted as a (single) key.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Split along rows (0) or columns (1). For `Series` this parameter
#     is unused and defaults to 0.
#
#     .. deprecated:: 2.1.0
#
#         Will be removed and behave like axis=0 in a future version.
#         For ``axis=1``, do ``frame.T.groupby(...)`` instead.
#
# level : int, level name, or sequence of such, default None
#     If the axis is a MultiIndex (hierarchical), group by a particular
#     level or levels. Do not specify both ``by`` and ``level``.
# as_index : bool, default True
#     Return object with group labels as the
#     index. Only relevant for DataFrame input. as_index=False is
#     effectively "SQL-style" grouped output. This argument has no effect
#     on filtrations (see the `filtrations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#filtration>`_),
#     such as ``head()``, ``tail()``, ``nth()`` and in transformations
#     (see the `transformations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#transformation>`_).
# sort : bool, default True
#     Sort group keys. Get better performance by turning this off.
#     Note this does not influence the order of observations within each
#     group. Groupby preserves the order of rows within each group. If False,
#     the groups will appear in the same order as they did in the original DataFrame.
#     This argument has no effect on filtrations (see the `filtrations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#filtration>`_),
#     such as ``head()``, ``tail()``, ``nth()`` and in transformations
#     (see the `transformations in the user guide
#     <https://pandas.pydata.org/docs/dev/user_guide/groupby.html#transformation>`_).
#
#     .. versionchanged:: 2.0.0
#
#         Specifying ``sort=False`` with an ordered categorical grouper will no
#         longer sort the values.
#
# group_keys : bool, default True
#     When calling apply and the ``by`` argument produces a like-indexed
#     (i.e. :ref:`a transform <groupby.transform>`) result, add group keys to
#     index to identify pieces. By default group keys are not included
#     when the result's index (and column) labels match the inputs, and
#     are included otherwise.
#
#     .. versionchanged:: 1.5.0
#
#        Warns that ``group_keys`` will no longer be ignored when the
#        result from ``apply`` is a like-indexed Series or DataFrame.
#        Specify ``group_keys`` explicitly to include the group keys or
#        not.
#
#     .. versionchanged:: 2.0.0
#
#        ``group_keys`` now defaults to ``True``.
#
# observed : bool, default False
#     This only applies if any of the groupers are Categoricals.
#     If True: only show observed values for categorical groupers.
#     If False: show all values for categorical groupers.
#
#     .. deprecated:: 2.1.0
#
#         The default value will change to True in a future version of pandas.
#
# dropna : bool, default True
#     If True, and if group keys contain NA values, NA values together
#     with row/column will be dropped.
#     If False, NA values will also be treated as the key in groups.
#
# Returns
# -------
# pandas.api.typing.DataFrameGroupBy
#     Returns a groupby object that contains information about the groups.
#
# See Also
# --------
# resample : Convenience method for frequency conversion and resampling
#     of time series.
#
# Notes
# -----
# See the `user guide
# <https://pandas.pydata.org/pandas-docs/stable/groupby.html>`__ for more
# detailed usage and examples, including splitting an object into groups,
# iterating through groups, selecting a group, aggregation, and more.
#
# Examples
# --------
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0
# >>> df.groupby(['Animal']).mean()
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0
#
# **Hierarchical Indexes**
#
# We can groupby different levels of a hierarchical index
# using the `level` parameter:
#
# >>> arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
# ...           ['Captive', 'Wild', 'Captive', 'Wild']]
# >>> index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
# >>> df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
# ...                   index=index)
# >>> df
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0
# >>> df.groupby(level=0).mean()
#         Max Speed
# Animal
# Falcon      370.0
# Parrot       25.0
# >>> df.groupby(level="Type").mean()
#          Max Speed
# Type
# Captive      210.0
# Wild         185.0
#
# We can also choose to include NA in group keys or not by setting
# `dropna` parameter, the default setting is `True`.
#
# >>> l = [[1, 2, 3], [1, None, 4], [2, 1, 3], [1, 2, 2]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by=["b"]).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
#
# >>> df.groupby(by=["b"], dropna=False).sum()
#     a   c
# b
# 1.0 2   3
# 2.0 2   5
# NaN 1   4
#
# >>> l = [["a", 12, 12], [None, 12.3, 33.], ["b", 12.3, 123], ["a", 1, 1]]
# >>> df = pd.DataFrame(l, columns=["a", "b", "c"])
#
# >>> df.groupby(by="a").sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
#
# >>> df.groupby(by="a", dropna=False).sum()
#     b     c
# a
# a   13.0   13.0
# b   12.3  123.0
# NaN 12.3   33.0
#
# When using ``.apply()``, use ``group_keys`` to include or exclude the
# group keys. The ``group_keys`` argument defaults to ``True`` (include).
#
# >>> df = pd.DataFrame({'Animal': ['Falcon', 'Falcon',
# ...                               'Parrot', 'Parrot'],
# ...                    'Max Speed': [380., 370., 24., 26.]})
# >>> df.groupby("Animal", group_keys=True)[['Max Speed']].apply(lambda x: x)
#           Max Speed
# Animal
# Falcon 0      380.0
#        1      370.0
# Parrot 2       24.0
#        3       26.0
#
# >>> df.groupby("Animal", group_keys=False)[['Max Speed']].apply(lambda x: x)
#    Max Speed
# 0      380.0
# 1      370.0
# 2       24.0
# 3       26.0
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      function

# %% [markdown]
# Pandas documentation: https://pandas.pydata.org/docs/reference/index.html

# %% [markdown]
# ## Reading tabular data into pandas

# %%
# !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
# Out:
# --2024-07-01 15:17:16--  https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_1896_2004.csv [following]
# --2024-07-01 15:17:17--  https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_1896_2004.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2398388 (2.3M) [text/plain]
# Saving to: ‘olympics_1896_2004.csv’
#
# olympics_1896_2004. 100%[===================>]   2.29M  3.20MB/s    in 0.7s
#
# 2024-07-01 15:17:17 (3.20 MB/s) - ‘olympics_1896_2004.csv’ saved [2398388/2398388]

# %%
#from google.colab import files
#files.upload()

# %%
# !ls -la
# Out:
# total 5280
# drwxr-xr-x  13 owenyaggy  staff      416 Jul  1 15:17 .
# drwxr-xr-x  30 owenyaggy  staff      960 Jul  1 14:40 ..
# drwxr-xr-x  12 owenyaggy  staff      384 Jul  1 14:24 .git
# drwxr-xr-x   6 owenyaggy  staff      192 Jul  1 14:24 .github
# -rw-r--r--   1 owenyaggy  staff       42 Jul  1 14:24 .gitignore
# -rw-r--r--   1 owenyaggy  staff      635 Jul  1 14:24 CONTRIBUTING.md
# -rw-r--r--   1 owenyaggy  staff     6648 Jul  1 14:24 LICENSE
# -rw-r--r--   1 owenyaggy  staff      617 Jul  1 14:24 NOTICE
# -rw-r--r--   1 owenyaggy  staff   271396 Jul  1 14:56 Pandas_Essential_Training.ipynb
# -rw-r--r--   1 owenyaggy  staff     1568 Jul  1 14:24 README.md
# drwxr-xr-x   7 owenyaggy  staff      224 Jul  1 14:30 linkedin
# -rw-r--r--   1 owenyaggy  staff      490 Jul  1 15:00 notes.md
# -rw-r--r--   1 owenyaggy  staff  2398388 Jul  1 15:17 olympics_1896_2004.csv

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]',
#     *,
#     sep: 'str | None | lib.NoDefault' = <no_default>,
#     delimiter: 'str | None | lib.NoDefault' = None,
#     header: "int | Sequence[int] | None | Literal['infer']" = 'infer',
#     names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>,
#     index_col: 'IndexLabel | Literal[False] | None' = None,
#     usecols: 'UsecolsArgType' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: 'CSVEngine | None' = None,
#     converters: 'Mapping[Hashable, Callable] | None' = None,
#     true_values: 'list | None' = None,
#     false_values: 'list | None' = None,
#     skipinitialspace: 'bool' = False,
#     skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None,
#     skipfooter: 'int' = 0,
#     nrows: 'int | None' = None,
#     na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool | lib.NoDefault' = <no_default>,
#     skip_blank_lines: 'bool' = True,
#     parse_dates: 'bool | Sequence[Hashable] | None' = None,
#     infer_datetime_format: 'bool | lib.NoDefault' = <no_default>,
#     keep_date_col: 'bool | lib.NoDefault' = <no_default>,
#     date_parser: 'Callable | lib.NoDefault' = <no_default>,
#     date_format: 'str | dict[Hashable, str] | None' = None,
#     dayfirst: 'bool' = False,
#     cache_dates: 'bool' = True,
#     iterator: 'bool' = False,
#     chunksize: 'int | None' = None,
#     compression: 'CompressionOptions' = 'infer',
#     thousands: 'str | None' = None,
#     decimal: 'str' = '.',
#     lineterminator: 'str | None' = None,
#     quotechar: 'str' = '"',
#     quoting: 'int' = 0,
#     doublequote: 'bool' = True,
#     escapechar: 'str | None' = None,
#     comment: 'str | None' = None,
#     encoding: 'str | None' = None,
#     encoding_errors: 'str | None' = 'strict',
#     dialect: 'str | csv.Dialect | None' = None,
#     on_bad_lines: 'str' = 'error',
#     delim_whitespace: 'bool | lib.NoDefault' = <no_default>,
#     low_memory: 'bool' = True,
#     memory_map: 'bool' = False,
#     float_precision: "Literal['high', 'legacy'] | None" = None,
#     storage_options: 'StorageOptions | None' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
# ) -> 'DataFrame | TextFileReader'
# Docstring:
# Read a comma-separated values (csv) file into DataFrame.
#
# Also supports optionally iterating or breaking of the file
# into chunks.
#
# Additional help can be found in the online docs for
# `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
# Parameters
# ----------
# filepath_or_buffer : str, path object or file-like object
#     Any valid string path is acceptable. The string could be a URL. Valid
#     URL schemes include http, ftp, s3, gs, and file. For file URLs, a host is
#     expected. A local file could be: file://localhost/path/to/table.csv.
#
#     If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#     By file-like object, we refer to objects with a ``read()`` method, such as
#     a file handle (e.g. via builtin ``open`` function) or ``StringIO``.
# sep : str, default ','
#     Character or regex pattern to treat as the delimiter. If ``sep=None``, the
#     C engine cannot automatically detect
#     the separator, but the Python parsing engine can, meaning the latter will
#     be used and automatically detect the separator from only the first valid
#     row of the file by Python's builtin sniffer tool, ``csv.Sniffer``.
#     In addition, separators longer than 1 character and different from
#     ``'\s+'`` will be interpreted as regular expressions and will also force
#     the use of the Python parsing engine. Note that regex delimiters are prone
#     to ignoring quoted data. Regex example: ``'\r\t'``.
# delimiter : str, optional
#     Alias for ``sep``.
# header : int, Sequence of int, 'infer' or None, default 'infer'
#     Row number(s) containing column labels and marking the start of the
#     data (zero-indexed). Default behavior is to infer the column names: if no ``names``
#     are passed the behavior is identical to ``header=0`` and column
#     names are inferred from the first line of the file, if column
#     names are passed explicitly to ``names`` then the behavior is identical to
#     ``header=None``. Explicitly pass ``header=0`` to be able to
#     replace existing names. The header can be a list of integers that
#     specify row locations for a :class:`~pandas.MultiIndex` on the columns
#     e.g. ``[0, 1, 3]``. Intervening rows that are not specified will be
#     skipped (e.g. 2 in this example is skipped). Note that this
#     parameter ignores commented lines and empty lines if
#     ``skip_blank_lines=True``, so ``header=0`` denotes the first line of
#     data rather than the first line of the file.
# names : Sequence of Hashable, optional
#     Sequence of column labels to apply. If the file contains a header row,
#     then you should explicitly pass ``header=0`` to override the column names.
#     Duplicates in this list are not allowed.
# index_col : Hashable, Sequence of Hashable or False, optional
#   Column(s) to use as row label(s), denoted either by column labels or column
#   indices.  If a sequence of labels or indices is given, :class:`~pandas.MultiIndex`
#   will be formed for the row labels.
#
#   Note: ``index_col=False`` can be used to force pandas to *not* use the first
#   column as the index, e.g., when you have a malformed file with delimiters at
#   the end of each line.
# usecols : Sequence of Hashable or Callable, optional
#     Subset of columns to select, denoted either by column labels or column indices.
#     If list-like, all elements must either
#     be positional (i.e. integer indices into the document columns) or strings
#     that correspond to column names provided either by the user in ``names`` or
#     inferred from the document header row(s). If ``names`` are given, the document
#     header row(s) are not taken into account. For example, a valid list-like
#     ``usecols`` parameter would be ``[0, 1, 2]`` or ``['foo', 'bar', 'baz']``.
#     Element order is ignored, so ``usecols=[0, 1]`` is the same as ``[1, 0]``.
#     To instantiate a :class:`~pandas.DataFrame` from ``data`` with element order
#     preserved use ``pd.read_csv(data, usecols=['foo', 'bar'])[['foo', 'bar']]``
#     for columns in ``['foo', 'bar']`` order or
#     ``pd.read_csv(data, usecols=['foo', 'bar'])[['bar', 'foo']]``
#     for ``['bar', 'foo']`` order.
#
#     If callable, the callable function will be evaluated against the column
#     names, returning names where the callable function evaluates to ``True``. An
#     example of a valid callable argument would be ``lambda x: x.upper() in
#     ['AAA', 'BBB', 'DDD']``. Using this parameter results in much faster
#     parsing time and lower memory usage.
# dtype : dtype or dict of {Hashable : dtype}, optional
#     Data type(s) to apply to either the whole dataset or individual columns.
#     E.g., ``{'a': np.float64, 'b': np.int32, 'c': 'Int64'}``
#     Use ``str`` or ``object`` together with suitable ``na_values`` settings
#     to preserve and not interpret ``dtype``.
#     If ``converters`` are specified, they will be applied INSTEAD
#     of ``dtype`` conversion.
#
#     .. versionadded:: 1.5.0
#
#         Support for ``defaultdict`` was added. Specify a ``defaultdict`` as input where
#         the default determines the ``dtype`` of the columns which are not explicitly
#         listed.
# engine : {'c', 'python', 'pyarrow'}, optional
#     Parser engine to use. The C and pyarrow engines are faster, while the python engine
#     is currently more feature-complete. Multithreading is currently only supported by
#     the pyarrow engine.
#
#     .. versionadded:: 1.4.0
#
#         The 'pyarrow' engine was added as an *experimental* engine, and some features
#         are unsupported, or may not work correctly, with this engine.
# converters : dict of {Hashable : Callable}, optional
#     Functions for converting values in specified columns. Keys can either
#     be column labels or column indices.
# true_values : list, optional
#     Values to consider as ``True`` in addition to case-insensitive variants of 'True'.
# false_values : list, optional
#     Values to consider as ``False`` in addition to case-insensitive variants of 'False'.
# skipinitialspace : bool, default False
#     Skip spaces after delimiter.
# skiprows : int, list of int or Callable, optional
#     Line numbers to skip (0-indexed) or number of lines to skip (``int``)
#     at the start of the file.
#
#     If callable, the callable function will be evaluated against the row
#     indices, returning ``True`` if the row should be skipped and ``False`` otherwise.
#     An example of a valid callable argument would be ``lambda x: x in [0, 2]``.
# skipfooter : int, default 0
#     Number of lines at bottom of file to skip (Unsupported with ``engine='c'``).
# nrows : int, optional
#     Number of rows of file to read. Useful for reading pieces of large files.
# na_values : Hashable, Iterable of Hashable or dict of {Hashable : Iterable}, optional
#     Additional strings to recognize as ``NA``/``NaN``. If ``dict`` passed, specific
#     per-column ``NA`` values.  By default the following values are interpreted as
#     ``NaN``: " ", "#N/A", "#N/A N/A", "#NA", "-1.#IND", "-1.#QNAN", "-NaN", "-nan",
#     "1.#IND", "1.#QNAN", "<NA>", "N/A", "NA", "NULL", "NaN", "None",
#     "n/a", "nan", "null ".
#
# keep_default_na : bool, default True
#     Whether or not to include the default ``NaN`` values when parsing the data.
#     Depending on whether ``na_values`` is passed in, the behavior is as follows:
#
#     * If ``keep_default_na`` is ``True``, and ``na_values`` are specified, ``na_values``
#       is appended to the default ``NaN`` values used for parsing.
#     * If ``keep_default_na`` is ``True``, and ``na_values`` are not specified, only
#       the default ``NaN`` values are used for parsing.
#     * If ``keep_default_na`` is ``False``, and ``na_values`` are specified, only
#       the ``NaN`` values specified ``na_values`` are used for parsing.
#     * If ``keep_default_na`` is ``False``, and ``na_values`` are not specified, no
#       strings will be parsed as ``NaN``.
#
#     Note that if ``na_filter`` is passed in as ``False``, the ``keep_default_na`` and
#     ``na_values`` parameters will be ignored.
# na_filter : bool, default True
#     Detect missing value markers (empty strings and the value of ``na_values``). In
#     data without any ``NA`` values, passing ``na_filter=False`` can improve the
#     performance of reading a large file.
# verbose : bool, default False
#     Indicate number of ``NA`` values placed in non-numeric columns.
#
#     .. deprecated:: 2.2.0
# skip_blank_lines : bool, default True
#     If ``True``, skip over blank lines rather than interpreting as ``NaN`` values.
# parse_dates : bool, list of Hashable, list of lists or dict of {Hashable : list}, default False
#     The behavior is as follows:
#
#     * ``bool``. If ``True`` -> try parsing the index. Note: Automatically set to
#       ``True`` if ``date_format`` or ``date_parser`` arguments have been passed.
#     * ``list`` of ``int`` or names. e.g. If ``[1, 2, 3]`` -> try parsing columns 1, 2, 3
#       each as a separate date column.
#     * ``list`` of ``list``. e.g.  If ``[[1, 3]]`` -> combine columns 1 and 3 and parse
#       as a single date column. Values are joined with a space before parsing.
#     * ``dict``, e.g. ``{'foo' : [1, 3]}`` -> parse columns 1, 3 as date and call
#       result 'foo'. Values are joined with a space before parsing.
#
#     If a column or index cannot be represented as an array of ``datetime``,
#     say because of an unparsable value or a mixture of timezones, the column
#     or index will be returned unaltered as an ``object`` data type. For
#     non-standard ``datetime`` parsing, use :func:`~pandas.to_datetime` after
#     :func:`~pandas.read_csv`.
#
#     Note: A fast-path exists for iso8601-formatted dates.
# infer_datetime_format : bool, default False
#     If ``True`` and ``parse_dates`` is enabled, pandas will attempt to infer the
#     format of the ``datetime`` strings in the columns, and if it can be inferred,
#     switch to a faster method of parsing them. In some cases this can increase
#     the parsing speed by 5-10x.
#
#     .. deprecated:: 2.0.0
#         A strict version of this argument is now the default, passing it has no effect.
#
# keep_date_col : bool, default False
#     If ``True`` and ``parse_dates`` specifies combining multiple columns then
#     keep the original columns.
# date_parser : Callable, optional
#     Function to use for converting a sequence of string columns to an array of
#     ``datetime`` instances. The default uses ``dateutil.parser.parser`` to do the
#     conversion. pandas will try to call ``date_parser`` in three different ways,
#     advancing to the next if an exception occurs: 1) Pass one or more arrays
#     (as defined by ``parse_dates``) as arguments; 2) concatenate (row-wise) the
#     string values from the columns defined by ``parse_dates`` into a single array
#     and pass that; and 3) call ``date_parser`` once for each row using one or
#     more strings (corresponding to the columns defined by ``parse_dates``) as
#     arguments.
#
#     .. deprecated:: 2.0.0
#        Use ``date_format`` instead, or read in as ``object`` and then apply
#        :func:`~pandas.to_datetime` as-needed.
# date_format : str or dict of column -> format, optional
#     Format to use for parsing dates when used in conjunction with ``parse_dates``.
#     The strftime to parse time, e.g. :const:`"%d/%m/%Y"`. See
#     `strftime documentation
#     <https://docs.python.org/3/library/datetime.html
#     #strftime-and-strptime-behavior>`_ for more information on choices, though
#     note that :const:`"%f"` will parse all the way up to nanoseconds.
#     You can also pass:
#
#     - "ISO8601", to parse any `ISO8601 <https://en.wikipedia.org/wiki/ISO_8601>`_
#         time string (not necessarily in exactly the same format);
#     - "mixed", to infer the format for each element individually. This is risky,
#         and you should probably use it along with `dayfirst`.
#
#     .. versionadded:: 2.0.0
# dayfirst : bool, default False
#     DD/MM format dates, international and European format.
# cache_dates : bool, default True
#     If ``True``, use a cache of unique, converted dates to apply the ``datetime``
#     conversion. May produce significant speed-up when parsing duplicate
#     date strings, especially ones with timezone offsets.
#
# iterator : bool, default False
#     Return ``TextFileReader`` object for iteration or getting chunks with
#     ``get_chunk()``.
# chunksize : int, optional
#     Number of lines to read from the file per chunk. Passing a value will cause the
#     function to return a ``TextFileReader`` object for iteration.
#     See the `IO Tools docs
#     <https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking>`_
#     for more information on ``iterator`` and ``chunksize``.
#
# compression : str or dict, default 'infer'
#     For on-the-fly decompression of on-disk data. If 'infer' and 'filepath_or_buffer' is
#     path-like, then detect compression from the following extensions: '.gz',
#     '.bz2', '.zip', '.xz', '.zst', '.tar', '.tar.gz', '.tar.xz' or '.tar.bz2'
#     (otherwise no compression).
#     If using 'zip' or 'tar', the ZIP file must contain only one data file to be read in.
#     Set to ``None`` for no decompression.
#     Can also be a dict with key ``'method'`` set
#     to one of {``'zip'``, ``'gzip'``, ``'bz2'``, ``'zstd'``, ``'xz'``, ``'tar'``} and
#     other key-value pairs are forwarded to
#     ``zipfile.ZipFile``, ``gzip.GzipFile``,
#     ``bz2.BZ2File``, ``zstandard.ZstdDecompressor``, ``lzma.LZMAFile`` or
#     ``tarfile.TarFile``, respectively.
#     As an example, the following could be passed for Zstandard decompression using a
#     custom compression dictionary:
#     ``compression={'method': 'zstd', 'dict_data': my_compression_dict}``.
#
#     .. versionadded:: 1.5.0
#         Added support for `.tar` files.
#
#     .. versionchanged:: 1.4.0 Zstandard support.
#
# thousands : str (length 1), optional
#     Character acting as the thousands separator in numerical values.
# decimal : str (length 1), default '.'
#     Character to recognize as decimal point (e.g., use ',' for European data).
# lineterminator : str (length 1), optional
#     Character used to denote a line break. Only valid with C parser.
# quotechar : str (length 1), optional
#     Character used to denote the start and end of a quoted item. Quoted
#     items can include the ``delimiter`` and it will be ignored.
# quoting : {0 or csv.QUOTE_MINIMAL, 1 or csv.QUOTE_ALL, 2 or csv.QUOTE_NONNUMERIC, 3 or csv.QUOTE_NONE}, default csv.QUOTE_MINIMAL
#     Control field quoting behavior per ``csv.QUOTE_*`` constants. Default is
#     ``csv.QUOTE_MINIMAL`` (i.e., 0) which implies that only fields containing special
#     characters are quoted (e.g., characters defined in ``quotechar``, ``delimiter``,
#     or ``lineterminator``.
# doublequote : bool, default True
#    When ``quotechar`` is specified and ``quoting`` is not ``QUOTE_NONE``, indicate
#    whether or not to interpret two consecutive ``quotechar`` elements INSIDE a
#    field as a single ``quotechar`` element.
# escapechar : str (length 1), optional
#     Character used to escape other characters.
# comment : str (length 1), optional
#     Character indicating that the remainder of line should not be parsed.
#     If found at the beginning
#     of a line, the line will be ignored altogether. This parameter must be a
#     single character. Like empty lines (as long as ``skip_blank_lines=True``),
#     fully commented lines are ignored by the parameter ``header`` but not by
#     ``skiprows``. For example, if ``comment='#'``, parsing
#     ``#empty\na,b,c\n1,2,3`` with ``header=0`` will result in ``'a,b,c'`` being
#     treated as the header.
# encoding : str, optional, default 'utf-8'
#     Encoding to use for UTF when reading/writing (ex. ``'utf-8'``). `List of Python
#     standard encodings
#     <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .
#
# encoding_errors : str, optional, default 'strict'
#     How encoding errors are treated. `List of possible values
#     <https://docs.python.org/3/library/codecs.html#error-handlers>`_ .
#
#     .. versionadded:: 1.3.0
#
# dialect : str or csv.Dialect, optional
#     If provided, this parameter will override values (default or not) for the
#     following parameters: ``delimiter``, ``doublequote``, ``escapechar``,
#     ``skipinitialspace``, ``quotechar``, and ``quoting``. If it is necessary to
#     override values, a ``ParserWarning`` will be issued. See ``csv.Dialect``
#     documentation for more details.
# on_bad_lines : {'error', 'warn', 'skip'} or Callable, default 'error'
#     Specifies what to do upon encountering a bad line (a line with too many fields).
#     Allowed values are :
#
#     - ``'error'``, raise an Exception when a bad line is encountered.
#     - ``'warn'``, raise a warning when a bad line is encountered and skip that line.
#     - ``'skip'``, skip bad lines without raising or warning when they are encountered.
#
#     .. versionadded:: 1.3.0
#
#     .. versionadded:: 1.4.0
#
#         - Callable, function with signature
#           ``(bad_line: list[str]) -> list[str] | None`` that will process a single
#           bad line. ``bad_line`` is a list of strings split by the ``sep``.
#           If the function returns ``None``, the bad line will be ignored.
#           If the function returns a new ``list`` of strings with more elements than
#           expected, a ``ParserWarning`` will be emitted while dropping extra elements.
#           Only supported when ``engine='python'``
#
#     .. versionchanged:: 2.2.0
#
#         - Callable, function with signature
#           as described in `pyarrow documentation
#           <https://arrow.apache.org/docs/python/generated/pyarrow.csv.ParseOptions.html
#           #pyarrow.csv.ParseOptions.invalid_row_handler>`_ when ``engine='pyarrow'``
#
# delim_whitespace : bool, default False
#     Specifies whether or not whitespace (e.g. ``' '`` or ``'\t'``) will be
#     used as the ``sep`` delimiter. Equivalent to setting ``sep='\s+'``. If this option
#     is set to ``True``, nothing should be passed in for the ``delimiter``
#     parameter.
#
#     .. deprecated:: 2.2.0
#         Use ``sep="\s+"`` instead.
# low_memory : bool, default True
#     Internally process the file in chunks, resulting in lower memory use
#     while parsing, but possibly mixed type inference.  To ensure no mixed
#     types either set ``False``, or specify the type with the ``dtype`` parameter.
#     Note that the entire file is read into a single :class:`~pandas.DataFrame`
#     regardless, use the ``chunksize`` or ``iterator`` parameter to return the data in
#     chunks. (Only valid with C parser).
# memory_map : bool, default False
#     If a filepath is provided for ``filepath_or_buffer``, map the file object
#     directly onto memory and access the data directly from there. Using this
#     option can improve performance because there is no longer any I/O overhead.
# float_precision : {'high', 'legacy', 'round_trip'}, optional
#     Specifies which converter the C engine should use for floating-point
#     values. The options are ``None`` or ``'high'`` for the ordinary converter,
#     ``'legacy'`` for the original lower precision pandas converter, and
#     ``'round_trip'`` for the round-trip converter.
#
# storage_options : dict, optional
#     Extra options that make sense for a particular storage connection, e.g.
#     host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#     are forwarded to ``urllib.request.Request`` as header options. For other
#     URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#     forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#     details, and for more examples on storage options refer `here
#     <https://pandas.pydata.org/docs/user_guide/io.html?
#     highlight=storage_options#reading-writing-remote-files>`_.
#
# dtype_backend : {'numpy_nullable', 'pyarrow'}, default 'numpy_nullable'
#     Back-end data type applied to the resultant :class:`DataFrame`
#     (still experimental). Behaviour is as follows:
#
#     * ``"numpy_nullable"``: returns nullable-dtype-backed :class:`DataFrame`
#       (default).
#     * ``"pyarrow"``: returns pyarrow-backed nullable :class:`ArrowDtype`
#       DataFrame.
#
#     .. versionadded:: 2.0
#
# Returns
# -------
# DataFrame or TextFileReader
#     A comma-separated values (csv) file is returned as two-dimensional
#     data structure with labeled axes.
#
# See Also
# --------
# DataFrame.to_csv : Write DataFrame to a comma-separated values (csv) file.
# read_table : Read general delimited file into DataFrame.
# read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
# Examples
# --------
# >>> pd.read_csv('data.csv')  # doctest: +SKIP
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/io/parsers/readers.py
# Type:      function

# %%
pd.read_csv('olympics_1896_2004.csv')
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# 1            NaN        NaN         NaN                 NaN        NaN
# 2            NaN        NaN         NaN                 NaN        NaN
# 3            NaN        NaN         NaN                 NaN        NaN
# 4           City      Sport  Discipline        Athlete Name        NOC
# ...          ...        ...         ...                 ...        ...
# 27174     Athens    Fencing     Fencing  LOGOUNOVA, Tatiana        RUS
# 27175     Athens    Fencing     Fencing       SIVKOVA, Anna        RUS
# 27176     Athens    Fencing     Fencing      BOKEL, Claudia        GER
# 27177     Athens    Fencing     Fencing     DUPLITZER, Imke        GER
# 27178     Athens    Fencing     Fencing   HEIDEMANN, Britta        GER
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0            NaN        NaN           NaN        NaN         NaN
# 1            NaN        NaN           NaN        NaN         NaN
# 2            NaN        NaN           NaN        NaN         NaN
# 3            NaN        NaN           NaN        NaN         NaN
# 4         Gender      Event  Event Gender      Medal    Position
# ...          ...        ...           ...        ...         ...
# 27174      Women  épée team             W       Gold           1
# 27175      Women  épée team             W       Gold           1
# 27176      Women  épée team             W     Silver           2
# 27177      Women  épée team             W     Silver           2
# 27178      Women  épée team             W     Silver           2
#
# [27179 rows x 11 columns]

# %%
pd.read_csv(filepath_or_buffer='olympics_1896_2004.csv')
# Out:
#       This is a list of medallists at the Summer Olympic Games (1896-2004) with details of the year of the olympics, city, sport, discipline, athlete name, gender, event and medal  \
# 0                                                    NaN
# 1      DISCLAIMER: No guarantees, express or implied,...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                   Year
# ...                                                  ...
# 27174                                               2004
# 27175                                               2004
# 27176                                               2004
# 27177                                               2004
# 27178                                               2004
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3          Unnamed: 4 Unnamed: 5  \
# 0            NaN        NaN         NaN                 NaN        NaN
# 1            NaN        NaN         NaN                 NaN        NaN
# 2            NaN        NaN         NaN                 NaN        NaN
# 3            NaN        NaN         NaN                 NaN        NaN
# 4           City      Sport  Discipline        Athlete Name        NOC
# ...          ...        ...         ...                 ...        ...
# 27174     Athens    Fencing     Fencing  LOGOUNOVA, Tatiana        RUS
# 27175     Athens    Fencing     Fencing       SIVKOVA, Anna        RUS
# 27176     Athens    Fencing     Fencing      BOKEL, Claudia        GER
# 27177     Athens    Fencing     Fencing     DUPLITZER, Imke        GER
# 27178     Athens    Fencing     Fencing   HEIDEMANN, Britta        GER
#
#       Unnamed: 6 Unnamed: 7    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0            NaN        NaN           NaN        NaN         NaN
# 1            NaN        NaN           NaN        NaN         NaN
# 2            NaN        NaN           NaN        NaN         NaN
# 3            NaN        NaN           NaN        NaN         NaN
# 4         Gender      Event  Event Gender      Medal    Position
# ...          ...        ...           ...        ...         ...
# 27174      Women  épée team             W       Gold           1
# 27175      Women  épée team             W       Gold           1
# 27176      Women  épée team             W     Silver           2
# 27177      Women  épée team             W     Silver           2
# 27178      Women  épée team             W     Silver           2
#
# [27179 rows x 11 columns]

# %%
oo = pd.read_csv('olympics_1896_2004.csv')
oo

# %%
oo = pd.read_csv('olympics_1896_2004.csv', skiprows=5)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
filename = "olympics_1896_2004.csv"

# %%
#from google.colab import files
#files.upload()

# %% [markdown]
# ## Get an overview of the data and displaying it

# %%
#!pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# Installed all of the necessary files for this section ...

# %%
oo = pd.read_csv(filename, skiprows=5)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
oo.shape
# Out:
# (27174, 11)

# %%
oo.shape?
# Out:
# Type:        property
# String form: <property object at 0x112ff9bd0>
# Docstring:
# Return a tuple representing the dimensionality of the DataFrame.
#
# See Also
# --------
# ndarray.shape : Tuple of array dimensions.
#
# Examples
# --------
# >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
# >>> df.shape
# (2, 2)
#
# >>> df = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4],
# ...                    'col3': [5, 6]})
# >>> df.shape
# (2, 3)

# %%
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3
# 3   100m            M  Bronze         3
# 4   100m            M    Gold         1

# %%
oo.head?
# Out:
# Signature: oo.head(n: 'int' = 5) -> 'Self'
# Docstring:
# Return the first `n` rows.
#
# This function returns the first `n` rows for the object based
# on position. It is useful for quickly testing if your object
# has the right type of data in it.
#
# For negative values of `n`, this function returns all rows except
# the last `|n|` rows, equivalent to ``df[:n]``.
#
# If n is larger than the number of rows, this function returns all rows.
#
# Parameters
# ----------
# n : int, default 5
#     Number of rows to select.
#
# Returns
# -------
# same type as caller
#     The first `n` rows of the caller object.
#
# See Also
# --------
# DataFrame.tail: Returns the last `n` rows.
#
# Examples
# --------
# >>> df = pd.DataFrame({'animal': ['alligator', 'bee', 'falcon', 'lion',
# ...                    'monkey', 'parrot', 'shark', 'whale', 'zebra']})
# >>> df
#       animal
# 0  alligator
# 1        bee
# 2     falcon
# 3       lion
# 4     monkey
# 5     parrot
# 6      shark
# 7      whale
# 8      zebra
#
# Viewing the first 5 lines
#
# >>> df.head()
#       animal
# 0  alligator
# 1        bee
# 2     falcon
# 3       lion
# 4     monkey
#
# Viewing the first `n` lines (three in this case)
#
# >>> df.head(3)
#       animal
# 0  alligator
# 1        bee
# 2     falcon
#
# For negative values of `n`
#
# >>> df.head(-3)
#       animal
# 0  alligator
# 1        bee
# 2     falcon
# 3       lion
# 4     monkey
# 5     parrot
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/generic.py
# Type:      method

# %%
oo.head(3)

# %%
oo.tail()

# %%
oo.sample(5)
# Out:
#        Year     City          Sport     Discipline          Athlete Name  NOC  \
# 18905  1988    Seoul       Football       Football   SCHREIER, Christian  FRG
# 3746   1920  Antwerp          Rugby          Rugby  SLATER, Colby Edward  USA
# 4448   1924    Paris     Gymnastics    Artistic G.    GANGLOFF, François  FRA
# 22606  1996  Atlanta         Hockey         Hockey         THATE, Carole  NED
# 25218  2004   Athens  Weightlifting  Weightlifting            WU, Meijin  CHN
#
#       Gender                         Event Event Gender   Medal  Position
# 18905    Men                      football            M  Bronze         3
# 3746     Men                         rugby            M    Gold         1
# 4448     Men               Sidehorse vault            M  Silver         2
# 22606  Women                        hockey            W  Bronze         3
# 25218    Men  - 56kg, total (bantamweight)            M  Silver         2

# %%
oo.sample?
# Out:
# Signature:
# oo.sample(
#     n: 'int | None' = None,
#     frac: 'float | None' = None,
#     replace: 'bool_t' = False,
#     weights=None,
#     random_state: 'RandomState | None' = None,
#     axis: 'Axis | None' = None,
#     ignore_index: 'bool_t' = False,
# ) -> 'Self'
# Docstring:
# Return a random sample of items from an axis of object.
#
# You can use `random_state` for reproducibility.
#
# Parameters
# ----------
# n : int, optional
#     Number of items from axis to return. Cannot be used with `frac`.
#     Default = 1 if `frac` = None.
# frac : float, optional
#     Fraction of axis items to return. Cannot be used with `n`.
# replace : bool, default False
#     Allow or disallow sampling of the same row more than once.
# weights : str or ndarray-like, optional
#     Default 'None' results in equal probability weighting.
#     If passed a Series, will align with target object on index. Index
#     values in weights not found in sampled object will be ignored and
#     index values in sampled object not in weights will be assigned
#     weights of zero.
#     If called on a DataFrame, will accept the name of a column
#     when axis = 0.
#     Unless weights are a Series, weights must be same length as axis
#     being sampled.
#     If weights do not sum to 1, they will be normalized to sum to 1.
#     Missing values in the weights column will be treated as zero.
#     Infinite values not allowed.
# random_state : int, array-like, BitGenerator, np.random.RandomState, np.random.Generator, optional
#     If int, array-like, or BitGenerator, seed for random number generator.
#     If np.random.RandomState or np.random.Generator, use as given.
#
#     .. versionchanged:: 1.4.0
#
#         np.random.Generator objects now accepted
#
# axis : {0 or 'index', 1 or 'columns', None}, default None
#     Axis to sample. Accepts axis number or name. Default is stat axis
#     for given data type. For `Series` this parameter is unused and defaults to `None`.
# ignore_index : bool, default False
#     If True, the resulting index will be labeled 0, 1, …, n - 1.
#
#     .. versionadded:: 1.3.0
#
# Returns
# -------
# Series or DataFrame
#     A new object of same type as caller containing `n` items randomly
#     sampled from the caller object.
#
# See Also
# --------
# DataFrameGroupBy.sample: Generates random samples from each group of a
#     DataFrame object.
# SeriesGroupBy.sample: Generates random samples from each group of a
#     Series object.
# numpy.random.choice: Generates a random sample from a given 1-D numpy
#     array.
#
# Notes
# -----
# If `frac` > 1, `replacement` should be set to `True`.
#
# Examples
# --------
# >>> df = pd.DataFrame({'num_legs': [2, 4, 8, 0],
# ...                    'num_wings': [2, 0, 0, 0],
# ...                    'num_specimen_seen': [10, 2, 1, 8]},
# ...                   index=['falcon', 'dog', 'spider', 'fish'])
# >>> df
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# dog            4          0                  2
# spider         8          0                  1
# fish           0          0                  8
#
# Extract 3 random elements from the ``Series`` ``df['num_legs']``:
# Note that we use `random_state` to ensure the reproducibility of
# the examples.
#
# >>> df['num_legs'].sample(n=3, random_state=1)
# fish      0
# spider    8
# falcon    2
# Name: num_legs, dtype: int64
#
# A random 50% sample of the ``DataFrame`` with replacement:
#
# >>> df.sample(frac=0.5, replace=True, random_state=1)
#       num_legs  num_wings  num_specimen_seen
# dog          4          0                  2
# fish         0          0                  8
#
# An upsample sample of the ``DataFrame`` with replacement:
# Note that `replace` parameter has to be `True` for `frac` parameter > 1.
#
# >>> df.sample(frac=2, replace=True, random_state=1)
#         num_legs  num_wings  num_specimen_seen
# dog            4          0                  2
# fish           0          0                  8
# falcon         2          2                 10
# falcon         2          2                 10
# fish           0          0                  8
# dog            4          0                  2
# fish           0          0                  8
# dog            4          0                  2
#
# Using a DataFrame column as weights. Rows with larger value in the
# `num_specimen_seen` column are more likely to be sampled.
#
# >>> df.sample(n=2, weights='num_specimen_seen', random_state=1)
#         num_legs  num_wings  num_specimen_seen
# falcon         2          2                 10
# fish           0          0                  8
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/generic.py
# Type:      method

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27174 entries, 0 to 27173
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          27174 non-null  int64
#  1   City          27174 non-null  object
#  2   Sport         27174 non-null  object
#  3   Discipline    27174 non-null  object
#  4   Athlete Name  27174 non-null  object
#  5   NOC           27174 non-null  object
#  6   Gender        27174 non-null  object
#  7   Event         27174 non-null  object
#  8   Event Gender  27174 non-null  object
#  9   Medal         27174 non-null  object
#  10  Position      27174 non-null  int64
# dtypes: int64(2), object(9)
# memory usage: 2.3+ MB

# %%
oo.describe()
# Out:
#                Year      Position
# count  27174.000000  27174.000000
# mean    1964.685803      1.992566
# std       31.590396      0.817469
# min     1896.000000      1.000000
# 25%     1936.000000      1.000000
# 50%     1972.000000      2.000000
# 75%     1992.000000      3.000000
# max     2004.000000      3.000000

# %%
pd.get_option("display.max_rows")
# Out:
# 60

# %%
pd.set_option("display.max_rows", None)
oo
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
pd.set_option("display.max_rows", 60)
oo

# %%
pd.get_option("display.max_columns")

# %%
pd.get_option("display.width")
# Out:
# 80

# %%
pd.set_option("display.width", 100)

# %% [markdown]
# ## Select a Series (column)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year       City     Sport Discipline         Athlete Name  NOC Gender  \
# 7012   1936     Berlin      Polo       Polo  MULLER LUJAN, Julio  MEX    Men
# 26424  2004     Athens  Handball   Handball       FRITZ, Henning  GER    Men
# 20813  1992  Barcelona    Hockey     Hockey        CAREY, Ashley  AUS    Men
#
#           Event Event Gender   Medal  Position
# 7012       polo            M  Bronze         3
# 26424  handball            M  Silver         2
# 20813    hockey            M  Silver         2

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
oo["Discipline"]
# Out:
# 0        Cycling Track
# 1        Cycling Track
# 2            Athletics
# 3            Athletics
# 4            Athletics
#              ...
# 27169          Fencing
# 27170          Fencing
# 27171          Fencing
# 27172          Fencing
# 27173          Fencing
# Name: Discipline, Length: 27174, dtype: object

# %%
oo['Discipline']
# Out:
# 0        Cycling Track
# 1        Cycling Track
# 2            Athletics
# 3            Athletics
# 4            Athletics
#              ...
# 27169          Fencing
# 27170          Fencing
# 27171          Fencing
# 27172          Fencing
# 27173          Fencing
# Name: Discipline, Length: 27174, dtype: object

# %%
#oo["discipline"]

# %%
type(oo["Discipline"])
# Out:
# pandas.core.series.Series

# %%
oo.Discipline

# %%
oo.columns

# %%
oo["Athlete Name"]
# Out:
# 0             FLAMENG, Léon
# 1        KOLETTIS, Georgios
# 2             LANE, Francis
# 3          SZOKOLYI, Alajos
# 4             BURKE, Thomas
#                 ...
# 27169    LOGOUNOVA, Tatiana
# 27170         SIVKOVA, Anna
# 27171        BOKEL, Claudia
# 27172       DUPLITZER, Imke
# 27173     HEIDEMANN, Britta
# Name: Athlete Name, Length: 27174, dtype: object

# %%
#oo.Athlete Name

# %%
oo.sample(3)

# %%
oo['Year'].unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %%
oo.Year.unique?
# Out:
# Signature: oo.Year.unique() -> 'ArrayLike'
# Docstring:
# Return unique values of Series object.
#
# Uniques are returned in order of appearance. Hash table-based unique,
# therefore does NOT sort.
#
# Returns
# -------
# ndarray or ExtensionArray
#     The unique values returned as a NumPy array. See Notes.
#
# See Also
# --------
# Series.drop_duplicates : Return Series with duplicate values removed.
# unique : Top-level unique method for any 1-d array-like object.
# Index.unique : Return Index with unique values from an Index object.
#
# Notes
# -----
# Returns the unique values as a NumPy array. In case of an
# extension-array backed Series, a new
# :class:`~api.extensions.ExtensionArray` of that type with just
# the unique values is returned. This includes
#
#     * Categorical
#     * Period
#     * Datetime with Timezone
#     * Datetime without Timezone
#     * Timedelta
#     * Interval
#     * Sparse
#     * IntegerNA
#
# See Examples section.
#
# Examples
# --------
# >>> pd.Series([2, 1, 3, 3], name='A').unique()
# array([2, 1, 3])
#
# >>> pd.Series([pd.Timestamp('2016-01-01') for _ in range(3)]).unique()
# <DatetimeArray>
# ['2016-01-01 00:00:00']
# Length: 1, dtype: datetime64[ns]
#
# >>> pd.Series([pd.Timestamp('2016-01-01', tz='US/Eastern')
# ...            for _ in range(3)]).unique()
# <DatetimeArray>
# ['2016-01-01 00:00:00-05:00']
# Length: 1, dtype: datetime64[ns, US/Eastern]
#
# An Categorical will return categories in the order of
# appearance and with the same dtype.
#
# >>> pd.Series(pd.Categorical(list('baabc'))).unique()
# ['b', 'a', 'c']
# Categories (3, object): ['a', 'b', 'c']
# >>> pd.Series(pd.Categorical(list('baabc'), categories=list('abc'),
# ...                          ordered=True)).unique()
# ['b', 'a', 'c']
# Categories (3, object): ['a' < 'b' < 'c']
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/series.py
# Type:      method

# %%
oo.Sport.unique()

# %%
oo.sample(3)

# %%
oo.Year.value_counts()
# Out:
# Year
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: count, dtype: int64

# %%
oo.Year.value_counts?
# Out:
# Signature:
# oo.Year.value_counts(
#     normalize: 'bool' = False,
#     sort: 'bool' = True,
#     ascending: 'bool' = False,
#     bins=None,
#     dropna: 'bool' = True,
# ) -> 'Series'
# Docstring:
# Return a Series containing counts of unique values.
#
# The resulting object will be in descending order so that the
# first element is the most frequently-occurring element.
# Excludes NA values by default.
#
# Parameters
# ----------
# normalize : bool, default False
#     If True then the object returned will contain the relative
#     frequencies of the unique values.
# sort : bool, default True
#     Sort by frequencies when True. Preserve the order of the data when False.
# ascending : bool, default False
#     Sort in ascending order.
# bins : int, optional
#     Rather than count values, group them into half-open bins,
#     a convenience for ``pd.cut``, only works with numeric data.
# dropna : bool, default True
#     Don't include counts of NaN.
#
# Returns
# -------
# Series
#
# See Also
# --------
# Series.count: Number of non-NA elements in a Series.
# DataFrame.count: Number of non-NA elements in a DataFrame.
# DataFrame.value_counts: Equivalent method on DataFrames.
#
# Examples
# --------
# >>> index = pd.Index([3, 1, 2, 3, 4, np.nan])
# >>> index.value_counts()
# 3.0    2
# 1.0    1
# 2.0    1
# 4.0    1
# Name: count, dtype: int64
#
# With `normalize` set to `True`, returns the relative frequency by
# dividing all values by the sum of values.
#
# >>> s = pd.Series([3, 1, 2, 3, 4, np.nan])
# >>> s.value_counts(normalize=True)
# 3.0    0.4
# 1.0    0.2
# 2.0    0.2
# 4.0    0.2
# Name: proportion, dtype: float64
#
# **bins**
#
# Bins can be useful for going from a continuous variable to a
# categorical variable; instead of counting unique
# apparitions of values, divide the index in the specified
# number of half-open bins.
#
# >>> s.value_counts(bins=3)
# (0.996, 2.0]    2
# (2.0, 3.0]      2
# (3.0, 4.0]      1
# Name: count, dtype: int64
#
# **dropna**
#
# With `dropna` set to `False` we can also see NaN index values.
#
# >>> s.value_counts(dropna=False)
# 3.0    2
# 1.0    1
# 2.0    1
# 4.0    1
# NaN    1
# Name: count, dtype: int64
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/base.py
# Type:      method

# %%
oo.Year.value_counts(normalize=True)
# Out:
# Year
# 2000    0.074152
# 2004    0.073526
# 1996    0.068411
# 1992    0.062744
# 1988    0.056893
# 1984    0.053691
# 1980    0.051041
# 1976    0.048024
# 1920    0.047766
# 1972    0.043608
# 1968    0.037941
# 1964    0.037168
# 1952    0.032715
# 1956    0.032568
# 1912    0.032568
# 1924    0.032531
# 1960    0.032457
# 1936    0.032200
# 1948    0.029955
# 1908    0.029587
# 1928    0.026128
# 1932    0.022632
# 1900    0.018842
# 1904    0.017296
# 1896    0.005557
# Name: proportion, dtype: float64

# %% [markdown]
# ## Challenge

# %% [markdown]
# Answer the following questions. Indicate the Pandas command where relevant.
#
# 1.   What is the time range covered in this dataset?
# 2.   The Olympics take place every 4 years. Why are there missing years?
# 3.   What are the types of medals awarded?
# 4.   Across all of the Olympic Games, how many Gold, Silver and Bronze medals have there been?
# 5.   Why are there not an equal number of Gold, Silver and Bronze medals?
# 6.   There are more Gold medals than Silver, and more Silver than Bronze. Why might that be?
# 7.   What are the different NOCs (National Olympic Committees)
# 8.   What does the NOC 'ZZX' represent?

# %% [markdown]
# ## Solution

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %% [markdown]
# 1. What is the time range covered in this dataset?

# %%
oo.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004])

# %% [markdown]
# 2. The Olympics take place every 4 years. Why are there missing years?
# - World War 1: 1914-1918
# - World War 2: 1939-1945

# %% [markdown]
# 3. What are the types of medals awarded?

# %%
oo.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %% [markdown]
# 4. Across all of the Olympics, how many Gold, Silver and Bronze medals have there been?

# %%
oo.Medal.value_counts()
# Out:
# Medal
# Gold      9181
# Silver    9014
# Bronze    8979
# Name: count, dtype: int64

# %% [markdown]
# 5. Why are there not an equal number of Gold, Silver and Bronze medals?
# - Tied results
# - Team events
# - Disqualifications

# %%
oo.head(10)

# %% [markdown]
# 6. There are more Gold medals than Silver, and more Silver than Bronze. Why might that be?
#
# Men's 100km cycling
# - https://en.wikipedia.org/wiki/Cycling_at_the_1896_Summer_Olympics_%E2%80%93_Men%27s_100_kilometres
# - https://en.wikipedia.org/wiki/Aristidis_Konstantinidis
#
# Men's 100m freestyle (1896)
# - https://en.wikipedia.org/wiki/Swimming_at_the_1896_Summer_Olympics_%E2%80%93_Men%27s_100_metre_freestyle

# %% [markdown]
# 7. What are the different NOCs (National Olympic Committees)

# %%
oo.NOC.unique()
# Out:
# array(['FRA', 'GRE', 'USA', 'HUN', 'GER', 'AUT', 'GBR', 'AUS', 'DEN',
#        'ZZX', 'SUI', 'IND', 'NED', 'CAN', 'NOR', 'BEL', 'ESP', 'BOH',
#        'ITA', 'SWE', 'CUB', 'RU1', 'FIN', 'RSA', 'ANZ', 'LUX', 'EST',
#        'BRA', 'JPN', 'TCH', 'NZL', 'ARG', 'HAI', 'POL', 'URU', 'YUG',
#        'ROU', 'POR', 'EGY', 'PHI', 'IRL', 'CHI', 'MEX', 'LAT', 'TUR',
#        'KOR', 'PAN', 'JAM', 'SRI', 'PER', 'PUR', 'IRI', 'TRI', 'URS',
#        'LIB', 'BUL', 'VEN', 'EUA', 'PAK', 'ISL', 'BAH', 'BWI', 'GHA',
#        'IRQ', 'SIN', 'TPE', 'ETH', 'MAR', 'TUN', 'NGR', 'KEN', 'FRG',
#        'MGL', 'GDR', 'UGA', 'CMR', 'PRK', 'COL', 'NIG', 'BER', 'THA',
#        'TAN', 'GUY', 'ZIM', 'ZAM', 'CHN', 'CIV', 'DOM', 'ALG', 'SYR',
#        'SUR', 'CRC', 'SEN', 'AHO', 'DJI', 'ISV', 'INA', 'EUN', 'NAM',
#        'IOP', 'QAT', 'ISR', 'LTU', 'CRO', 'SLO', 'MAS', 'RUS', 'UKR',
#        'TGA', 'ARM', 'BLR', 'MDA', 'ECU', 'KAZ', 'AZE', 'BDI', 'SVK',
#        'CZE', 'UZB', 'GEO', 'MOZ', 'HKG', 'KGZ', 'BAR', 'KSA', 'VIE',
#        'MKD', 'KUW', 'ERI', 'SCG', 'UAE', 'PAR'], dtype=object)

# %% [markdown]
# 8. What does the NOC 'ZZX' represent?
# - https://en.wikipedia.org/wiki/Mixed_teams_at_the_Olympics

# %% [markdown]
# ## Python Lists and Dictionaries

# %%
medals = ["Gold", "Silver", "Bronze"]
medals
# Out:
# ['Gold', 'Silver', 'Bronze']

# %%
type(medals)
# Out:
# list

# %%
position = {"First": "Gold",
            "Second": "Silver",
            "Third": "Bronze"
}
position
# Out:
# {'First': 'Gold', 'Second': 'Silver', 'Third': 'Bronze'}

# %%
type(position)
# Out:
# dict

# %%
position["First"]
# Out:
# 'Gold'

# %% [markdown]
# ## Rename a series (or column)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year      City       Sport Discipline     Athlete Name  NOC Gender  \
# 26663  2004    Athens      Rowing     Rowing  REIMER, Daniela  GER  Women
# 22274  1996   Atlanta     Sailing    Sailing     SKALIN, Igor  RUS    Men
# 14983  1976  Montreal  Equestrian   Dressage  LEHMANN, Ulrich  SUI    Men
#
#                                          Event Event Gender   Medal  Position
# 26663           lightweight double sculls (2x)            W  Silver         2
# 22274  fleet/match race keelboat open (Soling)            X  Silver         2
# 14983                                     team            X  Silver         2

# %%
mapper = {"Athlete Name": "Athlete_Name",
          "Event Gender": "Event_Gender"}

# %%
oo.rename?
# Out:
# Signature:
# oo.rename(
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool | None' = None,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'IgnoreRaise' = 'ignore',
# ) -> 'DataFrame | None'
# Docstring:
# Rename columns or index labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper : dict-like or function
#     Dict-like or function transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# index : dict-like or function
#     Alternative to specifying axis (``mapper, axis=0``
#     is equivalent to ``index=mapper``).
# columns : dict-like or function
#     Alternative to specifying axis (``mapper, axis=1``
#     is equivalent to ``columns=mapper``).
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Axis to target with ``mapper``. Can be either the axis name
#     ('index', 'columns') or number (0, 1). The default is 'index'.
# copy : bool, default True
#     Also copy underlying data.
#
#     .. note::
#         The `copy` keyword will change behavior in pandas 3.0.
#         `Copy-on-Write
#         <https://pandas.pydata.org/docs/dev/user_guide/copy_on_write.html>`__
#         will be enabled by default, which means that all methods with a
#         `copy` keyword will use a lazy copy mechanism to defer the copy and
#         ignore the `copy` keyword. The `copy` keyword will be removed in a
#         future version of pandas.
#
#         You can already get the future behavior and improvements through
#         enabling copy on write ``pd.options.mode.copy_on_write = True``
# inplace : bool, default False
#     Whether to modify the DataFrame rather than creating a new one.
#     If True then value of copy is ignored.
# level : int or level name, default None
#     In case of a MultiIndex, only rename labels in the specified
#     level.
# errors : {'ignore', 'raise'}, default 'ignore'
#     If 'raise', raise a `KeyError` when a dict-like `mapper`, `index`,
#     or `columns` contains labels that are not present in the Index
#     being transformed.
#     If 'ignore', existing keys will be renamed and extra keys will be
#     ignored.
#
# Returns
# -------
# DataFrame or None
#     DataFrame with the renamed axis labels or None if ``inplace=True``.
#
# Raises
# ------
# KeyError
#     If any of the labels is not found in the selected axis and
#     "errors='raise'".
#
# See Also
# --------
# DataFrame.rename_axis : Set the name of the axis.
#
# Examples
# --------
# ``DataFrame.rename`` supports two calling conventions
#
# * ``(index=index_mapper, columns=columns_mapper, ...)``
# * ``(mapper, axis={'index', 'columns'}, ...)``
#
# We *highly* recommend using keyword arguments to clarify your
# intent.
#
# Rename columns using a mapping:
#
# >>> df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
# >>> df.rename(columns={"A": "a", "B": "c"})
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6
#
# Rename index using a mapping:
#
# >>> df.rename(index={0: "x", 1: "y", 2: "z"})
#    A  B
# x  1  4
# y  2  5
# z  3  6
#
# Cast index labels to a different type:
#
# >>> df.index
# RangeIndex(start=0, stop=3, step=1)
# >>> df.rename(index=str).index
# Index(['0', '1', '2'], dtype='object')
#
# >>> df.rename(columns={"A": "a", "B": "b", "C": "c"}, errors="raise")
# Traceback (most recent call last):
# KeyError: ['C'] not found in axis
#
# Using axis-style parameters:
#
# >>> df.rename(str.lower, axis='columns')
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
#
# >>> df.rename({1: 2, 2: 4}, axis='index')
#    A  B
# 0  1  4
# 2  2  5
# 4  3  6
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      method

# %%
oo.rename(columns=mapper)

# %%
oo.sample(3)
# Out:
#        Year       City       Sport  Discipline              Athlete_Name  NOC  \
# 11107  1964      Tokyo  Basketball  Basketball  PEREIRA UBIRATAN, Maciel  BRA
# 13537  1972     Munich      Hockey      Hockey           SINGH, Mukhbain  IND
# 2534   1912  Stockholm  Equestrian     Jumping    DELOCH, Ernst Hubertus  GER
#
#       Gender       Event Event_Gender   Medal  Position
# 11107    Men  basketball            M  Bronze         3
# 13537    Men      hockey            M  Bronze         3
# 2534     Men        team            X  Bronze         3

# %%
oo = oo.rename(columns=mapper)
oo.sample(3)

# %%
oo = pd.read_csv(filename, skiprows=5).rename(columns=mapper)
oo.sample(3)
# Out:
#        Year                   City      Sport  Discipline   Athlete_Name  NOC  \
# 23636  2000                 Sydney  Taekwondo   Taekwondo  LOPEZ, Steven  USA
# 9383   1956  Melbourne / Stockholm    Fencing     Fencing  SOMODI, Lajos  HUN
# 5699   1928              Amsterdam   Aquatics  Water polo  BLANK, Johann  GER
#
#       Gender       Event Event_Gender   Medal  Position
# 23636    Men  58 - 68 kg            M    Gold         1
# 9383     Men   foil team            M  Bronze         3
# 5699     Men  water polo            M    Gold         1

# %%
oo = pd.read_csv(filename, skiprows=5)
oo = oo.rename(columns={"Athlete Name": "Athlete_Name", "Event Gender": "Event_Gender"})
oo.sample(3)

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
#        'Event', 'Event Gender', 'Medal', 'Position'],
#       dtype='object')

# %%
column_names = ['Year', 'City', 'Sport', 'Discipline', 'Athlete_Name', 'NOC', 'Gender',
       'Event', 'Event_Gender', 'Medal', 'Position']
oo.columns = column_names
oo.sample(3)
# Out:
#        Year       City     Sport Discipline          Athlete_Name  NOC Gender  \
# 5363   1928  Amsterdam  Football   Football    PIETROBONI, Silvio  ITA    Men
# 2051   1912  Stockholm  Shooting   Shooting           PALEN, Paul  SWE    Men
# 19727  1992  Barcelona  Aquatics   Swimming  LOPEZ-ZUBERO, Martin  ESP    Men
#
#                                   Event Event_Gender   Medal  Position
# 5363                           football            M  Bronze         3
# 2051   25m rapid fire pistol (60 shots)            M  Silver         2
# 19727                   200m backstroke            M    Gold         1

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)

# %%
oo = pd.read_csv(filename, skiprows=5, names=column_names)
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete_Name  NOC  Gender  \
# 0  Year    City      Sport     Discipline        Athlete Name  NOC  Gender
# 1  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA     Men
# 2  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE     Men
# 3  1896  Athens  Athletics      Athletics       LANE, Francis  USA     Men
# 4  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN     Men
#
#    Event  Event_Gender   Medal  Position
# 0  Event  Event Gender   Medal  Position
# 1  100km             M    Gold         1
# 2  100km             M  Silver         2
# 3   100m             M  Bronze         3
# 4   100m             M  Bronze         3

# %%
oo = pd.read_csv(filename, skiprows=5, names=column_names, header=0)
oo.head()
# Out:
#    Year    City      Sport     Discipline        Athlete_Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event_Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 2   100m            M  Bronze         3
# 3   100m            M  Bronze         3
# 4   100m            M    Gold         1

# %% [markdown]
# ## Remove a Series (column) or row

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.sample(3)
# Out:
#        Year       City       Sport  Discipline             Athlete Name  NOC  \
# 2764   1912  Stockholm  Tug of War  Tug of War  FREDRIKSSON, Erik Algot  SWE
# 15170  1976   Montreal    Aquatics  Water polo           HORKAI, Gyorgy  HUN
# 7361   1948     London    Aquatics    Swimming              NYEKI, Imre  HUN
#
#       Gender                   Event Event Gender   Medal  Position
# 2764     Men              tug of war            M    Gold         1
# 15170    Men              water polo            M    Gold         1
# 7361     Men  4x200m freestyle relay            M  Silver         2

# %%
oo.drop('Position', axis=1)
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal
# 0          100km            M    Gold
# 1          100km            M  Silver
# 2           100m            M  Bronze
# 3           100m            M  Bronze
# 4           100m            M    Gold
# ...          ...          ...     ...
# 27169  épée team            W    Gold
# 27170  épée team            W    Gold
# 27171  épée team            W  Silver
# 27172  épée team            W  Silver
# 27173  épée team            W  Silver
#
# [27174 rows x 10 columns]

# %%
oo.drop('Position', axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 oo.drop('Position', axis=0)
#
# File ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Position'] not found in axis"

# %%
oo.sample(3)

# %%
oo = oo.drop('Position', axis=1)
oo.sample(3)

# %%
oo = pd.read_csv(filename, skiprows=5).drop('Position', axis=1)
oo.sample(3)

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City              Sport       Discipline  \
# 18465  1988      Seoul          Wrestling  Wrestling Free.
# 8382   1952   Helsinki  Modern Pentathlon  Modern Pentath.
# 5203   1928  Amsterdam             Boxing           Boxing
#
#               Athlete Name  NOC Gender                           Event  \
# 18465      MONDAY, Kenneth  USA    Men        68 - 74kg (welterweight)
# 8382   ROKKA, Olavi Antero  FIN    Men                Team competition
# 5203        TOSCANI, Piero  ITA    Men  66.68 - 72.57kg (middleweight)
#
#       Event Gender   Medal
# 18465            M    Gold
# 8382             M  Bronze
# 5203             M    Gold

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year      City     Sport Discipline            Athlete Name  NOC  \
# 8435   1952  Helsinki    Rowing     Rowing  LOGG, Charles Paul Jr.  USA
# 13326  1972    Munich   Sailing    Sailing        WENNERSTRÖ, Stig  SWE
# 11280  1964     Tokyo  Football   Football        NEPOMUCKY, Karel  TCH
#
#       Gender                                    Event Event Gender   Medal
# 8435     Men                        coxless pair (2-)            M    Gold
# 13326    Men  fleet/match race keelboat open (Soling)            X  Silver
# 11280    Men                                 football            M  Silver

# %%
oo = pd.read_csv(filename, skiprows=5)
oo.drop('Position', axis=1, inplace=True)
oo.sample(3)

# %%
#oo = (pd.read_csv(filename, skiprows=5)
#      .drop('Position', axis=1, inplace=True)
#)
#oo.sample(3)

# %%
oo.drop?
# Out:
# Signature:
# oo.drop(
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise',
# ) -> 'DataFrame | None'
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by directly specifying index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the :ref:`user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as a list-like.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
#     columns (1 or 'columns').
# index : single label or list-like
#     Alternative to specifying axis (``labels, axis=0``
#     is equivalent to ``index=labels``).
# columns : single label or list-like
#     Alternative to specifying axis (``labels, axis=1``
#     is equivalent to ``columns=labels``).
# level : int or level name, optional
#     For MultiIndex, level from which the labels will be removed.
# inplace : bool, default False
#     If False, return a copy. Otherwise, do operation
#     in place and return None.
# errors : {'ignore', 'raise'}, default 'raise'
#     If 'ignore', suppress error and only existing labels are
#     dropped.
#
# Returns
# -------
# DataFrame or None
#     Returns DataFrame or None DataFrame with the specified
#     index or column labels removed or None if inplace=True.
#
# Raises
# ------
# KeyError
#     If any of the labels is not found in the selected axis.
#
# See Also
# --------
# DataFrame.loc : Label-location based indexer for selection by label.
# DataFrame.dropna : Return DataFrame with labels on given axis omitted
#     where (all or any) data are missing.
# DataFrame.drop_duplicates : Return DataFrame with duplicate rows
#     removed, optionally only considering certain columns.
# Series.drop : Return Series with specified index labels removed.
#
# Examples
# --------
# >>> df = pd.DataFrame(np.arange(12).reshape(3, 4),
# ...                   columns=['A', 'B', 'C', 'D'])
# >>> df
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11
#
# Drop columns
#
# >>> df.drop(['B', 'C'], axis=1)
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11
#
# >>> df.drop(columns=['B', 'C'])
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11
#
# Drop a row by index
#
# >>> df.drop([0, 1])
#    A  B   C   D
# 2  8  9  10  11
#
# Drop columns and/or rows of MultiIndex DataFrame
#
# >>> midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],
# ...                              ['speed', 'weight', 'length']],
# ...                      codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
# ...                             [0, 1, 2, 0, 1, 2, 0, 1, 2]])
# >>> df = pd.DataFrame(index=midx, columns=['big', 'small'],
# ...                   data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
# ...                         [250, 150], [1.5, 0.8], [320, 250],
# ...                         [1, 0.8], [0.3, 0.2]])
# >>> df
#                 big     small
# llama   speed   45.0    30.0
#         weight  200.0   100.0
#         length  1.5     1.0
# cow     speed   30.0    20.0
#         weight  250.0   150.0
#         length  1.5     0.8
# falcon  speed   320.0   250.0
#         weight  1.0     0.8
#         length  0.3     0.2
#
# Drop a specific index combination from the MultiIndex
# DataFrame, i.e., drop the combination ``'falcon'`` and
# ``'weight'``, which deletes only the corresponding row
#
# >>> df.drop(index=('falcon', 'weight'))
#                 big     small
# llama   speed   45.0    30.0
#         weight  200.0   100.0
#         length  1.5     1.0
# cow     speed   30.0    20.0
#         weight  250.0   150.0
#         length  1.5     0.8
# falcon  speed   320.0   250.0
#         length  0.3     0.2
#
# >>> df.drop(index='cow', columns='small')
#                 big
# llama   speed   45.0
#         weight  200.0
#         length  1.5
# falcon  speed   320.0
#         weight  1.0
#         length  0.3
#
# >>> df.drop(index='length', level=1)
#                 big     small
# llama   speed   45.0    30.0
#         weight  200.0   100.0
# cow     speed   30.0    20.0
#         weight  250.0   150.0
# falcon  speed   320.0   250.0
#         weight  1.0     0.8
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      method

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year      City      Sport Discipline    Athlete Name  NOC Gender  \
# 23565  2000    Sydney  Athletics  Athletics   WOLDE, Millon  ETH    Men
# 8526   1952  Helsinki   Football   Football  LÖFGREN, Gösta  SWE    Men
# 26101  2004    Athens     Rowing     Rowing  TOMKINS, James  AUS    Men
#
#                    Event Event Gender   Medal
# 23565              5000m            M    Gold
# 8526            football            M  Bronze
# 26101  coxless pair (2-)            M    Gold

# %%
oo.head(3)

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop(2, axis=0)
)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
#
#    Event Event Gender   Medal  Position
# 0  100km            M    Gold         1
# 1  100km            M  Silver         2
# 3   100m            M  Bronze         3

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop([0, 1, 3], axis=0)
)
oo.head(3)

# %%
oo = oo.drop(['City', 'Sport'], axis=1)
oo.head(3)

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year       City    Sport     Discipline               Athlete Name  \
# 5263   1928  Amsterdam  Cycling  Cycling Track           BEAUFRAND, Roger
# 10284  1960       Rome  Sailing        Sailing  PETERSEN, Ole Erik Gunnar
# 8842   1952   Helsinki  Sailing        Sailing              REID, John S.
#
#        NOC Gender                            Event Event Gender   Medal
# 5263   FRA    Men                  Sprint indivual            M    Gold
# 10284  DEN    Men                  flying dutchman            X  Silver
# 8842   USA    Men  two-person keelboat open (Star)            X  Silver

# %%
pd.merge?

# %%
pd.concat?

# %%
oo.groupby?

# %% [markdown]
# ## Filtering rows for a single condition

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)

# %%
type(True)

# %%
type(False)

# %%
oo.Year.dtype
# Out:
# dtype('int64')

# %%
type(oo.Year)
# Out:
# pandas.core.series.Series

# %%
first_olympics = (oo.Year == 1896)
first_olympics
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 27169    False
# 27170    False
# 27171    False
# 27172    False
# 27173    False
# Name: Year, Length: 27174, dtype: bool

# %%
oo[first_olympics]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# 1      Men        100km            M  Silver
# 2      Men         100m            M  Bronze
# 3      Men         100m            M  Bronze
# 4      Men         100m            M    Gold
# ..     ...          ...          ...     ...
# 146    Men  triple jump            M    Gold
# 147    Men  triple jump            M  Silver
# 148    Men        vault            M  Bronze
# 149    Men        vault            M    Gold
# 150    Men        vault            M  Silver
#
# [151 rows x 10 columns]

# %%
oo[oo.Year == 1896]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# 1      Men        100km            M  Silver
# 2      Men         100m            M  Bronze
# 3      Men         100m            M  Bronze
# 4      Men         100m            M    Gold
# ..     ...          ...          ...     ...
# 146    Men  triple jump            M    Gold
# 147    Men  triple jump            M  Silver
# 148    Men        vault            M  Bronze
# 149    Men        vault            M    Gold
# 150    Men        vault            M  Silver
#
# [151 rows x 10 columns]

# %%
oo[oo.Year < 1896]

# %%
oo[(oo.Year <= 1896)]
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     Cycling  Cycling Track         FLAMENG, Léon  FRA
# 1    1896  Athens     Cycling  Cycling Track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   Athletics      Athletics         LANE, Francis  USA
# 3    1896  Athens   Athletics      Athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   Athletics      Athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   Athletics      Athletics       CONNOLLY, James  USA
# 147  1896  Athens   Athletics      Athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  Gymnastics    Artistic G.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  Gymnastics    Artistic G.        SCHUMANN, Carl  GER
# 150  1896  Athens  Gymnastics    Artistic G.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# 1      Men        100km            M  Silver
# 2      Men         100m            M  Bronze
# 3      Men         100m            M  Bronze
# 4      Men         100m            M    Gold
# ..     ...          ...          ...     ...
# 146    Men  triple jump            M    Gold
# 147    Men  triple jump            M  Silver
# 148    Men        vault            M  Bronze
# 149    Men        vault            M    Gold
# 150    Men        vault            M  Silver
#
# [151 rows x 10 columns]

# %% [markdown]
# ## Filter rows for multiple conditions

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.tail(3)
# Out:
#        Year    City    Sport Discipline       Athlete Name  NOC Gender  \
# 27171  2004  Athens  Fencing    Fencing     BOKEL, Claudia  GER  Women
# 27172  2004  Athens  Fencing    Fencing    DUPLITZER, Imke  GER  Women
# 27173  2004  Athens  Fencing    Fencing  HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal
# 27171  épée team            W  Silver
# 27172  épée team            W  Silver
# 27173  épée team            W  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
oo[oo.City == 'Athens']

# %%
#oo[oo.City == Athens]

# %%
oo[(oo.Year == 1896) | (oo.Year == 2004)]
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal
# 0          100km            M    Gold
# 1          100km            M  Silver
# 2           100m            M  Bronze
# 3           100m            M  Bronze
# 4           100m            M    Gold
# ...          ...          ...     ...
# 27169  épée team            W    Gold
# 27170  épée team            W    Gold
# 27171  épée team            W  Silver
# 27172  épée team            W  Silver
# 27173  épée team            W  Silver
#
# [2149 rows x 10 columns]

# %%
oo[(oo.City == 'Athens') & (oo.Year == 2004)]

# %%
oo[(oo.City == 'Athens') & ~(oo.Year == 1896)]

# %%
first_men_100m = oo[(oo.Year == 1896) & (oo.Gender == 'Men') & (oo.Event == '100m')]
first_men_100m
# Out:
#    Year    City      Sport Discipline      Athlete Name  NOC Gender Event  \
# 2  1896  Athens  Athletics  Athletics     LANE, Francis  USA    Men  100m
# 3  1896  Athens  Athletics  Athletics  SZOKOLYI, Alajos  HUN    Men  100m
# 4  1896  Athens  Athletics  Athletics     BURKE, Thomas  USA    Men  100m
# 5  1896  Athens  Athletics  Athletics    HOFMANN, Fritz  GER    Men  100m
#
#   Event Gender   Medal
# 2            M  Bronze
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver

# %%
oo[(oo.Year == 1896) & (oo.Gender == 'Men') & (oo.Event == '100m')][["Year", "Athlete Name", "NOC", "Event", "Medal"]]
# Out:
#    Year      Athlete Name  NOC Event   Medal
# 2  1896     LANE, Francis  USA  100m  Bronze
# 3  1896  SZOKOLYI, Alajos  HUN  100m  Bronze
# 4  1896     BURKE, Thomas  USA  100m    Gold
# 5  1896    HOFMANN, Fritz  GER  100m  Silver

# %%
first_men_100m[["Year", "Athlete Name", "NOC", "Event", "Medal"]]
# Out:
#    Year      Athlete Name  NOC Event   Medal
# 2  1896     LANE, Francis  USA  100m  Bronze
# 3  1896  SZOKOLYI, Alajos  HUN  100m  Bronze
# 4  1896     BURKE, Thomas  USA  100m    Gold
# 5  1896    HOFMANN, Fritz  GER  100m  Silver

# %% [markdown]
# ## Using String methods

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# zsh:1: /Users/owenyaggy/code/pandas-esst/linkedin/bin/pip: bad interpreter: /Users/owenyaggy/code/pandas-essential-training-new-dataset-dupe-4493047/linkedin/bin/python3: no such file or directory
# WARNING: You are using pip version 21.3.1; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Installed all of the necessary files for this section ...

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.head(3)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
#
#    Event Event Gender   Medal
# 0  100km            M    Gold
# 1  100km            M  Silver
# 2   100m            M  Bronze

# %%
oo["Athlete Name"].str.lower()
# Out:
# 0             flameng, léon
# 1        kolettis, georgios
# 2             lane, francis
# 3          szokolyi, alajos
# 4             burke, thomas
#                 ...
# 27169    logounova, tatiana
# 27170         sivkova, anna
# 27171        bokel, claudia
# 27172       duplitzer, imke
# 27173     heidemann, britta
# Name: Athlete Name, Length: 27174, dtype: object

# %%
oo.Event.unique()
# Out:
# array(['100km', '100m', '100m freestyle', '100m freestyle for sailors',
#        '10km', '110m hurdles', '12-hour race', '1200m freestyle', '1500m',
#        '1km time trial', '25m army pistol',
#        '25m rapid fire pistol (60 shots)', '400m', '400m freestyle',
#        '50m pistol (60 shots)', '800m', 'Sprint indivual',
#        'army rifle, 200m', 'army rifle, 300m', 'discus throw', 'doubles',
#        'foil individual', 'foil, masters', 'heavyweight - one hand lift',
#        'heavyweight - two hand lift', 'high jump', 'horizontal bar',
#        'individual road race', 'long jump', 'marathon', 'open event',
#        'parallel bars', 'pole vault', 'pommel horse', 'rings',
#        'rope climbing', 'sabre individual', 'shot put', 'singles',
#        'team, horizontal bar', 'team, parallel bars', 'triple jump',
#        'vault', '0.5-1t', '10-20t', '1500m freestyle', '200m',
#        '200m backstroke', '200m freestyle', '200m hurdles',
#        '200m obstacle event', '200m team swimming', '25 kilometres',
#        '3-10t', '3000m steeplechase', '4000m freestyle',
#        '4000m steeplechase', '400m hurdles', '5000m team',
#        '50m army pistol, team', '60m', 'army rifle, 300m, 3 positions',
#        'army rifle, 300m, kneeling', 'army rifle, 300m, prone',
#        'army rifle, 300m, standing', 'au chapelet, 33m',
#        'au chapelet, 50m', 'au cordon doré, 33m', 'au cordon doré, 50m',
#        'cesta punta', 'cricket', 'double', 'eight with coxswain (8+)',
#        'football', 'four-oared shell with coxswain (4-)',
#        'free rifle, team', 'hammer throw', 'high jump, standing',
#        'individual', 'individual 1 ball', 'individual 2 balls',
#        'individual all-round', 'long jump individual',
#        'long jump, standing', 'mixed doubles', 'open class',
#        'pair-oared shell with coxswain (2+)', 'polo', 'rugby',
#        'sabre, masters', 'single sculls (1x)', 'sur la perche à la herse',
#        'sur la perche à la pyramide', 'trap (125 targets)',
#        'triple jump, standing', 'tug of war', 'underwater swimming',
#        'water polo', 'épée individual', 'épée, amateurs and masters',
#        'épée, masters', '+ 71.67kg (heavyweight)',
#        '- 47.63kg (flyweight)', '- 47.6kg (light-flyweight)',
#        '1 mile (1609.3m)', '1/2 mile (804.7m)', '1/3 mile (536.5m)',
#        '1/4 mile (402.3m)', '100m backstroke', '10m platform',
#        '2 miles (3.218km)', '25 miles (40.232km)', '400m breaststroke',
#        '47.6 - 52.16kg (flyweight)', '47.63 - 52.16kg (bantamweight)',
#        '4miles team', '4x50y freestyle relay', '5 miles (8.046km)',
#        '50y freestyle (45.72m)', '52.16 - 56.7kg (bantamweight)',
#        '52.16 - 56.7kg (featherweight)', '56.7 - 61.23kg (featherweight)',
#        '56.7 - 61.24kg (lightweight)', '56lb weight throw (25.4kg)',
#        '61.23 - 65.77kg (lightweight)', '61.24 - 65.77kg (welterweight)',
#        '65.77 - 71.67kg (middleweight)', '65.77 - 71.67kg (welterweight)',
#        '880y freestyle (804.66m)', 'all-around Dumbbell contest',
#        'club swinging', 'combined 3 events', 'combined 4 events',
#        'coxless pair (2-)', 'decathlon',
#        'double american round (60y - 50y - 40y)',
#        'double columbia round (50y - 40y - 30y)',
#        'double national round (60y - 50y)', 'double sculls (2x)',
#        'double york round (100y - 80y - 60y)', 'foil team',
#        'four without coxswain (4-)', 'lacrosse', 'plunge for distance',
#        'stick, single', 'team', 'team competition', 'team round 60y',
#        'teams FITA round', 'triathlon (long jump / shot put / 100 yards)',
#        '+ 73kg (heavyweight)', '+ 93kg (super heavyweight)',
#        '- 52.62kg (bantamweight)', '- 54kg (bantamweight)',
#        '- 66.6kg (lightweight)', '1000y free rifle, prone',
#        '100m running deer, double shots',
#        '100m running deer, single shots',
#        '100m running deer, single shots, team', '10miles walk (16093m)',
#        '12m', '1980 yards Pursuit, Team', '2000m tandem',
#        '200m breaststroke', '20km',
#        '25y small bore rifle, disappearing target',
#        '25y small bore rifle, moving target',
#        '300m free rifle 3 positions (3x40 shots)', '3200m steeplechase',
#        '3500m walk', '3m springboard', '3miles team (4828m)',
#        '4x200m freestyle relay', '4x400m relay', '5 miles (8047m)',
#        '50+100y small bore rifle, team', '5000m',
#        '50m rifle prone (60 shots)', '50y army pistol, team',
#        '52.62 - 57.15kg (featherweight)', '54 - 60.3kg (featherweight)',
#        '57.15 - 63.5kg (lightweight)', '60.3 - 66.6kg (lightweight)',
#        '63.5 - 71.67kg (middleweight)', '66.6 - 73kg (middleweight)',
#        '6m', '73 - 93kg (light-heavyweight)', '7m', '8m', '8m class C',
#        'One lap (660y) sprint', 'class B up to 60 feet',
#        'clay pigeons, team', 'continental style 50m',
#        'discus throw ancient style', 'doubles indoor', 'hockey',
#        'javelin throw', 'javelin throw freestyle',
#        'national round (60y - 50y)', 'open class A', 'pairs',
#        'rifle, team', 'sabre team', 'singles indoor', 'special figures',
#        'york round (100y - 80y - 60y)', 'épée team',
#        '+ 82.5kg (super heavyweight)', '- 60kg (featherweight)', '10000m',
#        '10000m walk', '10m', '25m small bore rifle, team',
#        '25m small rifle', '3000m team', '30m army pistol, team',
#        '4x100m freestyle relay', '4x100m relay',
#        '50m small bore rifle, team', '60 - 67.5kg (lightweight)',
#        '600m free rifle', '67.5 - 75kg (middleweight)',
#        '75 - 82.5kg (light-heavyweight)', 'Individual competition',
#        'coxed fours Jugriggers', 'cross country individual',
#        'cross country team', 'discus throw, both hands',
#        'individual time trial', 'javelin throw, both hands',
#        'mixed doubles indoor', 'pentathlon', 'plain high diving',
#        'shot put, both hands', 'team time trial', 'team, Swedish system',
#        'team, free system', '+ 79.38kg (heavyweight)',
#        '+ 80kg (heavyweight)',
#        '+ 82.5kg, one-two hand 3 events (heavyweight)',
#        '+ 82kg (super heavyweight)', '- 50.8kg (flyweight)',
#        '- 60kg, one-two hand 3 events (featherweight)',
#        '100m running deer, double shots, team', '10m (rating 1907)',
#        '10m (rating 1919)', '12 foot dinghy', '12m (rating 1907)',
#        '12m (rating 1919)', '18 foot dinghy',
#        '300+600m free rifle, team, prone', '3000m walk',
#        '300m free rifle, prone, team', '300m free rifle, standing, team',
#        '30m sq', '40m sq', '50.8 - 53.52kg (bantamweight)', '50km',
#        '50m small bore rifle, standing, individual',
#        '53.52 - 57.15kg (featherweight)', '57.15 - 61.24kg (lightweight)',
#        '6.5m (rating 1919)',
#        '60 - 67.5kg, one-two hand 3 events (lightweight)',
#        '600m free rifle, prone', '600m free rifle, team',
#        '61.24 - 66.68kg (welterweight)', '66.68 - 72.57kg (middleweight)',
#        '67.5 - 75kg, one-two hand 3 events (middleweight)',
#        '6m (rating 1907)', '6m (rating 1919)',
#        '72.57 - 79.38kg (light-heavyweight)',
#        '75 - 80kg (light-heavyweight)',
#        '75 - 82.5kg, one-two hand 3 e. (light-heavyweight)',
#        '75 - 82kg (light-heavyweight)', '8m (rating 1907)',
#        '8m (rating 1919)', 'Team Pursuit (4000m)',
#        'figure riding individual', 'figure riding team',
#        'fixed bird target large birds',
#        'fixed bird target large birds teams',
#        'fixed bird target small bird, teams',
#        'fixed bird target small birds', 'ice hockey',
#        'moving bird target 28m teams', 'moving bird target 33m teams',
#        'moving bird target 50m teams', 'moving bird target, 28m',
#        'moving bird target, 33m', 'moving bird target, 50m',
#        '+ 82.5kg, one-two hand 5 events (heavyweight)',
#        '+ 87kg (heavyweight)', '- 56kg (bantamweight)',
#        '- 58kg (bantamweight)',
#        '- 60kg, one-two hand 5 events (featherweight)',
#        '400, 600, 800m free rifle, team', '56 - 61kg (featherweight)',
#        '58 - 62kg (featherweight)',
#        '60 - 67.5kg, one-two hand 5 events (lightweight)',
#        '600m free rifle, individual', '61 - 66kg (lightweight)',
#        '62 - 67.5kg (lightweight)', '66 - 72kg (welterweight)',
#        '67.5 - 75kg, one-two hand 5 events (middleweight)',
#        '72 - 79kg (middleweight)',
#        '75 - 82.5kg, one-two hand 5 e. (light-heavyweight)',
#        '79 - 87kg (light-heavyweight)', 'Sidehorse vault',
#        'olympic class monotype', '+ 82.5kg, total (heavyweight)',
#        '- 60kg, total (featherweight)', '12 foot dinghy individual',
#        '1km Pursuit', '58 - 60kg (featherweight)',
#        '60 - 67.5kg, total (lightweight)',
#        '67.5 - 75kg, total (middleweight)',
#        '75 - 82.5kg, total (light-heavyweight)',
#        '+ 87kg (super heavyweight)', '50.8 - 54kg (bantamweight)',
#        '50km walk', '54 - 57.15kg (featherweight)', '80m hurdles',
#        'floor exercises', 'indian clubs', 'tumbling',
#        'two-person keelboat open (Star)', 'C-1 1000m (canoe single)',
#        'C-2 10000m', 'C-2 1000m (canoe double)', 'K-1 10000m',
#        'K-1 1000m (kayak single)', 'K-2 10000m',
#        'K-2 1000m (kayak double)', 'basketball', 'folding K-1 10000m',
#        'folding K-2 10000m', 'handball', '- 51kg (flyweight)',
#        '- 52kg (flyweight)', '- 56kg, total (bantamweight)',
#        '51 - 54kg (bantamweight)', '52 - 57kg (bantamweight)',
#        '54 - 58kg (featherweight)', '56 - 60kg, total (featherweight)',
#        '57 - 61kg (featherweight)', '57 - 63kg (featherweight)',
#        '58 - 62kg (lightweight)', '61 - 67kg (lightweight)',
#        '62 - 67kg (welterweight)', '63 - 67kg (lightweight)',
#        '67 - 73kg (middleweight)', '67 - 73kg (welterweight)',
#        '73 - 79kg (middleweight)', '73 - 80kg (light-heavyweight)',
#        'C-1 10000m', 'K-1 500m (kayak single)', 'dragon', 'firefly class',
#        'swallow (golondrina)', '+ 81kg (heavyweight)',
#        '+ 90kg, total (heavyweight)',
#        '100m running deer, single/double shots', '5.5m',
#        '50m rifle 3 positions (3x40 shots)', '54 - 57kg (featherweight)',
#        '57 - 60kg (lightweight)', '60 - 63.5kg (light-welterweight)',
#        '63.5 - 67kg (welterweight)', '67 - 71kg (light-middleweight)',
#        '71-75kg', '75 - 81kg (light-heavyweight)',
#        '82.5 - 90kg, total (middle-heavyweight)', 'Team competition',
#        'balance beam', 'single-handed dinghy (Finn)',
#        'team, portable apparatus', 'uneven bars', '100m butterfly',
#        '200m butterfly', '20km walk', 'sharpie 12m2',
#        '4x100m medley relay', 'K-1 4x500m', 'K-2 500m (kayak double)',
#        'flying dutchman', '+ 97kg (heavyweight)',
#        '+ 97kg (super heavyweight)', '- 68kg (lightweight)',
#        '400m individual medley', '63 - 70kg (lightweight)',
#        '68 - 80kg (middleweight)', '70 - 78kg (welterweight)',
#        '78 - 87kg (middleweight)', '87 - 97kg (light-heavyweight)',
#        'Individual Pursuit', 'K-4 1000m (kayak four)', 'open category',
#        'volleyball', '- 48kg (light-flyweight)', '100m breaststroke',
#        '200m individual medley', '48 - 51kg (flyweight)',
#        '800m freestyle', 'skeet (125 targets)',
#        '+ 100kg (super heavyweight)',
#        '+ 110kg, total (super heavyweight)', '+ 93kg (heavyweight)',
#        '- 52kg, total (flyweight)', '- 63kg (lightweight)',
#        '100m hurdles', '48 - 52kg (flyweight)',
#        '50m running target (30+30 shots)',
#        '52 - 56kg, total (bantamweight)', '57 - 62kg (featherweight)',
#        '62 - 68kg (lightweight)', '63 - 70kg (half-middleweight)',
#        '68 - 74kg (welterweight)', '70 - 80kg (middleweight)',
#        '74 - 82kg (middleweight)', '80 - 93kg (half-heavyweight)',
#        '82 - 90kg (light-heavyweight)', '90 - 100kg (heavyweight)',
#        '91 - 110kg, total (heavyweight)', 'C-1 (canoe single)',
#        'C-2 (canoe double)', 'K-1 (kayak single)',
#        'fleet/match race keelboat open (Soling)', 'individual FITA round',
#        'tempest', '470 - Two Person Dinghy', 'C-1 500m (canoe single)',
#        'C-2 500m (canoe double)', 'Tornado - Multihull',
#        'pair without coxswain (2-)',
#        'quadruple sculls with coxswain (4x)',
#        'quadruple sculls without coxswain (4x)', '+ 95kg (heavyweight)',
#        '- 60 kg', '100 - 110kg, total (heavyweight)',
#        '60 - 65kg (half-lightweight)', '65 - 71kg (lightweight)',
#        '71 - 78kg (half-middleweight)', '78 - 86kg (middleweight)',
#        '86 - 95kg (half-heavyweight)',
#        '90 - 100kg, total (first-heavyweight)',
#        '+ 91kg (super heavyweight)', '10m air rifle (40 shots)',
#        '10m air rifle (60 shots)', '25m pistol (30+30 shots)', '3000m',
#        '50m rifle 3 positions (3x20 shots)', '81 - 91kg (heavyweight)',
#        'K-4 500m (kayak four)', 'Points Race', 'board (windglider)',
#        'duet', 'heptathlon', 'solo', '100 - 130kg (super heavyweight)',
#        '10m air pistol (40 shots)', '10m air pistol (60 shots)',
#        '50m freestyle', 'board (division II)', 'sprint',
#        '+ 72kg (heavyweight)', '- 48kg (extra-lightweight)',
#        '48 - 52kg (half-lightweight)', '52 - 56kg (lightweight)',
#        '56 - 61kg (half-middleweight)', '61 - 66kg (middleweight)',
#        '66 - 72kg (half-heavyweight)', 'baseball', 'board (lechner)',
#        'coxless four (4-)', 'individual (FITA Olympic round - 70m)',
#        'individual pursuit', 'single-handed dinghy (Europe)',
#        'team (FITA Olympic round - 70m)', '+ 100kg (heavyweight)',
#        '+ 108kg, total (super heavyweight)', '- 54kg, total (flyweight)',
#        '54 - 59kg, total (bantamweight)',
#        '59 - 64kg, total (featherweight)', '60 - 66kg (half-lightweight)',
#        '64 - 70kg, total (lightweight)', '66 - 73kg (lightweight)',
#        '70 - 76kg, total (middleweight)', '73 - 81kg (half-middleweight)',
#        '76 - 83kg, total (light-heavyweight)', '81 - 90kg (middleweight)',
#        '83 - 91kg, total (middle-heavyweight)',
#        '90 - 100kg (half-heavyweight)',
#        '91 - 99kg, total (first-heavyweight)',
#        '99 - 108kg, total (heavyweight)', 'beach volleyball',
#        'board (Mistral)', 'cross-country', 'double trap (120 targets)',
#        'double trap (150 targets)', 'group competition',
#        'lightweight coxless four (4-)', 'lightweight double sculls (2x)',
#        'points race', 'single-handed dinghy open (Laser)', 'softball',
#        '+ 105kg', '+ 67 kg', '+ 75kg', '+ 78kg (heavyweight)', '+ 80 kg',
#        '- 49 kg', '- 58 kg', '105kg', '10m running target (30+30 shots)',
#        '20km race walk', '48 - 54kg', '48kg', '49 - 57 kg',
#        '49er - Skiff', '500m time trial', '52 - 57kg (lightweight)',
#        '53kg', '54 - 58kg', '56kg', '57 - 63kg (half-middleweight)',
#        '57 - 67 kg', '58 - 63kg', '58 - 68 kg', '58kg', '62kg',
#        '63 - 69kg', '63 - 70kg (middleweight)', '63kg', '68 - 80 kg',
#        '69 - 76kg', '69kg', '70 - 78kg (half-heavyweight)', '75kg',
#        '76 - 85kg', '77kg', '85 - 97kg', '85kg', '94kg', '97 - 130kg',
#        'Individual', 'Keirin', 'Madison', 'Olympic Sprint',
#        'skeet (75 targets)', 'synchronized diving 10m platform',
#        'synchronized diving 3m springboard', 'trap (75 targets)',
#        '- 48 kg', '- 48kg', '- 55kg', '48 - 55kg',
#        '48kg (light flywieght)', '55 - 60kg', '55 - 63kg', '60 - 64 kg',
#        '60 - 66kg', '63 - 72kg', '64 - 69 kg', '66 - 74kg', '69 - 75 kg',
#        '74 - 84kg', '84 - 96kg', '96 - 120kg', 'Star - Keelboat',
#        'Team Sprint', 'Yngling - Keelboat'], dtype=object)

# %%
oo.Event.str.capitalize()

# %%
oo.Event = oo.Event.str.capitalize()
oo.Event.unique()

# %%
dir(oo.Event.str)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__frozen',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_data',
#  '_doc_args',
#  '_freeze',
#  '_get_series_list',
#  '_index',
#  '_inferred_dtype',
#  '_is_categorical',
#  '_is_string',
#  '_name',
#  '_orig',
#  '_parent',
#  '_validate',
#  '_wrap_result',
#  'capitalize',
#  'casefold',
#  'cat',
#  'center',
#  'contains',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'extract',
#  'extractall',
#  'find',
#  'findall',
#  'fullmatch',
#  'get',
#  'get_dummies',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'islower',
#  'isnumeric',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'len',
#  'ljust',
#  'lower',
#  'lstrip',
#  'match',
#  'normalize',
#  'pad',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'repeat',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'slice',
#  'slice_replace',
#  'split',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'wrap',
#  'zfill']

# %%
oo["Athlete Name"].str.contains("Latynina")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 27169    False
# 27170    False
# 27171    False
# 27172    False
# 27173    False
# Name: Athlete Name, Length: 27174, dtype: bool

# %%
# Larisa Latynina - most decorated Female athlete
oo[oo["Athlete Name"].str.contains("Latynina")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo[oo["Athlete Name"].str.contains("LATYNINA")]
# Out:
#        Year                   City       Sport   Discipline      Athlete Name  \
# 9372   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9539   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9679   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9702   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9735   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 9741   1956  Melbourne / Stockholm  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10179  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10277  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10458  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10576  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10612  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 10616  1960                   Rome  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11095  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11195  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11387  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11517  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11551  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
# 11558  1964                  Tokyo  Gymnastics  Artistic G.  LATYNINA, Larisa
#
#        NOC Gender                     Event Event Gender   Medal
# 9372   URS  Women           floor exercises            W    Gold
# 9539   URS  Women      individual all-round            W    Gold
# 9679   URS  Women          team competition            W    Gold
# 9702   URS  Women  team, portable apparatus            W  Bronze
# 9735   URS  Women               uneven bars            W  Silver
# 9741   URS  Women                     vault            W    Gold
# 10179  URS  Women              balance beam            W  Silver
# 10277  URS  Women           floor exercises            W    Gold
# 10458  URS  Women      individual all-round            W    Gold
# 10576  URS  Women          team competition            W    Gold
# 10612  URS  Women               uneven bars            W  Silver
# 10616  URS  Women                     vault            W  Bronze
# 11095  URS  Women              balance beam            W  Bronze
# 11195  URS  Women           floor exercises            W    Gold
# 11387  URS  Women      individual all-round            W  Silver
# 11517  URS  Women          team competition            W    Gold
# 11551  URS  Women               uneven bars            W  Bronze
# 11558  URS  Women                     vault            W  Silver

# %%
dir(oo.Event.str)

# %%
oo.City = oo.City.str.upper()
oo.sample(3)
# Out:
#        Year         City      Sport Discipline        Athlete Name  NOC  \
# 18047  1984  LOS ANGELES    Fencing    Fencing  HENRY, Jean-Michel  FRA
# 19956  1992    BARCELONA  Athletics  Athletics       WATTS, Quincy  USA
# 26369  2004       ATHENS     Rowing     Rowing    WILLIAMS, Barney  CAN
#
#       Gender                       Event Event Gender   Medal
# 18047    Men                   épée team            M  Silver
# 19956    Men                4x400m relay            M    Gold
# 26369    Men  four without coxswain (4-)            M  Silver

# %%
oo.City.unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney'],
#       dtype=object)

# %% [markdown]
# ## Sorting a DataFrame or Series

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year         City     Sport Discipline       Athlete Name  NOC Gender  \
# 17153  1984  Los Angeles   Sailing    Sailing        GLASER, Jay  USA    Men
# 24344  2000       Sydney  Football   Football       FOUDY, Julie  USA  Women
# 2366   1912    Stockholm    Rowing     Rowing  ARNHEITER, Albert  GER    Men
#
#                                      Event Event Gender   Medal
# 17153                  Tornado - Multihull            X  Silver
# 24344                             football            W  Silver
# 2366   four-oared shell with coxswain (4-)            M    Gold

# %%
oo["Athlete Name"].sort_values()
# Out:
# 611                 AABYE, Edgar
# 3060       AALTONEN, Arvo Ossian
# 2963       AALTONEN, Arvo Ossian
# 7792    AALTONEN, Paavo Johannes
# 7906    AALTONEN, Paavo Johannes
#                   ...
# 275                   ÖSTMO, Ole
# 443                   ÖSTMO, Ole
# 280                   ÖSTMO, Ole
# 268                   ÖSTMO, Ole
# 8125           ÖSTRAND, Per-Olof
# Name: Athlete Name, Length: 27174, dtype: object

# %%
type(oo["Athlete Name"].sort_values())

# %%
oo.sort_values("Athlete Name")

# %%
type(oo.sort_values("Athlete Name"))

# %%
oo.head(3)

# %%
oo.sort_values("Athlete Name", ascending=False)

# %%
oo.sort_values("Athlete Name", ascending=False).head(25)

# %%
oo.sort_values(by=['Year','Athlete Name'])

# %%
oo.sort_values(by=["Year", "Athlete Name"], ascending=[False, True])

# %%
oo.head(7)

# %%
oo.sort_values(by=["Year", "Event", "Medal"], ascending=[True, True, False]).head(7)

# %%
oo.dtypes

# %% [markdown]
# ## Working with data types (dtype)

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year     City     Sport Discipline          Athlete Name  NOC Gender  \
# 21787  1996  Atlanta    Boxing     Boxing    IBZAIMOV, Ezmouhan  KAZ    Men
# 4326   1924    Paris  Aquatics   Swimming  PERSSON, O. Gösta A.  SWE    Men
# 23299  2000   Sydney  Aquatics   Swimming         KOWAL, Kristy  USA  Women
#
#                                 Event Event Gender   Medal
# 21787  67 - 71kg (light-middleweight)            M  Bronze
# 4326           4x200m freestyle relay            M  Bronze
# 23299               200m breaststroke            W  Silver

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
oo.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
oo.Medal = oo.Medal.astype("category")
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender            object
# Event             object
# Event Gender      object
# Medal           category
# dtype: object

# %%
oo.Gender.unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
oo['Event Gender'].unique()
# Out:
# array(['M', 'X', 'W'], dtype=object)

# %%
oo.Gender = oo.Gender.astype("category")
oo['Event Gender'] = oo['Event Gender'].astype("category")
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender          category
# Event             object
# Event Gender    category
# Medal           category
# dtype: object

# %%
oo.Medal.astype("category")
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3        Bronze
# 4          Gold
#           ...
# 27169      Gold
# 27170      Gold
# 27171    Silver
# 27172    Silver
# 27173    Silver
# Name: Medal, Length: 27174, dtype: category
# Categories (3, object): ['Bronze', 'Gold', 'Silver']

# %%
pd.Categorical?

# %%
medal_order = ["Bronze", "Silver", "Gold"]
pd.Categorical(oo.Medal, categories=medal_order, ordered=True)
# Out:
# ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold', ..., 'Gold', 'Gold', 'Silver', 'Silver', 'Silver']
# Length: 27174
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %%
oo.Medal = pd.Categorical(oo.Medal, categories=medal_order, ordered=True)
oo.dtypes
# Out:
# Year               int64
# City              object
# Sport             object
# Discipline        object
# Athlete Name      object
# NOC               object
# Gender            object
# Event             object
# Event Gender      object
# Medal           category
# dtype: object

# %%
oo.Medal
# Out:
# 0          Gold
# 1        Silver
# 2        Bronze
# 3        Bronze
# 4          Gold
#           ...
# 27169      Gold
# 27170      Gold
# 27171    Silver
# 27172    Silver
# 27173    Silver
# Name: Medal, Length: 27174, dtype: category
# Categories (3, object): ['Bronze' < 'Silver' < 'Gold']

# %%
oo.sort_values(by=["Year", "Event", "Medal"], ascending=[True, True, False]).head(7)
# Out:
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# 5  1896  Athens  Athletics      Athletics      HOFMANN, Fritz  GER    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 6  1896  Athens   Aquatics       Swimming       HAJOS, Alfred  HUN    Men
#
#             Event Event Gender   Medal
# 0           100km            M    Gold
# 1           100km            M  Silver
# 4            100m            M    Gold
# 5            100m            M  Silver
# 2            100m            M  Bronze
# 3            100m            M  Bronze
# 6  100m freestyle            M    Gold

# %% [markdown]
# ## Memory usage of different dtypes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
df = pd.read_csv(filename, skiprows=5)
df.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# Position         int64
# dtype: object

# %%
oo.dtypes

# %%
oo.Medal.memory_usage?
# Out:
# Signature: oo.Medal.memory_usage(index: 'bool' = True, deep: 'bool' = False) -> 'int'
# Docstring:
# Return the memory usage of the Series.
#
# The memory usage can optionally include the contribution of
# the index and of elements of `object` dtype.
#
# Parameters
# ----------
# index : bool, default True
#     Specifies whether to include the memory usage of the Series index.
# deep : bool, default False
#     If True, introspect the data deeply by interrogating
#     `object` dtypes for system-level memory consumption, and include
#     it in the returned value.
#
# Returns
# -------
# int
#     Bytes of memory consumed.
#
# See Also
# --------
# numpy.ndarray.nbytes : Total bytes consumed by the elements of the
#     array.
# DataFrame.memory_usage : Bytes consumed by a DataFrame.
#
# Examples
# --------
# >>> s = pd.Series(range(3))
# >>> s.memory_usage()
# 152
#
# Not including the index gives the size of the rest of the data, which
# is necessarily smaller:
#
# >>> s.memory_usage(index=False)
# 24
#
# The memory footprint of `object` values is ignored by default:
#
# >>> s = pd.Series(["a", "b"])
# >>> s.values
# array(['a', 'b'], dtype=object)
# >>> s.memory_usage()
# 144
# >>> s.memory_usage(deep=True)
# 244
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/series.py
# Type:      method

# %%
print(f"Medal series memory usage using dtype category: {oo.Medal.memory_usage(deep=True)}")
print(f"Medal series memory usage using dtype object: {df.Medal.memory_usage(deep=True)}")
# Out:
# Medal series memory usage using dtype category: 27597
# Medal series memory usage using dtype object: 1693728

# %%
oo.Medal.memory_usage(deep=True) / df.Medal.memory_usage(deep=True)
# Out:
# 0.016293643371308734

# %%
print(f"Gender series memory usage using dtype category: {oo.Gender.memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype object: {df.Gender.memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype category: {oo['Event Gender'].memory_usage(deep=True)}")
print(f"Gender series memory usage using dtype object: {df['Event Gender'].memory_usage(deep=True)}")
# Out:
# Gender series memory usage using dtype category: 27532
# Gender series memory usage using dtype object: 1643694
# Gender series memory usage using dtype category: 27584
# Gender series memory usage using dtype object: 1576220

# %%
oo.Medal.memory_usage(deep=True)
# Out:
# 27597

# %%
oo.City.astype("string")
# Out:
# 0        Athens
# 1        Athens
# 2        Athens
# 3        Athens
# 4        Athens
#           ...
# 27169    Athens
# 27170    Athens
# 27171    Athens
# 27172    Athens
# 27173    Athens
# Name: City, Length: 27174, dtype: string

# %%
oo.sample(2)
# Out:
#        Year       City      Sport       Discipline     Athlete Name  NOC  \
# 12894  1972     Munich  Wrestling  Wrestling Gre-R     KIROV, Petar  BUL
# 20826  1992  Barcelona     Hockey           Hockey  ATKINS, Gillian  GBR
#
#       Gender                  Event Event Gender   Medal
# 12894    Men  48 - 52kg (flyweight)            M    Gold
# 20826  Women                 hockey            W  Bronze

# %%
oo.dtypes

# %%
oo.City = oo.City.astype("string")
oo.Sport = oo.Sport.astype("string")
oo.Discipline = oo.Discipline.astype("string")
oo["Athlete Name"] = oo["Athlete Name"].astype("string")
oo.NOC = oo.NOC.astype("string")
oo.Event = oo.Event.astype("string")
oo.dtypes

# %%
oo.City.dtype

# %%
df.City.dtype

# %%
print(f"City series memory usage using dtype string: {oo.City.memory_usage(deep=True)}")
print(f"City series memory usage using dtype object: {df.City.memory_usage(deep=True)}")

# %% [markdown]
# ## Defining dtypes when you read in a file

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year         City       Sport Discipline            Athlete Name  NOC  \
# 5890   1932  Los Angeles      Boxing     Boxing     SCHLEINKOFER, Josef  GER
# 19619  1992    Barcelona      Boxing     Boxing  BOJINOV, Daniel Petrov  BUL
# 19351  1988        Seoul  Equestrian   Dressage       PRACHT, Eva Maria  CAN
#
#       Gender                         Event Event Gender   Medal
# 5890     Men  54 - 57.15kg (featherweight)            M  Silver
# 19619    Men      - 48kg (light-flyweight)            M  Silver
# 19351  Women                          team            X  Bronze

# %%
oo.dtypes
# Out:
# Year             int64
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": "category"}

dtype_mapper

# %%
pd.api.types.CategoricalDtype?

# %%
ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
ordered_medals
# Out:
# CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True, categories_dtype=object)

# %%
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_gender': 'category',
#  'Medal': CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True, categories_dtype=object)}

# %%
oo = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
oo.sample(3)
# Out:
#        Year      City       Sport   Discipline            Athlete Name  NOC  \
# 14688  1976  Montreal      Rowing       Rowing  SEVOSTYANOVA, Nadezhda  URS
# 4015   1920   Antwerp  Gymnastics  Artistic G.       BJÖRNSTAD, Jörgen  NOR
# 22371  1996   Atlanta    Football     Football          SANDAUNE, Brit  NOR
#
#       Gender                                Event Event Gender   Medal  \
# 14688  Women  four-oared shell with coxswain (4-)            W  Bronze
# 4015     Men                    team, free system            M  Silver
# 22371  Women                             football            W  Bronze
#
#        Position
# 14688         3
# 4015          2
# 22371         3

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender            object
# Medal                 category
# Position                 int64
# dtype: object

# %%
oo["Event Gender"].unique()

# %%
oo = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
oo['Event Gender'] = oo['Event Gender'].astype("category")
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# Position                 int64
# dtype: object

# %% [markdown]
# ## Python Functions

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def show_df(filename="olympics_1896_2004.csv"):
  """Read in csv file and display DataFrame"""
  df = pd.read_csv(filename, skiprows=5)
  return df

show_df()
# Out:
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal  Position
# 0          100km            M    Gold         1
# 1          100km            M  Silver         2
# 2           100m            M  Bronze         3
# 3           100m            M  Bronze         3
# 4           100m            M    Gold         1
# ...          ...          ...     ...       ...
# 27169  épée team            W    Gold         1
# 27170  épée team            W    Gold         1
# 27171  épée team            W  Silver         2
# 27172  épée team            W  Silver         2
# 27173  épée team            W  Silver         2
#
# [27174 rows x 11 columns]

# %%
type(show_df())
# Out:
# pandas.core.frame.DataFrame

# %%
ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}

dtype_mapper
# Out:
# {'Year': 'int64',
#  'City': 'string',
#  'Sport': 'string',
#  'Discipline': 'string',
#  'Athlete Name': 'string',
#  'NOC': 'string',
#  'Gender': 'category',
#  'Event': 'string',
#  'Event_gender': 'category',
#  'Medal': CategoricalDtype(categories=['Bronze', 'Silver', 'Gold'], ordered=True, categories_dtype=object)}

# %%
oo = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year                   City          Sport       Discipline  \
# 3173   1920                Antwerp         Boxing           Boxing
# 9228   1956  Melbourne / Stockholm  Canoe / Kayak  Canoe / Kayak F
# 25434  2004                 Athens       Aquatics         Swimming
#
#            Athlete Name  NOC Gender                            Event  \
# 3173   GARZENA, Edoardo  ITA    Men  53.52 - 57.15kg (featherweight)
# 9228        KISS, Lajos  HUN    Men         K-1 1000m (kayak single)
# 25434  SCHOEMAN, Roland  RSA    Men           4x100m freestyle relay
#
#       Event Gender   Medal
# 3173             M  Bronze
# 9228             M  Bronze
# 25434            M    Gold

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )

  return df

preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal
# 0          100km            M    Gold
# 1          100km            M  Silver
# 2           100m            M  Bronze
# 3           100m            M  Bronze
# 4           100m            M    Gold
# ...          ...          ...     ...
# 27169  épée team            W    Gold
# 27170  épée team            W    Gold
# 27171  épée team            W  Silver
# 27172  épée team            W  Silver
# 27173  épée team            W  Silver
#
# [27174 rows x 10 columns]

# %%
preprocess()

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year       City     Sport Discipline    Athlete Name  NOC Gender  \
# 20116  1992  Barcelona  Aquatics   Swimming    EVANS, Janet  USA  Women
# 26221  2004     Athens    Rowing     Rowing  FLOREA, Rodica  ROU  Women
# 6387   1936     Berlin  Aquatics   Swimming  TERADA, Noboru  JPN    Men
#
#                           Event Event Gender Medal
# 20116            800m freestyle            W  Gold
# 26221  eight with coxswain (8+)            W  Gold
# 6387            1500m freestyle            M  Gold

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender            object
# Medal                 category
# dtype: object

# %%
oo["Event Gender"].unique()

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year         City              Sport       Discipline  \
# 20175  1992    Barcelona  Modern Pentathlon  Modern Pentath.
# 5842   1932  Los Angeles          Athletics        Athletics
# 14964  1976     Montreal          Athletics        Athletics
#
#                    Athlete Name  NOC Gender                   Event  \
# 20175    SKRZYPASZEK, Arkadiusz  POL    Men  Individual competition
# 5842   PORTER, Gwendoline Alice  GBR  Women            4x100m relay
# 14964                BEYER, Udo  GDR    Men                shot put
#
#       Event Gender   Medal
# 20175            M    Gold
# 5842             W  Bronze
# 14964            M    Gold

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %% [markdown]
# ## Working with Indexes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.head(5)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal
# 0  100km            M    Gold
# 1  100km            M  Silver
# 2   100m            M  Bronze
# 3   100m            M  Bronze
# 4   100m            M    Gold

# %%
oo.index
# Out:
# RangeIndex(start=0, stop=27174, step=1)

# %%
oo.columns

# %%
oo.shape

# %%
pd.read_csv(filename, skiprows=5, header=None).head()
# Out:
#      0       1          2              3                   4    5       6   \
# 0  Year    City      Sport     Discipline        Athlete Name  NOC  Gender
# 1  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA     Men
# 2  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE     Men
# 3  1896  Athens  Athletics      Athletics       LANE, Francis  USA     Men
# 4  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN     Men
#
#       7             8       9         10
# 0  Event  Event Gender   Medal  Position
# 1  100km             M    Gold         1
# 2  100km             M  Silver         2
# 3   100m             M  Bronze         3
# 4   100m             M  Bronze         3

# %%
oo = preprocess()
oo.head(5)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#    Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0  1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1  1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2  1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3  1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4  1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
#
#    Event Event Gender   Medal
# 0  100km            M    Gold
# 1  100km            M  Silver
# 2   100m            M  Bronze
# 3   100m            M  Bronze
# 4   100m            M    Gold

# %%
oo[oo['Athlete Name'].str.contains("LEWIS, Carl")]
# Out:
#        Year         City      Sport Discipline Athlete Name  NOC Gender  \
# 16636  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 16697  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 16847  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 17709  1984  Los Angeles  Athletics  Athletics  LEWIS, Carl  USA    Men
# 18098  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 18165  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 19227  1988        Seoul  Athletics  Athletics  LEWIS, Carl  USA    Men
# 19908  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men
# 20917  1992    Barcelona  Athletics  Athletics  LEWIS, Carl  USA    Men
# 22719  1996      Atlanta  Athletics  Athletics  LEWIS, Carl  USA    Men
#
#               Event Event Gender   Medal
# 16636          100m            M    Gold
# 16697          200m            M    Gold
# 16847  4x100m relay            M    Gold
# 17709     long jump            M    Gold
# 18098          100m            M    Gold
# 18165          200m            M  Silver
# 19227     long jump            M    Gold
# 19908  4x100m relay            M    Gold
# 20917     long jump            M    Gold
# 22719     long jump            M    Gold

# %%
oo.loc[22719, "Event"]
# Out:
# 'long jump'

# %%
oo = oo.set_index("Athlete Name")
oo.head(5)
# Out:
#                     Year    City      Sport     Discipline  NOC Gender  Event  \
# Athlete Name
# FLAMENG, Léon       1896  Athens    Cycling  Cycling Track  FRA    Men  100km
# KOLETTIS, Georgios  1896  Athens    Cycling  Cycling Track  GRE    Men  100km
# LANE, Francis       1896  Athens  Athletics      Athletics  USA    Men   100m
# SZOKOLYI, Alajos    1896  Athens  Athletics      Athletics  HUN    Men   100m
# BURKE, Thomas       1896  Athens  Athletics      Athletics  USA    Men   100m
#
#                    Event Gender   Medal
# Athlete Name
# FLAMENG, Léon                 M    Gold
# KOLETTIS, Georgios            M  Silver
# LANE, Francis                 M  Bronze
# SZOKOLYI, Alajos              M  Bronze
# BURKE, Thomas                 M    Gold

# %%
oo.index
# Out:
# Index(['FLAMENG, Léon', 'KOLETTIS, Georgios', 'LANE, Francis',
#        'SZOKOLYI, Alajos', 'BURKE, Thomas', 'HOFMANN, Fritz', 'HAJOS, Alfred',
#        'HERSCHMANN, Otto', 'DRIVAS, Dimitrios', 'MALOKINIS, Ioannis',
#        ...
#        'FLESSEL-COLOVIC, Laura', 'KIRALY PICOT, Hajnalka', 'NISIMA, Maureen',
#        'AZNAVOURIAN, Karina', 'ERMAKOVA, Oxana', 'LOGOUNOVA, Tatiana',
#        'SIVKOVA, Anna', 'BOKEL, Claudia', 'DUPLITZER, Imke',
#        'HEIDEMANN, Britta'],
#       dtype='string', name='Athlete Name', length=27174)

# %%
oo.loc["LEWIS, Carl", "Event"]
# Out:
# Athlete Name
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl            100m
# LEWIS, Carl            200m
# LEWIS, Carl       long jump
# LEWIS, Carl    4x100m relay
# LEWIS, Carl       long jump
# LEWIS, Carl       long jump
# Name: Event, dtype: string

# %%
oo.head(3)

# %%
oo.columns

# %%
oo.shape

# %%
oo.head(3)

# %%
oo.loc["LEWIS, Carl", ["Year", "Event", "Medal"]]
# Out:
#               Year         Event   Medal
# Athlete Name
# LEWIS, Carl   1984          100m    Gold
# LEWIS, Carl   1984          200m    Gold
# LEWIS, Carl   1984  4x100m relay    Gold
# LEWIS, Carl   1984     long jump    Gold
# LEWIS, Carl   1988          100m    Gold
# LEWIS, Carl   1988          200m  Silver
# LEWIS, Carl   1988     long jump    Gold
# LEWIS, Carl   1992  4x100m relay    Gold
# LEWIS, Carl   1992     long jump    Gold
# LEWIS, Carl   1996     long jump    Gold

# %%
oo.loc["LEWIS, Carl", :]
# Out:
#               Year         City      Sport Discipline  NOC Gender  \
# Athlete Name
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1996      Atlanta  Athletics  Athletics  USA    Men
#
#                      Event Event Gender   Medal
# Athlete Name
# LEWIS, Carl           100m            M    Gold
# LEWIS, Carl           200m            M    Gold
# LEWIS, Carl   4x100m relay            M    Gold
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl           100m            M    Gold
# LEWIS, Carl           200m            M  Silver
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl   4x100m relay            M    Gold
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl      long jump            M    Gold

# %%
oo.loc["LEWIS, Carl"]
# Out:
#               Year         City      Sport Discipline  NOC Gender  \
# Athlete Name
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1984  Los Angeles  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1988        Seoul  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1992    Barcelona  Athletics  Athletics  USA    Men
# LEWIS, Carl   1996      Atlanta  Athletics  Athletics  USA    Men
#
#                      Event Event Gender   Medal
# Athlete Name
# LEWIS, Carl           100m            M    Gold
# LEWIS, Carl           200m            M    Gold
# LEWIS, Carl   4x100m relay            M    Gold
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl           100m            M    Gold
# LEWIS, Carl           200m            M  Silver
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl   4x100m relay            M    Gold
# LEWIS, Carl      long jump            M    Gold
# LEWIS, Carl      long jump            M    Gold

# %%
oo = oo.sort_index()
oo.head(3)
# Out:
#                        Year     City       Sport  Discipline  NOC Gender  \
# Athlete Name
# AABYE, Edgar           1900    Paris  Tug of War  Tug of War  ZZX    Men
# AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men
# AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men
#
#                                    Event Event Gender   Medal
# Athlete Name
# AABYE, Edgar                  tug of war            M    Gold
# AALTONEN, Arvo Ossian  400m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian  200m breaststroke            M  Bronze

# %%
oo = oo.reset_index()
oo.head(3)
# Out:
#             Athlete Name  Year     City       Sport  Discipline  NOC Gender  \
# 0           AABYE, Edgar  1900    Paris  Tug of War  Tug of War  ZZX    Men
# 1  AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men
# 2  AALTONEN, Arvo Ossian  1920  Antwerp    Aquatics    Swimming  FIN    Men
#
#                Event Event Gender   Medal
# 0         tug of war            M    Gold
# 1  400m breaststroke            M  Bronze
# 2  200m breaststroke            M  Bronze

# %%
oo.iloc[0, 0]
# Out:
# 'AABYE, Edgar'

# %%
oo.iloc[0, 5]
# Out:
# 'ZZX'

# %%
oo.iloc[0, :]
# Out:
# Athlete Name    AABYE, Edgar
# Year                    1900
# City                   Paris
# Sport             Tug of War
# Discipline        Tug of War
# NOC                      ZZX
# Gender                   Men
# Event             tug of war
# Event Gender               M
# Medal                   Gold
# Name: 0, dtype: object

# %%
oo.iloc[0]
# Out:
# Athlete Name    AABYE, Edgar
# Year                    1900
# City                   Paris
# Sport             Tug of War
# Discipline        Tug of War
# NOC                      ZZX
# Gender                   Men
# Event             tug of war
# Event Gender               M
# Medal                   Gold
# Name: 0, dtype: object

# %% [markdown]
# ## Being Productive in pandas - My Best Practices

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year     City      Sport Discipline           Athlete Name  NOC Gender  \
# 3410   1920  Antwerp    Archery    Archery        FLAMAND, Firmin  BEL    Men
# 24756  2000   Sydney    Sailing    Sailing   MATTHIJSSE, Margriet  NED  Women
# 7379   1948   London  Athletics  Athletics  LJUNGGREN, John Artur  SWE    Men
#
#                                Event Event Gender   Medal
# 3410   fixed bird target large birds            M  Bronze
# 24756  single-handed dinghy (Europe)            W  Silver
# 7379                       50km walk            M    Gold

# %% [markdown]
# **Get immediate feedback**

# %%
oo = preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...

# %%
oo.sample(3)

# %%
oo = preprocess()
oo.sample(3)

# %% [markdown]
# **Understand the basics of Python**

# %%
dir(pd)

# %%
[func.upper() for func in dir(pd)]

# %% [markdown]
# **Searching for method names**

# %%
import re
import pandas as pd

search_string = "excel"

[func for func in dir(pd) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['ExcelFile', 'ExcelWriter', 'read_excel']

# %%
pd.read_excel?

# %%
[func
 for func in dir(pd)
 if re.search(rf"{search_string}", func, re.IGNORECASE)]

# %% [markdown]
# **Documentation while staying in the IDE**

# %%
pd.read_excel?
# Out:
# Signature:
# pd.read_excel(
#     io,
#     sheet_name: 'str | int | list[IntStrT] | None' = 0,
#     *,
#     header: 'int | Sequence[int] | None' = 0,
#     names: 'SequenceNotStr[Hashable] | range | None' = None,
#     index_col: 'int | str | Sequence[int] | None' = None,
#     usecols: 'int | str | Sequence[int] | Sequence[str] | Callable[[str], bool] | None' = None,
#     dtype: 'DtypeArg | None' = None,
#     engine: "Literal['xlrd', 'openpyxl', 'odf', 'pyxlsb', 'calamine'] | None" = None,
#     converters: 'dict[str, Callable] | dict[int, Callable] | None' = None,
#     true_values: 'Iterable[Hashable] | None' = None,
#     false_values: 'Iterable[Hashable] | None' = None,
#     skiprows: 'Sequence[int] | int | Callable[[int], object] | None' = None,
#     nrows: 'int | None' = None,
#     na_values=None,
#     keep_default_na: 'bool' = True,
#     na_filter: 'bool' = True,
#     verbose: 'bool' = False,
#     parse_dates: 'list | dict | bool' = False,
#     date_parser: 'Callable | lib.NoDefault' = <no_default>,
#     date_format: 'dict[Hashable, str] | str | None' = None,
#     thousands: 'str | None' = None,
#     decimal: 'str' = '.',
#     comment: 'str | None' = None,
#     skipfooter: 'int' = 0,
#     storage_options: 'StorageOptions | None' = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
#     engine_kwargs: 'dict | None' = None,
# ) -> 'DataFrame | dict[IntStrT, DataFrame]'
# Docstring:
# Read an Excel file into a ``pandas`` ``DataFrame``.
#
# Supports `xls`, `xlsx`, `xlsm`, `xlsb`, `odf`, `ods` and `odt` file extensions
# read from a local filesystem or URL. Supports an option to read
# a single sheet or a list of sheets.
#
# Parameters
# ----------
# io : str, bytes, ExcelFile, xlrd.Book, path object, or file-like object
#     Any valid string path is acceptable. The string could be a URL. Valid
#     URL schemes include http, ftp, s3, and file. For file URLs, a host is
#     expected. A local file could be: ``file://localhost/path/to/table.xlsx``.
#
#     If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#     By file-like object, we refer to objects with a ``read()`` method,
#     such as a file handle (e.g. via builtin ``open`` function)
#     or ``StringIO``.
#
#     .. deprecated:: 2.1.0
#         Passing byte strings is deprecated. To read from a
#         byte string, wrap it in a ``BytesIO`` object.
# sheet_name : str, int, list, or None, default 0
#     Strings are used for sheet names. Integers are used in zero-indexed
#     sheet positions (chart sheets do not count as a sheet position).
#     Lists of strings/integers are used to request multiple sheets.
#     Specify ``None`` to get all worksheets.
#
#     Available cases:
#
#     * Defaults to ``0``: 1st sheet as a `DataFrame`
#     * ``1``: 2nd sheet as a `DataFrame`
#     * ``"Sheet1"``: Load sheet with name "Sheet1"
#     * ``[0, 1, "Sheet5"]``: Load first, second and sheet named "Sheet5"
#       as a dict of `DataFrame`
#     * ``None``: All worksheets.
#
# header : int, list of int, default 0
#     Row (0-indexed) to use for the column labels of the parsed
#     DataFrame. If a list of integers is passed those row positions will
#     be combined into a ``MultiIndex``. Use None if there is no header.
# names : array-like, default None
#     List of column names to use. If file contains no header row,
#     then you should explicitly pass header=None.
# index_col : int, str, list of int, default None
#     Column (0-indexed) to use as the row labels of the DataFrame.
#     Pass None if there is no such column.  If a list is passed,
#     those columns will be combined into a ``MultiIndex``.  If a
#     subset of data is selected with ``usecols``, index_col
#     is based on the subset.
#
#     Missing values will be forward filled to allow roundtripping with
#     ``to_excel`` for ``merged_cells=True``. To avoid forward filling the
#     missing values use ``set_index`` after reading the data instead of
#     ``index_col``.
# usecols : str, list-like, or callable, default None
#     * If None, then parse all columns.
#     * If str, then indicates comma separated list of Excel column letters
#       and column ranges (e.g. "A:E" or "A,C,E:F"). Ranges are inclusive of
#       both sides.
#     * If list of int, then indicates list of column numbers to be parsed
#       (0-indexed).
#     * If list of string, then indicates list of column names to be parsed.
#     * If callable, then evaluate each column name against it and parse the
#       column if the callable returns ``True``.
#
#     Returns a subset of the columns according to behavior above.
# dtype : Type name or dict of column -> type, default None
#     Data type for data or columns. E.g. {'a': np.float64, 'b': np.int32}
#     Use ``object`` to preserve data as stored in Excel and not interpret dtype,
#     which will necessarily result in ``object`` dtype.
#     If converters are specified, they will be applied INSTEAD
#     of dtype conversion.
#     If you use ``None``, it will infer the dtype of each column based on the data.
# engine : {'openpyxl', 'calamine', 'odf', 'pyxlsb', 'xlrd'}, default None
#     If io is not a buffer or path, this must be set to identify io.
#     Engine compatibility :
#
#     - ``openpyxl`` supports newer Excel file formats.
#     - ``calamine`` supports Excel (.xls, .xlsx, .xlsm, .xlsb)
#       and OpenDocument (.ods) file formats.
#     - ``odf`` supports OpenDocument file formats (.odf, .ods, .odt).
#     - ``pyxlsb`` supports Binary Excel files.
#     - ``xlrd`` supports old-style Excel files (.xls).
#
#     When ``engine=None``, the following logic will be used to determine the engine:
#
#     - If ``path_or_buffer`` is an OpenDocument format (.odf, .ods, .odt),
#       then `odf <https://pypi.org/project/odfpy/>`_ will be used.
#     - Otherwise if ``path_or_buffer`` is an xls format, ``xlrd`` will be used.
#     - Otherwise if ``path_or_buffer`` is in xlsb format, ``pyxlsb`` will be used.
#     - Otherwise ``openpyxl`` will be used.
# converters : dict, default None
#     Dict of functions for converting values in certain columns. Keys can
#     either be integers or column labels, values are functions that take one
#     input argument, the Excel cell content, and return the transformed
#     content.
# true_values : list, default None
#     Values to consider as True.
# false_values : list, default None
#     Values to consider as False.
# skiprows : list-like, int, or callable, optional
#     Line numbers to skip (0-indexed) or number of lines to skip (int) at the
#     start of the file. If callable, the callable function will be evaluated
#     against the row indices, returning True if the row should be skipped and
#     False otherwise. An example of a valid callable argument would be ``lambda
#     x: x in [0, 2]``.
# nrows : int, default None
#     Number of rows to parse.
# na_values : scalar, str, list-like, or dict, default None
#     Additional strings to recognize as NA/NaN. If dict passed, specific
#     per-column NA values. By default the following values are interpreted
#     as NaN: '', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan',
#     '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NA', 'NULL', 'NaN', 'None',
#     'n/a', 'nan', 'null'.
# keep_default_na : bool, default True
#     Whether or not to include the default NaN values when parsing the data.
#     Depending on whether ``na_values`` is passed in, the behavior is as follows:
#
#     * If ``keep_default_na`` is True, and ``na_values`` are specified,
#       ``na_values`` is appended to the default NaN values used for parsing.
#     * If ``keep_default_na`` is True, and ``na_values`` are not specified, only
#       the default NaN values are used for parsing.
#     * If ``keep_default_na`` is False, and ``na_values`` are specified, only
#       the NaN values specified ``na_values`` are used for parsing.
#     * If ``keep_default_na`` is False, and ``na_values`` are not specified, no
#       strings will be parsed as NaN.
#
#     Note that if `na_filter` is passed in as False, the ``keep_default_na`` and
#     ``na_values`` parameters will be ignored.
# na_filter : bool, default True
#     Detect missing value markers (empty strings and the value of na_values). In
#     data without any NAs, passing ``na_filter=False`` can improve the
#     performance of reading a large file.
# verbose : bool, default False
#     Indicate number of NA values placed in non-numeric columns.
# parse_dates : bool, list-like, or dict, default False
#     The behavior is as follows:
#
#     * ``bool``. If True -> try parsing the index.
#     * ``list`` of int or names. e.g. If [1, 2, 3] -> try parsing columns 1, 2, 3
#       each as a separate date column.
#     * ``list`` of lists. e.g.  If [[1, 3]] -> combine columns 1 and 3 and parse as
#       a single date column.
#     * ``dict``, e.g. {'foo' : [1, 3]} -> parse columns 1, 3 as date and call
#       result 'foo'
#
#     If a column or index contains an unparsable date, the entire column or
#     index will be returned unaltered as an object data type. If you don`t want to
#     parse some cells as date just change their type in Excel to "Text".
#     For non-standard datetime parsing, use ``pd.to_datetime`` after ``pd.read_excel``.
#
#     Note: A fast-path exists for iso8601-formatted dates.
# date_parser : function, optional
#     Function to use for converting a sequence of string columns to an array of
#     datetime instances. The default uses ``dateutil.parser.parser`` to do the
#     conversion. Pandas will try to call `date_parser` in three different ways,
#     advancing to the next if an exception occurs: 1) Pass one or more arrays
#     (as defined by `parse_dates`) as arguments; 2) concatenate (row-wise) the
#     string values from the columns defined by `parse_dates` into a single array
#     and pass that; and 3) call `date_parser` once for each row using one or
#     more strings (corresponding to the columns defined by `parse_dates`) as
#     arguments.
#
#     .. deprecated:: 2.0.0
#        Use ``date_format`` instead, or read in as ``object`` and then apply
#        :func:`to_datetime` as-needed.
# date_format : str or dict of column -> format, default ``None``
#    If used in conjunction with ``parse_dates``, will parse dates according to this
#    format. For anything more complex,
#    please read in as ``object`` and then apply :func:`to_datetime` as-needed.
#
#    .. versionadded:: 2.0.0
# thousands : str, default None
#     Thousands separator for parsing string columns to numeric.  Note that
#     this parameter is only necessary for columns stored as TEXT in Excel,
#     any numeric columns will automatically be parsed, regardless of display
#     format.
# decimal : str, default '.'
#     Character to recognize as decimal point for parsing string columns to numeric.
#     Note that this parameter is only necessary for columns stored as TEXT in Excel,
#     any numeric columns will automatically be parsed, regardless of display
#     format.(e.g. use ',' for European data).
#
#     .. versionadded:: 1.4.0
#
# comment : str, default None
#     Comments out remainder of line. Pass a character or characters to this
#     argument to indicate comments in the input file. Any data between the
#     comment string and the end of the current line is ignored.
# skipfooter : int, default 0
#     Rows at the end to skip (0-indexed).
# storage_options : dict, optional
#     Extra options that make sense for a particular storage connection, e.g.
#     host, port, username, password, etc. For HTTP(S) URLs the key-value pairs
#     are forwarded to ``urllib.request.Request`` as header options. For other
#     URLs (e.g. starting with "s3://", and "gcs://") the key-value pairs are
#     forwarded to ``fsspec.open``. Please see ``fsspec`` and ``urllib`` for more
#     details, and for more examples on storage options refer `here
#     <https://pandas.pydata.org/docs/user_guide/io.html?
#     highlight=storage_options#reading-writing-remote-files>`_.
#
# dtype_backend : {'numpy_nullable', 'pyarrow'}, default 'numpy_nullable'
#     Back-end data type applied to the resultant :class:`DataFrame`
#     (still experimental). Behaviour is as follows:
#
#     * ``"numpy_nullable"``: returns nullable-dtype-backed :class:`DataFrame`
#       (default).
#     * ``"pyarrow"``: returns pyarrow-backed nullable :class:`ArrowDtype`
#       DataFrame.
#
#     .. versionadded:: 2.0
#
# engine_kwargs : dict, optional
#     Arbitrary keyword arguments passed to excel engine.
#
# Returns
# -------
# DataFrame or dict of DataFrames
#     DataFrame from the passed in Excel file. See notes in sheet_name
#     argument for more information on when a dict of DataFrames is returned.
#
# See Also
# --------
# DataFrame.to_excel : Write DataFrame to an Excel file.
# DataFrame.to_csv : Write DataFrame to a comma-separated values (csv) file.
# read_csv : Read a comma-separated values (csv) file into DataFrame.
# read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
# Notes
# -----
# For specific information on the methods used for each Excel engine, refer to the pandas
# :ref:`user guide <io.excel_reader>`
#
# Examples
# --------
# The file can be read using the file name as string or an open file object:
#
# >>> pd.read_excel('tmp.xlsx', index_col=0)  # doctest: +SKIP
#        Name  Value
# 0   string1      1
# 1   string2      2
# 2  #Comment      3
#
# >>> pd.read_excel(open('tmp.xlsx', 'rb'),
# ...               sheet_name='Sheet3')  # doctest: +SKIP
#    Unnamed: 0      Name  Value
# 0           0   string1      1
# 1           1   string2      2
# 2           2  #Comment      3
#
# Index and header can be specified via the `index_col` and `header` arguments
#
# >>> pd.read_excel('tmp.xlsx', index_col=None, header=None)  # doctest: +SKIP
#      0         1      2
# 0  NaN      Name  Value
# 1  0.0   string1      1
# 2  1.0   string2      2
# 3  2.0  #Comment      3
#
# Column types are inferred but can be explicitly specified
#
# >>> pd.read_excel('tmp.xlsx', index_col=0,
# ...               dtype={'Name': str, 'Value': float})  # doctest: +SKIP
#        Name  Value
# 0   string1    1.0
# 1   string2    2.0
# 2  #Comment    3.0
#
# True, False, and NA values, and thousands separators have defaults,
# but can be explicitly specified, too. Supply the values you would like
# as strings or lists of strings!
#
# >>> pd.read_excel('tmp.xlsx', index_col=0,
# ...               na_values=['string1', 'string2'])  # doctest: +SKIP
#        Name  Value
# 0       NaN      1
# 1       NaN      2
# 2  #Comment      3
#
# Comment lines in the excel input file can be skipped using the
# ``comment`` kwarg.
#
# >>> pd.read_excel('tmp.xlsx', index_col=0, comment='#')  # doctest: +SKIP
#       Name  Value
# 0  string1    1.0
# 1  string2    2.0
# 2     None    NaN
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/io/excel/_base.py
# Type:      function

# %% [markdown]
# **head() vs. sample()**

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.sample(3)
# Out:
#        Year                   City     Sport     Discipline    Athlete Name  \
# 25886  2004                 Athens   Cycling  Cycling Track  LLANERAS, Joan
# 9770   1956  Melbourne / Stockholm  Aquatics     Water polo  RADONIC, Lovro
# 13765  1972                 Munich   Sailing        Sailing  ANDERSON, John
#
#        NOC Gender                            Event Event Gender   Medal
# 25886  ESP    Men                      Points Race            M  Silver
# 9770   YUG    Men                       water polo            M  Silver
# 13765  AUS    Men  two-person keelboat open (Star)            X    Gold

# %% [markdown]
# **Functions to preprocess data. Modify the data, not the original files**

# %%
def preprocess(filename):
  """Transform the data. Change the dataframe and not the original csv files"""
  ...

preprocess(filename)

# %% [markdown]
# **Using python assert**

# %%
oo[(oo.Year < 1896) & (oo.Year > 2004)].shape
# Out:
# (0, 10)

# %%
oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0
# Out:
# True

# %%
assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0)

# %%
assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == 0)
print("All tests passed")
# Out:
# All tests passed

# %%
#assert(oo[(oo.Year < 1896) & (oo.Year > 2004)].shape[0] == (0, 10))
#print("All tests passed")

# %% [markdown]
# **Chaining and splitting over several rows. No inplace=True**

# %%
oo = pd.read_csv(filename, skiprows=5)
oo = oo.drop('Position', axis=1)
oo.head(3)

# %%
oo = (pd.read_csv(filename, skiprows=5)
      .drop('Position', axis=1)
)
oo.head(3)

# %%
last3 = pd.read_csv(filename, skiprows=5).sort_values(['Year', 'Athlete Name']).tail(3)
last3

# %%
last3 = (pd.read_csv(filename, skiprows=5)
        .sort_values(['Year', 'Athlete Name'])
        .tail(3)
)
last3

# %%
last3 = (pd.read_csv(filename, skiprows=5)
#        .sort_values(['Year', 'Athlete Name'])
        .tail(3)
)
last3

# %% [markdown]
# **isin()**

# %%
oo.Year.isin?
# Out:
# Signature: oo.Year.isin(values) -> 'Series'
# Docstring:
# Whether elements in Series are contained in `values`.
#
# Return a boolean Series showing whether each element in the Series
# matches an element in the passed sequence of `values` exactly.
#
# Parameters
# ----------
# values : set or list-like
#     The sequence of values to test. Passing in a single string will
#     raise a ``TypeError``. Instead, turn a single string into a
#     list of one element.
#
# Returns
# -------
# Series
#     Series of booleans indicating if each element is in values.
#
# Raises
# ------
# TypeError
#   * If `values` is a string
#
# See Also
# --------
# DataFrame.isin : Equivalent method on DataFrame.
#
# Examples
# --------
# >>> s = pd.Series(['llama', 'cow', 'llama', 'beetle', 'llama',
# ...                'hippo'], name='animal')
# >>> s.isin(['cow', 'llama'])
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# Name: animal, dtype: bool
#
# To invert the boolean values, use the ``~`` operator:
#
# >>> ~s.isin(['cow', 'llama'])
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: animal, dtype: bool
#
# Passing a single string as ``s.isin('llama')`` will raise an error. Use
# a list of one element instead:
#
# >>> s.isin(['llama'])
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# Name: animal, dtype: bool
#
# Strings and integers are distinct and are therefore not comparable:
#
# >>> pd.Series([1]).isin(['1'])
# 0    False
# dtype: bool
# >>> pd.Series([1.1]).isin(['1.1'])
# 0    False
# dtype: bool
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/series.py
# Type:      method

# %%
years_of_interest = [1972, 1980, 1984, 1992, 2000, 2004]

# %%
oo[oo.Year.isin(years_of_interest)]
# Out:
#        Year    City      Sport       Discipline            Athlete Name  NOC  \
# 12715  1972  Munich  Wrestling  Wrestling Free.  TAYLOR, Christopher J.  USA
# 12716  1972  Munich  Wrestling  Wrestling Free.       MEDVED, Aleksandr  URS
# 12717  1972  Munich  Wrestling  Wrestling Free.         DURALIEV, Osman  BUL
# 12718  1972  Munich  Wrestling  Wrestling Gre-R       DOLIPSCHI, Victor  ROU
# 12719  1972  Munich  Wrestling  Wrestling Gre-R       ROSHCHIN, Anatoli  URS
# ...     ...     ...        ...              ...                     ...  ...
# 27169  2004  Athens    Fencing          Fencing      LOGOUNOVA, Tatiana  RUS
# 27170  2004  Athens    Fencing          Fencing           SIVKOVA, Anna  RUS
# 27171  2004  Athens    Fencing          Fencing          BOKEL, Claudia  GER
# 27172  2004  Athens    Fencing          Fencing         DUPLITZER, Imke  GER
# 27173  2004  Athens    Fencing          Fencing       HEIDEMANN, Britta  GER
#
#       Gender                        Event Event Gender   Medal
# 12715    Men  + 100kg (super heavyweight)            M  Bronze
# 12716    Men  + 100kg (super heavyweight)            M    Gold
# 12717    Men  + 100kg (super heavyweight)            M  Silver
# 12718    Men  + 100kg (super heavyweight)            M  Bronze
# 12719    Men  + 100kg (super heavyweight)            M    Gold
# ...      ...                          ...          ...     ...
# 27169  Women                    épée team            W    Gold
# 27170  Women                    épée team            W    Gold
# 27171  Women                    épée team            W  Silver
# 27172  Women                    épée team            W  Silver
# 27173  Women                    épée team            W  Silver
#
# [9749 rows x 10 columns]

# %%
oo[~oo.Year.isin(years_of_interest)]
# Out:
#        Year     City      Sport     Discipline            Athlete Name  NOC  \
# 0      1896   Athens    Cycling  Cycling Track           FLAMENG, Léon  FRA
# 1      1896   Athens    Cycling  Cycling Track      KOLETTIS, Georgios  GRE
# 2      1896   Athens  Athletics      Athletics           LANE, Francis  USA
# 3      1896   Athens  Athletics      Athletics        SZOKOLYI, Alajos  HUN
# 4      1896   Athens  Athletics      Athletics           BURKE, Thomas  USA
# ...     ...      ...        ...            ...                     ...  ...
# 23156  1996  Atlanta    Fencing        Fencing  FLESSEL-COLOVIC, Laura  FRA
# 23157  1996  Atlanta    Fencing        Fencing  MORESEE-PICHOT, Sophie  FRA
# 23158  1996  Atlanta    Fencing        Fencing           CHIESA, Laura  ITA
# 23159  1996  Atlanta    Fencing        Fencing              UGA, Elisa  ITA
# 23160  1996  Atlanta    Fencing        Fencing     ZALAFFI, Margherita  ITA
#
#       Gender      Event Event Gender   Medal
# 0        Men      100km            M    Gold
# 1        Men      100km            M  Silver
# 2        Men       100m            M  Bronze
# 3        Men       100m            M  Bronze
# 4        Men       100m            M    Gold
# ...      ...        ...          ...     ...
# 23156  Women  épée team            W    Gold
# 23157  Women  épée team            W    Gold
# 23158  Women  épée team            W  Silver
# 23159  Women  épée team            W  Silver
# 23160  Women  épée team            W  Silver
#
# [17425 rows x 10 columns]

# %% [markdown]
# **Finding and dealing with missing values**

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27174 entries, 0 to 27173
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          27174 non-null  int64
#  1   City          27174 non-null  object
#  2   Sport         27174 non-null  object
#  3   Discipline    27174 non-null  object
#  4   Athlete Name  27174 non-null  object
#  5   NOC           27174 non-null  object
#  6   Gender        27174 non-null  object
#  7   Event         27174 non-null  object
#  8   Event Gender  27174 non-null  object
#  9   Medal         27174 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Creating Series and DataFrames

# %%
import pandas as pd

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]

# %%
pd.Series(city)
# Out:
# 0    London
# 1       Rio
# 2     Tokyo
# dtype: object

# %%
zip(city, start_date)
zip?
# Out:
# Init signature: zip(self, /, *args, **kwargs)
# Docstring:
# zip(*iterables) --> A zip object yielding tuples until an input is exhausted.
#
#    >>> list(zip('abcdefg', range(3), range(4)))
#    [('a', 0, 0), ('b', 1, 1), ('c', 2, 2)]
#
# The zip object yields n-length tuples, where n is the number of iterables
# passed as positional arguments to zip().  The i-th element in every tuple
# comes from the i-th iterable argument to zip().  This continues until the
# shortest argument is exhausted.
# Type:           type
# Subclasses:

# %%
pd.DataFrame({"City": pd.Series(city),
              "Start Date": pd.Series(start_date)})
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame({"City": city,
              "Start Date": start_date})
# Out:
#      City       Start Date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date))
# Out:
#         0                1
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.DataFrame(zip(city, start_date), columns=["City", "Start Date"])

# %% [markdown]
# ## Working with dates

# %%
import pandas as pd

# %%
city = ["London", "Rio", "Tokyo"]
start_date = ["07-27-2012", "5th Aug, 2016", "23rd Jul, 2021"]
end_date = ["12th Aug, 2012", "21-08-2016", "8th Aug, 2021"]

# %%
games = pd.DataFrame(zip(city, start_date, end_date), columns=["City", "Start Date", "End Date"])
games
# Out:
#      City      Start Date        End Date
# 0  London      07-27-2012  12th Aug, 2012
# 1     Rio   5th Aug, 2016      21-08-2016
# 2   Tokyo  23rd Jul, 2021   8th Aug, 2021

# %%
games.dtypes
# Out:
# City          object
# Start Date    object
# End Date      object
# dtype: object

# %%
import re
import pandas as pd

search_string = "date"

[func for func in dir(pd) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  '_pandas_datetime_CAPI',
#  'bdate_range',
#  'date_range',
#  'to_datetime']

# %%
pd.to_datetime?
# Out:
# Signature:
# pd.to_datetime(
#     arg: 'DatetimeScalarOrArrayConvertible | DictConvertible',
#     errors: 'DateTimeErrorChoices' = 'raise',
#     dayfirst: 'bool' = False,
#     yearfirst: 'bool' = False,
#     utc: 'bool' = False,
#     format: 'str | None' = None,
#     exact: 'bool | lib.NoDefault' = <no_default>,
#     unit: 'str | None' = None,
#     infer_datetime_format: 'lib.NoDefault | bool' = <no_default>,
#     origin: 'str' = 'unix',
#     cache: 'bool' = True,
# ) -> 'DatetimeIndex | Series | DatetimeScalar | NaTType | None'
# Docstring:
# Convert argument to datetime.
#
# This function converts a scalar, array-like, :class:`Series` or
# :class:`DataFrame`/dict-like to a pandas datetime object.
#
# Parameters
# ----------
# arg : int, float, str, datetime, list, tuple, 1-d array, Series, DataFrame/dict-like
#     The object to convert to a datetime. If a :class:`DataFrame` is provided, the
#     method expects minimally the following columns: :const:`"year"`,
#     :const:`"month"`, :const:`"day"`. The column "year"
#     must be specified in 4-digit format.
# errors : {'ignore', 'raise', 'coerce'}, default 'raise'
#     - If :const:`'raise'`, then invalid parsing will raise an exception.
#     - If :const:`'coerce'`, then invalid parsing will be set as :const:`NaT`.
#     - If :const:`'ignore'`, then invalid parsing will return the input.
# dayfirst : bool, default False
#     Specify a date parse order if `arg` is str or is list-like.
#     If :const:`True`, parses dates with the day first, e.g. :const:`"10/11/12"`
#     is parsed as :const:`2012-11-10`.
#
#     .. warning::
#
#         ``dayfirst=True`` is not strict, but will prefer to parse
#         with day first.
#
# yearfirst : bool, default False
#     Specify a date parse order if `arg` is str or is list-like.
#
#     - If :const:`True` parses dates with the year first, e.g.
#       :const:`"10/11/12"` is parsed as :const:`2010-11-12`.
#     - If both `dayfirst` and `yearfirst` are :const:`True`, `yearfirst` is
#       preceded (same as :mod:`dateutil`).
#
#     .. warning::
#
#         ``yearfirst=True`` is not strict, but will prefer to parse
#         with year first.
#
# utc : bool, default False
#     Control timezone-related parsing, localization and conversion.
#
#     - If :const:`True`, the function *always* returns a timezone-aware
#       UTC-localized :class:`Timestamp`, :class:`Series` or
#       :class:`DatetimeIndex`. To do this, timezone-naive inputs are
#       *localized* as UTC, while timezone-aware inputs are *converted* to UTC.
#
#     - If :const:`False` (default), inputs will not be coerced to UTC.
#       Timezone-naive inputs will remain naive, while timezone-aware ones
#       will keep their time offsets. Limitations exist for mixed
#       offsets (typically, daylight savings), see :ref:`Examples
#       <to_datetime_tz_examples>` section for details.
#
#     .. warning::
#
#         In a future version of pandas, parsing datetimes with mixed time
#         zones will raise an error unless `utc=True`.
#         Please specify `utc=True` to opt in to the new behaviour
#         and silence this warning. To create a `Series` with mixed offsets and
#         `object` dtype, please use `apply` and `datetime.datetime.strptime`.
#
#     See also: pandas general documentation about `timezone conversion and
#     localization
#     <https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
#     #time-zone-handling>`_.
#
# format : str, default None
#     The strftime to parse time, e.g. :const:`"%d/%m/%Y"`. See
#     `strftime documentation
#     <https://docs.python.org/3/library/datetime.html
#     #strftime-and-strptime-behavior>`_ for more information on choices, though
#     note that :const:`"%f"` will parse all the way up to nanoseconds.
#     You can also pass:
#
#     - "ISO8601", to parse any `ISO8601 <https://en.wikipedia.org/wiki/ISO_8601>`_
#       time string (not necessarily in exactly the same format);
#     - "mixed", to infer the format for each element individually. This is risky,
#       and you should probably use it along with `dayfirst`.
#
#     .. note::
#
#         If a :class:`DataFrame` is passed, then `format` has no effect.
#
# exact : bool, default True
#     Control how `format` is used:
#
#     - If :const:`True`, require an exact `format` match.
#     - If :const:`False`, allow the `format` to match anywhere in the target
#       string.
#
#     Cannot be used alongside ``format='ISO8601'`` or ``format='mixed'``.
# unit : str, default 'ns'
#     The unit of the arg (D,s,ms,us,ns) denote the unit, which is an
#     integer or float number. This will be based off the origin.
#     Example, with ``unit='ms'`` and ``origin='unix'``, this would calculate
#     the number of milliseconds to the unix epoch start.
# infer_datetime_format : bool, default False
#     If :const:`True` and no `format` is given, attempt to infer the format
#     of the datetime strings based on the first non-NaN element,
#     and if it can be inferred, switch to a faster method of parsing them.
#     In some cases this can increase the parsing speed by ~5-10x.
#
#     .. deprecated:: 2.0.0
#         A strict version of this argument is now the default, passing it has
#         no effect.
#
# origin : scalar, default 'unix'
#     Define the reference date. The numeric values would be parsed as number
#     of units (defined by `unit`) since this reference date.
#
#     - If :const:`'unix'` (or POSIX) time; origin is set to 1970-01-01.
#     - If :const:`'julian'`, unit must be :const:`'D'`, and origin is set to
#       beginning of Julian Calendar. Julian day number :const:`0` is assigned
#       to the day starting at noon on January 1, 4713 BC.
#     - If Timestamp convertible (Timestamp, dt.datetime, np.datetimt64 or date
#       string), origin is set to Timestamp identified by origin.
#     - If a float or integer, origin is the difference
#       (in units determined by the ``unit`` argument) relative to 1970-01-01.
# cache : bool, default True
#     If :const:`True`, use a cache of unique, converted dates to apply the
#     datetime conversion. May produce significant speed-up when parsing
#     duplicate date strings, especially ones with timezone offsets. The cache
#     is only used when there are at least 50 values. The presence of
#     out-of-bounds values will render the cache unusable and may slow down
#     parsing.
#
# Returns
# -------
# datetime
#     If parsing succeeded.
#     Return type depends on input (types in parenthesis correspond to
#     fallback in case of unsuccessful timezone or out-of-range timestamp
#     parsing):
#
#     - scalar: :class:`Timestamp` (or :class:`datetime.datetime`)
#     - array-like: :class:`DatetimeIndex` (or :class:`Series` with
#       :class:`object` dtype containing :class:`datetime.datetime`)
#     - Series: :class:`Series` of :class:`datetime64` dtype (or
#       :class:`Series` of :class:`object` dtype containing
#       :class:`datetime.datetime`)
#     - DataFrame: :class:`Series` of :class:`datetime64` dtype (or
#       :class:`Series` of :class:`object` dtype containing
#       :class:`datetime.datetime`)
#
# Raises
# ------
# ParserError
#     When parsing a date from string fails.
# ValueError
#     When another datetime conversion error happens. For example when one
#     of 'year', 'month', day' columns is missing in a :class:`DataFrame`, or
#     when a Timezone-aware :class:`datetime.datetime` is found in an array-like
#     of mixed time offsets, and ``utc=False``.
#
# See Also
# --------
# DataFrame.astype : Cast argument to a specified dtype.
# to_timedelta : Convert argument to timedelta.
# convert_dtypes : Convert dtypes.
#
# Notes
# -----
#
# Many input types are supported, and lead to different output types:
#
# - **scalars** can be int, float, str, datetime object (from stdlib :mod:`datetime`
#   module or :mod:`numpy`). They are converted to :class:`Timestamp` when
#   possible, otherwise they are converted to :class:`datetime.datetime`.
#   None/NaN/null scalars are converted to :const:`NaT`.
#
# - **array-like** can contain int, float, str, datetime objects. They are
#   converted to :class:`DatetimeIndex` when possible, otherwise they are
#   converted to :class:`Index` with :class:`object` dtype, containing
#   :class:`datetime.datetime`. None/NaN/null entries are converted to
#   :const:`NaT` in both cases.
#
# - **Series** are converted to :class:`Series` with :class:`datetime64`
#   dtype when possible, otherwise they are converted to :class:`Series` with
#   :class:`object` dtype, containing :class:`datetime.datetime`. None/NaN/null
#   entries are converted to :const:`NaT` in both cases.
#
# - **DataFrame/dict-like** are converted to :class:`Series` with
#   :class:`datetime64` dtype. For each row a datetime is created from assembling
#   the various dataframe columns. Column keys can be common abbreviations
#   like ['year', 'month', 'day', 'minute', 'second', 'ms', 'us', 'ns']) or
#   plurals of the same.
#
# The following causes are responsible for :class:`datetime.datetime` objects
# being returned (possibly inside an :class:`Index` or a :class:`Series` with
# :class:`object` dtype) instead of a proper pandas designated type
# (:class:`Timestamp`, :class:`DatetimeIndex` or :class:`Series`
# with :class:`datetime64` dtype):
#
# - when any input element is before :const:`Timestamp.min` or after
#   :const:`Timestamp.max`, see `timestamp limitations
#   <https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
#   #timeseries-timestamp-limits>`_.
#
# - when ``utc=False`` (default) and the input is an array-like or
#   :class:`Series` containing mixed naive/aware datetime, or aware with mixed
#   time offsets. Note that this happens in the (quite frequent) situation when
#   the timezone has a daylight savings policy. In that case you may wish to
#   use ``utc=True``.
#
# Examples
# --------
#
# **Handling various input formats**
#
# Assembling a datetime from multiple columns of a :class:`DataFrame`. The keys
# can be common abbreviations like ['year', 'month', 'day', 'minute', 'second',
# 'ms', 'us', 'ns']) or plurals of the same
#
# >>> df = pd.DataFrame({'year': [2015, 2016],
# ...                    'month': [2, 3],
# ...                    'day': [4, 5]})
# >>> pd.to_datetime(df)
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]
#
# Using a unix epoch time
#
# >>> pd.to_datetime(1490195805, unit='s')
# Timestamp('2017-03-22 15:16:45')
# >>> pd.to_datetime(1490195805433502912, unit='ns')
# Timestamp('2017-03-22 15:16:45.433502912')
#
# .. warning:: For float arg, precision rounding might happen. To prevent
#     unexpected behavior use a fixed-width exact type.
#
# Using a non-unix epoch origin
#
# >>> pd.to_datetime([1, 2, 3], unit='D',
# ...                origin=pd.Timestamp('1960-01-01'))
# DatetimeIndex(['1960-01-02', '1960-01-03', '1960-01-04'],
#               dtype='datetime64[ns]', freq=None)
#
# **Differences with strptime behavior**
#
# :const:`"%f"` will parse all the way up to nanoseconds.
#
# >>> pd.to_datetime('2018-10-26 12:00:00.0000000011',
# ...                format='%Y-%m-%d %H:%M:%S.%f')
# Timestamp('2018-10-26 12:00:00.000000001')
#
# **Non-convertible date/times**
#
# Passing ``errors='coerce'`` will force an out-of-bounds date to :const:`NaT`,
# in addition to forcing non-dates (or non-parseable dates) to :const:`NaT`.
#
# >>> pd.to_datetime('13000101', format='%Y%m%d', errors='coerce')
# NaT
#
# .. _to_datetime_tz_examples:
#
# **Timezones and time offsets**
#
# The default behaviour (``utc=False``) is as follows:
#
# - Timezone-naive inputs are converted to timezone-naive :class:`DatetimeIndex`:
#
# >>> pd.to_datetime(['2018-10-26 12:00:00', '2018-10-26 13:00:15'])
# DatetimeIndex(['2018-10-26 12:00:00', '2018-10-26 13:00:15'],
#               dtype='datetime64[ns]', freq=None)
#
# - Timezone-aware inputs *with constant time offset* are converted to
#   timezone-aware :class:`DatetimeIndex`:
#
# >>> pd.to_datetime(['2018-10-26 12:00 -0500', '2018-10-26 13:00 -0500'])
# DatetimeIndex(['2018-10-26 12:00:00-05:00', '2018-10-26 13:00:00-05:00'],
#               dtype='datetime64[ns, UTC-05:00]', freq=None)
#
# - However, timezone-aware inputs *with mixed time offsets* (for example
#   issued from a timezone with daylight savings, such as Europe/Paris)
#   are **not successfully converted** to a :class:`DatetimeIndex`.
#   Parsing datetimes with mixed time zones will show a warning unless
#   `utc=True`. If you specify `utc=False` the warning below will be shown
#   and a simple :class:`Index` containing :class:`datetime.datetime`
#   objects will be returned:
#
# >>> pd.to_datetime(['2020-10-25 02:00 +0200',
# ...                 '2020-10-25 04:00 +0100'])  # doctest: +SKIP
# FutureWarning: In a future version of pandas, parsing datetimes with mixed
# time zones will raise an error unless `utc=True`. Please specify `utc=True`
# to opt in to the new behaviour and silence this warning. To create a `Series`
# with mixed offsets and `object` dtype, please use `apply` and
# `datetime.datetime.strptime`.
# Index([2020-10-25 02:00:00+02:00, 2020-10-25 04:00:00+01:00],
#       dtype='object')
#
# - A mix of timezone-aware and timezone-naive inputs is also converted to
#   a simple :class:`Index` containing :class:`datetime.datetime` objects:
#
# >>> from datetime import datetime
# >>> pd.to_datetime(["2020-01-01 01:00:00-01:00",
# ...                 datetime(2020, 1, 1, 3, 0)])  # doctest: +SKIP
# FutureWarning: In a future version of pandas, parsing datetimes with mixed
# time zones will raise an error unless `utc=True`. Please specify `utc=True`
# to opt in to the new behaviour and silence this warning. To create a `Series`
# with mixed offsets and `object` dtype, please use `apply` and
# `datetime.datetime.strptime`.
# Index([2020-01-01 01:00:00-01:00, 2020-01-01 03:00:00], dtype='object')
#
# |
#
# Setting ``utc=True`` solves most of the above issues:
#
# - Timezone-naive inputs are *localized* as UTC
#
# >>> pd.to_datetime(['2018-10-26 12:00', '2018-10-26 13:00'], utc=True)
# DatetimeIndex(['2018-10-26 12:00:00+00:00', '2018-10-26 13:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)
#
# - Timezone-aware inputs are *converted* to UTC (the output represents the
#   exact same datetime, but viewed from the UTC time offset `+00:00`).
#
# >>> pd.to_datetime(['2018-10-26 12:00 -0530', '2018-10-26 12:00 -0500'],
# ...                utc=True)
# DatetimeIndex(['2018-10-26 17:30:00+00:00', '2018-10-26 17:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)
#
# - Inputs can contain both string or datetime, the above
#   rules still apply
#
# >>> pd.to_datetime(['2018-10-26 12:00', datetime(2020, 1, 1, 18)], utc=True)
# DatetimeIndex(['2018-10-26 12:00:00+00:00', '2020-01-01 18:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/tools/datetimes.py
# Type:      function

# %%
#pd.to_datetime(games["Start Date"])

# %%
pd.to_datetime(games["Start Date"], format='mixed')
# Out:
# 0   2012-07-27
# 1   2016-08-05
# 2   2021-07-23
# Name: Start Date, dtype: datetime64[ns]

# %%
games["Start Date"] = pd.to_datetime(games["Start Date"], format='mixed')
games["End Date"] = pd.to_datetime(games["End Date"], format='mixed')
games["City"] = games.City.astype("string")
games
# Out:
#      City Start Date   End Date
# 0  London 2012-07-27 2012-08-12
# 1     Rio 2016-08-05 2016-08-21
# 2   Tokyo 2021-07-23 2021-08-08

# %%
games.dtypes
# Out:
# City          string[python]
# Start Date    datetime64[ns]
# End Date      datetime64[ns]
# dtype: object

# %%
games["End Date"]
# Out:
# 0   2012-08-12
# 1   2016-08-21
# 2   2021-08-08
# Name: End Date, dtype: datetime64[ns]

# %%
games["Start Date"]
# Out:
# 0   2012-07-27
# 1   2016-08-05
# 2   2021-07-23
# Name: Start Date, dtype: datetime64[ns]

# %%
games["End Date"] - games["Start Date"]
# Out:
# 0   16 days
# 1   16 days
# 2   16 days
# dtype: timedelta64[ns]

# %%
games = games.assign(duration=games["End Date"] - games["Start Date"])
games

# %%
games.dtypes

# %% [markdown]
# ## Combining DataFrames

# %%
import pandas as pd

# %%
start = pd.DataFrame({"city": ["London", "Rio", "Tokyo"],
                      "start_date": ["27th Jul, 2012", "5th Aug, 2016", "23rd July, 2021"]})
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end = pd.DataFrame({"City": ["London", "Tokyo", "Paris"],
                    "end_date": ["12th Aug, 2012", "8th Aug, 2021", "11th Aug, 2024"]})
end
# Out:
#      City        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.concat?

# %%
pd.concat([start, end], axis=0)
# Out:
#      city       start_date    City        end_date
# 0  London   27th Jul, 2012     NaN             NaN
# 1     Rio    5th Aug, 2016     NaN             NaN
# 2   Tokyo  23rd July, 2021     NaN             NaN
# 0     NaN              NaN  London  12th Aug, 2012
# 1     NaN              NaN   Tokyo   8th Aug, 2021
# 2     NaN              NaN   Paris  11th Aug, 2024

# %%
end = pd.DataFrame({"city": ["London", "Tokyo", "Paris"],
                    "end_date": ["12th Aug, 2012", "8th Aug, 2021", "11th Aug, 2024"]})
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.concat([start, end], axis=0)
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012             NaN
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021             NaN
# 0  London              NaN  12th Aug, 2012
# 1   Tokyo              NaN   8th Aug, 2021
# 2   Paris              NaN  11th Aug, 2024

# %%
pd.concat([start, end], axis=1)
# Out:
#      city       start_date    city        end_date
# 0  London   27th Jul, 2012  London  12th Aug, 2012
# 1     Rio    5th Aug, 2016   Tokyo   8th Aug, 2021
# 2   Tokyo  23rd July, 2021   Paris  11th Aug, 2024

# %% [markdown]
# **Inner join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.merge?

# %%
pd.merge(left=start, right=end, on="city", how="inner")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Tokyo  23rd July, 2021   8th Aug, 2021

# %% [markdown]
# **Outer join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
end
# Out:
#      city        end_date
# 0  London  12th Aug, 2012
# 1   Tokyo   8th Aug, 2021
# 2   Paris  11th Aug, 2024

# %%
pd.merge(left=start, right=end, on="city", how="outer")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1   Paris              NaN  11th Aug, 2024
# 2     Rio    5th Aug, 2016             NaN
# 3   Tokyo  23rd July, 2021   8th Aug, 2021

# %% [markdown]
# **Left join**

# %%
start
# Out:
#      city       start_date
# 0  London   27th Jul, 2012
# 1     Rio    5th Aug, 2016
# 2   Tokyo  23rd July, 2021

# %%
pd.merge(left=start, right=end, on="city", how="left")
# Out:
#      city       start_date        end_date
# 0  London   27th Jul, 2012  12th Aug, 2012
# 1     Rio    5th Aug, 2016             NaN
# 2   Tokyo  23rd July, 2021   8th Aug, 2021

# %% [markdown]
# **Right join**

# %%
end

# %%
pd.merge(left=start, right=end, on="city", how="right")

# %% [markdown]
# ## Combining Datasets

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

preprocess()
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City      Sport     Discipline        Athlete Name  NOC Gender  \
# 0      1896  Athens    Cycling  Cycling Track       FLAMENG, Léon  FRA    Men
# 1      1896  Athens    Cycling  Cycling Track  KOLETTIS, Georgios  GRE    Men
# 2      1896  Athens  Athletics      Athletics       LANE, Francis  USA    Men
# 3      1896  Athens  Athletics      Athletics    SZOKOLYI, Alajos  HUN    Men
# 4      1896  Athens  Athletics      Athletics       BURKE, Thomas  USA    Men
# ...     ...     ...        ...            ...                 ...  ...    ...
# 27169  2004  Athens    Fencing        Fencing  LOGOUNOVA, Tatiana  RUS  Women
# 27170  2004  Athens    Fencing        Fencing       SIVKOVA, Anna  RUS  Women
# 27171  2004  Athens    Fencing        Fencing      BOKEL, Claudia  GER  Women
# 27172  2004  Athens    Fencing        Fencing     DUPLITZER, Imke  GER  Women
# 27173  2004  Athens    Fencing        Fencing   HEIDEMANN, Britta  GER  Women
#
#            Event Event Gender   Medal
# 0          100km            M    Gold
# 1          100km            M  Silver
# 2           100m            M  Bronze
# 3           100m            M  Bronze
# 4           100m            M    Gold
# ...          ...          ...     ...
# 27169  épée team            W    Gold
# 27170  épée team            W    Gold
# 27171  épée team            W  Silver
# 27172  épée team            W  Silver
# 27173  épée team            W  Silver
#
# [27174 rows x 10 columns]

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year    City    Sport    Discipline             Athlete Name  NOC  \
# 24569  2000  Sydney   Hockey        Hockey            MORRIS, Jenny  AUS
# 18782  1988   Seoul   Rowing        Rowing  PATTON, Edward Bickford  USA
# 7139   1936  Berlin  Cycling  Cycling Road                OTT, Kurt  SUI
#
#       Gender                     Event Event Gender   Medal
# 24569  Women                    hockey            W    Gold
# 18782    Men  eight with coxswain (8+)            M  Bronze
# 7139     Men           team time trial            M  Silver

# %%
# !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv
# Out:
# --2024-07-04 10:02:07--  https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_2008.csv [following]
# --2024-07-04 10:02:07--  https://raw.githubusercontent.com/jonfernandes/pandas_essential/main/olympics_2008.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 174220 (170K) [text/plain]
# Saving to: ‘olympics_2008.csv’
#
# olympics_2008.csv   100%[===================>] 170.14K  --.-KB/s    in 0.04s
#
# 2024-07-04 10:02:08 (4.21 MB/s) - ‘olympics_2008.csv’ saved [174220/174220]

# %%
new_filename =  "olympics_2008.csv"
nw = pd.read_csv(new_filename)
nw.head(5)
# Out:
#       city  edition     sport discipline           athlete country_code  \
# 0  Beijing   2008.0  aquatics     Diving    GALPERIN, Gleb          RUS
# 1  Beijing   2008.0  aquatics     Diving  MITCHAM, Matthew          AUS
# 2  Beijing   2008.0  aquatics     Diving       ZHOU, Luxin          CHN
# 3  Beijing   2008.0  aquatics     Diving         WANG, Xin          CHN
# 4  Beijing   2008.0  aquatics     Diving      CHEN, Ruolin          CHN
#
#   gender         event event_gender   medal  result
# 0    Men  10m platform            M  bronze     3.0
# 1    Men  10m platform            M    gold     1.0
# 2    Men  10m platform            M  silver     2.0
# 3  Women  10m platform            W  bronze     3.0
# 4  Women  10m platform            W    gold     1.0

# %%
oo.sample(3)
# Out:
#        Year         City          Sport       Discipline      Athlete Name  \
# 21928  1996      Atlanta  Canoe / Kayak  Canoe / Kayak F  PORTWICH, Ramona
# 17003  1984  Los Angeles         Boxing           Boxing  JOSIPOVIC, Antun
# 14370  1976     Montreal        Cycling    Cycling Track     BRAUN, Gregor
#
#        NOC Gender                          Event Event Gender   Medal
# 21928  GER  Women        K-2 500m (kayak double)            W  Silver
# 17003  YUG    Men  75 - 81kg (light-heavyweight)            M    Gold
# 14370  FRG    Men           Team Pursuit (4000m)            M    Gold

# %%
pd.concat([oo, nw], axis=0)
# Out:
#         Year    City      Sport     Discipline        Athlete Name   NOC  \
# 0     1896.0  Athens    Cycling  Cycling Track       FLAMENG, Léon   FRA
# 1     1896.0  Athens    Cycling  Cycling Track  KOLETTIS, Georgios   GRE
# 2     1896.0  Athens  Athletics      Athletics       LANE, Francis   USA
# 3     1896.0  Athens  Athletics      Athletics    SZOKOLYI, Alajos   HUN
# 4     1896.0  Athens  Athletics      Athletics       BURKE, Thomas   USA
# ...      ...     ...        ...            ...                 ...   ...
# 2054     NaN    <NA>       <NA>           <NA>                <NA>  <NA>
# 2055     NaN    <NA>       <NA>           <NA>                <NA>  <NA>
# 2056     NaN    <NA>       <NA>           <NA>                <NA>  <NA>
# 2057     NaN    <NA>       <NA>           <NA>                <NA>  <NA>
# 2058     NaN    <NA>       <NA>           <NA>                <NA>  <NA>
#
#      Gender  Event Event Gender   Medal  ... edition      sport  \
# 0       Men  100km            M    Gold  ...     NaN        NaN
# 1       Men  100km            M  Silver  ...     NaN        NaN
# 2       Men   100m            M  Bronze  ...     NaN        NaN
# 3       Men   100m            M  Bronze  ...     NaN        NaN
# 4       Men   100m            M    Gold  ...     NaN        NaN
# ...     ...    ...          ...     ...  ...     ...        ...
# 2054    NaN   <NA>          NaN     NaN  ...  2008.0  wrestling
# 2055    NaN   <NA>          NaN     NaN  ...  2008.0  wrestling
# 2056    NaN   <NA>          NaN     NaN  ...  2008.0  wrestling
# 2057    NaN   <NA>          NaN     NaN  ...  2008.0  wrestling
# 2058    NaN   <NA>          NaN     NaN  ...  2008.0  wrestling
#
#            discipline         athlete country_code gender       event  \
# 0                 NaN             NaN          NaN    NaN         NaN
# 1                 NaN             NaN          NaN    NaN         NaN
# 2                 NaN             NaN          NaN    NaN         NaN
# 3                 NaN             NaN          NaN    NaN         NaN
# 4                 NaN             NaN          NaN    NaN         NaN
# ...               ...             ...          ...    ...         ...
# 2054  Wrestling Gre-R  BAROEV, Khasan          RUS    Men  96 - 120kg
# 2055  Wrestling Gre-R  BAROEV, Khasan          RUS    Men  96 - 120kg
# 2056  Wrestling Gre-R  BAROEV, Khasan          RUS    Men  96 - 120kg
# 2057  Wrestling Gre-R  BAROEV, Khasan          RUS    Men  96 - 120kg
# 2058  Wrestling Gre-R  BAROEV, Khasan          RUS    Men  96 - 120kg
#
#      event_gender   medal result
# 0             NaN     NaN    NaN
# 1             NaN     NaN    NaN
# 2             NaN     NaN    NaN
# 3             NaN     NaN    NaN
# 4             NaN     NaN    NaN
# ...           ...     ...    ...
# 2054            M  silver    2.0
# 2055            M  silver    2.0
# 2056            M  silver    2.0
# 2057            M  silver    2.0
# 2058            M  silver    2.0
#
# [29233 rows x 21 columns]

# %%
nw.columns
# Out:
# Index(['city', 'edition', 'sport', 'discipline', 'athlete', 'country_code',
#        'gender', 'event', 'event_gender', 'medal', 'result'],
#       dtype='object')

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
#        'Event', 'Event Gender', 'Medal'],
#       dtype='object')

# %%
nw.columns = ['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
       'Gender', 'Event', 'Event_gender', 'Medal', 'Result']
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
#        'Gender', 'Event', 'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
new_columns = ['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
       'Gender', 'Event', 'Event_gender', 'Medal', 'Result']

# %%
nw = pd.read_csv(new_filename, names=new_columns)
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
#        'Gender', 'Event', 'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
nw.columns = [column.capitalize() for column in nw.columns]
nw.columns
# Out:
# Index(['City', 'Edition', 'Sport', 'Discipline', 'Athlete', 'Country_code',
#        'Gender', 'Event', 'Event_gender', 'Medal', 'Result'],
#       dtype='object')

# %%
pd.concat([oo, nw], axis=0)
# Out:
#         Year     City      Sport       Discipline        Athlete Name   NOC  \
# 0     1896.0   Athens    Cycling    Cycling Track       FLAMENG, Léon   FRA
# 1     1896.0   Athens    Cycling    Cycling Track  KOLETTIS, Georgios   GRE
# 2     1896.0   Athens  Athletics        Athletics       LANE, Francis   USA
# 3     1896.0   Athens  Athletics        Athletics    SZOKOLYI, Alajos   HUN
# 4     1896.0   Athens  Athletics        Athletics       BURKE, Thomas   USA
# ...      ...      ...        ...              ...                 ...   ...
# 2055     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>
# 2056     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>
# 2057     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>
# 2058     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>
# 2059     NaN  Beijing  wrestling  Wrestling Gre-R                <NA>  <NA>
#
#      Gender       Event Event Gender   Medal Edition         Athlete  \
# 0       Men       100km            M    Gold     NaN             NaN
# 1       Men       100km            M  Silver     NaN             NaN
# 2       Men        100m            M  Bronze     NaN             NaN
# 3       Men        100m            M  Bronze     NaN             NaN
# 4       Men        100m            M    Gold     NaN             NaN
# ...     ...         ...          ...     ...     ...             ...
# 2055    Men  96 - 120kg          NaN  silver    2008  BAROEV, Khasan
# 2056    Men  96 - 120kg          NaN  silver    2008  BAROEV, Khasan
# 2057    Men  96 - 120kg          NaN  silver    2008  BAROEV, Khasan
# 2058    Men  96 - 120kg          NaN  silver    2008  BAROEV, Khasan
# 2059    Men  96 - 120kg          NaN  silver    2008  BAROEV, Khasan
#
#      Country_code Event_gender Result
# 0             NaN          NaN    NaN
# 1             NaN          NaN    NaN
# 2             NaN          NaN    NaN
# 3             NaN          NaN    NaN
# 4             NaN          NaN    NaN
# ...           ...          ...    ...
# 2055          RUS            M      2
# 2056          RUS            M      2
# 2057          RUS            M      2
# 2058          RUS            M      2
# 2059          RUS            M      2
#
# [29234 rows x 15 columns]

# %%
oo.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
#        'Event', 'Event Gender', 'Medal'],
#       dtype='object')

# %%
nw.columns

# %%
nw.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']

# %%
pd.concat([oo, nw], axis=0)
# Out:
#       Year     City      Sport       Discipline        Athlete Name  NOC  \
# 0     1896   Athens    Cycling    Cycling Track       FLAMENG, Léon  FRA
# 1     1896   Athens    Cycling    Cycling Track  KOLETTIS, Georgios  GRE
# 2     1896   Athens  Athletics        Athletics       LANE, Francis  USA
# 3     1896   Athens  Athletics        Athletics    SZOKOLYI, Alajos  HUN
# 4     1896   Athens  Athletics        Athletics       BURKE, Thomas  USA
# ...    ...      ...        ...              ...                 ...  ...
# 2055  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2056  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2057  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2058  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2059  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
#
#      Gender       Event Event Gender   Medal Result
# 0       Men       100km            M    Gold    NaN
# 1       Men       100km            M  Silver    NaN
# 2       Men        100m            M  Bronze    NaN
# 3       Men        100m            M  Bronze    NaN
# 4       Men        100m            M    Gold    NaN
# ...     ...         ...          ...     ...    ...
# 2055    Men  96 - 120kg            M  silver      2
# 2056    Men  96 - 120kg            M  silver      2
# 2057    Men  96 - 120kg            M  silver      2
# 2058    Men  96 - 120kg            M  silver      2
# 2059    Men  96 - 120kg            M  silver      2
#
# [29234 rows x 11 columns]

# %%
nw.Result.unique()
# Out:
# array(['result', '3', '1', '2', nan], dtype=object)

# %%
nw = nw.drop("Result", axis=1)
nw.sample(3)
# Out:
#          City  Year       Sport  Discipline      Athlete Name  NOC Gender  \
# 229   Beijing  2008    aquatics    Swimming         TAN, Miao  CHN  Women
# 1905  Beijing  2008  volleyball  Volleyball        MA, Yunwen  CHN  Women
# 1122  Beijing  2008    football    Football  TARPLEY, Lindsay  USA  Women
#
#                        Event Event Gender   Medal
# 229   4x200m freestyle relay            W  silver
# 1905              volleyball            W  bronze
# 1122                football            W    gold

# %%
pd.concat([oo, nw], axis=0)
# Out:
#       Year     City      Sport       Discipline        Athlete Name  NOC  \
# 0     1896   Athens    Cycling    Cycling Track       FLAMENG, Léon  FRA
# 1     1896   Athens    Cycling    Cycling Track  KOLETTIS, Georgios  GRE
# 2     1896   Athens  Athletics        Athletics       LANE, Francis  USA
# 3     1896   Athens  Athletics        Athletics    SZOKOLYI, Alajos  HUN
# 4     1896   Athens  Athletics        Athletics       BURKE, Thomas  USA
# ...    ...      ...        ...              ...                 ...  ...
# 2055  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2056  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2057  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2058  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
# 2059  2008  Beijing  wrestling  Wrestling Gre-R      BAROEV, Khasan  RUS
#
#      Gender       Event Event Gender   Medal
# 0       Men       100km            M    Gold
# 1       Men       100km            M  Silver
# 2       Men        100m            M  Bronze
# 3       Men        100m            M  Bronze
# 4       Men        100m            M    Gold
# ...     ...         ...          ...     ...
# 2055    Men  96 - 120kg            M  silver
# 2056    Men  96 - 120kg            M  silver
# 2057    Men  96 - 120kg            M  silver
# 2058    Men  96 - 120kg            M  silver
# 2059    Men  96 - 120kg            M  silver
#
# [29234 rows x 10 columns]

# %%
pd.concat([oo, nw], axis=0).dtypes
# Out:
# Year            object
# City            object
# Sport           object
# Discipline      object
# Athlete Name    object
# NOC             object
# Gender          object
# Event           object
# Event Gender    object
# Medal           object
# dtype: object

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport     Discipline      Athlete Name  NOC  \
# 892   Beijing  2008.0     cycling  Cycling Track  GONZALEZ, Yoanka  CUB
# 1244  Beijing  2008.0    handball       Handball  ENTRERRIOS, Raul  ESP
# 1147  Beijing  2008.0  gymnastics    Artistic G.    LIUKIN, Nastia  USA
#
#      Gender            Event Event Gender   Medal
# 892   Women      points race            W  silver
# 1244    Men         handball            M  bronze
# 1147  Women  floor exercises            W  bronze

# %% [markdown]
# ## Working with Missing Data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport   Discipline    Athlete Name  NOC Gender  \
# 1140  Beijing  2008.0    football     Football           TANIA  BRA  Women
# 51    Beijing  2008.0    aquatics     Swimming  CAVIC, Milorad  SRB    Men
# 1173  Beijing  2008.0  gymnastics  Artistic G.    TAN, Kai Wen  USA    Men
#
#                  Event Event Gender   Medal
# 1140          football            W  silver
# 51      100m butterfly            M  silver
# 1173  team competition            M  bronze

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2033 non-null   object
#  1   Year          2025 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
nw.isna()
# Out:
#        City   Year  Sport  Discipline  Athlete Name    NOC  Gender  Event  \
# 0     False  False  False       False         False  False   False  False
# 1     False  False  False       False         False  False   False  False
# 2     False  False  False       False         False  False   False  False
# 3     False  False  False       False         False  False   False  False
# 4     False  False  False       False         False  False   False  False
# ...     ...    ...    ...         ...           ...    ...     ...    ...
# 2054  False  False  False       False         False  False   False  False
# 2055  False  False  False       False         False  False   False  False
# 2056  False  False  False       False         False  False   False  False
# 2057  False  False  False       False         False  False   False  False
# 2058  False  False  False       False         False  False   False  False
#
#       Event Gender  Medal
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...            ...    ...
# 2054         False  False
# 2055         False  False
# 2056         False  False
# 2057         False  False
# 2058         False  False
#
# [2059 rows x 10 columns]

# %%
import re

search_string = "na"

[func for func in dir(nw.City) if re.search(rf"{search_string}$", func, re.IGNORECASE)]
# Out:
# ['_can_hold_na', 'dropna', 'fillna', 'isna', 'notna']

# %%
nw.City.isna?
# Out:
# Signature: nw.City.isna() -> 'Series'
# Docstring:
# Detect missing values.
#
# Return a boolean same-sized object indicating if the values are NA.
# NA values, such as None or :attr:`numpy.NaN`, gets mapped to True
# values.
# Everything else gets mapped to False values. Characters such as empty
# strings ``''`` or :attr:`numpy.inf` are not considered NA values
# (unless you set ``pandas.options.mode.use_inf_as_na = True``).
#
# Returns
# -------
# Series
#     Mask of bool values for each element in Series that
#     indicates whether an element is an NA value.
#
# See Also
# --------
# Series.isnull : Alias of isna.
# Series.notna : Boolean inverse of isna.
# Series.dropna : Omit axes labels with missing values.
# isna : Top-level isna.
#
# Examples
# --------
# Show which entries in a DataFrame are NA.
#
# >>> df = pd.DataFrame(dict(age=[5, 6, np.nan],
# ...                        born=[pd.NaT, pd.Timestamp('1939-05-27'),
# ...                              pd.Timestamp('1940-04-25')],
# ...                        name=['Alfred', 'Batman', ''],
# ...                        toy=[None, 'Batmobile', 'Joker']))
# >>> df
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker
#
# >>> df.isna()
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False
#
# Show which entries in a Series are NA.
#
# >>> ser = pd.Series([5, 6, np.nan])
# >>> ser
# 0    5.0
# 1    6.0
# 2    NaN
# dtype: float64
#
# >>> ser.isna()
# 0    False
# 1    False
# 2     True
# dtype: bool
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/series.py
# Type:      method

# %%
pd.DataFrame.isna?
# Out:
# Signature: pd.DataFrame.isna(self) -> 'DataFrame'
# Docstring:
# Detect missing values.
#
# Return a boolean same-sized object indicating if the values are NA.
# NA values, such as None or :attr:`numpy.NaN`, gets mapped to True
# values.
# Everything else gets mapped to False values. Characters such as empty
# strings ``''`` or :attr:`numpy.inf` are not considered NA values
# (unless you set ``pandas.options.mode.use_inf_as_na = True``).
#
# Returns
# -------
# DataFrame
#     Mask of bool values for each element in DataFrame that
#     indicates whether an element is an NA value.
#
# See Also
# --------
# DataFrame.isnull : Alias of isna.
# DataFrame.notna : Boolean inverse of isna.
# DataFrame.dropna : Omit axes labels with missing values.
# isna : Top-level isna.
#
# Examples
# --------
# Show which entries in a DataFrame are NA.
#
# >>> df = pd.DataFrame(dict(age=[5, 6, np.nan],
# ...                        born=[pd.NaT, pd.Timestamp('1939-05-27'),
# ...                              pd.Timestamp('1940-04-25')],
# ...                        name=['Alfred', 'Batman', ''],
# ...                        toy=[None, 'Batmobile', 'Joker']))
# >>> df
#    age       born    name        toy
# 0  5.0        NaT  Alfred       None
# 1  6.0 1939-05-27  Batman  Batmobile
# 2  NaN 1940-04-25              Joker
#
# >>> df.isna()
#      age   born   name    toy
# 0  False   True  False   True
# 1  False  False  False  False
# 2   True  False  False  False
#
# Show which entries in a Series are NA.
#
# >>> ser = pd.Series([5, 6, np.nan])
# >>> ser
# 0    5.0
# 1    6.0
# 2    NaN
# dtype: float64
#
# >>> ser.isna()
# 0    False
# 1    False
# 2     True
# dtype: bool
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      function

# %%
nw.City.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054    False
# 2055    False
# 2056    False
# 2057    False
# 2058    False
# Name: City, Length: 2059, dtype: bool

# %%
nw.City.isna().sum()
# Out:
# np.int64(26)

# %%
nw[nw.City.isna()]
# Out:
#      City    Year          Sport       Discipline  \
# 17    NaN  2008.0       aquatics           Diving
# 25    NaN  2008.0       aquatics           Diving
# 83    NaN  2008.0       aquatics         Swimming
# 133   NaN  2008.0       aquatics         Swimming
# 199   NaN  2008.0       aquatics         Swimming
# 364   NaN  2008.0        archery          Archery
# 372   NaN  2008.0        archery          Archery
# 531   NaN  2008.0      athletics        Athletics
# 640   NaN  2008.0       baseball         Baseball
# 660   NaN  2008.0     basketball       Basketball
# 701   NaN  2008.0     basketball       Basketball
# 785   NaN  2008.0  canoe / kayak  Canoe / Kayak F
# 895   NaN  2008.0        cycling    Cycling Track
# 938   NaN  2008.0     equestrian         Eventing
# 1036  NaN  2008.0       football         Football
# 1183  NaN  2008.0     gymnastics      Artistic G.
# 1411  NaN  2008.0         hockey           Hockey
# 1505  NaN  2008.0         rowing           Rowing
# 1515  NaN  2008.0         rowing           Rowing
# 1690  NaN  2008.0       shooting         Shooting
# 1700  NaN  2008.0       shooting         Shooting
# 1819  NaN  2008.0      taekwondo        Taekwondo
# 1845  NaN  2008.0         tennis           Tennis
# 1853  NaN  2008.0     volleyball    Beach volley.
# 1913  NaN     NaN     volleyball       Volleyball
# 1995  NaN  2008.0      wrestling  Wrestling Free.
#
#                         Athlete Name  NOC Gender  \
# 17                     KLEIN, Sascha  GER    Men
# 25                 PRYGOROV, Oleksiy  UKR    Men
# 83                  NORDENSTAM, Sara  NOR  Women
# 133                  MALLET, Gregory  FRA    Men
# 199                    KELLER, Klete  USA    Men
# 364                       JIANG, Lin  CHN    Men
# 372                   NESPOLI, Mauro  ITA    Men
# 531                  MOKOENA, Khotso  RSA    Men
# 640                 MARTINEZ, Jonder  CUB    Men
# 660   KAMMERICHS, Guillermo Federico  ARG    Men
# 701                 STEPANOVA, Maria  RUS  Women
# 785                  MENG, Guanliang  CHN    Men
# 895                     MEARES, Anna  AUS  Women
# 938                 ROMEIKE, Hinrich  GER    Men
# 1036                           BRENO  BRA    Men
# 1183                  SAKAMOTO, Koki  JPN    Men
# 1411                      GAO, Lihua  CHN  Women
# 1505                 COPPOLA, Steven  USA    Men
# 1515                     KREEK, Adam  CAN    Men
# 1690                EMMONS, Katerina  CZE  Women
# 1700                  SCHUMANN, Ralf  GER    Men
# 1819                HWANG, Kyung Sun  KOR  Women
# 1845               DEMENTIEVA, Elena  RUS  Women
# 1853                   REGO, Emanuel  BRA    Men
# 1913           ALBUQUERQUE, Carolina  BRA  Women
# 1995                 YUMOTO, Kenichi  JPN    Men
#
#                                    Event Event Gender   Medal
# 17      synchronized diving 10m platform            M  silver
# 25    synchronized diving 3m springboard            M  bronze
# 83                     200m breaststroke            W  bronze
# 133               4x100m freestyle relay            M  silver
# 199               4x200m freestyle relay            M    gold
# 364      team (FITA Olympic round - 70m)            M  bronze
# 372      team (FITA Olympic round - 70m)            M  silver
# 531                            long jump            M  silver
# 640                             baseball            M  silver
# 660                           basketball            M  bronze
# 701                           basketball            W  bronze
# 785              C-2 500m (canoe double)            M    gold
# 895                               sprint            W  silver
# 938                           individual            X    gold
# 1036                            football            M  bronze
# 1183                    team competition            M  silver
# 1411                              hockey            W  silver
# 1505            eight with coxswain (8+)            M  bronze
# 1515            eight with coxswain (8+)            M    gold
# 1690            10m air rifle (40 shots)            W    gold
# 1700    25m rapid fire pistol (60 shots)            M  silver
# 1819                          57 - 67 kg            W    gold
# 1845                             singles            W    gold
# 1853                    beach volleyball            M  bronze
# 1913                          volleyball            W    gold
# 1995                           55 - 60kg            M  bronze

# %%
nw.City.unique()
# Out:
# array(['Beijing', nan], dtype=object)

# %%
nw.shape
# Out:
# (2059, 10)

# %%
import re

search_string = "na"

[func for func in dir(nw.City) if re.search(rf"{search_string}$", func, re.IGNORECASE)]
# Out:
# ['_can_hold_na', 'dropna', 'fillna', 'isna', 'notna']

# %%
nw.City.fillna?

# %%
nw.City = nw.City.fillna(value="Beijing")
nw.City.unique()
# Out:
# array(['Beijing'], dtype=object)

# %%
nw.Year
# Out:
# 0       2008.0
# 1       2008.0
# 2       2008.0
# 3       2008.0
# 4       2008.0
#          ...
# 2054    2008.0
# 2055    2008.0
# 2056    2008.0
# 2057    2008.0
# 2058    2008.0
# Name: Year, Length: 2059, dtype: float64

# %%
nw.Year.unique()
# Out:
# array([2008.,   nan])

# %%
nw.Year = nw.Year.fillna(value=2008)
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2033 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year       Sport  Discipline      Athlete Name  NOC Gender  \
# 1378  Beijing  2008.0      hockey      Hockey  BURKART, Claudia  ARG  Women
# 1389  Beijing  2008.0      hockey      Hockey      SUCCI, Belen  ARG  Women
# 724   Beijing  2008.0  basketball  Basketball    SNELL, Belinda  AUS  Women
#
#            Event Event Gender   Medal
# 1378      hockey            W  bronze
# 1389      hockey            W  bronze
# 724   basketball            W  silver

# %%
nw.dtypes
# Out:
# City             object
# Year            float64
# Sport            object
# Discipline       object
# Athlete Name     object
# NOC              object
# Gender           object
# Event            object
# Event Gender     object
# Medal            object
# dtype: object

# %% [markdown]
# ## Removing Missing Data

# %%
# !pip install --quiet pandas

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# zsh:1: /Users/owenyaggy/code/pandas-esst/linkedin/bin/pip: bad interpreter: /Users/owenyaggy/code/pandas-essential-training-new-dataset-dupe-4493047/linkedin/bin/python3: no such file or directory
# WARNING: You are using pip version 21.3.1; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Installed all of the necessary files for this section ...

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year    Sport     Discipline            Athlete Name  NOC  \
# 1575  Beijing  2008.0   rowing         Rowing           EBERT, Thomas  DEN
# 884   Beijing  2008.0  cycling  Cycling Track  PEREZ, Walter Fernando  ARG
# 1433  Beijing  2008.0     judo           Judo          ISHII, Satoshi  JPN
#
#      Gender                          Event Event Gender Medal
# 1575    Men  lightweight coxless four (4-)            M  gold
# 884     Men                        Madison            M  gold
# 1433    Men          + 100kg (heavyweight)            M  gold

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2059 non-null   object
#  1   Year          2059 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 161.0+ KB

# %%
nw[nw.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event  \
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
#
#     Event Gender Medal
# 62           NaN   NaN
# 63           NaN   NaN
# 64           NaN   NaN
# 65           NaN   NaN
# 66           NaN   NaN
# 67           NaN   NaN
# 68           NaN   NaN
# 69           NaN   NaN
# 70           NaN   NaN
# 220          NaN   NaN
# 221          NaN   NaN

# %%
nw.dropna(how="all", axis=0) # if all columns in a row are NaN, delete that row
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN
# ...       ...     ...        ...              ...               ...  ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
#
#      Gender         Event Event Gender   Medal
# 0       Men  10m platform            M  bronze
# 1       Men  10m platform            M    gold
# 2       Men  10m platform            M  silver
# 3     Women  10m platform            W  bronze
# 4     Women  10m platform            W    gold
# ...     ...           ...          ...     ...
# 2054    Men    96 - 120kg            M  silver
# 2055    Men    96 - 120kg            M  silver
# 2056    Men    96 - 120kg            M  silver
# 2057    Men    96 - 120kg            M  silver
# 2058    Men    96 - 120kg            M  silver
#
# [2059 rows x 10 columns]

# %%
nw.dropna(how="any", axis=0) # if any column in a row has a NaN, delete that row
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN
# ...       ...     ...        ...              ...               ...  ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
#
#      Gender         Event Event Gender   Medal
# 0       Men  10m platform            M  bronze
# 1       Men  10m platform            M    gold
# 2       Men  10m platform            M  silver
# 3     Women  10m platform            W  bronze
# 4     Women  10m platform            W    gold
# ...     ...           ...          ...     ...
# 2054    Men    96 - 120kg            M  silver
# 2055    Men    96 - 120kg            M  silver
# 2056    Men    96 - 120kg            M  silver
# 2057    Men    96 - 120kg            M  silver
# 2058    Men    96 - 120kg            M  silver
#
# [2048 rows x 10 columns]

# %%
nw[nw.Sport.isna()]
# Out:
#         City    Year Sport Discipline Athlete Name  NOC Gender Event  \
# 62   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 63   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 64   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 65   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 66   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 67   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 68   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 69   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 70   Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 220  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
# 221  Beijing  2008.0   NaN        NaN          NaN  NaN    NaN   NaN
#
#     Event Gender Medal
# 62           NaN   NaN
# 63           NaN   NaN
# 64           NaN   NaN
# 65           NaN   NaN
# 66           NaN   NaN
# 67           NaN   NaN
# 68           NaN   NaN
# 69           NaN   NaN
# 70           NaN   NaN
# 220          NaN   NaN
# 221          NaN   NaN

# %%
nw.dropna?

# %%
nw.columns

# %%
nw.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
# Out:
#          City    Year      Sport       Discipline      Athlete Name  NOC  \
# 0     Beijing  2008.0   aquatics           Diving    GALPERIN, Gleb  RUS
# 1     Beijing  2008.0   aquatics           Diving  MITCHAM, Matthew  AUS
# 2     Beijing  2008.0   aquatics           Diving       ZHOU, Luxin  CHN
# 3     Beijing  2008.0   aquatics           Diving         WANG, Xin  CHN
# 4     Beijing  2008.0   aquatics           Diving      CHEN, Ruolin  CHN
# ...       ...     ...        ...              ...               ...  ...
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R    BAROEV, Khasan  RUS
#
#      Gender         Event Event Gender   Medal
# 0       Men  10m platform            M  bronze
# 1       Men  10m platform            M    gold
# 2       Men  10m platform            M  silver
# 3     Women  10m platform            W  bronze
# 4     Women  10m platform            W    gold
# ...     ...           ...          ...     ...
# 2054    Men    96 - 120kg            M  silver
# 2055    Men    96 - 120kg            M  silver
# 2056    Men    96 - 120kg            M  silver
# 2057    Men    96 - 120kg            M  silver
# 2058    Men    96 - 120kg            M  silver
#
# [2048 rows x 10 columns]

# %%
nw = nw.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2048 entries, 0 to 2058
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2048 non-null   object
#  1   Year          2048 non-null   float64
#  2   Sport         2048 non-null   object
#  3   Discipline    2048 non-null   object
#  4   Athlete Name  2048 non-null   object
#  5   NOC           2048 non-null   object
#  6   Gender        2048 non-null   object
#  7   Event         2048 non-null   object
#  8   Event Gender  2048 non-null   object
#  9   Medal         2048 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 176.0+ KB

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  return df

nw = preprocess_2008()
nw.sample(3)

# %% [markdown]
# ## Working with Duplicates

# %%
# !pip install --quiet pandas

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")
# Out:
# zsh:1: /Users/owenyaggy/code/pandas-esst/linkedin/bin/pip: bad interpreter: /Users/owenyaggy/code/pandas-essential-training-new-dataset-dupe-4493047/linkedin/bin/python3: no such file or directory
# WARNING: You are using pip version 21.3.1; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Installed all of the necessary files for this section ...

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year     Sport Discipline       Athlete Name  NOC Gender  \
# 25    Beijing  2008.0  aquatics     Diving  PRYGOROV, Oleksiy  UKR    Men
# 1077  Beijing  2008.0  football   Football     ISAAC, Promise  NGR    Men
# 1316  Beijing  2008.0  handball   Handball    POLENOVA, Elena  RUS  Women
#
#                                    Event Event Gender   Medal
# 25    synchronized diving 3m springboard            M  bronze
# 1077                            football            M  silver
# 1316                            handball            W  silver

# %%
nw.shape
# Out:
# (2048, 10)

# %%
nw.duplicated?
# Out:
# Signature:
# nw.duplicated(
#     subset: 'Hashable | Sequence[Hashable] | None' = None,
#     keep: 'DropKeep' = 'first',
# ) -> 'Series'
# Docstring:
# Return boolean Series denoting duplicate rows.
#
# Considering certain columns is optional.
#
# Parameters
# ----------
# subset : column label or sequence of labels, optional
#     Only consider certain columns for identifying duplicates, by
#     default use all of the columns.
# keep : {'first', 'last', False}, default 'first'
#     Determines which duplicates (if any) to mark.
#
#     - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
#     - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
#     - False : Mark all duplicates as ``True``.
#
# Returns
# -------
# Series
#     Boolean series for each duplicated rows.
#
# See Also
# --------
# Index.duplicated : Equivalent method on index.
# Series.duplicated : Equivalent method on Series.
# Series.drop_duplicates : Remove duplicate values from Series.
# DataFrame.drop_duplicates : Remove duplicate values from DataFrame.
#
# Examples
# --------
# Consider dataset containing ramen rating.
#
# >>> df = pd.DataFrame({
# ...     'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
# ...     'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
# ...     'rating': [4, 4, 3.5, 15, 5]
# ... })
# >>> df
#     brand style  rating
# 0  Yum Yum   cup     4.0
# 1  Yum Yum   cup     4.0
# 2  Indomie   cup     3.5
# 3  Indomie  pack    15.0
# 4  Indomie  pack     5.0
#
# By default, for each set of duplicated values, the first occurrence
# is set on False and all others on True.
#
# >>> df.duplicated()
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool
#
# By using 'last', the last occurrence of each set of duplicated values
# is set on False and all others on True.
#
# >>> df.duplicated(keep='last')
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
#
# By setting ``keep`` on False, all duplicates are True.
#
# >>> df.duplicated(keep=False)
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool
#
# To find duplicates on specific column(s), use ``subset``.
#
# >>> df.duplicated(subset=['brand'])
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# dtype: bool
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      method

# %%
nw.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2054     True
# 2055     True
# 2056     True
# 2057     True
# 2058     True
# Length: 2048, dtype: bool

# %%
nw.duplicated().sum()
# Out:
# np.int64(6)

# %%
nw.loc[nw.duplicated(), :]
# Out:
#          City    Year      Sport       Discipline    Athlete Name  NOC Gender  \
# 2053  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2054  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2055  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2056  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2057  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
# 2058  Beijing  2008.0  wrestling  Wrestling Gre-R  BAROEV, Khasan  RUS    Men
#
#            Event Event Gender   Medal
# 2053  96 - 120kg            M  silver
# 2054  96 - 120kg            M  silver
# 2055  96 - 120kg            M  silver
# 2056  96 - 120kg            M  silver
# 2057  96 - 120kg            M  silver
# 2058  96 - 120kg            M  silver

# %%
nw.shape

# %%
nw = nw.drop_duplicates()
nw.shape
# Out:
# (2042, 10)

# %%
nw.columns

# %%
athlete_multiple_events = nw.duplicated(subset=['Athlete Name', 'NOC', 'Gender'])
athlete_multiple_events
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2048    False
# 2049    False
# 2050    False
# 2051    False
# 2052    False
# Length: 2042, dtype: bool

# %%
nw.duplicated?

# %%
nw.loc[athlete_multiple_events, :]
# Out:
#          City    Year         Sport    Discipline    Athlete Name  NOC Gender  \
# 13    Beijing  2008.0      aquatics        Diving  GALPERIN, Gleb  RUS    Men
# 20    Beijing  2008.0      aquatics        Diving    CHEN, Ruolin  CHN  Women
# 21    Beijing  2008.0      aquatics        Diving       WANG, Xin  CHN  Women
# 26    Beijing  2008.0      aquatics        Diving        QIN, Kai  CHN    Men
# 32    Beijing  2008.0      aquatics        Diving   GUO, Jingjing  CHN  Women
# ...       ...     ...           ...           ...             ...  ...    ...
# 1783  Beijing  2008.0  table tennis  Table Tennis       WANG, Hao  CHN    Men
# 1784  Beijing  2008.0  table tennis  Table Tennis     WANG, Liqin  CHN    Men
# 1791  Beijing  2008.0  table tennis  Table Tennis        GUO, Yue  CHN  Women
# 1792  Beijing  2008.0  table tennis  Table Tennis       WANG, Nan  CHN  Women
# 1793  Beijing  2008.0  table tennis  Table Tennis   ZHANG, Yining  CHN  Women
#
#                                    Event Event Gender   Medal
# 13      synchronized diving 10m platform            M  bronze
# 20      synchronized diving 10m platform            W    gold
# 21      synchronized diving 10m platform            W    gold
# 26    synchronized diving 3m springboard            M    gold
# 32    synchronized diving 3m springboard            W    gold
# ...                                  ...          ...     ...
# 1783                                team            M    gold
# 1784                                team            M    gold
# 1791                                team            W    gold
# 1792                                team            W    gold
# 1793                                team            W    gold
#
# [175 rows x 10 columns]

# %%
nw.loc[athlete_multiple_events, :].sort_values("Athlete Name")
# Out:
#          City    Year         Sport    Discipline          Athlete Name  NOC  \
# 489   Beijing  2008.0     athletics     Athletics    ABEYLEGESSE, Elvan  TUR
# 239   Beijing  2008.0      aquatics      Swimming    ADLINGTON, Rebecca  GBR
# 1595  Beijing  2008.0        rowing        Rowing  ANDRUNACHE, Georgeta  ROU
# 485   Beijing  2008.0     athletics     Athletics      BEKELE, Kenenisa  ETH
# 129   Beijing  2008.0      aquatics      Swimming        BERNARD, Alain  FRA
# ...       ...     ...           ...           ...                   ...  ...
# 1024  Beijing  2008.0       fencing       Fencing       ZAGUNIS, Mariel  USA
# 381   Beijing  2008.0       archery       Archery      ZHANG, Juan Juan  CHN
# 1793  Beijing  2008.0  table tennis  Table Tennis         ZHANG, Yining  CHN
# 1179  Beijing  2008.0    gymnastics   Artistic G.              ZOU, Kai  CHN
# 1151  Beijing  2008.0    gymnastics   Artistic G.              ZOU, Kai  CHN
#
#      Gender                            Event Event Gender   Medal
# 489   Women                            5000m            W  silver
# 239   Women                   800m freestyle            W    gold
# 1595  Women       pair without coxswain (2-)            W    gold
# 485     Men                            5000m            M    gold
# 129     Men           4x100m freestyle relay            M  silver
# ...     ...                              ...          ...     ...
# 1024  Women                       sabre team            W  bronze
# 381   Women  team (FITA Olympic round - 70m)            W  silver
# 1793  Women                             team            W    gold
# 1179    Men                 team competition            M    gold
# 1151    Men                   horizontal bar            M    gold
#
# [175 rows x 10 columns]

# %%
nw.loc[nw["Athlete Name"] == "ZOU, Kai"]
# Out:
#          City    Year       Sport   Discipline Athlete Name  NOC Gender  \
# 1145  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
# 1151  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
# 1179  Beijing  2008.0  gymnastics  Artistic G.     ZOU, Kai  CHN    Men
#
#                  Event Event Gender Medal
# 1145   floor exercises            M  gold
# 1151    horizontal bar            M  gold
# 1179  team competition            M  gold

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year          Sport       Discipline    Athlete Name  NOC  \
# 497   Beijing  2008.0      athletics        Athletics  JELIMO, Pamela  KEN
# 827   Beijing  2008.0  canoe / kayak  Canoe / Kayak F     VLCEK, Erik  SVK
# 1651  Beijing  2008.0        sailing          Sailing  GOODISON, Paul  GBR
#
#      Gender                      Event Event Gender   Medal
# 497   Women                       800m            W    gold
# 827     Men     K-4 1000m (kayak four)            M  silver
# 1651    Men  Laser - One Person Dinghy            M    gold

# %% [markdown]
# ## Validating data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#          City    Year     Sport Discipline            Athlete Name  NOC  \
# 756   Beijing  2008.0    boxing     Boxing            KIM, Jungjoo  KOR
# 1304  Beijing  2008.0  handball   Handball           LARSEN, Tonje  NOR
# 1315  Beijing  2008.0  handball   Handball  MARENNIKOVA, Ekaterina  RUS
#
#      Gender       Event Event Gender   Medal
# 756     Men  64 - 69 kg            M  bronze
# 1304  Women    handball            W    gold
# 1315  Women    handball            W  silver

# %%
nw["Event Gender"].unique()
# Out:
# array(['M', 'W', 'X'], dtype=object)

# %%
nw.Gender.unique()
# Out:
# array(['Men', 'Women'], dtype=object)

# %%
nw.loc[(nw["Event Gender"] == "M") & (nw.Gender != "Men")]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw["Event Gender"] == "F") & (nw.Gender != "Women")]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw.Gender == "Women") & ((nw["Event Gender"] != "W") & (nw["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
nw.loc[(nw.Gender == "Men") & ((nw["Event Gender"] != "M") & (nw["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [City, Year, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo["Event Gender"].unique()
# Out:
# ['M', 'X', 'W']
# Categories (3, object): ['M', 'W', 'X']

# %%
oo.Gender.unique()
# Out:
# ['Men', 'Women']
# Categories (2, object): ['Men', 'Women']

# %%
oo.loc[(oo["Event Gender"] == "M") & (oo.Gender != "Men")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo["Event Gender"] == "F") & (oo.Gender != "Women")]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo.Gender == "Women") & ((oo["Event Gender"] != "W") & (oo["Event Gender"] != "X"))]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete Name, NOC, Gender, Event, Event Gender, Medal]
# Index: []

# %%
oo.loc[(oo.Gender == "Men") & ((oo["Event Gender"] != "M") & (oo["Event Gender"] != "X"))]
# Out:
#        Year    City      Sport Discipline       Athlete Name  NOC Gender  \
# 24676  2000  Sydney  Athletics  Athletics  CHEPCHUMBA, Joyce  KEN    Men
#
#           Event Event Gender   Medal
# 24676  marathon            W  Bronze

# %%
oo.loc[(oo.Year == 2000) & (oo.Event == "marathon")]
# Out:
#        Year    City      Sport Discipline        Athlete Name  NOC Gender  \
# 24675  2000  Sydney  Athletics  Athletics       TOLA, Tesfaye  ETH    Men
# 24676  2000  Sydney  Athletics  Athletics   CHEPCHUMBA, Joyce  KEN    Men
# 24677  2000  Sydney  Athletics  Athletics    ABERA, Gezahegne  ETH    Men
# 24678  2000  Sydney  Athletics  Athletics     WAINAINA, Erick  KEN    Men
# 24679  2000  Sydney  Athletics  Athletics    TAKAHASHI, Naoko  JPN  Women
# 24680  2000  Sydney  Athletics  Athletics  SIMON, Lidia Elena  ROU  Women
#
#           Event Event Gender   Medal
# 24675  marathon            M  Bronze
# 24676  marathon            W  Bronze
# 24677  marathon            M    Gold
# 24678  marathon            M  Silver
# 24679  marathon            W    Gold
# 24680  marathon            W  Silver

# %%
oo.loc[24676, "Gender"] = "Women"
oo.loc[(oo.Year == 2000) & (oo.Event == "marathon")]
# Out:
#        Year    City      Sport Discipline        Athlete Name  NOC Gender  \
# 24675  2000  Sydney  Athletics  Athletics       TOLA, Tesfaye  ETH    Men
# 24676  2000  Sydney  Athletics  Athletics   CHEPCHUMBA, Joyce  KEN  Women
# 24677  2000  Sydney  Athletics  Athletics    ABERA, Gezahegne  ETH    Men
# 24678  2000  Sydney  Athletics  Athletics     WAINAINA, Erick  KEN    Men
# 24679  2000  Sydney  Athletics  Athletics    TAKAHASHI, Naoko  JPN  Women
# 24680  2000  Sydney  Athletics  Athletics  SIMON, Lidia Elena  ROU  Women
#
#           Event Event Gender   Medal
# 24675  marathon            M  Bronze
# 24676  marathon            W  Bronze
# 24677  marathon            M    Gold
# 24678  marathon            M  Silver
# 24679  marathon            W    Gold
# 24680  marathon            W  Silver

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  return df

oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#       Year     City       Sport   Discipline      Athlete Name  NOC Gender  \
# 1530  1908   London    Shooting     Shooting  COURQUIN, Albert  FRA    Men
# 346   1900    Paris      Rowing       Rowing       EXLEY, John  USA    Men
# 3923  1920  Antwerp  Gymnastics  Artistic G.     FIEMS, Joseph  BEL    Men
#
#                          Event Event Gender   Medal
# 1530          free rifle, team            M  Bronze
# 346   eight with coxswain (8+)            M    Gold
# 3923      team, Swedish system            M  Bronze

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
nw.Year.unique()
# Out:
# array([2008.])

# %%
nw.City.unique()
# Out:
# array(['Beijing'], dtype=object)

# %%
nw["Event Gender"].unique()
# Out:
# array(['M', 'W', 'X'], dtype=object)

# %%
nw["Event Gender"].unique().tolist()
# Out:
# ['M', 'W', 'X']

# %%
oo["Event Gender"].unique().tolist()
# Out:
# ['M', 'X', 'W']

# %%
nw["Event Gender"].unique().tolist() == oo["Event Gender"].unique().tolist()
# Out:
# False

# %%
sorted(nw["Event Gender"].unique().tolist())
# Out:
# ['M', 'W', 'X']

# %%
sorted(oo["Event Gender"].unique().tolist())
# Out:
# ['M', 'W', 'X']

# %%
assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
print("Passes all tests ...")
# Out:
# Passes all tests ...

# %%
assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
assert(sorted(nw.Gender.unique().tolist()) == sorted(oo.Gender.unique().tolist()))
assert(sorted(nw.Medal.unique().tolist()) == sorted(oo.Medal.unique().tolist()))
#print("Passes all tests ...")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[235], line 3
#       1 assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
#       2 assert(sorted(nw.Gender.unique().tolist()) == sorted(oo.Gender.unique().tolist()))
# ----> 3 assert(sorted(nw.Medal.unique().tolist()) == sorted(oo.Medal.unique().tolist()))
#       4 #print("Passes all tests ...")
#
# AssertionError:

# %%
sorted(oo.Medal.unique().tolist())
# Out:
# ['Bronze', 'Gold', 'Silver']

# %%
sorted(nw.Medal.unique().tolist())
# Out:
# ['bronze', 'gold', 'silver']

# %%
nw.Medal.str.capitalize()
# Out:
# 0       Bronze
# 1         Gold
# 2       Silver
# 3       Bronze
# 4         Gold
#          ...
# 2048    Silver
# 2049    Bronze
# 2050    Bronze
# 2051      Gold
# 2052    Silver
# Name: Medal, Length: 2042, dtype: object

# %%
nw.Medal = nw.Medal.str.capitalize()
nw.sample(3)
# Out:
#          City    Year       Sport  Discipline     Athlete Name  NOC Gender  \
# 518   Beijing  2008.0   athletics   Athletics   SILNOV, Andrey  RUS    Men
# 1882  Beijing  2008.0  volleyball  Volleyball       LEE, David  USA    Men
# 998   Beijing  2008.0     fencing     Fencing  BOYKO, Svetlana  RUS  Women
#
#            Event Event Gender Medal
# 518    high jump            M  Gold
# 1882  volleyball            M  Gold
# 998    foil team            W  Gold

# %%
assert(sorted(nw["Event Gender"].unique().tolist()) == sorted(oo["Event Gender"].unique().tolist()))
assert(sorted(nw.Gender.unique().tolist()) == sorted(oo.Gender.unique().tolist()))
assert(sorted(nw.Medal.unique().tolist()) == sorted(oo.Medal.unique().tolist()))
print("Passes all tests ...")
# Out:
# Passes all tests ...

# %%
sorted(nw.Sport.unique().tolist())
# Out:
# ['aquatics',
#  'archery',
#  'athletics',
#  'badminton',
#  'baseball',
#  'basketball',
#  'boxing',
#  'canoe / kayak',
#  'cycling',
#  'equestrian',
#  'fencing',
#  'football',
#  'gymnastics',
#  'handball',
#  'hockey',
#  'judo',
#  'modern pentathlon',
#  'rowing',
#  'sailing',
#  'shooting',
#  'softball',
#  'table tennis',
#  'taekwondo',
#  'tennis',
#  'triathlon',
#  'volleyball',
#  'weightlifting',
#  'wrestling']

# %%
sorted(oo.Sport.unique().tolist())
# Out:
# ['Aquatics',
#  'Archery',
#  'Athletics',
#  'Badminton',
#  'Baseball',
#  'Basketball',
#  'Basque Pelota',
#  'Boxing',
#  'Canoe / Kayak',
#  'Cricket',
#  'Croquet',
#  'Cycling',
#  'Equestrian',
#  'Fencing',
#  'Football',
#  'Golf',
#  'Gymnastics',
#  'Handball',
#  'Hockey',
#  'Ice Hockey',
#  'Jeu de paume',
#  'Judo',
#  'Lacrosse',
#  'Modern Pentathlon',
#  'Polo',
#  'Rackets',
#  'Roque',
#  'Rowing',
#  'Rugby',
#  'Sailing',
#  'Shooting',
#  'Skating',
#  'Softball',
#  'Table Tennis',
#  'Taekwondo',
#  'Tennis',
#  'Triathlon',
#  'Tug of War',
#  'Volleyball',
#  'Water Motorsports',
#  'Weightlifting',
#  'Wrestling']

# %%
nw.NOC.unique()
# Out:
# array(['RUS', 'AUS', 'CHN', 'CAN', 'GER', 'MEX', 'UKR', 'USA', 'ZIM',
#        'FRA', 'JPN', 'NOR', 'AUT', 'SRB', 'BRA', 'TUN', 'HUN', 'KOR',
#        'ITA', 'SLO', 'GBR', 'NED', 'DEN', 'ESP', 'KEN', 'ETH', 'TUR',
#        'JAM', 'TRI', 'CUB', 'NZL', 'ECU', 'NGR', 'BEL', 'BAH', 'SUD',
#        'MAR', 'BLR', 'LTU', 'EST', 'POL', 'CRO', 'FIN', 'LAT', 'CZE',
#        'PAN', 'RSA', 'ROU', 'POR', 'GRE', 'CMR', 'INA', 'MAS', 'ARG',
#        'THA', 'IRL', 'MGL', 'MDA', 'MRI', 'AZE', 'ARM', 'DOM', 'KAZ',
#        'IND', 'SVK', 'TOG', 'SUI', 'SWE', 'UZB', 'PRK', 'ISL', 'ALG',
#        'TJK', 'EGY', 'GEO', 'BUL', 'ISR', 'SIN', 'VEN', 'TPE', 'AFG',
#        'IRI', 'CHI', 'VIE', 'COL', 'KGZ'], dtype=object)

# %%
nw.Sport = nw.Sport.str.lower()
nw.Discipline = nw.Discipline.str.lower()
nw.Event = nw.Event.str.lower()
nw.NOC = nw.NOC.str.upper()
nw.sample(3)
# Out:
#          City    Year          Sport     Discipline    Athlete Name  NOC  \
# 30    Beijing  2008.0       aquatics         diving  FISCHER, Heike  GER
# 1636  Beijing  2008.0        sailing        sailing    SWAN, Isabel  BRA
# 1944  Beijing  2008.0  weightlifting  weightlifting     JANG, Miran  KOR
#
#      Gender                               Event Event Gender   Medal
# 30    Women  synchronized diving 3m springboard            W  Bronze
# 1636  Women             470 - two person dinghy            W  Bronze
# 1944  Women                              + 75kg            W    Gold

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
#          City    Year     Sport  Discipline     Athlete Name  NOC Gender  \
# 1543  Beijing  2008.0    rowing      rowing    GOODALE, Anna  USA  Women
# 308   Beijing  2008.0  aquatics  water polo  BEAUBIEN, Layne  USA    Men
# 1435  Beijing  2008.0      judo        judo    ORTIZ, Idalys  CUB  Women
#
#                          Event Event Gender   Medal
# 1543  eight with coxswain (8+)            W    Gold
# 308                 water polo            M  Silver
# 1435      + 78kg (heavyweight)            W  Bronze

# %% [markdown]
# ## Further Data Validation

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  return df

oo = preprocess()

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#         City    Year          Sport       Discipline      Athlete Name  NOC  \
# 915  Beijing  2008.0        cycling    Cycling Track      KENNY, Jason  GBR
# 42   Beijing  2008.0       aquatics         Swimming  COVENTRY, Kirsty  ZIM
# 788  Beijing  2008.0  canoe / kayak  Canoe / Kayak F    ULEGIN, Sergey  RUS
#
#     Gender                    Event Event Gender   Medal
# 915    Men              Team Sprint            M    gold
# 42   Women          100m backstroke            W  silver
# 788    Men  C-2 500m (canoe double)            M  silver

# %%
medals = ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold']
medals
# Out:
# ['Gold', 'Silver', 'Bronze', 'Bronze', 'Gold']

# %%
medals[0]
# Out:
# 'Gold'

# %%
medals[1]
# Out:
# 'Silver'

# %%
len(medals)
# Out:
# 5

# %%
nw["Athlete Name"]
# Out:
# 0             GALPERIN, Gleb
# 1           MITCHAM, Matthew
# 2                ZHOU, Luxin
# 3                  WANG, Xin
# 4               CHEN, Ruolin
#                 ...
# 2048          ENGLICH, Mirko
# 2049    MIZGAITIS, Mindaugas
# 2050         PATRIKEEV, Yuri
# 2051           LOPEZ, Mijain
# 2052          BAROEV, Khasan
# Name: Athlete Name, Length: 2042, dtype: object

# %%
import re

search_string = "split"

[func for func in dir(nw["Athlete Name"].str) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['rsplit', 'split']

# %%
nw["Athlete Name"].str.split?
# Out:
# Signature: str.split(self, /, sep=None, maxsplit=-1)
# Docstring:
# Return a list of the words in the string, using sep as the delimiter string.
#
# sep
#   The delimiter according which to split the string.
#   None (the default value) means split according to any whitespace,
#   and discard empty strings from the result.
# maxsplit
#   Maximum number of splits to do.
#   -1 (the default value) means no limit.
# Type:      method_descriptor

# %%
nw["Athlete Name"].str.split(", ")
# Out:
# 0             [GALPERIN, Gleb]
# 1           [MITCHAM, Matthew]
# 2                [ZHOU, Luxin]
# 3                  [WANG, Xin]
# 4               [CHEN, Ruolin]
#                  ...
# 2048          [ENGLICH, Mirko]
# 2049    [MIZGAITIS, Mindaugas]
# 2050         [PATRIKEEV, Yuri]
# 2051           [LOPEZ, Mijain]
# 2052          [BAROEV, Khasan]
# Name: Athlete Name, Length: 2042, dtype: object

# %%
nw["Athlete Name"].str.split(", ").tolist()
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
athlete_names = nw["Athlete Name"].str.split(", ").tolist()
athlete_names
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
import re

search_string = "upper"

[func for func in dir(nw["Athlete Name"].str) if re.search(rf"{search_string}", func, re.IGNORECASE)]
# Out:
# ['isupper', 'upper']

# %%
[athlete_name for athlete_name in athlete_names]
# Out:
# [['GALPERIN', 'Gleb'],
#  ['MITCHAM', 'Matthew'],
#  ['ZHOU', 'Luxin'],
#  ['WANG', 'Xin'],
#  ['CHEN', 'Ruolin'],
#  ['HEYMANS', 'Emilie'],
#  ['QIN', 'Kai'],
#  ['HE', 'Chong'],
#  ['DESPATIE', 'Alexandre'],
#  ['WU', 'Minxia'],
#  ['GUO', 'Jingjing'],
#  ['PAKHALINA', 'Julia'],
#  ['DOBROSKOK', 'Dmitriy'],
#  ['GALPERIN', 'Gleb'],
#  ['HUO', 'Liang'],
#  ['LIN', 'Yue'],
#  ['HAUSDING', 'Patrick'],
#  ['KLEIN', 'Sascha'],
#  ['ESPINOSA', 'Paola'],
#  ['ORTIZ', 'Tatiana'],
#  ['CHEN', 'Ruolin'],
#  ['WANG', 'Xin'],
#  ['COLE', 'Briony'],
#  ['WU', 'Melissa'],
#  ['KVASHA', 'Illya'],
#  ['PRYGOROV', 'Oleksiy'],
#  ['QIN', 'Kai'],
#  ['WANG', 'Feng'],
#  ['KUNAKOV', 'Yuriy'],
#  ['SAUTIN', 'Dmitry'],
#  ['FISCHER', 'Heike'],
#  ['KOTZIAN', 'Ditte'],
#  ['GUO', 'Jingjing'],
#  ['WU', 'Minxia'],
#  ['PAKHALINA', 'Julia'],
#  ['POZDNYAKOVA', 'Anastasia'],
#  ['STOECKEL', 'Hayden'],
#  ['VYATCHANIN', 'Arkady'],
#  ['PEIRSOL', 'Aaron'],
#  ['GREVERS', 'Matt'],
#  ['HOELZER', 'Margaret'],
#  ['COUGHLIN', 'Natalie'],
#  ['COVENTRY', 'Kirsty'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['OEN', 'Alexander Dale'],
#  ['JUKIC', 'Mirna'],
#  ['JONES', 'Leisel'],
#  ['SONI', 'Rebecca'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PHELPS', 'Michael'],
#  ['CAVIC', 'Milorad'],
#  ['SCHIPPER', 'Jessicah'],
#  ['TRICKETT', 'Lisbeth'],
#  ['MAGNUSON', 'Christine'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEZAK', 'Jason'],
#  ['BERNARD', 'Alain'],
#  ['SULLIVAN', 'Eamon'],
#  ['COUGHLIN', 'Natalie'],
#  ['STEFFEN', 'Britta'],
#  ['TRICKETT', 'Lisbeth'],
#  ['COCHRANE', 'Ryan'],
#  ['MELLOULI', 'Oussama'],
#  ['HACKETT', 'Grant'],
#  ['VYATCHANIN', 'Arkady'],
#  ['LOCHTE', 'Ryan'],
#  ['PEIRSOL', 'Aaron'],
#  ['NAKAMURA', 'Reiko'],
#  ['COVENTRY', 'Kirsty'],
#  ['HOELZER', 'Margaret'],
#  ['DUBOSCQ', 'Hugues'],
#  ['KITAJIMA', 'Kosuke'],
#  ['RICKARD', 'Brenton'],
#  ['NORDENSTAM', 'Sara'],
#  ['SONI', 'Rebecca'],
#  ['JONES', 'Leisel'],
#  ['MATSUDA', 'Takeshi'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['SCHIPPER', 'Jessicah'],
#  ['LIU', 'Zige'],
#  ['JIAO', 'Liuyang'],
#  ['VANDERKAAY', 'Peter'],
#  ['PHELPS', 'Michael'],
#  ['PARK', 'Taehwan'],
#  ['PANG', 'Jiaying'],
#  ['PELLEGRINI', 'Federica'],
#  ['ISAKOVIC', 'Sara'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['COUGHLIN', 'Natalie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['JENSEN', 'Larsen'],
#  ['PARK', 'Taehwan'],
#  ['ZHANG', 'Lin'],
#  ['JACKSON', 'Joanne'],
#  ['ADLINGTON', 'Rebecca'],
#  ['HOFF', 'Katie'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['CSEH', 'Laszlo'],
#  ['HOFF', 'Katie'],
#  ['RICE', 'Stephanie'],
#  ['COVENTRY', 'Kirsty'],
#  ['BRODIE', 'Leith'],
#  ['CALLUS', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['MURPHY', 'Patrick'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['ADRIAN', 'Nathan'],
#  ['GREVERS', 'Matt'],
#  ['JONES', 'Cullen'],
#  ['LEZAK', 'Jason'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['WILDMAN-TOBRINER', 'Ben'],
#  ['BERNARD', 'Alain'],
#  ['BOUSQUET', 'Frederick'],
#  ['GILOT', 'Fabien'],
#  ['LEVEAUX', 'Amaury'],
#  ['MALLET', 'Gregory'],
#  ['STEIMETZ', 'Boris'],
#  ['CAMPBELL', 'Cate'],
#  ['MILLS', 'Alice'],
#  ['REESE', 'Shayne'],
#  ['SCHLANGER', 'Melanie'],
#  ['TRICKETT', 'Lisbeth'],
#  ['DEKKER', 'Inge'],
#  ['HEEMSKERK', 'Femke'],
#  ['KROMOWIDJOJO', 'Ranomi'],
#  ['SCHREUDER', 'Hinkelien'],
#  ['VAN ROOIJEN', 'Manon'],
#  ['VELDHUIS', 'Marleen'],
#  ['COUGHLIN', 'Natalie'],
#  ['JOYCE', 'Kara Lynn'],
#  ['NYMEYER', 'Lacey'],
#  ['SILVER', 'Emily'],
#  ['SMIT', 'Julia'],
#  ['TORRES', 'Dara'],
#  ['FUJII', 'Takuro'],
#  ['KITAJIMA', 'Kosuke'],
#  ['MIYASHITA', 'Junichi'],
#  ['SATO', 'Hisayoshi'],
#  ['CROCKER', 'Ian'],
#  ['GANGLOFF', 'Mark'],
#  ['GREVERS', 'Matt'],
#  ['HANSEN', 'Brendan'],
#  ['LEZAK', 'Jason'],
#  ['PEIRSOL', 'Aaron'],
#  ['PHELPS', 'Michael'],
#  ['WEBER-GALE', 'Garrett'],
#  ['DELANEY', 'Ashley'],
#  ['LAUTERSTEIN', 'Andrew'],
#  ['PINE', 'Adam'],
#  ['RICKARD', 'Brenton'],
#  ['SPRENGER', 'Christian'],
#  ['STOECKEL', 'Hayden'],
#  ['SULLIVAN', 'Eamon'],
#  ['TARGETT', 'Matt'],
#  ['PANG', 'Jiaying'],
#  ['SUN', 'Ye'],
#  ['XU', 'Tianlongzi'],
#  ['ZHAO', 'Jing'],
#  ['ZHOU', 'Yafei'],
#  ['GALVEZ', 'Felicity'],
#  ['JONES', 'Leisel'],
#  ['REESE', 'Shayne'],
#  ['SCHIPPER', 'Jessicah'],
#  ['SEEBOHM', 'Emily'],
#  ['TRICKETT', 'Lisbeth'],
#  ['WHITE', 'Tarnee'],
#  ['BREEDEN', 'Elaine'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOELZER', 'Margaret'],
#  ['JENDRICK', 'Megan'],
#  ['JOYCE', 'Kara Lynn'],
#  ['MAGNUSON', 'Christine'],
#  ['SONI', 'Rebecca'],
#  ['TORRES', 'Dara'],
#  ['BRITS', 'Grant'],
#  ['BRODIE', 'Leith'],
#  ['FFROST', 'Nick'],
#  ['HACKETT', 'Grant'],
#  ['MURPHY', 'Patrick'],
#  ['PALMER', 'Kirk'],
#  ['BERENS', 'Ricky'],
#  ['KELLER', 'Klete'],
#  ['LOCHTE', 'Ryan'],
#  ['PHELPS', 'Michael'],
#  ['VANDERKAAY', 'Peter'],
#  ['VENDT', 'Erik'],
#  ['WALTERS', 'David'],
#  ['IZOTOV', 'Danila'],
#  ['LAGUNOV', 'Evgeniy'],
#  ['LOBINTSEV', 'Nikita'],
#  ['POLISHCHUK', 'Mikhail'],
#  ['SUKHORUKOV', 'Alexander'],
#  ['BURCKLE', 'Caroline'],
#  ['COUGHLIN', 'Natalie'],
#  ['HOFF', 'Katie'],
#  ['MARSHALL', 'Christine'],
#  ['SCHMITT', 'Allison'],
#  ['SMIT', 'Julia'],
#  ['VANDENBERG', 'Kim'],
#  ['BAINBRIDGE', 'Angie'],
#  ['BARRATT', 'Bronte'],
#  ['DAVENPORT', 'Lara'],
#  ['GALVEZ', 'Felicity'],
#  ['MACKENZIE', 'Linda'],
#  ['PALMER', 'Kylie'],
#  ['RICE', 'Stephanie'],
#  ['SCHLANGER', 'Melanie'],
#  ['PANG', 'Jiaying'],
#  ['TAN', 'Miao'],
#  ['TANG', 'Jingzhi'],
#  ['YANG', 'Yu'],
#  ['ZHU', 'Qianwei'],
#  ['BERNARD', 'Alain'],
#  ['CIELO FILHO', 'Cesar'],
#  ['LEVEAUX', 'Amaury'],
#  ['CAMPBELL', 'Cate'],
#  ['STEFFEN', 'Britta'],
#  ['TORRES', 'Dara'],
#  ['FRIIS', 'Lotte'],
#  ['ADLINGTON', 'Rebecca'],
#  ['FILIPPI', 'Alessia'],
#  ['LURZ', 'Thomas'],
#  ['VAN DER WEIJDEN', 'Maarten'],
#  ['DAVIES', 'David'],
#  ['PATTEN', 'Cassandra'],
#  ['ILCHENKO', 'Larisa'],
#  ['PAYNE', 'Keri-Anne'],
#  ['HARADA', 'Saho'],
#  ['SUZUKI', 'Emiko'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['FUENTES', 'Andrea'],
#  ['MENGUAL', 'Gemma'],
#  ['GU', 'Beibei'],
#  ['HUANG', 'Xuechen'],
#  ['JIANG', 'Tingting'],
#  ['JIANG', 'Wenwen'],
#  ['LIU', 'Ou'],
#  ['LUO', 'Xi'],
#  ['SUN', 'Qiuting'],
#  ['WANG', 'Na'],
#  ['ZHANG', 'Xiaohuan'],
#  ['DAVYDOVA', 'Anastasia'],
#  ['ERMAKOVA', 'Anastasia'],
#  ['GROMOVA', 'Maria'],
#  ['ISHCHENKO', 'Natalia'],
#  ['KHASYANOVA', 'Elvira'],
#  ['KUZHELA', 'Olga'],
#  ['OVCHINNIKOVA', 'Elena'],
#  ['ROMASHINA', 'Svetlana'],
#  ['SHORINA', 'Anna'],
#  ['CABELLO', 'Alba Maria'],
#  ['CORRAL', 'Raquel'],
#  ['FUENTES', 'Andrea'],
#  ['HENRIQUEZ', 'Thais'],
#  ['LOPEZ', 'Laura'],
#  ['MENGUAL', 'Gemma'],
#  ['MORON', 'Gisela'],
#  ['RODRIGUEZ', 'Irina'],
#  ['TIRADOS', 'Paola'],
#  ['CIRIC', 'Aleksandar'],
#  ['FILIPOVIC', 'Filip'],
#  ['GOCIC', 'Zivko'],
#  ['PEKOVIC', 'Branko'],
#  ['PIJETLOVIC', 'Dusko'],
#  ['PRLAINOVIC', 'Andrija'],
#  ['RADJEN', 'Nikola'],
#  ['SAPIC', 'Aleksandar'],
#  ['SAVIC', 'Dejan'],
#  ['SEFIK', 'Denis'],
#  ['SORO', 'Slobodan'],
#  ['UDOVICIC', 'Vanja'],
#  ['VUJASINOVIC', 'Vladimir'],
#  ['BENEDEK', 'Tibor'],
#  ['BIROS', 'Peter'],
#  ['GERGELY', 'Istvan'],
#  ['HOSNYANSZKY', 'Norbert'],
#  ['KASAS', 'Tamas'],
#  ['KIS', 'Gabor'],
#  ['KISS', 'Gergely'],
#  ['MADARAS', 'Norbert'],
#  ['MOLNAR', 'Tamas'],
#  ['SZECSI', 'Zoltan'],
#  ['VARGA', 'Daniel Rudolf'],
#  ['VARGA', 'Denes Andor'],
#  ['VARGA', 'Tamas'],
#  ['AZEVEDO', 'Tony'],
#  ['BAILEY', 'Ryan'],
#  ['BEAUBIEN', 'Layne'],
#  ['BROOKS', 'Brandon'],
#  ['HUDNUT', 'Peter'],
#  ['HUTTEN', 'Tim'],
#  ['KRUMPHOLZ', 'James'],
#  ['MERLO', 'Rick'],
#  ['MOSES', 'Merrill'],
#  ['POWERS', 'Jeffrey'],
#  ['SMITH', 'Jesse'],
#  ['VARELLAS', 'Peter'],
#  ['WRIGHT', 'Adam'],
#  ['BEADSWORTH', 'Gemma'],
#  ['CUFFE', 'Nikita'],
#  ['FRASER', 'Suzie'],
#  ['GOFERS', 'Taniele'],
#  ['GYNTHER', 'Kate'],
#  ['HETZEL', 'Amy'],
#  ['KNOX', 'Bronwen'],
#  ['KNOX', 'Emma'],
#  ['MCCORMACK', 'Alicia'],
#  ['RIPPON', 'Melissa'],
#  ['RIPPON', 'Rebecca'],
#  ['SANTOROMITO', 'Jenna'],
#  ['SANTOROMITO', 'Mia'],
#  ['CABOUT', 'Mieke'],
#  ['DE BRUIJN', 'Danielle'],
#  ['DE NOOY', 'Meike'],
#  ['GUICHELAAR', 'Rianne'],
#  ['HAKHVERDIAN', 'Biurakn'],
#  ['KLEIN', 'Noeki'],
#  ['KOOT', 'Simone'],
#  ['SIJBRING', 'Alette'],
#  ['SMIT', 'Yasemin'],
#  ['VAN BELKUM', 'Iefke'],
#  ['VAN DEN BERG', 'Gillian'],
#  ['VAN DEN HAM', 'Marieke'],
#  ['VAN DER MEIJDEN', 'Ilse'],
#  ['ARMSTRONG', 'Elizabeth'],
#  ['CARDENAS', 'Patty'],
#  ['CRAIG', 'Kami'],
#  ['GOLDA', 'Natalie'],
#  ['GREGORKA', 'Alison'],
#  ['HAYES', 'Brittany'],
#  ['HIPP', 'Jaime'],
#  ['PETRI', 'Heather'],
#  ['STEFFENS', 'Jessica'],
#  ['VAN NORMAN', 'Moriah'],
#  ['VILLA', 'Brenda'],
#  ['WENGER', 'Lauren'],
#  ['WINDES', 'Elsie'],
#  ['BADENOV', 'Bair'],
#  ['RUBAN', 'Viktor'],
#  ['PARK', 'Kyung-Mo'],
#  ['YUN', 'Ok-Hee'],
#  ['ZHANG', 'Juan Juan'],
#  ['PARK', 'Sung-Hyun'],
#  ['JIANG', 'Lin'],
#  ['LI', 'Wenquan'],
#  ['XUE', 'Hai Feng'],
#  ['IM', 'Dong-Hyun'],
#  ['LEE', 'Chang-Hwan'],
#  ['PARK', 'Kyung-Mo'],
#  ["DI BUO'", 'Ilario'],
#  ['GALIAZZO', 'Marco'],
#  ['NESPOLI', 'Mauro'],
#  ['ARNOLD', 'Virginie'],
#  ['DODEMONT', 'Sophie'],
#  ['SCHUH', 'Berengere'],
#  ['JOO', 'Hyun-Jung'],
#  ['PARK', 'Sung-Hyun'],
#  ['YUN', 'Ok-Hee'],
#  ['CHEN', 'Ling'],
#  ['GUO', 'Dan'],
#  ['ZHANG', 'Juan Juan'],
#  ['KOGO', 'Micah'],
#  ['BEKELE', 'Kenenisa'],
#  ['SIHINE', 'Sileshi'],
#  ['FLANAGAN', 'Shalane'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['THOMPSON', 'Richard'],
#  ['FRASER', 'Shelly-ann'],
#  ['SIMPSON', 'Sherone'],
#  ['STEWART', 'Kerron'],
#  ['LOPES-SCHLIEP', 'Priscilla'],
#  ['HARPER', 'Dawn'],
#  ['MCLELLAN', 'Sally'],
#  ['OLIVER', 'David'],
#  ['ROBLES', 'Dayron'],
#  ['PAYNE', 'David'],
#  ['BAALA', 'Mehdi'],
#  ['KIPROP', 'Asbel Kipruto'],
#  ['WILLIS', 'Nicholas'],
#  ['TOBIAS', 'Nataliya'],
#  ['LANGAT', 'Nancy jebet'],
#  ['LISHCHYNSKA', 'Iryna'],
#  ['DIX', 'Walter'],
#  ['BOLT', 'Usain'],
#  ['CRAWFORD', 'Shawn'],
#  ['STEWART', 'Kerron'],
#  ['CAMPBELL-BROWN', 'Veronica'],
#  ['FELIX', 'Allyson'],
#  ['RIGAUDO', 'Elisa'],
#  ['KANISKINA', 'Olga'],
#  ['PLATZER', 'Kjersti Tysse'],
#  ['TALLENT', 'Jared'],
#  ['BORCHIN', 'Valeriy'],
#  ['PEREZ', 'Jefferson'],
#  ['MATEELONG', 'Richard Kipkemboi'],
#  ['KIPRUTO', 'Brimin Kiprop'],
#  ['MEKHISSI-B.', 'Mahiedine'],
#  ['VOLKOVA', 'Ekaterina'],
#  ['GALKINA-SAMITOVA', 'Gulnara'],
#  ['JEPKORIR', 'Eunice'],
#  ['NEVILLE', 'David'],
#  ['MERRITT', 'LaShawn'],
#  ['WARINER', 'Jeremy'],
#  ['RICHARDS', 'Sanya'],
#  ['OHURUOGU', 'Christine'],
#  ['WILLIAMS', 'Shericka'],
#  ['JACKSON', 'Bershawn'],
#  ['TAYLOR', 'Angelo'],
#  ['CLEMENT', 'Kerron'],
#  ['DANVERS', 'Tasha'],
#  ['WALKER', 'Melaine'],
#  ['TOSTA', 'Sheena'],
#  ['ASAHARA', 'Nobuharu'],
#  ['SUETSUGU', 'Shingo'],
#  ['TAKAHIRA', 'Shinji'],
#  ['TSUKAHARA', 'Naoki'],
#  ['BOLT', 'Usain'],
#  ['CARTER', 'Nesta'],
#  ['FRATER', 'Michael'],
#  ['POWELL', 'Asafa'],
#  ['BLEDMAN', 'Keston'],
#  ['BURNS', 'Marc'],
#  ['CALLENDER', 'Emmanuel'],
#  ['THOMPSON', 'Richard'],
#  ['IDOKO', 'Franca'],
#  ['ISMAILA', 'Halimat'],
#  ['KEMASUODE', 'Gloria'],
#  ['OSAYOMI', 'Oludamola'],
#  ['CHERMOSHANSKAYA', 'Yuliya'],
#  ['FEDORIVA', 'Aleksandra'],
#  ['GUSHCHINA', 'Yulia'],
#  ['POLYAKOVA', 'Evgeniya'],
#  ['BORLEE', 'Olivia'],
#  ['GEVAERT', 'Kim'],
#  ['MARIEN', 'Hanna'],
#  ['OUEDRAOGO', 'Elodie'],
#  ['ALEXEEV', 'Denis'],
#  ['DYLDIN', 'Maksim'],
#  ['FROLOV', 'Vladislav'],
#  ['KOKORIN', 'Anton'],
#  ['MERRITT', 'LaShawn'],
#  ['NEVILLE', 'David'],
#  ['TAYLOR', 'Angelo'],
#  ['WARINER', 'Jeremy'],
#  ['BAIN', 'Andretti'],
#  ['BROWN', 'Christopher'],
#  ['MATHIEU', 'Michael'],
#  ['WILLIAMS', 'Andrae'],
#  ['LLOYD', 'Shereefa'],
#  ['WHYTE', 'Rosemarie'],
#  ['WILLIAMS', 'Novelene'],
#  ['WILLIAMS', 'Shericka'],
#  ['FELIX', 'Allyson'],
#  ['HENDERSON', 'Monique'],
#  ['RICHARDS', 'Sanya'],
#  ['WINEBERG', 'Mary'],
#  ['FIROVA', 'Tatiana'],
#  ['GUSHCHINA', 'Yulia'],
#  ['KAPACHINSKAYA', 'Anastasia'],
#  ['LITVINOVA', 'Liudmila'],
#  ['SOI', 'Edwin Cheruiyot'],
#  ['BEKELE', 'Kenenisa'],
#  ['KIPCHOGE', 'Eliud'],
#  ['DEFAR', 'Meseret'],
#  ['DIBABA', 'Tirunesh'],
#  ['ABEYLEGESSE', 'Elvan'],
#  ['NIZHEGORODOV', 'Denis'],
#  ['SCHWAZER', 'Alex'],
#  ['TALLENT', 'Jared'],
#  ['YEGO', 'Alfred Kirwa'],
#  ['BUNGEI', 'Wilfred'],
#  ['ISMAIL', 'Ismail Ahmed'],
#  ['BENHASSI', 'Hasna'],
#  ['JELIMO', 'Pamela'],
#  ['BUSIENEI', 'Janeth Jepkosgei'],
#  ['SUAREZ', 'Leonel'],
#  ['CLAY', 'Bryan'],
#  ['KRAUCHANKA', 'Andrei'],
#  ['ALEKNA', 'Virgilijus'],
#  ['KANTER', 'Gerd'],
#  ['MALACHOWSKI', 'Piotr'],
#  ['ANTONOVA', 'Olena'],
#  ['BROWN TRAFTON', 'Stephanie'],
#  ['BARRIOS', 'Yarelys'],
#  ['TSIKHAN', 'Ivan'],
#  ['KOZMUS', 'Primoz'],
#  ['DEVYATOVSKIY', 'Vadim'],
#  ['ZHANG', 'Wenxiu'],
#  ['MIANKOVA', 'Aksana'],
#  ['MORENO', 'Yipsi'],
#  ['CHERNOVA', 'Tatiana'],
#  ['DOBRYNSKA', 'Nataliia'],
#  ['FOUNTAIN', 'Hyleas'],
#  ['RYBAKOV', 'Yaroslav'],
#  ['SILNOV', 'Andrey'],
#  ['MASON', 'Germaine'],
#  ['CHICHEROVA', 'Anna'],
#  ['HELLEBAUT', 'Tia'],
#  ['VLASIC', 'Blanka'],
#  ['PITKAMAKI', 'Tero'],
#  ['THORKILDSEN', 'Andreas'],
#  ['KOVALS', 'Ainars'],
#  ['OBERGFOLL', 'Christina'],
#  ['SPOTAKOVA', 'Barbora'],
#  ['ABAKUMOVA', 'Maria'],
#  ['CAMEJO', 'Ibrahim'],
#  ['SALADINO ARANDA', 'Irving Jahir'],
#  ['MOKOENA', 'Khotso'],
#  ['OKAGBARE', 'Blessing'],
#  ['MAGGI', 'Maurren Higa'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['KEBEDE', 'Tsegay'],
#  ['WANSIRU', 'Samuel Kamau'],
#  ['GHARIB', 'Jaouad'],
#  ['ZHOU', 'Chunxiu'],
#  ['TOMESCU', 'Constantina'],
#  ['NDEREBA', 'Catherine'],
#  ['YURCHENKO', 'Denys'],
#  ['HOOKER', 'Steve'],
#  ['LUKYANENKO', 'Evgeny'],
#  ['FEOFANOVA', 'Svetlana'],
#  ['ISINBAEVA', 'Elena'],
#  ['STUCZYNSKI', 'Jennifer'],
#  ['MIKHNEVICH', 'Andrei'],
#  ['MAJEWSKI', 'Tomasz'],
#  ['CANTWELL', 'Christian'],
#  ['OSTAPCHUK', 'Nadzeya'],
#  ['VILI', 'Valerie'],
#  ['MIKHNEVICH', 'Natallia'],
#  ['SANDS', 'Leevan'],
#  ['EVORA', 'Nelson'],
#  ['IDOWU', 'Phillips'],
#  ['DEVETZI', 'Hrysopiyi'],
#  ['MBANGO ETONE', 'Francoise'],
#  ['LEBEDEVA', 'Tatyana'],
#  ['HWANG', 'Jiman'],
#  ['LEE', 'Jaejin'],
#  ['HE', 'Hanbin'],
#  ['KIDO', 'Markis'],
#  ['SETIAWAN', 'Hendra'],
#  ['LEE', 'Yongdae'],
#  ['CAI', 'Yun'],
#  ['FU', 'Haifeng'],
#  ['WIDIANTO', 'Nova'],
#  ['WEI', 'Yili'],
#  ['ZHANG', 'Yawen'],
#  ['YU', 'Yang'],
#  ['DU', 'Jing'],
#  ['YU', 'Yang'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Hyojung'],
#  ['LEE', 'Kyungwon'],
#  ['LILIYANA'],
#  ['CHEN', 'Jin'],
#  ['LIN', 'Dan'],
#  ['LEE', 'Chong Wei'],
#  ['YULIANTI', 'Maria Kristin'],
#  ['ZHANG', 'Ning'],
#  ['XIE', 'Xingfang'],
#  ['ANDERSON', 'Brett'],
#  ['ARRIETA', 'Jake'],
#  ['BARDEN', 'Brian'],
#  ['BROWN', 'Matt'],
#  ['CAHILL', 'Trevor'],
#  ['CUMMINGS', 'Jeremy'],
#  ['DONALD', 'Jason'],
#  ['DUENSING', 'Brian'],
#  ['FOWLER', 'Dexter'],
#  ['GALL', 'John'],
#  ['HESSMAN', 'Mike'],
#  ['JEPSEN', 'Kevin'],
#  ['KNIGHT', 'Brandon'],
#  ['KOPLOVE', 'Michael'],
#  ['LAPORTA', 'Matt'],
#  ['MARSON', 'Lou'],
#  ['NEAL', 'Blaine'],
#  ['NIX', 'Jayson'],
#  ['SCHIERHOLTZ', 'Nate'],
#  ['STEVENS', 'Jeff'],
#  ['STRASBURG', 'Stephen'],
#  ['TEAGARDEN', 'Taylor'],
#  ['TIFFEE', 'Terry'],
#  ['WEATHERS', 'Casey'],
#  ['BONG', 'Jungkeun'],
#  ['CHONG', 'Taehyon'],
#  ['HAN', 'Kijoo'],
#  ['JANG', 'Wonsam'],
#  ['JEONG', 'Keunwoo'],
#  ['JIN', 'Kabyong'],
#  ['KANG', 'Minho'],
#  ['KIM', 'Dongjoo'],
#  ['KIM', 'Hyunsoo'],
#  ['KIM', 'Kwanghyun'],
#  ['KIM', 'Minjae'],
#  ['KO', 'Youngmin'],
#  ['KWON', 'Hyuk'],
#  ['LEE', 'Daeho'],
#  ['LEE', 'Jinyoung'],
#  ['LEE', 'Jongwook'],
#  ['LEE', 'Seungyuop'],
#  ['LEE', 'Taekkeun'],
#  ['LEE', 'Yongkyu'],
#  ['OH', 'Seunghwan'],
#  ['PARK', 'Jinman'],
#  ['RYU', 'Hyunjin'],
#  ['SONG', 'Seungjun'],
#  ['YOON', 'Suk Min'],
#  ['BELL', 'Alexei'],
#  ['CEPEDA', 'Frederich'],
#  ['DESPAIGNE', 'Alfredo'],
#  ['DUVERGEL', 'Giorbis'],
#  ['ENRIQUEZ', 'Michel'],
#  ['GONZALEZ', 'Norberto'],
#  ['GOURRIEL', 'Yuliesky'],
#  ['LA HERA', 'Miguel'],
#  ['LAZO', 'Pedro Luis'],
#  ['MARTINEZ', 'Jonder'],
#  ['MAYETA', 'Alexander'],
#  ['MERINO', 'Rolando'],
#  ['NAVAS', 'Luis'],
#  ['ODELIN SANAME', 'Vicyohandri'],
#  ['OLIVERA', 'Hector'],
#  ['PALMA', 'Adiel'],
#  ['PARET', 'Eduardo'],
#  ['PEDROSO', 'Yadier'],
#  ['PESTANO', 'Ariel'],
#  ['RODRIGUEZ', 'Luis'],
#  ['SANCHEZ', 'Elier'],
#  ['SANCHEZ', 'Eriel'],
#  ['URGELLES', 'Yoandry'],
#  ['VERA', 'Norge Luis'],
#  ['DELFINO', 'Carlos Francisco'],
#  ['GINOBILI', 'Emanuel David'],
#  ['GONZALEZ', 'Roman Javier'],
#  ['GUTIERREZ LLANAS', 'Juan Pedro'],
#  ['GUTIERREZ', 'Leonardo Martin'],
#  ['KAMMERICHS', 'Guillermo Federico'],
#  ['NOCIONI', 'Andres Marcelo'],
#  ['OBERTO', 'Fabricio Raul Jesus'],
#  ['PORTA PERNIGOTTI', 'Antonio Alejandro'],
#  ['PRIGIONI', 'Pablo'],
#  ['QUINTEROS', 'Alfredo Paolo'],
#  ['SCOLA', 'Luis Alberto'],
#  ['ANTHONY', 'Carmelo'],
#  ['BOOZER', 'Carlos'],
#  ['BOSH', 'Chris'],
#  ['BRYANT', 'Kobe'],
#  ['HOWARD', 'Dwight'],
#  ['JAMES', 'Lebron'],
#  ['KIDD', 'Jason'],
#  ['PAUL', 'Chris'],
#  ['PRINCE', 'Tayshaun'],
#  ['REDD', 'Michael'],
#  ['WADE', 'Dwyane'],
#  ['WILLIAMS', 'Deron'],
#  ['CALDERON', 'Jose Manuel'],
#  ['FERNANDEZ', 'Rudy'],
#  ['GARBAJOSA', 'Jorge'],
#  ['GASOL', 'Marc'],
#  ['GASOL', 'Pau'],
#  ['JIMENEZ', 'Carlos'],
#  ['LOPEZ', 'Raul'],
#  ['MUMBRU', 'Alex'],
#  ['NAVARRO', 'Juan Carlos'],
#  ['REYES', 'Felipe'],
#  ['RODRIGUEZ', 'Berni'],
#  ['RUBIO', 'Ricky'],
#  ['ABROSIMOVA', 'Svetlana'],
#  ['HAMMON', 'Rebekka Linn'],
#  ['KARPUNINA', 'Marina'],
#  ['KORSTIN', 'Ilona'],
#  ['KUZINA', 'Marina'],
#  ['LISINA', 'Ekaterina'],
#  ['OSIPOVA', 'Irina'],
#  ['RAKHMATULINA', 'Oxana'],
#  ['SHCHEGOLEVA', 'Tatiana'],
#  ['SOKOLOVSKAYA', 'Irina'],
#  ['STEPANOVA', 'Maria'],
#  ['VODOPYANOVA', 'Natalia'],
#  ['AUGUSTUS', 'Seimone'],
#  ['BIRD', 'Sue'],
#  ['CATCHINGS', 'Tamika'],
#  ['FOWLES', 'Sylvia'],
#  ['LAWSON', 'Kara'],
#  ['LESLIE', 'Lisa'],
#  ['MILTON-JONES', 'Delisha'],
#  ['PARKER', 'Candace'],
#  ['PONDEXTER', 'Cappie'],
#  ['SMITH', 'Katie'],
#  ['TAURASI', 'Diana'],
#  ['THOMPSON', 'Tina'],
#  ['BATKOVIC', 'Suzy'],
#  ['BEVILAQUA', 'Tully'],
#  ['COX', 'Rohanee'],
#  ['GRIMA', 'Hollie'],
#  ['HARROWER', 'Kristi'],
#  ['JACKSON', 'Lauren'],
#  ['PHILLIPS', 'Erin'],
#  ['RANDALL', 'Emma'],
#  ['SCREEN', 'Jenni'],
#  ['SNELL', 'Belinda'],
#  ['SUMMERTON', 'Laura'],
#  ['TAYLOR', 'Penny'],
#  ['GLAZKOV', 'Vyacheslav'],
#  ['PRICE', 'David'],
#  ['CAMMARELLE', 'Roberto'],
#  ['ZHANG', 'Zhilei'],
#  ['BALAKSHIN', 'Georgy'],
#  ['PICARDI', 'Vincenzo'],
#  ['JONGJOHOR', 'Somjit'],
#  ['LAFFITA HERNANDEZ', 'Andris'],
#  ['BARNES', 'Paddy'],
#  ['HERNANDEZ G', 'Yampier'],
#  ['ZOU', 'Shiming'],
#  ['PUREVDORJ', 'Serdamba'],
#  ['GOJAN', 'Veaceslav'],
#  ['JULIE', 'Bruno'],
#  ['ENKHBAT', 'Badar-Uugan'],
#  ['LEON ALARCON', 'Yankiel'],
#  ['IMRANOV', 'Shahin'],
#  ['KILIC', 'Yakup'],
#  ['LOMACHENKO', 'Vasyl'],
#  ['DJELKHIR', 'Khedafi'],
#  ['JAVAKHYAN', 'Hrachik'],
#  ['UGAS', 'Yordenis'],
#  ['TISHCHENKO', 'Alexey'],
#  ['SOW', 'Daouda'],
#  ['IGLESIAS SOTOLONGO', 'Roniel'],
#  ['VASTINE', 'Alexis'],
#  ['DIAZ', 'Felix'],
#  ['BOONJUMNONG', 'Manus'],
#  ['HANATI', 'Silamu'],
#  ['KIM', 'Jungjoo'],
#  ['SARSEKBAYEV', 'Bakhyt'],
#  ['BANTEAUX SUAREZ', 'Carlos'],
#  ['KUMAR', 'Vijender'],
#  ['SUTHERLAND', 'Darren John'],
#  ['DEGALE', 'James'],
#  ['CORREA BAYEAUX', 'Emilio'],
#  ['JEFFRIES', 'Tony'],
#  ['SHYNALIYEV', 'Yerkebulan'],
#  ['ZHANG', 'Xiaoping'],
#  ['EGAN', 'Kenny'],
#  ['ACOSTA DUARTE', 'Osmai'],
#  ['WILDER', 'Deontay'],
#  ['CHAKHKIEV', 'Rakhim'],
#  ['RUSSO', 'Clemente'],
#  ['HALL', 'Thomas'],
#  ['VAJDA', 'Attila Sandor'],
#  ['CAL', 'David'],
#  ['CHEBAN', 'Iurii'],
#  ['OPALEV', 'Maxim'],
#  ['CAL', 'David'],
#  ['KISS', 'Tamas'],
#  ['KOZMANN', 'Gyorgy'],
#  ['BAHDANOVICH', 'Aliaksandr'],
#  ['BAHDANOVICH', 'Andrei'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['GILLE', 'Christian'],
#  ['WYLENZEK', 'Thomasz'],
#  ['MENG', 'Guanliang'],
#  ['YANG', 'Wenjun'],
#  ['KOSTOGLOD', 'Alexander'],
#  ['ULEGIN', 'Sergey'],
#  ['WALLACE', 'Ken'],
#  ['BRABANTS', 'Tim'],
#  ['LARSEN', 'Eirik Veraas'],
#  ['BRABANTS', 'Tim'],
#  ['WALLACE', 'Ken'],
#  ['VAN KOEVERDEN', 'Adam'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['OSYPENKO-RADOMSKA', 'Inna'],
#  ['IDEM', 'Josefa'],
#  ['FACCHIN', 'Andrea'],
#  ['SCADUTO', 'Antonio Massimiliano'],
#  ['HOLLSTEIN', 'Martin'],
#  ['IHLE', 'Andreas'],
#  ['KNUDSEN', 'Kim Wraae'],
#  ['POULSEN', 'Rene Holten'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['CRAVIOTTO', 'Saul'],
#  ['PEREZ', 'Carlos'],
#  ['RAUHE', 'Ronald'],
#  ['WIESKOTTER', 'Tim'],
#  ['DELATTRE', 'Marie'],
#  ['VIARD', 'Anne-Laure'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KONIECZNA', 'Aneta'],
#  ['MIKOLAJCZYK', 'Beata'],
#  ['ALTEPOST', 'Lutz'],
#  ['BROCKL', 'Norman'],
#  ['ECKBRETT', 'Torsten'],
#  ['GOLDSCHMIDT', 'Bjorn'],
#  ['ABALMASAU', 'Aliaksei'],
#  ['LITVINCHUK', 'Artur'],
#  ['MAKHNEU', 'Vadzim'],
#  ['PIATRUSHENKA', 'Raman'],
#  ['RISZDORFER', 'Michal'],
#  ['RISZDORFER', 'Richard'],
#  ['TARR', 'Juraj'],
#  ['VLCEK', 'Erik'],
#  ['DAVIS', 'Hannah'],
#  ['FOGARTY', 'Lyndsie'],
#  ['MEEK', 'Chantal'],
#  ['OLDENHOF', 'Lisa'],
#  ['FISCHER', 'Fanny'],
#  ['REINHARDT', 'Nicole'],
#  ['WAGNER-AUGUSTIN', 'Katrin'],
#  ['WASSMUTH', 'Conny'],
#  ['JANIC', 'Natasa'],
#  ['KOVACS', 'Katalin'],
#  ['KOZAK', 'Danuta'],
#  ['SZABO', 'Gabriella Timea'],
#  ['BELL', 'Robin'],
#  ['MARTIKAN', 'Michal'],
#  ['FLORENCE', 'David'],
#  ['KUZNETSOV', 'Mikhail'],
#  ['LARIONOV', 'Dmitry'],
#  ['HOCHSCHORNER', 'Pavol'],
#  ['HOCHSCHORNER', 'Peter'],
#  ['STEPANEK', 'Ondrej'],
#  ['VOLF', 'Jaroslav'],
#  ['BOUKPETI', 'Benjamin'],
#  ['GRIMM', 'Alexander'],
#  ['LEFEVRE', 'Fabien'],
#  ['OBLINGER PETERS', 'Violetta'],
#  ['KALISKA', 'Elena'],
#  ['LAWRENCE', 'Jacqueline'],
#  ['ROBINSON', 'Donny'],
#  ['STROMBERGS', 'Maris'],
#  ['DAY', 'Mike'],
#  ['KINTNER', 'Jill'],
#  ['CHAUSSON', 'Anne-Caroline'],
#  ['LE CORGUILLE', 'Laetitia'],
#  ['CANCELLARA', 'Fabian'],
#  ['SANCHEZ', 'Samuel'],
#  ['GUDERZO', 'Tatiana'],
#  ['COOKE', 'Nicole'],
#  ['JOHANSSON', 'Emma'],
#  ['LEIPHEIMER', 'Levi'],
#  ['CANCELLARA', 'Fabian'],
#  ['LARSSON', 'Gustav'],
#  ['THURIG', 'Karin'],
#  ['ARMSTRONG', 'Kristin'],
#  ['POOLEY', 'Emma'],
#  ['BURKE', 'Steven'],
#  ['WIGGINS', 'Bradley'],
#  ['ROULSTON', 'Hayden'],
#  ['KALITOVSKA', 'Lesya'],
#  ['ROMERO', 'Rebecca'],
#  ['HOUVENAGHEL', 'Wendy'],
#  ['NAGAI', 'Kiyofumi'],
#  ['HOY', 'Chris'],
#  ['EDGAR', 'Ross'],
#  ['IGNATYEV', 'Mikhail'],
#  ['MARKOV', 'Alexei'],
#  ['CURUCHET', 'Juan Esteban'],
#  ['PEREZ', 'Walter Fernando'],
#  ['LLANERAS', 'Joan'],
#  ['TAULER', 'Antonio'],
#  ['NEWTON', 'Chris'],
#  ['LLANERAS', 'Joan'],
#  ['KLUGE', 'Roger'],
#  ['OLABERRIA', 'Leire'],
#  ['VOS', 'Marianne'],
#  ['GONZALEZ', 'Yoanka'],
#  ['GUO', 'Shuang'],
#  ['PENDLETON', 'Victoria'],
#  ['MEARES', 'Anna'],
#  ['BOURGAIN', 'Mickael'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['BEWLEY', 'Sam'],
#  ['ROULSTON', 'Hayden'],
#  ['RYAN', 'Marc'],
#  ['SERGENT', 'Jesse'],
#  ['CLANCY', 'Ed'],
#  ['MANNING', 'Paul'],
#  ['THOMAS', 'Geraint'],
#  ['WIGGINS', 'Bradley'],
#  ['JOERGENSEN', 'Casper'],
#  ['MADSEN', 'Jens-Erik'],
#  ['MOERKOEV', 'Michael'],
#  ['RASMUSSEN', 'Alex Nicki'],
#  ['ENDERS', 'Rene'],
#  ['LEVY', 'Maximilian'],
#  ['NIMKE', 'Stefan'],
#  ['HOY', 'Chris'],
#  ['KENNY', 'Jason'],
#  ['STAFF', 'Jamie'],
#  ['BAUGE', 'Gregory'],
#  ['SIREAU', 'Kevin'],
#  ['TOURNANT', 'Arnaud'],
#  ['SCHURTER', 'Nino'],
#  ['ABSALON', 'Julien'],
#  ['PERAUD', 'Jean-Christophe'],
#  ['KALENTYEVA', 'Irina'],
#  ['SPITZ', 'Sabine'],
#  ['WLOSZCZOWSKA', 'Maja'],
#  ['KEMMER', 'Heike'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['WERTH', 'Isabell'],
#  ['HELGSTRAND', 'Andreas'],
#  ['MINDERHOUD', 'Hans Peter'],
#  ['VAN OLST', 'Anne'],
#  ['ZU-SAYN WITTGENSTEIN', 'Nathalie'],
#  ['CAPELLMANN', 'Nadine'],
#  ['KEMMER', 'Heike'],
#  ['WERTH', 'Isabell'],
#  ['SCHELLEKENS-BARTELS', 'Imke'],
#  ['VAN GRUNSVEN', 'Anky'],
#  ['ROMEIKE', 'Hinrich'],
#  ['COOK', 'Kristina'],
#  ['MILES', 'Gina'],
#  ['FOX-PITT', 'William'],
#  ['DIBOWSKI', 'Andreas'],
#  ['OSTHOLT', 'Frank'],
#  ['ROMEIKE', 'Hinrich'],
#  ['THOMSEN', 'Peter'],
#  ['FREDERICKS', 'Clayton'],
#  ['ROSE', 'Shane'],
#  ['COOK', 'Kristina'],
#  ['DICK', 'Daisy'],
#  ['HUNT', 'Sharon'],
#  ['KING', 'Mary'],
#  ['KLIMKE', 'Ingrid'],
#  ['FREDERICKS', 'Lucinda'],
#  ['JOHNSON', 'Sonja'],
#  ['JONES', 'Megan'],
#  ['LAMAZE', 'Eric'],
#  ['BENGTSSON', 'Rolf-Goran'],
#  ['MADDEN', 'Beezie'],
#  ['GUERDAT', 'Steve'],
#  ['SCHURTENBERGER', 'Niklaus'],
#  ['SCHWIZER', 'Pius'],
#  ['SIMPSON', 'Will'],
#  ['WARD', 'Mclain'],
#  ['CONE', 'Mac'],
#  ['LAMAZE', 'Eric'],
#  ['MILLAR', 'Ian'],
#  ['LIEBHERR', 'Christina'],
#  ['KRAUT', 'Laura'],
#  ['MADDEN', 'Beezie'],
#  ['HENSELWOOD', 'Jill'],
#  ['ABAJO', 'Jose Luis'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['MINCZA-NEBALD', 'Ildiko'],
#  ['HEIDEMANN', 'Britta'],
#  ['BRANZA', 'Ana Maria'],
#  ['CAROZZO', 'Stefano'],
#  ['CONFALONIERI', 'Diego'],
#  ['ROTA', 'Alfredo'],
#  ['TAGLIARIOL', 'Matteo'],
#  ['JEANNET', 'Fabrice'],
#  ['JEANNET', 'Jerome'],
#  ['ROBEIRI', 'Ulrich'],
#  ['ANDRZEJUK', 'Robert'],
#  ['MOTYKA', 'Tomasz'],
#  ['WIERCIOCH', 'Adam'],
#  ['ZAWROTNIAK', 'Radoslaw'],
#  ['SANZO', 'Salvatore'],
#  ['KLEIBRINK', 'Benjamin'],
#  ['OTA', 'Yuki'],
#  ['GRANBASSI', 'Margherita'],
#  ['VEZZALI', 'Valentina'],
#  ['NAM', 'Hyunhee'],
#  ['GRANBASSI', 'Margherita'],
#  ['SALVATORI', 'Ilaria'],
#  ['TRILLINI', 'Giovanna'],
#  ['VEZZALI', 'Valentina'],
#  ['BOYKO', 'Svetlana'],
#  ['CHANAEVA', 'Aida'],
#  ['LAMONOVA', 'Evgenia'],
#  ['NIKICHINA', 'Victoria'],
#  ['CROSS', 'Emily'],
#  ['SMART', 'Erinn'],
#  ['THOMPSON', 'Hanna'],
#  ['COVALIU', 'Mihai'],
#  ['ZHONG', 'Man'],
#  ['LOPEZ', 'Nicolas'],
#  ['WARD', 'Becca'],
#  ['ZAGUNIS', 'Mariel'],
#  ['JACOBSON', 'Sada'],
#  ...]

# %%
[athlete_name[0] for athlete_name in athlete_names]
# Out:
# ['GALPERIN',
#  'MITCHAM',
#  'ZHOU',
#  'WANG',
#  'CHEN',
#  'HEYMANS',
#  'QIN',
#  'HE',
#  'DESPATIE',
#  'WU',
#  'GUO',
#  'PAKHALINA',
#  'DOBROSKOK',
#  'GALPERIN',
#  'HUO',
#  'LIN',
#  'HAUSDING',
#  'KLEIN',
#  'ESPINOSA',
#  'ORTIZ',
#  'CHEN',
#  'WANG',
#  'COLE',
#  'WU',
#  'KVASHA',
#  'PRYGOROV',
#  'QIN',
#  'WANG',
#  'KUNAKOV',
#  'SAUTIN',
#  'FISCHER',
#  'KOTZIAN',
#  'GUO',
#  'WU',
#  'PAKHALINA',
#  'POZDNYAKOVA',
#  'STOECKEL',
#  'VYATCHANIN',
#  'PEIRSOL',
#  'GREVERS',
#  'HOELZER',
#  'COUGHLIN',
#  'COVENTRY',
#  'DUBOSCQ',
#  'KITAJIMA',
#  'OEN',
#  'JUKIC',
#  'JONES',
#  'SONI',
#  'LAUTERSTEIN',
#  'PHELPS',
#  'CAVIC',
#  'SCHIPPER',
#  'TRICKETT',
#  'MAGNUSON',
#  'CIELO FILHO',
#  'LEZAK',
#  'BERNARD',
#  'SULLIVAN',
#  'COUGHLIN',
#  'STEFFEN',
#  'TRICKETT',
#  'COCHRANE',
#  'MELLOULI',
#  'HACKETT',
#  'VYATCHANIN',
#  'LOCHTE',
#  'PEIRSOL',
#  'NAKAMURA',
#  'COVENTRY',
#  'HOELZER',
#  'DUBOSCQ',
#  'KITAJIMA',
#  'RICKARD',
#  'NORDENSTAM',
#  'SONI',
#  'JONES',
#  'MATSUDA',
#  'PHELPS',
#  'CSEH',
#  'SCHIPPER',
#  'LIU',
#  'JIAO',
#  'VANDERKAAY',
#  'PHELPS',
#  'PARK',
#  'PANG',
#  'PELLEGRINI',
#  'ISAKOVIC',
#  'LOCHTE',
#  'PHELPS',
#  'CSEH',
#  'COUGHLIN',
#  'RICE',
#  'COVENTRY',
#  'JENSEN',
#  'PARK',
#  'ZHANG',
#  'JACKSON',
#  'ADLINGTON',
#  'HOFF',
#  'LOCHTE',
#  'PHELPS',
#  'CSEH',
#  'HOFF',
#  'RICE',
#  'COVENTRY',
#  'BRODIE',
#  'CALLUS',
#  'LAUTERSTEIN',
#  'MURPHY',
#  'SULLIVAN',
#  'TARGETT',
#  'ADRIAN',
#  'GREVERS',
#  'JONES',
#  'LEZAK',
#  'PHELPS',
#  'WEBER-GALE',
#  'WILDMAN-TOBRINER',
#  'BERNARD',
#  'BOUSQUET',
#  'GILOT',
#  'LEVEAUX',
#  'MALLET',
#  'STEIMETZ',
#  'CAMPBELL',
#  'MILLS',
#  'REESE',
#  'SCHLANGER',
#  'TRICKETT',
#  'DEKKER',
#  'HEEMSKERK',
#  'KROMOWIDJOJO',
#  'SCHREUDER',
#  'VAN ROOIJEN',
#  'VELDHUIS',
#  'COUGHLIN',
#  'JOYCE',
#  'NYMEYER',
#  'SILVER',
#  'SMIT',
#  'TORRES',
#  'FUJII',
#  'KITAJIMA',
#  'MIYASHITA',
#  'SATO',
#  'CROCKER',
#  'GANGLOFF',
#  'GREVERS',
#  'HANSEN',
#  'LEZAK',
#  'PEIRSOL',
#  'PHELPS',
#  'WEBER-GALE',
#  'DELANEY',
#  'LAUTERSTEIN',
#  'PINE',
#  'RICKARD',
#  'SPRENGER',
#  'STOECKEL',
#  'SULLIVAN',
#  'TARGETT',
#  'PANG',
#  'SUN',
#  'XU',
#  'ZHAO',
#  'ZHOU',
#  'GALVEZ',
#  'JONES',
#  'REESE',
#  'SCHIPPER',
#  'SEEBOHM',
#  'TRICKETT',
#  'WHITE',
#  'BREEDEN',
#  'COUGHLIN',
#  'HOELZER',
#  'JENDRICK',
#  'JOYCE',
#  'MAGNUSON',
#  'SONI',
#  'TORRES',
#  'BRITS',
#  'BRODIE',
#  'FFROST',
#  'HACKETT',
#  'MURPHY',
#  'PALMER',
#  'BERENS',
#  'KELLER',
#  'LOCHTE',
#  'PHELPS',
#  'VANDERKAAY',
#  'VENDT',
#  'WALTERS',
#  'IZOTOV',
#  'LAGUNOV',
#  'LOBINTSEV',
#  'POLISHCHUK',
#  'SUKHORUKOV',
#  'BURCKLE',
#  'COUGHLIN',
#  'HOFF',
#  'MARSHALL',
#  'SCHMITT',
#  'SMIT',
#  'VANDENBERG',
#  'BAINBRIDGE',
#  'BARRATT',
#  'DAVENPORT',
#  'GALVEZ',
#  'MACKENZIE',
#  'PALMER',
#  'RICE',
#  'SCHLANGER',
#  'PANG',
#  'TAN',
#  'TANG',
#  'YANG',
#  'ZHU',
#  'BERNARD',
#  'CIELO FILHO',
#  'LEVEAUX',
#  'CAMPBELL',
#  'STEFFEN',
#  'TORRES',
#  'FRIIS',
#  'ADLINGTON',
#  'FILIPPI',
#  'LURZ',
#  'VAN DER WEIJDEN',
#  'DAVIES',
#  'PATTEN',
#  'ILCHENKO',
#  'PAYNE',
#  'HARADA',
#  'SUZUKI',
#  'DAVYDOVA',
#  'ERMAKOVA',
#  'FUENTES',
#  'MENGUAL',
#  'GU',
#  'HUANG',
#  'JIANG',
#  'JIANG',
#  'LIU',
#  'LUO',
#  'SUN',
#  'WANG',
#  'ZHANG',
#  'DAVYDOVA',
#  'ERMAKOVA',
#  'GROMOVA',
#  'ISHCHENKO',
#  'KHASYANOVA',
#  'KUZHELA',
#  'OVCHINNIKOVA',
#  'ROMASHINA',
#  'SHORINA',
#  'CABELLO',
#  'CORRAL',
#  'FUENTES',
#  'HENRIQUEZ',
#  'LOPEZ',
#  'MENGUAL',
#  'MORON',
#  'RODRIGUEZ',
#  'TIRADOS',
#  'CIRIC',
#  'FILIPOVIC',
#  'GOCIC',
#  'PEKOVIC',
#  'PIJETLOVIC',
#  'PRLAINOVIC',
#  'RADJEN',
#  'SAPIC',
#  'SAVIC',
#  'SEFIK',
#  'SORO',
#  'UDOVICIC',
#  'VUJASINOVIC',
#  'BENEDEK',
#  'BIROS',
#  'GERGELY',
#  'HOSNYANSZKY',
#  'KASAS',
#  'KIS',
#  'KISS',
#  'MADARAS',
#  'MOLNAR',
#  'SZECSI',
#  'VARGA',
#  'VARGA',
#  'VARGA',
#  'AZEVEDO',
#  'BAILEY',
#  'BEAUBIEN',
#  'BROOKS',
#  'HUDNUT',
#  'HUTTEN',
#  'KRUMPHOLZ',
#  'MERLO',
#  'MOSES',
#  'POWERS',
#  'SMITH',
#  'VARELLAS',
#  'WRIGHT',
#  'BEADSWORTH',
#  'CUFFE',
#  'FRASER',
#  'GOFERS',
#  'GYNTHER',
#  'HETZEL',
#  'KNOX',
#  'KNOX',
#  'MCCORMACK',
#  'RIPPON',
#  'RIPPON',
#  'SANTOROMITO',
#  'SANTOROMITO',
#  'CABOUT',
#  'DE BRUIJN',
#  'DE NOOY',
#  'GUICHELAAR',
#  'HAKHVERDIAN',
#  'KLEIN',
#  'KOOT',
#  'SIJBRING',
#  'SMIT',
#  'VAN BELKUM',
#  'VAN DEN BERG',
#  'VAN DEN HAM',
#  'VAN DER MEIJDEN',
#  'ARMSTRONG',
#  'CARDENAS',
#  'CRAIG',
#  'GOLDA',
#  'GREGORKA',
#  'HAYES',
#  'HIPP',
#  'PETRI',
#  'STEFFENS',
#  'VAN NORMAN',
#  'VILLA',
#  'WENGER',
#  'WINDES',
#  'BADENOV',
#  'RUBAN',
#  'PARK',
#  'YUN',
#  'ZHANG',
#  'PARK',
#  'JIANG',
#  'LI',
#  'XUE',
#  'IM',
#  'LEE',
#  'PARK',
#  "DI BUO'",
#  'GALIAZZO',
#  'NESPOLI',
#  'ARNOLD',
#  'DODEMONT',
#  'SCHUH',
#  'JOO',
#  'PARK',
#  'YUN',
#  'CHEN',
#  'GUO',
#  'ZHANG',
#  'KOGO',
#  'BEKELE',
#  'SIHINE',
#  'FLANAGAN',
#  'DIBABA',
#  'ABEYLEGESSE',
#  'DIX',
#  'BOLT',
#  'THOMPSON',
#  'FRASER',
#  'SIMPSON',
#  'STEWART',
#  'LOPES-SCHLIEP',
#  'HARPER',
#  'MCLELLAN',
#  'OLIVER',
#  'ROBLES',
#  'PAYNE',
#  'BAALA',
#  'KIPROP',
#  'WILLIS',
#  'TOBIAS',
#  'LANGAT',
#  'LISHCHYNSKA',
#  'DIX',
#  'BOLT',
#  'CRAWFORD',
#  'STEWART',
#  'CAMPBELL-BROWN',
#  'FELIX',
#  'RIGAUDO',
#  'KANISKINA',
#  'PLATZER',
#  'TALLENT',
#  'BORCHIN',
#  'PEREZ',
#  'MATEELONG',
#  'KIPRUTO',
#  'MEKHISSI-B.',
#  'VOLKOVA',
#  'GALKINA-SAMITOVA',
#  'JEPKORIR',
#  'NEVILLE',
#  'MERRITT',
#  'WARINER',
#  'RICHARDS',
#  'OHURUOGU',
#  'WILLIAMS',
#  'JACKSON',
#  'TAYLOR',
#  'CLEMENT',
#  'DANVERS',
#  'WALKER',
#  'TOSTA',
#  'ASAHARA',
#  'SUETSUGU',
#  'TAKAHIRA',
#  'TSUKAHARA',
#  'BOLT',
#  'CARTER',
#  'FRATER',
#  'POWELL',
#  'BLEDMAN',
#  'BURNS',
#  'CALLENDER',
#  'THOMPSON',
#  'IDOKO',
#  'ISMAILA',
#  'KEMASUODE',
#  'OSAYOMI',
#  'CHERMOSHANSKAYA',
#  'FEDORIVA',
#  'GUSHCHINA',
#  'POLYAKOVA',
#  'BORLEE',
#  'GEVAERT',
#  'MARIEN',
#  'OUEDRAOGO',
#  'ALEXEEV',
#  'DYLDIN',
#  'FROLOV',
#  'KOKORIN',
#  'MERRITT',
#  'NEVILLE',
#  'TAYLOR',
#  'WARINER',
#  'BAIN',
#  'BROWN',
#  'MATHIEU',
#  'WILLIAMS',
#  'LLOYD',
#  'WHYTE',
#  'WILLIAMS',
#  'WILLIAMS',
#  'FELIX',
#  'HENDERSON',
#  'RICHARDS',
#  'WINEBERG',
#  'FIROVA',
#  'GUSHCHINA',
#  'KAPACHINSKAYA',
#  'LITVINOVA',
#  'SOI',
#  'BEKELE',
#  'KIPCHOGE',
#  'DEFAR',
#  'DIBABA',
#  'ABEYLEGESSE',
#  'NIZHEGORODOV',
#  'SCHWAZER',
#  'TALLENT',
#  'YEGO',
#  'BUNGEI',
#  'ISMAIL',
#  'BENHASSI',
#  'JELIMO',
#  'BUSIENEI',
#  'SUAREZ',
#  'CLAY',
#  'KRAUCHANKA',
#  'ALEKNA',
#  'KANTER',
#  'MALACHOWSKI',
#  'ANTONOVA',
#  'BROWN TRAFTON',
#  'BARRIOS',
#  'TSIKHAN',
#  'KOZMUS',
#  'DEVYATOVSKIY',
#  'ZHANG',
#  'MIANKOVA',
#  'MORENO',
#  'CHERNOVA',
#  'DOBRYNSKA',
#  'FOUNTAIN',
#  'RYBAKOV',
#  'SILNOV',
#  'MASON',
#  'CHICHEROVA',
#  'HELLEBAUT',
#  'VLASIC',
#  'PITKAMAKI',
#  'THORKILDSEN',
#  'KOVALS',
#  'OBERGFOLL',
#  'SPOTAKOVA',
#  'ABAKUMOVA',
#  'CAMEJO',
#  'SALADINO ARANDA',
#  'MOKOENA',
#  'OKAGBARE',
#  'MAGGI',
#  'LEBEDEVA',
#  'KEBEDE',
#  'WANSIRU',
#  'GHARIB',
#  'ZHOU',
#  'TOMESCU',
#  'NDEREBA',
#  'YURCHENKO',
#  'HOOKER',
#  'LUKYANENKO',
#  'FEOFANOVA',
#  'ISINBAEVA',
#  'STUCZYNSKI',
#  'MIKHNEVICH',
#  'MAJEWSKI',
#  'CANTWELL',
#  'OSTAPCHUK',
#  'VILI',
#  'MIKHNEVICH',
#  'SANDS',
#  'EVORA',
#  'IDOWU',
#  'DEVETZI',
#  'MBANGO ETONE',
#  'LEBEDEVA',
#  'HWANG',
#  'LEE',
#  'HE',
#  'KIDO',
#  'SETIAWAN',
#  'LEE',
#  'CAI',
#  'FU',
#  'WIDIANTO',
#  'WEI',
#  'ZHANG',
#  'YU',
#  'DU',
#  'YU',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LILIYANA',
#  'CHEN',
#  'LIN',
#  'LEE',
#  'YULIANTI',
#  'ZHANG',
#  'XIE',
#  'ANDERSON',
#  'ARRIETA',
#  'BARDEN',
#  'BROWN',
#  'CAHILL',
#  'CUMMINGS',
#  'DONALD',
#  'DUENSING',
#  'FOWLER',
#  'GALL',
#  'HESSMAN',
#  'JEPSEN',
#  'KNIGHT',
#  'KOPLOVE',
#  'LAPORTA',
#  'MARSON',
#  'NEAL',
#  'NIX',
#  'SCHIERHOLTZ',
#  'STEVENS',
#  'STRASBURG',
#  'TEAGARDEN',
#  'TIFFEE',
#  'WEATHERS',
#  'BONG',
#  'CHONG',
#  'HAN',
#  'JANG',
#  'JEONG',
#  'JIN',
#  'KANG',
#  'KIM',
#  'KIM',
#  'KIM',
#  'KIM',
#  'KO',
#  'KWON',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'LEE',
#  'OH',
#  'PARK',
#  'RYU',
#  'SONG',
#  'YOON',
#  'BELL',
#  'CEPEDA',
#  'DESPAIGNE',
#  'DUVERGEL',
#  'ENRIQUEZ',
#  'GONZALEZ',
#  'GOURRIEL',
#  'LA HERA',
#  'LAZO',
#  'MARTINEZ',
#  'MAYETA',
#  'MERINO',
#  'NAVAS',
#  'ODELIN SANAME',
#  'OLIVERA',
#  'PALMA',
#  'PARET',
#  'PEDROSO',
#  'PESTANO',
#  'RODRIGUEZ',
#  'SANCHEZ',
#  'SANCHEZ',
#  'URGELLES',
#  'VERA',
#  'DELFINO',
#  'GINOBILI',
#  'GONZALEZ',
#  'GUTIERREZ LLANAS',
#  'GUTIERREZ',
#  'KAMMERICHS',
#  'NOCIONI',
#  'OBERTO',
#  'PORTA PERNIGOTTI',
#  'PRIGIONI',
#  'QUINTEROS',
#  'SCOLA',
#  'ANTHONY',
#  'BOOZER',
#  'BOSH',
#  'BRYANT',
#  'HOWARD',
#  'JAMES',
#  'KIDD',
#  'PAUL',
#  'PRINCE',
#  'REDD',
#  'WADE',
#  'WILLIAMS',
#  'CALDERON',
#  'FERNANDEZ',
#  'GARBAJOSA',
#  'GASOL',
#  'GASOL',
#  'JIMENEZ',
#  'LOPEZ',
#  'MUMBRU',
#  'NAVARRO',
#  'REYES',
#  'RODRIGUEZ',
#  'RUBIO',
#  'ABROSIMOVA',
#  'HAMMON',
#  'KARPUNINA',
#  'KORSTIN',
#  'KUZINA',
#  'LISINA',
#  'OSIPOVA',
#  'RAKHMATULINA',
#  'SHCHEGOLEVA',
#  'SOKOLOVSKAYA',
#  'STEPANOVA',
#  'VODOPYANOVA',
#  'AUGUSTUS',
#  'BIRD',
#  'CATCHINGS',
#  'FOWLES',
#  'LAWSON',
#  'LESLIE',
#  'MILTON-JONES',
#  'PARKER',
#  'PONDEXTER',
#  'SMITH',
#  'TAURASI',
#  'THOMPSON',
#  'BATKOVIC',
#  'BEVILAQUA',
#  'COX',
#  'GRIMA',
#  'HARROWER',
#  'JACKSON',
#  'PHILLIPS',
#  'RANDALL',
#  'SCREEN',
#  'SNELL',
#  'SUMMERTON',
#  'TAYLOR',
#  'GLAZKOV',
#  'PRICE',
#  'CAMMARELLE',
#  'ZHANG',
#  'BALAKSHIN',
#  'PICARDI',
#  'JONGJOHOR',
#  'LAFFITA HERNANDEZ',
#  'BARNES',
#  'HERNANDEZ G',
#  'ZOU',
#  'PUREVDORJ',
#  'GOJAN',
#  'JULIE',
#  'ENKHBAT',
#  'LEON ALARCON',
#  'IMRANOV',
#  'KILIC',
#  'LOMACHENKO',
#  'DJELKHIR',
#  'JAVAKHYAN',
#  'UGAS',
#  'TISHCHENKO',
#  'SOW',
#  'IGLESIAS SOTOLONGO',
#  'VASTINE',
#  'DIAZ',
#  'BOONJUMNONG',
#  'HANATI',
#  'KIM',
#  'SARSEKBAYEV',
#  'BANTEAUX SUAREZ',
#  'KUMAR',
#  'SUTHERLAND',
#  'DEGALE',
#  'CORREA BAYEAUX',
#  'JEFFRIES',
#  'SHYNALIYEV',
#  'ZHANG',
#  'EGAN',
#  'ACOSTA DUARTE',
#  'WILDER',
#  'CHAKHKIEV',
#  'RUSSO',
#  'HALL',
#  'VAJDA',
#  'CAL',
#  'CHEBAN',
#  'OPALEV',
#  'CAL',
#  'KISS',
#  'KOZMANN',
#  'BAHDANOVICH',
#  'BAHDANOVICH',
#  'GILLE',
#  'WYLENZEK',
#  'GILLE',
#  'WYLENZEK',
#  'MENG',
#  'YANG',
#  'KOSTOGLOD',
#  'ULEGIN',
#  'WALLACE',
#  'BRABANTS',
#  'LARSEN',
#  'BRABANTS',
#  'WALLACE',
#  'VAN KOEVERDEN',
#  'WAGNER-AUGUSTIN',
#  'OSYPENKO-RADOMSKA',
#  'IDEM',
#  'FACCHIN',
#  'SCADUTO',
#  'HOLLSTEIN',
#  'IHLE',
#  'KNUDSEN',
#  'POULSEN',
#  'MAKHNEU',
#  'PIATRUSHENKA',
#  'CRAVIOTTO',
#  'PEREZ',
#  'RAUHE',
#  'WIESKOTTER',
#  'DELATTRE',
#  'VIARD',
#  'JANIC',
#  'KOVACS',
#  'KONIECZNA',
#  'MIKOLAJCZYK',
#  'ALTEPOST',
#  'BROCKL',
#  'ECKBRETT',
#  'GOLDSCHMIDT',
#  'ABALMASAU',
#  'LITVINCHUK',
#  'MAKHNEU',
#  'PIATRUSHENKA',
#  'RISZDORFER',
#  'RISZDORFER',
#  'TARR',
#  'VLCEK',
#  'DAVIS',
#  'FOGARTY',
#  'MEEK',
#  'OLDENHOF',
#  'FISCHER',
#  'REINHARDT',
#  'WAGNER-AUGUSTIN',
#  'WASSMUTH',
#  'JANIC',
#  'KOVACS',
#  'KOZAK',
#  'SZABO',
#  'BELL',
#  'MARTIKAN',
#  'FLORENCE',
#  'KUZNETSOV',
#  'LARIONOV',
#  'HOCHSCHORNER',
#  'HOCHSCHORNER',
#  'STEPANEK',
#  'VOLF',
#  'BOUKPETI',
#  'GRIMM',
#  'LEFEVRE',
#  'OBLINGER PETERS',
#  'KALISKA',
#  'LAWRENCE',
#  'ROBINSON',
#  'STROMBERGS',
#  'DAY',
#  'KINTNER',
#  'CHAUSSON',
#  'LE CORGUILLE',
#  'CANCELLARA',
#  'SANCHEZ',
#  'GUDERZO',
#  'COOKE',
#  'JOHANSSON',
#  'LEIPHEIMER',
#  'CANCELLARA',
#  'LARSSON',
#  'THURIG',
#  'ARMSTRONG',
#  'POOLEY',
#  'BURKE',
#  'WIGGINS',
#  'ROULSTON',
#  'KALITOVSKA',
#  'ROMERO',
#  'HOUVENAGHEL',
#  'NAGAI',
#  'HOY',
#  'EDGAR',
#  'IGNATYEV',
#  'MARKOV',
#  'CURUCHET',
#  'PEREZ',
#  'LLANERAS',
#  'TAULER',
#  'NEWTON',
#  'LLANERAS',
#  'KLUGE',
#  'OLABERRIA',
#  'VOS',
#  'GONZALEZ',
#  'GUO',
#  'PENDLETON',
#  'MEARES',
#  'BOURGAIN',
#  'HOY',
#  'KENNY',
#  'BEWLEY',
#  'ROULSTON',
#  'RYAN',
#  'SERGENT',
#  'CLANCY',
#  'MANNING',
#  'THOMAS',
#  'WIGGINS',
#  'JOERGENSEN',
#  'MADSEN',
#  'MOERKOEV',
#  'RASMUSSEN',
#  'ENDERS',
#  'LEVY',
#  'NIMKE',
#  'HOY',
#  'KENNY',
#  'STAFF',
#  'BAUGE',
#  'SIREAU',
#  'TOURNANT',
#  'SCHURTER',
#  'ABSALON',
#  'PERAUD',
#  'KALENTYEVA',
#  'SPITZ',
#  'WLOSZCZOWSKA',
#  'KEMMER',
#  'VAN GRUNSVEN',
#  'WERTH',
#  'HELGSTRAND',
#  'MINDERHOUD',
#  'VAN OLST',
#  'ZU-SAYN WITTGENSTEIN',
#  'CAPELLMANN',
#  'KEMMER',
#  'WERTH',
#  'SCHELLEKENS-BARTELS',
#  'VAN GRUNSVEN',
#  'ROMEIKE',
#  'COOK',
#  'MILES',
#  'FOX-PITT',
#  'DIBOWSKI',
#  'OSTHOLT',
#  'ROMEIKE',
#  'THOMSEN',
#  'FREDERICKS',
#  'ROSE',
#  'COOK',
#  'DICK',
#  'HUNT',
#  'KING',
#  'KLIMKE',
#  'FREDERICKS',
#  'JOHNSON',
#  'JONES',
#  'LAMAZE',
#  'BENGTSSON',
#  'MADDEN',
#  'GUERDAT',
#  'SCHURTENBERGER',
#  'SCHWIZER',
#  'SIMPSON',
#  'WARD',
#  'CONE',
#  'LAMAZE',
#  'MILLAR',
#  'LIEBHERR',
#  'KRAUT',
#  'MADDEN',
#  'HENSELWOOD',
#  'ABAJO',
#  'TAGLIARIOL',
#  'JEANNET',
#  'MINCZA-NEBALD',
#  'HEIDEMANN',
#  'BRANZA',
#  'CAROZZO',
#  'CONFALONIERI',
#  'ROTA',
#  'TAGLIARIOL',
#  'JEANNET',
#  'JEANNET',
#  'ROBEIRI',
#  'ANDRZEJUK',
#  'MOTYKA',
#  'WIERCIOCH',
#  'ZAWROTNIAK',
#  'SANZO',
#  'KLEIBRINK',
#  'OTA',
#  'GRANBASSI',
#  'VEZZALI',
#  'NAM',
#  'GRANBASSI',
#  'SALVATORI',
#  'TRILLINI',
#  'VEZZALI',
#  'BOYKO',
#  'CHANAEVA',
#  'LAMONOVA',
#  'NIKICHINA',
#  'CROSS',
#  'SMART',
#  'THOMPSON',
#  'COVALIU',
#  'ZHONG',
#  'LOPEZ',
#  'WARD',
#  'ZAGUNIS',
#  'JACOBSON',
#  ...]

# %%
[athlete_name[0].isupper() for athlete_name in athlete_names]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  ...]

# %%
len([item[0].isupper() for item in athlete_names])
# Out:
# 2042

# %%
nw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2042 entries, 0 to 2052
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          2042 non-null   object
#  1   Year          2042 non-null   float64
#  2   Sport         2042 non-null   object
#  3   Discipline    2042 non-null   object
#  4   Athlete Name  2042 non-null   object
#  5   NOC           2042 non-null   object
#  6   Gender        2042 non-null   object
#  7   Event         2042 non-null   object
#  8   Event Gender  2042 non-null   object
#  9   Medal         2042 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 175.5+ KB

# %% [markdown]
# ## Updating the dtypes

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  return df

oo = preprocess()
nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#          City    Year     Sport Discipline           Athlete Name  NOC Gender  \
# 23    Beijing  2008.0  aquatics     diving            WU, Melissa  AUS  Women
# 95    Beijing  2008.0  aquatics   swimming          PANG, Jiaying  CHN  Women
# 1082  Beijing  2008.0  football   football  OGBUKE OBASI, Chinedu  NGR    Men
#
#                                  Event Event Gender   Medal
# 23    synchronized diving 10m platform            W  Silver
# 95                      200m freestyle            W  Bronze
# 1082                          football            M  Silver

# %%
nw.dtypes

# %%
oo.dtypes

# %%
def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_2008.csv ...
#          City  Year       Sport  Discipline    Athlete Name  NOC Gender  \
# 95    Beijing  2008    aquatics    swimming   PANG, Jiaying  CHN  Women
# 649   Beijing  2008    baseball    baseball  PESTANO, Ariel  CUB    Men
# 1875  Beijing  2008  volleyball  volleyball  VERBOV, Alexey  RUS    Men
#
#                Event Event Gender   Medal
# 95    200m freestyle            W  Bronze
# 649         baseball            M  Silver
# 1875      volleyball            M  Bronze

# %%
nw.dtypes
# Out:
# City            string[python]
# Year                     int64
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %% [markdown]
# ## Combine the datasets

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

# %%
oo = preprocess()
oo.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#        Year      City      Sport       Discipline       Athlete Name  NOC  \
# 12438  1968    Mexico  athletics        athletics    KIMIHARA, Kenji  JPN
# 14928  1976  Montreal     rowing           rowing  ERMOLAEVA, Galina  URS
# 1140   1908    London  wrestling  wrestling gre-r     WEISZ, Richard  HUN
#
#       Gender                                Event Event Gender   Medal
# 12438    Men                             marathon            M  Silver
# 14928  Women  quadruple sculls with coxswain (4x)            W  Silver
# 1140     Men           + 93kg (super heavyweight)            M    Gold

# %%
oo.dtypes
# Out:
# Year                     int64
# City            string[python]
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
nw = preprocess_2008()
nw.sample(3)
# Out:
# Preprocessing olympics_2008.csv ...
#          City  Year          Sport     Discipline           Athlete Name  NOC  \
# 1943  Beijing  2008  weightlifting  weightlifting  GRABOVETSKAYA, Mariya  KAZ
# 360   Beijing  2008        archery        archery         PARK, Kyung-Mo  KOR
# 1148  Beijing  2008     gymnastics    artistic g.         IZBASA, Sandra  ROU
#
#      Gender                                  Event Event Gender   Medal
# 1943  Women                                 + 75kg            W  Bronze
# 360     Men  individual (fita olympic round - 70m)            M  Silver
# 1148  Women                        floor exercises            W    Gold

# %%
nw.dtypes
# Out:
# City            string[python]
# Year                     int64
# Sport           string[python]
# Discipline      string[python]
# Athlete Name    string[python]
# NOC             string[python]
# Gender                category
# Event           string[python]
# Event Gender          category
# Medal                 category
# dtype: object

# %%
pd.concat([oo, nw])

# %%
pd.concat([oo, nw]).dtypes

# %%
up = pd.concat([oo, nw])
up.sample(3)

# %%
up.dtypes

# %% [markdown]
# ## Plotting data

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df


def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year         City       Sport  Discipline           Athlete Name  NOC  \
# 16889  1984  Los Angeles   athletics   athletics     BUSSMANN, Gabriele  FRG
# 3092   1920      Antwerp   athletics   athletics        HOLMSTRÖM, Agne  SWE
# 11106  1964        Tokyo  basketball  basketball  PASOS AMAURY, Antonio  BRA
#
#       Gender         Event Event Gender   Medal
# 16889  Women  4x400m relay            W  Bronze
# 3092     Men  4x100m relay            M  Bronze
# 11106    Men    basketball            M  Bronze

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.1-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
# Requirement already satisfied: python-dateutil>=2.7 in ./linkedin/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.5-cp39-cp39-macosx_10_9_x86_64.whl (68 kB)
# Requirement already satisfied: packaging>=20.0 in ./linkedin/lib/python3.9/site-packages (from matplotlib) (24.1)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.1-cp39-cp39-macosx_10_9_x86_64.whl (260 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: numpy>=1.23 in ./linkedin/lib/python3.9/site-packages (from matplotlib) (2.0.0)
# Collecting pillow>=8
#   Using cached pillow-10.4.0-cp39-cp39-macosx_10_10_x86_64.whl (3.5 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.53.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
# Requirement already satisfied: zipp>=3.1.0 in ./linkedin/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in ./linkedin/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.9.1 pillow-10.4.0 pyparsing-3.1.2
# WARNING: You are using pip version 21.2.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/Users/owenyaggy/code/pandas-esst/linkedin/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **For the first Olympics, how many events were there for each of the different sports? Plot them using different graphs.**

# %%
first_games = up[up.Year == 1896]
first_games
# Out:
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# 1      Men        100km            M  Silver
# 2      Men         100m            M  Bronze
# 3      Men         100m            M  Bronze
# 4      Men         100m            M    Gold
# ..     ...          ...          ...     ...
# 146    Men  triple jump            M    Gold
# 147    Men  triple jump            M  Silver
# 148    Men        vault            M  Bronze
# 149    Men        vault            M    Gold
# 150    Men        vault            M  Silver
#
# [151 rows x 10 columns]

# %%
first_games.Sport.value_counts()
# Out:
# Sport
# gymnastics       45
# athletics        37
# cycling          16
# shooting         15
# aquatics         11
# tennis           10
# fencing           8
# weightlifting     6
# wrestling         3
# Name: count, dtype: Int64

# %%
first_games.Sport.value_counts().plot?
# Out:
# Object `plot` not found.

# %%
type(first_games.Sport.value_counts())
# Out:
# pandas.core.series.Series

# %%
dir(pd.Series)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pandas_priority__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_agg_examples_doc',
#  '_agg_see_also_doc',
#  '_align_for_op',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_binop',
#  '_can_hold_na',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_result',
#  '_constructor',
#  '_constructor_expanddim',
#  '_constructor_expanddim_from_mgr',
#  '_constructor_from_mgr',
#  '_data',
#  '_deprecate_downcast',
#  '_dir_additions',
#  '_dir_deletions',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_duplicated',
#  '_find_valid_index',
#  '_flex_method',
#  '_from_mgr',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cacher',
#  '_get_cleaned_column_resolvers',
#  '_get_index_resolvers',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_rows_with_mask',
#  '_get_value',
#  '_get_values_tuple',
#  '_get_with',
#  '_getitem_slice',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_init_dict',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_cached',
#  '_is_copy',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_is_view_after_cow_rules',
#  '_ixs',
#  '_logical_func',
#  '_logical_method',
#  '_map_values',
#  '_maybe_update_cacher',
#  '_memory_usage',
#  '_metadata',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_pad_or_backfill',
#  '_protect_consolidate',
#  '_reduce',
#  '_references',
#  '_reindex_axes',
#  '_reindex_indexer',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_single',
#  '_repr_data_resource_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_set_as_cached',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_labels',
#  '_set_name',
#  '_set_value',
#  '_set_values',
#  '_set_with',
#  '_set_with_engine',
#  '_shift_with_freq',
#  '_slice',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_latex_via_styler',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'apply',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asfreq',
#  'asof',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'autocorr',
#  'axes',
#  'backfill',
#  'between',
#  'between_time',
#  'bfill',
#  'bool',
#  'case_when',
#  'cat',
#  'clip',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'divmod',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dt',
#  'dtype',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'ewm',
#  'expanding',
#  'explode',
#  'factorize',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'hasnans',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'interpolate',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_unique',
#  'isin',
#  'isna',
#  'isnull',
#  'item',
#  'items',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'list',
#  'loc',
#  'lt',
#  'map',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'memory_usage',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'nbytes',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'radd',
#  'rank',
#  'ravel',
#  'rdiv',
#  'rdivmod',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'repeat',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'searchsorted',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'sort_index',
#  'sort_values',
#  'sparse',
#  'squeeze',
#  'std',
#  'str',
#  'struct',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_frame',
#  'to_hdf',
#  'to_json',
#  'to_latex',
#  'to_list',
#  'to_markdown',
#  'to_numpy',
#  'to_period',
#  'to_pickle',
#  'to_sql',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'tolist',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unique',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'view',
#  'where',
#  'xs']

# %%
pd.Series.plot?
# Out:
# Init signature: pd.Series.plot(data: 'Series | DataFrame') -> 'None'
# Docstring:
# Make plots of Series or DataFrame.
#
# Uses the backend specified by the
# option ``plotting.backend``. By default, matplotlib is used.
#
# Parameters
# ----------
# data : Series or DataFrame
#     The object for which the method is called.
# x : label or position, default None
#     Only used if data is a DataFrame.
# y : label, position or list of label, positions, default None
#     Allows plotting of one column versus another. Only used if data is a
#     DataFrame.
# kind : str
#     The kind of plot to produce:
#
#     - 'line' : line plot (default)
#     - 'bar' : vertical bar plot
#     - 'barh' : horizontal bar plot
#     - 'hist' : histogram
#     - 'box' : boxplot
#     - 'kde' : Kernel Density Estimation plot
#     - 'density' : same as 'kde'
#     - 'area' : area plot
#     - 'pie' : pie plot
#     - 'scatter' : scatter plot (DataFrame only)
#     - 'hexbin' : hexbin plot (DataFrame only)
# ax : matplotlib axes object, default None
#     An axes of the current figure.
# subplots : bool or sequence of iterables, default False
#     Whether to group columns into subplots:
#
#     - ``False`` : No subplots will be used
#     - ``True`` : Make separate subplots for each column.
#     - sequence of iterables of column labels: Create a subplot for each
#       group of columns. For example `[('a', 'c'), ('b', 'd')]` will
#       create 2 subplots: one with columns 'a' and 'c', and one
#       with columns 'b' and 'd'. Remaining columns that aren't specified
#       will be plotted in additional subplots (one per column).
#
#       .. versionadded:: 1.5.0
#
# sharex : bool, default True if ax is None else False
#     In case ``subplots=True``, share x axis and set some x axis labels
#     to invisible; defaults to True if ax is None otherwise False if
#     an ax is passed in; Be aware, that passing in both an ax and
#     ``sharex=True`` will alter all x axis labels for all axis in a figure.
# sharey : bool, default False
#     In case ``subplots=True``, share y axis and set some y axis labels to invisible.
# layout : tuple, optional
#     (rows, columns) for the layout of subplots.
# figsize : a tuple (width, height) in inches
#     Size of a figure object.
# use_index : bool, default True
#     Use index as ticks for x axis.
# title : str or list
#     Title to use for the plot. If a string is passed, print the string
#     at the top of the figure. If a list is passed and `subplots` is
#     True, print each item in the list above the corresponding subplot.
# grid : bool, default None (matlab style default)
#     Axis grid lines.
# legend : bool or {'reverse'}
#     Place legend on axis subplots.
# style : list or dict
#     The matplotlib line style per column.
# logx : bool or 'sym', default False
#     Use log scaling or symlog scaling on x axis.
#
# logy : bool or 'sym' default False
#     Use log scaling or symlog scaling on y axis.
#
# loglog : bool or 'sym', default False
#     Use log scaling or symlog scaling on both x and y axes.
#
# xticks : sequence
#     Values to use for the xticks.
# yticks : sequence
#     Values to use for the yticks.
# xlim : 2-tuple/list
#     Set the x limits of the current axes.
# ylim : 2-tuple/list
#     Set the y limits of the current axes.
# xlabel : label, optional
#     Name to use for the xlabel on x-axis. Default uses index name as xlabel, or the
#     x-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# ylabel : label, optional
#     Name to use for the ylabel on y-axis. Default will show no ylabel, or the
#     y-column name for planar plots.
#
#     .. versionchanged:: 2.0.0
#
#         Now applicable to histograms.
#
# rot : float, default None
#     Rotation for ticks (xticks for vertical, yticks for horizontal
#     plots).
# fontsize : float, default None
#     Font size for xticks and yticks.
# colormap : str or matplotlib colormap object, default None
#     Colormap to select colors from. If string, load colormap with that
#     name from matplotlib.
# colorbar : bool, optional
#     If True, plot colorbar (only relevant for 'scatter' and 'hexbin'
#     plots).
# position : float
#     Specify relative alignments for bar plot layout.
#     From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#     (center).
# table : bool, Series or DataFrame, default False
#     If True, draw a table using the data in the DataFrame and the data
#     will be transposed to meet matplotlib's default layout.
#     If a Series or DataFrame is passed, use passed data to draw a
#     table.
# yerr : DataFrame, Series, array-like, dict and str
#     See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#     detail.
# xerr : DataFrame, Series, array-like, dict and str
#     Equivalent to yerr.
# stacked : bool, default False in line and bar plots, and True in area plot
#     If True, create stacked plot.
# secondary_y : bool or sequence, default False
#     Whether to plot on the secondary y-axis if a list/tuple, which
#     columns to plot on secondary y-axis.
# mark_right : bool, default True
#     When using a secondary_y axis, automatically mark the column
#     labels with "(right)" in the legend.
# include_bool : bool, default is False
#     If True, boolean values can be plotted.
# backend : str, default None
#     Backend to use instead of the backend specified in the option
#     ``plotting.backend``. For instance, 'matplotlib'. Alternatively, to
#     specify the ``plotting.backend`` for the whole session, set
#     ``pd.options.plotting.backend``.
# **kwargs
#     Options to pass to matplotlib plotting method.
#
# Returns
# -------
# :class:`matplotlib.axes.Axes` or numpy.ndarray of them
#     If the backend is not the default matplotlib one, the return value
#     will be the object returned by the backend.
#
# Notes
# -----
# - See matplotlib documentation online for more on this subject
# - If `kind` = 'bar' or 'barh', you can specify relative alignments
#   for bar plot layout by `position` keyword.
#   From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5
#   (center)
#
# Examples
# --------
# For Series:
#
# .. plot::
#     :context: close-figs
#
#     >>> ser = pd.Series([1, 2, 3, 3])
#     >>> plot = ser.plot(kind='hist', title="My plot")
#
# For DataFrame:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],
#     ...                   'width': [0.7, 0.2, 0.15, 0.2, 1.1]},
#     ...                   index=['pig', 'rabbit', 'duck', 'chicken', 'horse'])
#     >>> plot = df.plot(title="DataFrame Plot")
#
# For SeriesGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> lst = [-1, -2, -3, 1, 2, 3]
#     >>> ser = pd.Series([1, 2, 2, 4, 6, 6], index=lst)
#     >>> plot = ser.groupby(lambda x: x > 0).plot(title="SeriesGroupBy Plot")
#
# For DataFrameGroupBy:
#
# .. plot::
#     :context: close-figs
#
#     >>> df = pd.DataFrame({"col1" : [1, 2, 3, 4],
#     ...                   "col2" : ["A", "B", "A", "B"]})
#     >>> plot = df.groupby("col2").plot(kind="bar", title="DataFrameGroupBy Plot")
# File:           ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/plotting/_core.py
# Type:           type
# Subclasses:

# %%
first_games.Sport.value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Sport'>

# %%
first_games.Sport.value_counts().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(figsize=(10,3))
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 #.plot(figsize=(10,3))
)
# Out:
# Sport
# gymnastics       45
# athletics        37
# cycling          16
# shooting         15
# aquatics         11
# tennis           10
# fencing           8
# weightlifting     6
# wrestling         3
# Name: count, dtype: Int64

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='bar')
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot
 .bar()
)
# Out:
# <Axes: xlabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh')
)
# Out:
# <Axes: ylabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh', color='red')
)
# Out:
# <Axes: ylabel='Sport'>

# %%
(first_games
 .Sport
 .value_counts()
 .plot(kind='barh', color=['blue', 'red'])
)
# Out:
# <Axes: ylabel='Sport'>

# %% [markdown]
# ## Working with colormaps and Seaborn

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year     City     Sport Discipline               Athlete Name  NOC  \
# 7600   1948   London   sailing    sailing              BRODIN, Gösta  SWE
# 10922  1964    Tokyo  shooting   shooting  MARKKANEN, Väinö Johannes  FIN
# 3755   1920  Antwerp     rugby      rugby               CHILO, André  FRA
#
#       Gender                  Event Event Gender   Medal
# 7600     Men                 dragon            X  Silver
# 10922    Men  50m pistol (60 shots)            M    Gold
# 3755     Men                  rugby            M  Silver

# %%
games_2008 = up[up.Year == 2008]
games_2008.sample(3)
# Out:
#       Year     City     Sport  Discipline        Athlete Name  NOC Gender  \
# 335   2008  Beijing  aquatics  water polo  GUICHELAAR, Rianne  NED  Women
# 1756  2008  Beijing  softball    softball        UENO, Yukiko  JPN  Women
# 1619  2008  Beijing    rowing      rowing       FLOOD, Debbie  GBR  Women
#
#                                        Event Event Gender   Medal
# 335                               water polo            W    Gold
# 1756                                softball            W    Gold
# 1619  quadruple sculls without coxswain (4x)            W  Silver

# %%
(games_2008
 .Medal
 .value_counts())
# Out:
# Medal
# Bronze    710
# Gold      669
# Silver    663
# Name: count, dtype: int64

# %%
# %pip install seaborn
import seaborn as sns
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      |████████████████████████████████| 294 kB 3.0 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.2 in ./linkedin/lib/python3.9/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./linkedin/lib/python3.9/site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./linkedin/lib/python3.9/site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: packaging>=20.0 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./linkedin/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: zipp>=3.1.0 in ./linkedin/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: tzdata>=2022.7 in ./linkedin/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in ./linkedin/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in ./linkedin/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/Users/owenyaggy/code/pandas-esst/linkedin/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              )
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"])
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='seismic')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='coolwarm')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='bwr')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %%
plt.figure(figsize=(5,3))
plt.title("Medals from the 2008 games")
sns.countplot(data=games_2008,
              x='Medal',
              order=["Gold", "Silver", "Bronze"],
              hue='Gender',
              palette='bwr_r')
# Out:
# <Axes: title={'center': 'Medals from the 2008 games'}, xlabel='Medal', ylabel='count'>

# %% [markdown]
# ## Working with groupby

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = (pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
        .drop('Position', axis=1)
  )
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year      City       Sport  Discipline     Athlete Name  NOC Gender  \
# 24019  2000    Sydney  basketball  basketball   NEVES, Claudia  BRA  Women
# 14577  1976  Montreal     fencing     fencing  NOËL, Christian  FRA    Men
# 19029  1988     Seoul    handball    handball    LEE, Sang-Hyo  KOR    Men
#
#             Event Event Gender   Medal
# 24019  basketball            W  Bronze
# 14577   foil team            M  Bronze
# 19029    handball            M  Silver

# %%
sprints = up[(up.Year == 2008) & ((up.Event == '100m') | (up.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA
#
#     Gender Event Event Gender   Medal
# 388    Men  100m            M  Bronze
# 389    Men  100m            M    Gold
# 390    Men  100m            M  Silver
# 391  Women  100m            W    Gold
# 392  Women  100m            W  Silver
# 393  Women  100m            W  Silver
# 406    Men  200m            M  Bronze
# 407    Men  200m            M    Gold
# 408    Men  200m            M  Silver
# 409  Women  200m            W  Bronze
# 410  Women  200m            W    Gold
# 411  Women  200m            W  Silver

# %%
sp = sprints.groupby(['NOC', 'Gender', 'Event'])
sp
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1729970244.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sp = sprints.groupby(['NOC', 'Gender', 'Event'])

# %%
up.groupby("Year")

# %%
type(up.groupby('Year'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
up.groupby("Year").count()
# Out:
#       City  Sport  Discipline  Athlete Name   NOC  Gender  Event  \
# Year
# 1896   151    151         151           151   151     151    151
# 1900   512    512         512           512   512     512    512
# 1904   470    470         470           470   470     470    470
# 1908   804    804         804           804   804     804    804
# 1912   885    885         885           885   885     885    885
# 1920  1298   1298        1298          1298  1298    1298   1298
# 1924   884    884         884           884   884     884    884
# 1928   710    710         710           710   710     710    710
# 1932   615    615         615           615   615     615    615
# 1936   875    875         875           875   875     875    875
# 1948   814    814         814           814   814     814    814
# 1952   889    889         889           889   889     889    889
# 1956   885    885         885           885   885     885    885
# 1960   882    882         882           882   882     882    882
# 1964  1010   1010        1010          1010  1010    1010   1010
# 1968  1031   1031        1031          1031  1031    1031   1031
# 1972  1185   1185        1185          1185  1185    1185   1185
# 1976  1305   1305        1305          1305  1305    1305   1305
# 1980  1387   1387        1387          1387  1387    1387   1387
# 1984  1459   1459        1459          1459  1459    1459   1459
# 1988  1546   1546        1546          1546  1546    1546   1546
# 1992  1705   1705        1705          1705  1705    1705   1705
# 1996  1859   1859        1859          1859  1859    1859   1859
# 2000  2015   2015        2015          2015  2015    2015   2015
# 2004  1998   1998        1998          1998  1998    1998   1998
# 2008  2042   2042        2042          2042  2042    2042   2042
#
#       Event Gender  Medal
# Year
# 1896           151    151
# 1900           512    512
# 1904           470    470
# 1908           804    804
# 1912           885    885
# 1920          1298   1298
# 1924           884    884
# 1928           710    710
# 1932           615    615
# 1936           875    875
# 1948           814    814
# 1952           889    889
# 1956           885    885
# 1960           882    882
# 1964          1010   1010
# 1968          1031   1031
# 1972          1185   1185
# 1976          1305   1305
# 1980          1387   1387
# 1984          1459   1459
# 1988          1546   1546
# 1992          1705   1705
# 1996          1859   1859
# 2000          2015   2015
# 2004          1998   1998
# 2008          2042   2042

# %%
for group_key, group_value in up.groupby('Year'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#      Year    City       Sport     Discipline          Athlete Name  NOC  \
# 0    1896  Athens     cycling  cycling track         FLAMENG, Léon  FRA
# 1    1896  Athens     cycling  cycling track    KOLETTIS, Georgios  GRE
# 2    1896  Athens   athletics      athletics         LANE, Francis  USA
# 3    1896  Athens   athletics      athletics      SZOKOLYI, Alajos  HUN
# 4    1896  Athens   athletics      athletics         BURKE, Thomas  USA
# ..    ...     ...         ...            ...                   ...  ...
# 146  1896  Athens   athletics      athletics       CONNOLLY, James  USA
# 147  1896  Athens   athletics      athletics    TUFFERI, Alexandre  FRA
# 148  1896  Athens  gymnastics    artistic g.  WEINGÄRTNER, Hermann  GER
# 149  1896  Athens  gymnastics    artistic g.        SCHUMANN, Carl  GER
# 150  1896  Athens  gymnastics    artistic g.         ZUTTER, Louis  SUI
#
#     Gender        Event Event Gender   Medal
# 0      Men        100km            M    Gold
# 1      Men        100km            M  Silver
# 2      Men         100m            M  Bronze
# 3      Men         100m            M  Bronze
# 4      Men         100m            M    Gold
# ..     ...          ...          ...     ...
# 146    Men  triple jump            M    Gold
# 147    Men  triple jump            M  Silver
# 148    Men        vault            M  Bronze
# 149    Men        vault            M    Gold
# 150    Men        vault            M  Silver
#
# [151 rows x 10 columns]
# 1900
#      Year   City    Sport Discipline                 Athlete Name  NOC Gender  \
# 151  1900  Paris  sailing    sailing                 MICHELET, E.  FRA    Men
# 152  1900  Paris  sailing    sailing                 MICHELET, F.  FRA    Men
# 153  1900  Paris  sailing    sailing             GRETTON, John H.  GBR    Men
# 154  1900  Paris  sailing    sailing                 HOPE, Linton  GBR    Men
# 155  1900  Paris  sailing    sailing  LORD CURRIE, Lorne Campbell  GBR    Men
# ..    ...    ...      ...        ...                          ...  ...    ...
# 658  1900  Paris  fencing    fencing                 AYAT, Albert  FRA    Men
# 659  1900  Paris  fencing    fencing                 FONST, Ramon  CUB    Men
# 660  1900  Paris  fencing    fencing               LAURENT, Henri  FRA    Men
# 661  1900  Paris  fencing    fencing                 AYAT, Albert  FRA    Men
# 662  1900  Paris  fencing    fencing               BOUGNOL, Emile  FRA    Men
#
#                           Event Event Gender   Medal
# 151                      0.5-1t            X  Bronze
# 152                      0.5-1t            X  Bronze
# 153                      0.5-1t            X    Gold
# 154                      0.5-1t            X    Gold
# 155                      0.5-1t            X    Gold
# ..                          ...          ...     ...
# 658  épée, amateurs and masters            M    Gold
# 659  épée, amateurs and masters            M  Silver
# 660               épée, masters            M  Bronze
# 661               épée, masters            M    Gold
# 662               épée, masters            M  Silver
#
# [512 rows x 10 columns]
# 1904
#       Year      City       Sport       Discipline  \
# 663   1904  St Louis      boxing           boxing
# 664   1904  St Louis      boxing           boxing
# 665   1904  St Louis      boxing           boxing
# 666   1904  St Louis   wrestling  wrestling free.
# 667   1904  St Louis   wrestling  wrestling free.
# ...    ...       ...         ...              ...
# 1128  1904  St Louis  gymnastics      artistic g.
# 1129  1904  St Louis  gymnastics      artistic g.
# 1130  1904  St Louis     fencing          fencing
# 1131  1904  St Louis     fencing          fencing
# 1132  1904  St Louis     fencing          fencing
#
#                      Athlete Name  NOC Gender                    Event  \
# 663             MICHAELS, William  USA    Men  + 71.67kg (heavyweight)
# 664                BERGER, Samuel  USA    Men  + 71.67kg (heavyweight)
# 665                MAYER, Charles  USA    Men  + 71.67kg (heavyweight)
# 666   WARMBOLD, Frederick Charles  USA    Men  + 71.67kg (heavyweight)
# 667              HANSEN, Bernhuff  USA    Men  + 71.67kg (heavyweight)
# ...                           ...  ...    ...                      ...
# 1128                EYSER, George  USA    Men                    vault
# 1129                 HEIDA, Anton  USA    Men                    vault
# 1130       VAN ZO POST, Albertson  CUB    Men          épée individual
# 1131                 FONST, Ramon  CUB    Men          épée individual
# 1132              TATHAM, Charles  CUB    Men          épée individual
#
#      Event Gender   Medal
# 663             M  Bronze
# 664             M    Gold
# 665             M  Silver
# 666             M  Bronze
# 667             M    Gold
# ...           ...     ...
# 1128            M    Gold
# 1129            M    Gold
# 1130            M  Bronze
# 1131            M    Gold
# 1132            M  Silver
#
# [470 rows x 10 columns]
# 1908
#       Year    City      Sport       Discipline               Athlete Name  \
# 1133  1908  London     boxing           boxing           PARKS, Frederick
# 1134  1908  London     boxing           boxing     OLDMAN, Albert Leonard
# 1135  1908  London     boxing           boxing   EVANS, Sydney Charles H.
# 1136  1908  London  wrestling  wrestling free.     BARRETT, Edward Edmond
# 1137  1908  London  wrestling  wrestling free.  O'KELLY, George Cornelius
# ...    ...     ...        ...              ...                        ...
# 1932  1908  London    fencing          fencing     OLIVIER, Eugène Victor
# 1933  1908  London    fencing          fencing      DANIELL, Charles Leaf
# 1934  1908  London    fencing          fencing          HAIG, Cecil Henry
# 1935  1908  London    fencing          fencing      HOLT, Martin Drummond
# 1936  1908  London    fencing          fencing  MONTGOMERIE, Robert Cecil
#
#       NOC Gender                    Event Event Gender   Medal
# 1133  GBR    Men  + 71.67kg (heavyweight)            M  Bronze
# 1134  GBR    Men  + 71.67kg (heavyweight)            M    Gold
# 1135  GBR    Men  + 71.67kg (heavyweight)            M  Silver
# 1136  GBR    Men     + 73kg (heavyweight)            M  Bronze
# 1137  GBR    Men     + 73kg (heavyweight)            M    Gold
# ...   ...    ...                      ...          ...     ...
# 1932  FRA    Men                épée team            M    Gold
# 1933  GBR    Men                épée team            M  Silver
# 1934  GBR    Men                épée team            M  Silver
# 1935  GBR    Men                épée team            M  Silver
# 1936  GBR    Men                épée team            M  Silver
#
# [804 rows x 10 columns]
# 1912
#       Year       City      Sport       Discipline                Athlete Name  \
# 1937  1912  Stockholm  wrestling  wrestling gre-r        JENSEN, Sören Marius
# 1938  1912  Stockholm  wrestling  wrestling gre-r   SAARELA, Urjö Erik Mikael
# 1939  1912  Stockholm  wrestling  wrestling gre-r         OLIN, Johan Fredrik
# 1940  1912  Stockholm  wrestling  wrestling gre-r               LASANEN, Otto
# 1941  1912  Stockholm  wrestling  wrestling gre-r             KOSKELO, Kaarlo
# ...    ...        ...        ...              ...                         ...
# 2817  1912  Stockholm    fencing          fencing  EVERITT, Arthur Francis G.
# 2818  1912  Stockholm    fencing          fencing       HOLT, Martin Drummond
# 2819  1912  Stockholm    fencing          fencing           MARTINEAU, Sydney
# 2820  1912  Stockholm    fencing          fencing   MONTGOMERIE, Robert Cecil
# 2821  1912  Stockholm    fencing          fencing       SELIGMAN, Edgar Isaac
#
#       NOC Gender                         Event Event Gender   Medal
# 1937  DEN    Men  + 82.5kg (super heavyweight)            M  Bronze
# 1938  FIN    Men  + 82.5kg (super heavyweight)            M    Gold
# 1939  FIN    Men  + 82.5kg (super heavyweight)            M  Silver
# 1940  FIN    Men        - 60kg (featherweight)            M  Bronze
# 1941  FIN    Men        - 60kg (featherweight)            M    Gold
# ...   ...    ...                           ...          ...     ...
# 2817  GBR    Men                     épée team            M  Silver
# 2818  GBR    Men                     épée team            M  Silver
# 2819  GBR    Men                     épée team            M  Silver
# 2820  GBR    Men                     épée team            M  Silver
# 2821  GBR    Men                     épée team            M  Silver
#
# [885 rows x 10 columns]
# 1920
#       Year     City      Sport       Discipline  \
# 2822  1920  Antwerp     boxing           boxing
# 2823  1920  Antwerp     boxing           boxing
# 2824  1920  Antwerp     boxing           boxing
# 2825  1920  Antwerp  wrestling  wrestling free.
# 2826  1920  Antwerp  wrestling  wrestling free.
# ...    ...      ...        ...              ...
# 4115  1920  Antwerp    fencing          fencing
# 4116  1920  Antwerp    fencing          fencing
# 4117  1920  Antwerp    fencing          fencing
# 4118  1920  Antwerp    fencing          fencing
# 4119  1920  Antwerp    fencing          fencing
#
#                         Athlete Name  NOC Gender                    Event  \
# 2822           ELUERE, Albert Xavier  FRA    Men  + 79.38kg (heavyweight)
# 2823                  RAWSON, Ronald  GBR    Men  + 79.38kg (heavyweight)
# 2824                PETEERSEN, Sören  DEN    Men  + 79.38kg (heavyweight)
# 2825         MEYER, Frederick Julius  USA    Men     + 80kg (heavyweight)
# 2826                  NILSSON, Ernst  SWE    Men     + 80kg (heavyweight)
# ...                              ...  ...    ...                      ...
# 4115                 DE WEE, Maurice  BEL    Men                épée team
# 4116                  GEVERS, Ernest  BEL    Men                épée team
# 4117         GOBLET D'AVIELLA, Félix  BEL    Men                épée team
# 4118  LE HARDY DE BEAULIEU, Philippe  BEL    Men                épée team
# 4119                       TOM, Léon  BEL    Men                épée team
#
#      Event Gender   Medal
# 2822            M  Bronze
# 2823            M    Gold
# 2824            M  Silver
# 2825            M  Bronze
# 2826            M  Bronze
# ...           ...     ...
# 4115            M  Silver
# 4116            M  Silver
# 4117            M  Silver
# 4118            M  Silver
# 4119            M  Silver
#
# [1298 rows x 10 columns]
# 1924
#       Year   City      Sport       Discipline          Athlete Name  NOC  \
# 4120  1924  Paris     boxing           boxing       PORZIO, Alfredo  ARG
# 4121  1924  Paris     boxing           boxing       VON PORAT, Otto  NOR
# 4122  1924  Paris     boxing           boxing       PETERSEN, Sören  DEN
# 4123  1924  Paris  wrestling  wrestling gre-r         BADO, Rajmund  HUN
# 4124  1924  Paris  wrestling  wrestling gre-r        DEGLANE, Henri  FRA
# ...    ...    ...        ...              ...                   ...  ...
# 4999  1924  Paris    fencing          fencing   DE CRAECKER, Joseph  BEL
# 5000  1924  Paris    fencing          fencing  DE MONTIGNY, Fernand  BEL
# 5001  1924  Paris    fencing          fencing     DELPORTE, Charles  BEL
# 5002  1924  Paris    fencing          fencing        GEVERS, Ernest  BEL
# 5003  1924  Paris    fencing          fencing             TOM, Léon  BEL
#
#      Gender                         Event Event Gender   Medal
# 4120    Men       + 79.38kg (heavyweight)            M  Bronze
# 4121    Men       + 79.38kg (heavyweight)            M    Gold
# 4122    Men       + 79.38kg (heavyweight)            M  Silver
# 4123    Men  + 82.5kg (super heavyweight)            M  Bronze
# 4124    Men  + 82.5kg (super heavyweight)            M    Gold
# ...     ...                           ...          ...     ...
# 4999    Men                     épée team            M  Silver
# 5000    Men                     épée team            M  Silver
# 5001    Men                     épée team            M  Silver
# 5002    Men                     épée team            M  Silver
# 5003    Men                     épée team            M  Silver
#
# [884 rows x 10 columns]
# 1928
#       Year       City      Sport       Discipline               Athlete Name  \
# 5004  1928  Amsterdam     boxing           boxing  MICHAELSEN, Michael Jacob
# 5005  1928  Amsterdam     boxing           boxing   RODRIGUEZ JURADO, Arturo
# 5006  1928  Amsterdam     boxing           boxing           RAMM, Nils Arvid
# 5007  1928  Amsterdam  wrestling  wrestling gre-r             GEHRING, Georg
# 5008  1928  Amsterdam  wrestling  wrestling gre-r           SVENSSON, Rudolf
# ...    ...        ...        ...              ...                        ...
# 5709  1928  Amsterdam   aquatics       water polo             KESERU, Ferenc
# 5710  1928  Amsterdam   aquatics       water polo            VRABELY, Jozsef
# 5711  1928  Amsterdam    fencing          fencing     CALNAN, George Charles
# 5712  1928  Amsterdam    fencing          fencing             GAUDIN, Lucien
# 5713  1928  Amsterdam    fencing          fencing           BUCHARD, Georges
#
#       NOC Gender                         Event Event Gender   Medal
# 5004  DEN    Men       + 79.38kg (heavyweight)            M  Bronze
# 5005  ARG    Men       + 79.38kg (heavyweight)            M    Gold
# 5006  SWE    Men       + 79.38kg (heavyweight)            M  Silver
# 5007  GER    Men  + 82.5kg (super heavyweight)            M  Bronze
# 5008  SWE    Men  + 82.5kg (super heavyweight)            M    Gold
# ...   ...    ...                           ...          ...     ...
# 5709  HUN    Men                    water polo            M  Silver
# 5710  HUN    Men                    water polo            M  Silver
# 5711  USA    Men               épée individual            M  Bronze
# 5712  FRA    Men               épée individual            M    Gold
# 5713  FRA    Men               épée individual            M  Silver
#
# [710 rows x 10 columns]
# 1932
#       Year         City          Sport     Discipline  \
# 5714  1932  Los Angeles         boxing         boxing
# 5715  1932  Los Angeles         boxing         boxing
# 5716  1932  Los Angeles         boxing         boxing
# 5717  1932  Los Angeles  weightlifting  weightlifting
# 5718  1932  Los Angeles  weightlifting  weightlifting
# ...    ...          ...            ...            ...
# 6324  1932  Los Angeles        fencing        fencing
# 6325  1932  Los Angeles        fencing        fencing
# 6326  1932  Los Angeles        fencing        fencing
# 6327  1932  Los Angeles        fencing        fencing
# 6328  1932  Los Angeles        fencing        fencing
#
#                         Athlete Name  NOC Gender  \
# 5714                FEARY, Frederick  USA    Men
# 5715        LOVELL, Alberto Santiago  ARG    Men
# 5716                   ROVATI, Luigi  ITA    Men
# 5717             STRASSBERGER, Josef  GER    Men
# 5718                SKOBLA, Jaroslav  TCH    Men
# ...                              ...  ...    ...
# 6324                 AGOSTONI, Carlo  ITA    Men
# 6325  CORNAGGIA-MEDICI, Giancarlo C.  ITA    Men
# 6326                   MINOLI, Renzo  ITA    Men
# 6327                  RAGNO, Saverio  ITA    Men
# 6328                RICCARDI, Franco  ITA    Men
#
#                               Event Event Gender   Medal
# 5714        + 79.38kg (heavyweight)            M  Bronze
# 5715        + 79.38kg (heavyweight)            M    Gold
# 5716        + 79.38kg (heavyweight)            M  Silver
# 5717  + 82.5kg, total (heavyweight)            M  Bronze
# 5718  + 82.5kg, total (heavyweight)            M    Gold
# ...                             ...          ...     ...
# 6324                      épée team            M  Silver
# 6325                      épée team            M  Silver
# 6326                      épée team            M  Silver
# 6327                      épée team            M  Silver
# 6328                      épée team            M  Silver
#
# [615 rows x 10 columns]
# 1936
#       Year    City          Sport     Discipline            Athlete Name  NOC  \
# 6329  1936  Berlin         boxing         boxing          NILSEN, Erling  NOR
# 6330  1936  Berlin         boxing         boxing          RUNGE, Herbert  GER
# 6331  1936  Berlin         boxing         boxing  LOVELL, Jose Guillermo  ARG
# 6332  1936  Berlin  weightlifting  weightlifting         LUHAÄÄR, Arnold  EST
# 6333  1936  Berlin  weightlifting  weightlifting           MANGER, Josef  GER
# ...    ...     ...            ...            ...                     ...  ...
# 7199  1936  Berlin        fencing        fencing         CEDERIN, Birger  SWE
# 7200  1936  Berlin        fencing        fencing        DRAKENBERG, Hans  SWE
# 7201  1936  Berlin        fencing        fencing         DYRSSEN, Gustaf  SWE
# 7202  1936  Berlin        fencing        fencing          GRANFELT, Hans  SWE
# 7203  1936  Berlin        fencing        fencing           THOFELT, Sven  SWE
#
#      Gender                          Event Event Gender   Medal
# 6329    Men        + 79.38kg (heavyweight)            M  Bronze
# 6330    Men        + 79.38kg (heavyweight)            M    Gold
# 6331    Men        + 79.38kg (heavyweight)            M  Silver
# 6332    Men  + 82.5kg, total (heavyweight)            M  Bronze
# 6333    Men  + 82.5kg, total (heavyweight)            M    Gold
# ...     ...                            ...          ...     ...
# 7199    Men                      épée team            M  Silver
# 7200    Men                      épée team            M  Silver
# 7201    Men                      épée team            M  Silver
# 7202    Men                      épée team            M  Silver
# 7203    Men                      épée team            M  Silver
#
# [875 rows x 10 columns]
# 1948
#       Year    City          Sport     Discipline               Athlete Name  \
# 7204  1948  London         boxing         boxing               ARTHUR, John
# 7205  1948  London         boxing         boxing           IGLESIAS, Rafael
# 7206  1948  London         boxing         boxing            NILSSON, Gunnar
# 7207  1948  London  weightlifting  weightlifting           CHARITE, Abraham
# 7208  1948  London  weightlifting  weightlifting      DAVIS, John Henry Jr.
# ...    ...     ...            ...            ...                        ...
# 8013  1948  London        fencing        fencing             CANTONE, Luigi
# 8014  1948  London        fencing        fencing  MANDRUZZATO, Marc Antonio
# 8015  1948  London        fencing        fencing         MANGIAROTTI, Dario
# 8016  1948  London        fencing        fencing       MANGIAROTTI, Edoardo
# 8017  1948  London        fencing        fencing           MARINI, Fiorenzo
#
#       NOC Gender                          Event Event Gender   Medal
# 7204  RSA    Men           + 80kg (heavyweight)            M  Bronze
# 7205  ARG    Men           + 80kg (heavyweight)            M    Gold
# 7206  SWE    Men           + 80kg (heavyweight)            M  Silver
# 7207  NED    Men  + 82.5kg, total (heavyweight)            M  Bronze
# 7208  USA    Men  + 82.5kg, total (heavyweight)            M    Gold
# ...   ...    ...                            ...          ...     ...
# 8013  ITA    Men                      épée team            M  Silver
# 8014  ITA    Men                      épée team            M  Silver
# 8015  ITA    Men                      épée team            M  Silver
# 8016  ITA    Men                      épée team            M  Silver
# 8017  ITA    Men                      épée team            M  Silver
#
# [814 rows x 10 columns]
# 1952
#       Year      City      Sport       Discipline               Athlete Name  \
# 8018  1952  Helsinki     boxing           boxing      KOSKI, Ilkka Rickhard
# 8019  1952  Helsinki     boxing           boxing         NIEMAN, Andries C.
# 8020  1952  Helsinki     boxing           boxing      SANDERS, Hayes Edward
# 8021  1952  Helsinki     boxing           boxing  JOHANSSON, Ingemar (Ingo)
# 8022  1952  Helsinki  wrestling  wrestling free.     RICHMOND, Kenneth Alan
# ...    ...       ...        ...              ...                        ...
# 8902  1952  Helsinki    fencing          fencing              FAHLMAN, Sven
# 8903  1952  Helsinki    fencing          fencing             FORSSELL, Carl
# 8904  1952  Helsinki    fencing          fencing          LJUNGQUIST, Bengt
# 8905  1952  Helsinki    fencing          fencing         MAGNUSSON, Lennart
# 8906  1952  Helsinki    fencing          fencing     REHBINDER, Berndt-Otto
#
#       NOC Gender                 Event Event Gender   Medal
# 8018  FIN    Men  + 81kg (heavyweight)            M  Bronze
# 8019  RSA    Men  + 81kg (heavyweight)            M  Bronze
# 8020  USA    Men  + 81kg (heavyweight)            M    Gold
# 8021  SWE    Men  + 81kg (heavyweight)            M  Silver
# 8022  GBR    Men  + 87kg (heavyweight)            M  Bronze
# ...   ...    ...                   ...          ...     ...
# 8902  SWE    Men             épée team            M  Silver
# 8903  SWE    Men             épée team            M  Silver
# 8904  SWE    Men             épée team            M  Silver
# 8905  SWE    Men             épée team            M  Silver
# 8906  SWE    Men             épée team            M  Silver
#
# [889 rows x 10 columns]
# 1956
#       Year                   City      Sport       Discipline  \
# 8907  1956  Melbourne / Stockholm     boxing           boxing
# 8908  1956  Melbourne / Stockholm     boxing           boxing
# 8909  1956  Melbourne / Stockholm     boxing           boxing
# 8910  1956  Melbourne / Stockholm     boxing           boxing
# 8911  1956  Melbourne / Stockholm  wrestling  wrestling free.
# ...    ...                    ...        ...              ...
# 9787  1956  Melbourne / Stockholm    fencing          fencing
# 9788  1956  Melbourne / Stockholm    fencing          fencing
# 9789  1956  Melbourne / Stockholm    fencing          fencing
# 9790  1956  Melbourne / Stockholm    fencing          fencing
# 9791  1956  Melbourne / Stockholm    fencing          fencing
#
#                     Athlete Name  NOC Gender                 Event  \
# 8907      BEKKER, Daniel Wepener  RSA    Men  + 81kg (heavyweight)
# 8908            BOZZANO, Giacomo  ITA    Men  + 81kg (heavyweight)
# 8909    RADEMACHER, Thomas Peter  USA    Men  + 81kg (heavyweight)
# 8910                 MUKHIN, Lev  URS    Men  + 81kg (heavyweight)
# 8911  KANGASNIEMI, Taisto Ilmari  FIN    Men  + 87kg (heavyweight)
# ...                          ...  ...    ...                   ...
# 9787         BERZSENYI, Barnabas  HUN    Men             épée team
# 9788              MAROSI, Jozsef  HUN    Men             épée team
# 9789                NAGY, Ambrus  HUN    Men             épée team
# 9790               RERRICH, Bela  HUN    Men             épée team
# 9791            SAKOVICS, Jozsef  HUN    Men             épée team
#
#      Event Gender   Medal
# 8907            M  Bronze
# 8908            M  Bronze
# 8909            M    Gold
# 8910            M  Silver
# 8911            M  Bronze
# ...           ...     ...
# 9787            M  Silver
# 9788            M  Silver
# 9789            M  Silver
# 9790            M  Silver
# 9791            M  Silver
#
# [885 rows x 10 columns]
# 1960
#        Year  City      Sport       Discipline                  Athlete Name  \
# 9792   1960  Rome     boxing           boxing                  NEMEC, Josef
# 9793   1960  Rome     boxing           boxing              SIEGMUND, Günter
# 9794   1960  Rome     boxing           boxing         DE PICCOLI, Francesco
# 9795   1960  Rome     boxing           boxing        BEKKER, Daniel Wepener
# 9796   1960  Rome  wrestling  wrestling free.              DZARASOV, Savkus
# ...     ...   ...        ...              ...                           ...
# 10669  1960  Rome    fencing          fencing        HARRISON, Raymond Alan
# 10670  1960  Rome    fencing          fencing  HOSKYNS, Henry William Furse
# 10671  1960  Rome    fencing          fencing    HOWARD, Michael John Peter
# 10672  1960  Rome    fencing          fencing      JAY, Allan Louis Neville
# 10673  1960  Rome    fencing          fencing          PELLING, John Albert
#
#        NOC Gender                 Event Event Gender   Medal
# 9792   TCH    Men  + 81kg (heavyweight)            M  Bronze
# 9793   EUA    Men  + 81kg (heavyweight)            M  Bronze
# 9794   ITA    Men  + 81kg (heavyweight)            M    Gold
# 9795   RSA    Men  + 81kg (heavyweight)            M  Silver
# 9796   URS    Men  + 87kg (heavyweight)            M  Bronze
# ...    ...    ...                   ...          ...     ...
# 10669  GBR    Men             épée team            M  Silver
# 10670  GBR    Men             épée team            M  Silver
# 10671  GBR    Men             épée team            M  Silver
# 10672  GBR    Men             épée team            M  Silver
# 10673  GBR    Men             épée team            M  Silver
#
# [882 rows x 10 columns]
# 1964
#        Year   City    Sport Discipline                   Athlete Name  NOC  \
# 10674  1964  Tokyo     judo       judo           CHIKVILADZE, Parnaos  URS
# 10675  1964  Tokyo     judo       judo                KIKNADZE, Anzor  URS
# 10676  1964  Tokyo     judo       judo                  INOKUMA, Isao  JPN
# 10677  1964  Tokyo     judo       judo  ROGERS, Alfred Harold Douglas  CAN
# 10678  1964  Tokyo   boxing     boxing               EMELYANOV, Vadim  URS
# ...     ...    ...      ...        ...                            ...  ...
# 11679  1964  Tokyo  fencing    fencing       BREDA, Giovanni Battista  ITA
# 11680  1964  Tokyo  fencing    fencing              DELFINO, Giuseppe  ITA
# 11681  1964  Tokyo  fencing    fencing           PAOLUCCI, Gianfranco  ITA
# 11682  1964  Tokyo  fencing    fencing            PELLEGRINO, Alberto  ITA
# 11683  1964  Tokyo  fencing    fencing             SACCARO, Gianluigi  ITA
#
#       Gender                 Event Event Gender   Medal
# 10674    Men  + 80kg (heavyweight)            M  Bronze
# 10675    Men  + 80kg (heavyweight)            M  Bronze
# 10676    Men  + 80kg (heavyweight)            M    Gold
# 10677    Men  + 80kg (heavyweight)            M  Silver
# 10678    Men  + 81kg (heavyweight)            M  Bronze
# ...      ...                   ...          ...     ...
# 11679    Men             épée team            M  Silver
# 11680    Men             épée team            M  Silver
# 11681    Men             épée team            M  Silver
# 11682    Men             épée team            M  Silver
# 11683    Men             épée team            M  Silver
#
# [1010 rows x 10 columns]
# 1968
#        Year    City          Sport     Discipline          Athlete Name  NOC  \
# 11684  1968  Mexico         boxing         boxing      BAMBINI, Giorgio  ITA
# 11685  1968  Mexico         boxing         boxing        ROCHA, Joaquin  MEX
# 11686  1968  Mexico         boxing         boxing       FOREMAN, George  USA
# 11687  1968  Mexico         boxing         boxing       CHEPULIS, Ionas  URS
# 11688  1968  Mexico  weightlifting  weightlifting  DUBE, Joseph Douglas  USA
# ...     ...     ...            ...            ...                   ...  ...
# 12710  1968  Mexico        fencing        fencing        KRISS, Grigori  URS
# 12711  1968  Mexico        fencing        fencing   MODZALEVSKY, Viktor  URS
# 12712  1968  Mexico        fencing        fencing  NIKANCHIKOV, Aleksei  URS
# 12713  1968  Mexico        fencing        fencing       SMOLYAKOV, Yuri  URS
# 12714  1968  Mexico        fencing        fencing       VITEBSKY, Iosif  URS
#
#       Gender                        Event Event Gender   Medal
# 11684    Men         + 81kg (heavyweight)            M  Bronze
# 11685    Men         + 81kg (heavyweight)            M  Bronze
# 11686    Men         + 81kg (heavyweight)            M    Gold
# 11687    Men         + 81kg (heavyweight)            M  Silver
# 11688    Men  + 90kg, total (heavyweight)            M  Bronze
# ...      ...                          ...          ...     ...
# 12710    Men                    épée team            M  Silver
# 12711    Men                    épée team            M  Silver
# 12712    Men                    épée team            M  Silver
# 12713    Men                    épée team            M  Silver
# 12714    Men                    épée team            M  Silver
#
# [1031 rows x 10 columns]
# 1972
#        Year    City      Sport       Discipline            Athlete Name  NOC  \
# 12715  1972  Munich  wrestling  wrestling free.  TAYLOR, Christopher J.  USA
# 12716  1972  Munich  wrestling  wrestling free.       MEDVED, Aleksandr  URS
# 12717  1972  Munich  wrestling  wrestling free.         DURALIEV, Osman  BUL
# 12718  1972  Munich  wrestling  wrestling gre-r       DOLIPSCHI, Victor  ROU
# 12719  1972  Munich  wrestling  wrestling gre-r       ROSHCHIN, Anatoli  URS
# ...     ...     ...        ...              ...                     ...  ...
# 13895  1972  Munich    fencing          fencing            EVEQUOZ, Guy  SUI
# 13896  1972  Munich    fencing          fencing           GIGER, Daniel  SUI
# 13897  1972  Munich    fencing          fencing       KAUTER, Christian  SUI
# 13898  1972  Munich    fencing          fencing         LÖTSCHER, Peter  SUI
# 13899  1972  Munich    fencing          fencing    SUCHANECKI, Francois  SUI
#
#       Gender                        Event Event Gender   Medal
# 12715    Men  + 100kg (super heavyweight)            M  Bronze
# 12716    Men  + 100kg (super heavyweight)            M    Gold
# 12717    Men  + 100kg (super heavyweight)            M  Silver
# 12718    Men  + 100kg (super heavyweight)            M  Bronze
# 12719    Men  + 100kg (super heavyweight)            M    Gold
# ...      ...                          ...          ...     ...
# 13895    Men                    épée team            M  Silver
# 13896    Men                    épée team            M  Silver
# 13897    Men                    épée team            M  Silver
# 13898    Men                    épée team            M  Silver
# 13899    Men                    épée team            M  Silver
#
# [1185 rows x 10 columns]
# 1976
#        Year      City      Sport       Discipline           Athlete Name  NOC  \
# 13900  1976  Montreal  wrestling  wrestling free.        SIMON, Ladislau  ROU
# 13901  1976  Montreal  wrestling  wrestling free.         ANDIEV, Soslan  URS
# 13902  1976  Montreal  wrestling  wrestling free.          BALLA, Jozsef  HUN
# 13903  1976  Montreal  wrestling  wrestling gre-r        CODREANU, Roman  ROU
# 13904  1976  Montreal  wrestling  wrestling gre-r  KOLCHINSKY, Aleksandr  URS
# ...     ...       ...        ...              ...                    ...  ...
# 15200  1976  Montreal    fencing          fencing        VON ESSEN, Carl  SWE
# 15201  1976  Montreal    fencing          fencing         BEHR, Reinhold  FRG
# 15202  1976  Montreal    fencing          fencing        FISCHER, Volker  FRG
# 15203  1976  Montreal    fencing          fencing      HEHN, Hans-Jürgen  FRG
# 15204  1976  Montreal    fencing          fencing       PUSCH, Alexander  FRG
#
#       Gender                        Event Event Gender   Medal
# 13900    Men  + 100kg (super heavyweight)            M  Bronze
# 13901    Men  + 100kg (super heavyweight)            M    Gold
# 13902    Men  + 100kg (super heavyweight)            M  Silver
# 13903    Men  + 100kg (super heavyweight)            M  Bronze
# 13904    Men  + 100kg (super heavyweight)            M    Gold
# ...      ...                          ...          ...     ...
# 15200    Men                    épée team            M    Gold
# 15201    Men                    épée team            M  Silver
# 15202    Men                    épée team            M  Silver
# 15203    Men                    épée team            M  Silver
# 15204    Men                    épée team            M  Silver
#
# [1305 rows x 10 columns]
# 1980
#        Year    City      Sport       Discipline           Athlete Name  NOC  \
# 15205  1980  Moscow  wrestling  wrestling free.        SANDURSKI, Adam  POL
# 15206  1980  Moscow  wrestling  wrestling free.         ANDIEV, Soslan  URS
# 15207  1980  Moscow  wrestling  wrestling free.          BALLA, Jozsef  HUN
# 15208  1980  Moscow  wrestling  wrestling gre-r         BCHARA, Hassan  LIB
# 15209  1980  Moscow  wrestling  wrestling gre-r  KOLCHINSKY, Aleksandr  URS
# ...     ...     ...        ...              ...                    ...  ...
# 16587  1980  Moscow    fencing          fencing    CHRONOWSKI, Ludomir  POL
# 16588  1980  Moscow    fencing          fencing      JABLKOWSKI, Piotr  POL
# 16589  1980  Moscow    fencing          fencing           LIS, Andrzej  POL
# 16590  1980  Moscow    fencing          fencing      STRZALKA, Mariusz  POL
# 16591  1980  Moscow    fencing          fencing     SWORNOWSKI, Leszek  POL
#
#       Gender                        Event Event Gender   Medal
# 15205    Men  + 100kg (super heavyweight)            M  Bronze
# 15206    Men  + 100kg (super heavyweight)            M    Gold
# 15207    Men  + 100kg (super heavyweight)            M  Silver
# 15208    Men  + 100kg (super heavyweight)            M  Bronze
# 15209    Men  + 100kg (super heavyweight)            M    Gold
# ...      ...                          ...          ...     ...
# 16587    Men                    épée team            M  Silver
# 16588    Men                    épée team            M  Silver
# 16589    Men                    épée team            M  Silver
# 16590    Men                    épée team            M  Silver
# 16591    Men                    épée team            M  Silver
#
# [1387 rows x 10 columns]
# 1984
#        Year         City      Sport       Discipline  \
# 16592  1984  Los Angeles  wrestling  wrestling free.
# 16593  1984  Los Angeles  wrestling  wrestling free.
# 16594  1984  Los Angeles  wrestling  wrestling free.
# 16595  1984  Los Angeles  wrestling  wrestling gre-r
# 16596  1984  Los Angeles  wrestling  wrestling gre-r
# ...     ...          ...        ...              ...
# 18046  1984  Los Angeles    fencing          fencing
# 18047  1984  Los Angeles    fencing          fencing
# 18048  1984  Los Angeles    fencing          fencing
# 18049  1984  Los Angeles    fencing          fencing
# 18050  1984  Los Angeles    fencing          fencing
#
#                     Athlete Name  NOC Gender                        Event  \
# 16592              TASKIN, Ayhan  TUR    Men  + 100kg (super heavyweight)
# 16593  BAUMGARTNER, Bruce Robert  USA    Men  + 100kg (super heavyweight)
# 16594              MOLLE, Robert  CAN    Men  + 100kg (super heavyweight)
# 16595          DOLIPSCHI, Victor  ROU    Men  + 100kg (super heavyweight)
# 16596     BLATNICK, Jeffrey Carl  USA    Men  + 100kg (super heavyweight)
# ...                          ...  ...    ...                          ...
# 18046           BOISSE, Philippe  FRA    Men                    épée team
# 18047         HENRY, Jean-Michel  FRA    Men                    épée team
# 18048           LENGLET, Olivier  FRA    Men                    épée team
# 18049           RIBOUD, Philippe  FRA    Men                    épée team
# 18050            SALESSE, Michel  FRA    Men                    épée team
#
#       Event Gender   Medal
# 16592            M  Bronze
# 16593            M    Gold
# 16594            M  Silver
# 16595            M  Bronze
# 16596            M    Gold
# ...            ...     ...
# 18046            M  Silver
# 18047            M  Silver
# 18048            M  Silver
# 18049            M  Silver
# 18050            M  Silver
#
# [1459 rows x 10 columns]
# 1988
#        Year   City          Sport     Discipline               Athlete Name  \
# 18051  1988  Seoul  weightlifting  weightlifting            ZAWIEJA, Martin
# 18052  1988  Seoul  weightlifting  weightlifting       KURLOVICH, Alexandre
# 18053  1988  Seoul  weightlifting  weightlifting         NERLINGER, Manfred
# 18054  1988  Seoul         boxing         boxing  MIROSHNICHENKO, Aleksandr
# 18055  1988  Seoul         boxing         boxing       ZARENKIEWICZ, Janusz
# ...     ...    ...            ...            ...                        ...
# 19592  1988  Seoul        fencing        fencing            BORRMANN, Elmar
# 19593  1988  Seoul        fencing        fencing            FISCHER, Volker
# 19594  1988  Seoul        fencing        fencing             GERULL, Thomas
# 19595  1988  Seoul        fencing        fencing           PUSCH, Alexander
# 19596  1988  Seoul        fencing        fencing      SCHMITT, Arnd Rüdiger
#
#        NOC Gender                               Event Event Gender   Medal
# 18051  FRG    Men  + 110kg, total (super heavyweight)            M  Bronze
# 18052  URS    Men  + 110kg, total (super heavyweight)            M    Gold
# 18053  FRG    Men  + 110kg, total (super heavyweight)            M  Silver
# 18054  URS    Men          + 91kg (super heavyweight)            M  Bronze
# 18055  POL    Men          + 91kg (super heavyweight)            M  Bronze
# ...    ...    ...                                 ...          ...     ...
# 19592  FRG    Men                           épée team            M  Silver
# 19593  FRG    Men                           épée team            M  Silver
# 19594  FRG    Men                           épée team            M  Silver
# 19595  FRG    Men                           épée team            M  Silver
# 19596  FRG    Men                           épée team            M  Silver
#
# [1546 rows x 10 columns]
# 1992
#        Year       City          Sport     Discipline          Athlete Name  \
# 19597  1992  Barcelona  weightlifting  weightlifting    NERLINGER, Manfred
# 19598  1992  Barcelona  weightlifting  weightlifting  KURLOVICH, Alexandre
# 19599  1992  Barcelona  weightlifting  weightlifting     TARANENKO, Leonid
# 19600  1992  Barcelona           judo           judo       LUPINO, Natalia
# 19601  1992  Barcelona           judo           judo          SAKAUE, Yoko
# ...     ...        ...            ...            ...                   ...
# 21297  1992  Barcelona        fencing        fencing       HEGEDUS, Ferenc
# 21298  1992  Barcelona        fencing        fencing       KOLCZONAI, Erno
# 21299  1992  Barcelona        fencing        fencing          KOVACS, Ivan
# 21300  1992  Barcelona        fencing        fencing    KULCSAR, Krisztian
# 21301  1992  Barcelona        fencing        fencing         TOTOLA, Gabor
#
#        NOC Gender                               Event Event Gender   Medal
# 19597  GER    Men  + 110kg, total (super heavyweight)            M  Bronze
# 19598  EUN    Men  + 110kg, total (super heavyweight)            M    Gold
# 19599  EUN    Men  + 110kg, total (super heavyweight)            M  Silver
# 19600  FRA  Women                + 72kg (heavyweight)            W  Bronze
# 19601  JPN  Women                + 72kg (heavyweight)            W  Bronze
# ...    ...    ...                                 ...          ...     ...
# 21297  HUN    Men                           épée team            M  Silver
# 21298  HUN    Men                           épée team            M  Silver
# 21299  HUN    Men                           épée team            M  Silver
# 21300  HUN    Men                           épée team            M  Silver
# 21301  HUN    Men                           épée team            M  Silver
#
# [1705 rows x 10 columns]
# 1996
#        Year     City          Sport     Discipline            Athlete Name  \
# 21302  1996  Atlanta           judo           judo          MOELLER, Frank
# 21303  1996  Atlanta           judo           judo    VAN BARNEVELD, Harry
# 21304  1996  Atlanta           judo           judo         DOUILLET, David
# 21305  1996  Atlanta           judo           judo     PEREZ LOBO, Ernesto
# 21306  1996  Atlanta  weightlifting  weightlifting           BOTEV, Stefan
# ...     ...      ...            ...            ...                     ...
# 23156  1996  Atlanta        fencing        fencing  FLESSEL-COLOVIC, Laura
# 23157  1996  Atlanta        fencing        fencing  MORESEE-PICHOT, Sophie
# 23158  1996  Atlanta        fencing        fencing           CHIESA, Laura
# 23159  1996  Atlanta        fencing        fencing              UGA, Elisa
# 23160  1996  Atlanta        fencing        fencing     ZALAFFI, Margherita
#
#        NOC Gender                               Event Event Gender   Medal
# 21302  GER    Men               + 100kg (heavyweight)            M  Bronze
# 21303  BEL    Men               + 100kg (heavyweight)            M  Bronze
# 21304  FRA    Men               + 100kg (heavyweight)            M    Gold
# 21305  ESP    Men               + 100kg (heavyweight)            M  Silver
# 21306  AUS    Men  + 108kg, total (super heavyweight)            M  Bronze
# ...    ...    ...                                 ...          ...     ...
# 23156  FRA  Women                           épée team            W    Gold
# 23157  FRA  Women                           épée team            W    Gold
# 23158  ITA  Women                           épée team            W  Silver
# 23159  ITA  Women                           épée team            W  Silver
# 23160  ITA  Women                           épée team            W  Silver
#
# [1859 rows x 10 columns]
# 2000
#        Year    City          Sport     Discipline         Athlete Name  NOC  \
# 23161  2000  Sydney           judo           judo    PERTELSON, Indrek  EST
# 23162  2000  Sydney           judo           judo     TMENOV, Tamerlan  RUS
# 23163  2000  Sydney           judo           judo      DOUILLET, David  FRA
# 23164  2000  Sydney           judo           judo  SHINOHARA, Shinichi  JPN
# 23165  2000  Sydney  weightlifting  weightlifting    CHEMERKIN, Andrey  RUS
# ...     ...     ...            ...            ...                  ...  ...
# 25171  2000  Sydney        fencing        fencing   LOGOUNOVA, Tatiana  RUS
# 25172  2000  Sydney        fencing        fencing       MAZINA, Mariya  RUS
# 25173  2000  Sydney        fencing        fencing       BUERKI, Gianna  SUI
# 25174  2000  Sydney        fencing        fencing        LAMON, Sophie  SUI
# 25175  2000  Sydney        fencing        fencing     ROMAGNOLI, Diana  SUI
#
#       Gender                  Event Event Gender   Medal
# 23161    Men  + 100kg (heavyweight)            M  Bronze
# 23162    Men  + 100kg (heavyweight)            M  Bronze
# 23163    Men  + 100kg (heavyweight)            M    Gold
# 23164    Men  + 100kg (heavyweight)            M  Silver
# 23165    Men                + 105kg            M  Bronze
# ...      ...                    ...          ...     ...
# 25171  Women              épée team            W    Gold
# 25172  Women              épée team            W    Gold
# 25173  Women              épée team            W  Silver
# 25174  Women              épée team            W  Silver
# 25175  Women              épée team            W  Silver
#
# [2015 rows x 10 columns]
# 2004
#        Year    City          Sport     Discipline           Athlete Name  NOC  \
# 25176  2004  Athens           judo           judo      PERTELSON, Indrek  EST
# 25177  2004  Athens           judo           judo  VAN DER GEEST, Dennis  NED
# 25178  2004  Athens           judo           judo          SUZUKI, Keiji  JPN
# 25179  2004  Athens           judo           judo       TMENOV, Tamerlan  RUS
# 25180  2004  Athens  weightlifting  weightlifting     CHOLAKOV, Velichko  BUL
# ...     ...     ...            ...            ...                    ...  ...
# 27169  2004  Athens        fencing        fencing     LOGOUNOVA, Tatiana  RUS
# 27170  2004  Athens        fencing        fencing          SIVKOVA, Anna  RUS
# 27171  2004  Athens        fencing        fencing         BOKEL, Claudia  GER
# 27172  2004  Athens        fencing        fencing        DUPLITZER, Imke  GER
# 27173  2004  Athens        fencing        fencing      HEIDEMANN, Britta  GER
#
#       Gender                  Event Event Gender   Medal
# 25176    Men  + 100kg (heavyweight)            M  Bronze
# 25177    Men  + 100kg (heavyweight)            M  Bronze
# 25178    Men  + 100kg (heavyweight)            M    Gold
# 25179    Men  + 100kg (heavyweight)            M  Silver
# 25180    Men                + 105kg            M  Bronze
# ...      ...                    ...          ...     ...
# 27169  Women              épée team            W    Gold
# 27170  Women              épée team            W    Gold
# 27171  Women              épée team            W  Silver
# 27172  Women              épée team            W  Silver
# 27173  Women              épée team            W  Silver
#
# [1998 rows x 10 columns]
# 2008
#       Year     City      Sport       Discipline          Athlete Name  NOC  \
# 0     2008  Beijing   aquatics           diving        GALPERIN, Gleb  RUS
# 1     2008  Beijing   aquatics           diving      MITCHAM, Matthew  AUS
# 2     2008  Beijing   aquatics           diving           ZHOU, Luxin  CHN
# 3     2008  Beijing   aquatics           diving             WANG, Xin  CHN
# 4     2008  Beijing   aquatics           diving          CHEN, Ruolin  CHN
# ...    ...      ...        ...              ...                   ...  ...
# 2048  2008  Beijing  wrestling  wrestling gre-r        ENGLICH, Mirko  GER
# 2049  2008  Beijing  wrestling  wrestling gre-r  MIZGAITIS, Mindaugas  LTU
# 2050  2008  Beijing  wrestling  wrestling gre-r       PATRIKEEV, Yuri  ARM
# 2051  2008  Beijing  wrestling  wrestling gre-r         LOPEZ, Mijain  CUB
# 2052  2008  Beijing  wrestling  wrestling gre-r        BAROEV, Khasan  RUS
#
#      Gender         Event Event Gender   Medal
# 0       Men  10m platform            M  Bronze
# 1       Men  10m platform            M    Gold
# 2       Men  10m platform            M  Silver
# 3     Women  10m platform            W  Bronze
# 4     Women  10m platform            W    Gold
# ...     ...           ...          ...     ...
# 2048    Men     84 - 96kg            M  Silver
# 2049    Men    96 - 120kg            M  Bronze
# 2050    Men    96 - 120kg            M  Bronze
# 2051    Men    96 - 120kg            M    Gold
# 2052    Men    96 - 120kg            M  Silver
#
# [2042 rows x 10 columns]

# %%
type(group_value)
# Out:
# pandas.core.frame.DataFrame

# %%
up.groupby(['Year']).count()
# Out:
#       City  Sport  Discipline  Athlete Name   NOC  Gender  Event  \
# Year
# 1896   151    151         151           151   151     151    151
# 1900   512    512         512           512   512     512    512
# 1904   470    470         470           470   470     470    470
# 1908   804    804         804           804   804     804    804
# 1912   885    885         885           885   885     885    885
# 1920  1298   1298        1298          1298  1298    1298   1298
# 1924   884    884         884           884   884     884    884
# 1928   710    710         710           710   710     710    710
# 1932   615    615         615           615   615     615    615
# 1936   875    875         875           875   875     875    875
# 1948   814    814         814           814   814     814    814
# 1952   889    889         889           889   889     889    889
# 1956   885    885         885           885   885     885    885
# 1960   882    882         882           882   882     882    882
# 1964  1010   1010        1010          1010  1010    1010   1010
# 1968  1031   1031        1031          1031  1031    1031   1031
# 1972  1185   1185        1185          1185  1185    1185   1185
# 1976  1305   1305        1305          1305  1305    1305   1305
# 1980  1387   1387        1387          1387  1387    1387   1387
# 1984  1459   1459        1459          1459  1459    1459   1459
# 1988  1546   1546        1546          1546  1546    1546   1546
# 1992  1705   1705        1705          1705  1705    1705   1705
# 1996  1859   1859        1859          1859  1859    1859   1859
# 2000  2015   2015        2015          2015  2015    2015   2015
# 2004  1998   1998        1998          1998  1998    1998   1998
# 2008  2042   2042        2042          2042  2042    2042   2042
#
#       Event Gender  Medal
# Year
# 1896           151    151
# 1900           512    512
# 1904           470    470
# 1908           804    804
# 1912           885    885
# 1920          1298   1298
# 1924           884    884
# 1928           710    710
# 1932           615    615
# 1936           875    875
# 1948           814    814
# 1952           889    889
# 1956           885    885
# 1960           882    882
# 1964          1010   1010
# 1968          1031   1031
# 1972          1185   1185
# 1976          1305   1305
# 1980          1387   1387
# 1984          1459   1459
# 1988          1546   1546
# 1992          1705   1705
# 1996          1859   1859
# 2000          2015   2015
# 2004          1998   1998
# 2008          2042   2042

# %%
up.groupby("Year").size()
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
up.groupby(['Year','NOC']).count()
# Out:
#           City  Sport  Discipline  Athlete Name  Gender  Event  Event Gender  \
# Year NOC
# 1896 AUS     2      2           2             2       2      2             2
#      AUT     5      5           5             5       5      5             5
#      DEN     6      6           6             6       6      6             6
#      FRA    11     11          11            11      11     11            11
#      GBR     7      7           7             7       7      7             7
# ...        ...    ...         ...           ...     ...    ...           ...
# 2008 USA   315    315         315           315     315    315           315
#      UZB     6      6           6             6       6      6             6
#      VEN     1      1           1             1       1      1             1
#      VIE     1      1           1             1       1      1             1
#      ZIM     4      4           4             4       4      4             4
#
#           Medal
# Year NOC
# 1896 AUS      2
#      AUT      5
#      DEN      6
#      FRA     11
#      GBR      7
# ...         ...
# 2008 USA    315
#      UZB      6
#      VEN      1
#      VIE      1
#      ZIM      4
#
# [1072 rows x 8 columns]

# %%
up.groupby(['Year','NOC'])['Medal'].count()
# Out:
# Year  NOC
# 1896  AUS      2
#       AUT      5
#       DEN      6
#       FRA     11
#       GBR      7
#             ...
# 2008  USA    315
#       UZB      6
#       VEN      1
#       VIE      1
#       ZIM      4
# Name: Medal, Length: 1072, dtype: int64

# %%
up.groupby(['Year','NOC']).size()
# Out:
# Year  NOC
# 1896  AUS      2
#       AUT      5
#       DEN      6
#       FRA     11
#       GBR      7
#             ...
# 2008  USA    315
#       UZB      6
#       VEN      1
#       VIE      1
#       ZIM      4
# Length: 1072, dtype: int64

# %%
up.groupby(['Year','NOC','Medal']).size()
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3440006672.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   up.groupby(['Year','NOC','Medal']).size()
# Year  NOC  Medal
# 1896  AFG  Bronze    0
#            Silver    0
#            Gold      0
#       AHO  Bronze    0
#            Silver    0
#                     ..
# 2008  ZIM  Silver    3
#            Gold      1
#       ZZX  Bronze    0
#            Silver    0
#            Gold      0
# Length: 10764, dtype: int64

# %%
up.groupby(['NOC'])['Year'].min()
# Out:
# NOC
# AFG    2008
# AHO    1988
# ALG    1984
# ANZ    1908
# ARG    1924
#        ...
# VIE    2000
# YUG    1924
# ZAM    1984
# ZIM    1980
# ZZX    1896
# Name: Year, Length: 138, dtype: int64

# %%
up.groupby(['NOC'])['Year'].max()

# %%
up.groupby(['NOC'])['Year'].min()

# %%
up.groupby(['NOC'])['Year'].agg(['min', 'max', 'count'])

# %% [markdown]
# ## Reshaping data: Stacking, Unstacking and MultiIndex

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt


if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year     City       Sport Discipline               Athlete Name  NOC  \
# 1644   2008  Beijing     sailing    sailing              WARRER, Jonas  DEN
# 9904   1960     Rome    aquatics   swimming         YAMANAKA, Tsuyoshi  JPN
# 19356  1988    Seoul  equestrian   dressage  STUECKELBERGER, Christine  SUI
#
#       Gender           Event Event Gender   Medal
# 1644     Men    49er - skiff            X    Gold
# 9904     Men  400m freestyle            M  Silver
# 19356  Women            team            X  Silver

# %%
sprints = up[(up.Year == 2008) & ( (up.Event == '100m') | (up.Event == '200m'))]
sprints
# Out:
#      Year     City      Sport Discipline              Athlete Name  NOC  \
# 388  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 389  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 390  2008  Beijing  athletics  athletics         THOMPSON, Richard  TRI
# 391  2008  Beijing  athletics  athletics        FRASER, Shelly-ann  JAM
# 392  2008  Beijing  athletics  athletics          SIMPSON, Sherone  JAM
# 393  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 406  2008  Beijing  athletics  athletics               DIX, Walter  USA
# 407  2008  Beijing  athletics  athletics               BOLT, Usain  JAM
# 408  2008  Beijing  athletics  athletics           CRAWFORD, Shawn  USA
# 409  2008  Beijing  athletics  athletics           STEWART, Kerron  JAM
# 410  2008  Beijing  athletics  athletics  CAMPBELL-BROWN, Veronica  JAM
# 411  2008  Beijing  athletics  athletics            FELIX, Allyson  USA
#
#     Gender Event Event Gender   Medal
# 388    Men  100m            M  Bronze
# 389    Men  100m            M    Gold
# 390    Men  100m            M  Silver
# 391  Women  100m            W    Gold
# 392  Women  100m            W  Silver
# 393  Women  100m            W  Silver
# 406    Men  200m            M  Bronze
# 407    Men  200m            M    Gold
# 408    Men  200m            M  Silver
# 409  Women  200m            W  Bronze
# 410  Women  200m            W    Gold
# 411  Women  200m            W  Silver

# %%
sp = sprints.groupby(['NOC','Gender','Event']).size()
sp
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/791319611.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sp = sprints.groupby(['NOC','Gender','Event']).size()
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
sp.unstack?

# %%
sp.unstack('Gender', fill_value=0)
# Out:
# Gender     Men  Women
# NOC Event
# JAM 100m     1      3
#     200m     1      2
# TRI 100m     1      0
#     200m     0      0
# USA 100m     1      0
#     200m     2      1

# %%
(sp
 .unstack('Gender', fill_value=0)
 .unstack('Event', fill_value=0)
)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sp.unstack?
# Out:
# Signature:
# sp.unstack(
#     level: 'IndexLabel' = -1,
#     fill_value: 'Hashable | None' = None,
#     sort: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#
# Parameters
# ----------
# level : int, str, or list of these, default last level
#     Level(s) to unstack, can pass level name.
# fill_value : scalar value, default None
#     Value to use when replacing NaN values.
# sort : bool, default True
#     Sort the level(s) in the resulting MultiIndex columns.
#
# Returns
# -------
# DataFrame
#     Unstacked Series.
#
# Notes
# -----
# Reference :ref:`the user guide <reshaping.stacking>` for more examples.
#
# Examples
# --------
# >>> s = pd.Series([1, 2, 3, 4],
# ...               index=pd.MultiIndex.from_product([['one', 'two'],
# ...                                                 ['a', 'b']]))
# >>> s
# one  a    1
#      b    2
# two  a    3
#      b    4
# dtype: int64
#
# >>> s.unstack(level=-1)
#      a  b
# one  1  2
# two  3  4
#
# >>> s.unstack(level=0)
#    one  two
# a    1    3
# b    2    4
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/series.py
# Type:      method

# %%
sp.unstack(['Gender', 'Event'], fill_value=0)
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sp = sprints.groupby(['NOC','Gender','Event']).size()
sp
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/791319611.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sp = sprints.groupby(['NOC','Gender','Event']).size()
# NOC  Gender  Event
# JAM  Men     100m     1
#              200m     1
#      Women   100m     3
#              200m     2
# TRI  Men     100m     1
#              200m     0
#      Women   100m     0
#              200m     0
# USA  Men     100m     1
#              200m     2
#      Women   100m     0
#              200m     1
# dtype: int64

# %%
sp.unstack(level=1, fill_value=0)
# Out:
# Gender     Men  Women
# NOC Event
# JAM 100m     1      3
#     200m     1      2
# TRI 100m     1      0
#     200m     0      0
# USA 100m     1      0
#     200m     2      1

# %%
sprints_table = sp.unstack(level=1, fill_value=0).unstack(level=1, fill_value=0)
sprints_table
# Out:
# Gender  Men      Women
# Event  100m 200m  100m 200m
# NOC
# JAM       1    1     3    2
# TRI       1    0     0    0
# USA       1    2     0    1

# %%
sprints_NOC = sprints_table.stack("Gender")
sprints_NOC
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3568702013.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   sprints_NOC = sprints_table.stack("Gender")
# Event       100m  200m
# NOC Gender
# JAM Men        1     1
#     Women      3     2
# TRI Men        1     0
#     Women      0     0
# USA Men        1     2
#     Women      0     1

# %%
sprints_NOC.index
# Out:
# MultiIndex([('JAM',   'Men'),
#             ('JAM', 'Women'),
#             ('TRI',   'Men'),
#             ('TRI', 'Women'),
#             ('USA',   'Men'),
#             ('USA', 'Women')],
#            names=['NOC', 'Gender'])

# %%
sprints_NOC.loc[('JAM',   'Men'), :]
# Out:
# Event
# 100m    1
# 200m    1
# Name: (JAM, Men), dtype: int64

# %%
sprints_NOC.loc[('JAM',   'Men'), '100m']
# Out:
# np.int64(1)

# %%
sprints_NOC.iloc[0, :]
# Out:
# Event
# 100m    1
# 200m    1
# Name: (JAM, Men), dtype: int64

# %%
sprints_NOC.iloc[0, 0]
# Out:
# np.int64(1)

# %%
sprints_NOC.stack?

# %%
sprints_NOC.unstack?

# %% [markdown]
# ## Challenge

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year       City      Sport Discipline              Athlete Name  NOC  \
# 21464  1996    Atlanta  athletics  athletics  LAMBRUSCHINI, Alessandro  ITA
# 2247   1912  Stockholm   shooting   shooting           PALMER, Charles  GBR
# 8084   1952   Helsinki   aquatics   swimming       KONNO, Ford Hiroshi  USA
#
#       Gender               Event Event Gender   Medal
# 21464    Men  3000m steeplechase            M  Bronze
# 2247     Men  clay pigeons, team            M  Silver
# 8084     Men     1500m freestyle            M    Gold

# %% [markdown]
# **Using a line graph, plot the number of gold medals won by the USA male and female Olympians throughout the history of the Olympics?
# Distinguish between the male and female Olympians in the line graph using blue and pink**

# %% [markdown]
# **Using a bar chart, plot the 5 Olympians who have won the most gold medals from the dataset (1896 to 2008). When there is a tie, consider the number of silver medals, then bronze medals.**

# %% [markdown]
# ## Solution

# %% [markdown]
# **Using a line graph, plot the number of gold medals won by the USA male and female Olympians throughout the history of the Olympics?
# Distinguish between the male and female Olympians in the line graph using blue (male) and pink (female)**

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)

# %%
usa_gold = up[(up.NOC == 'USA') & (up.Medal == 'Gold')]
usa_gold
# Out:
#       Year     City       Sport       Discipline      Athlete Name  NOC  \
# 4     1896   Athens   athletics        athletics     BURKE, Thomas  USA
# 14    1896   Athens   athletics        athletics    CURTIS, Thomas  USA
# 28    1896   Athens    shooting         shooting       PAINE, John  USA
# 34    1896   Athens   athletics        athletics     BURKE, Thomas  USA
# 40    1896   Athens    shooting         shooting     PAINE, Sumner  USA
# ...    ...      ...         ...              ...               ...  ...
# 1885  2008  Beijing  volleyball       volleyball      ROONEY, Sean  USA
# 1886  2008  Beijing  volleyball       volleyball     SALMON, Riley  USA
# 1887  2008  Beijing  volleyball       volleyball  STANLEY, Clayton  USA
# 1888  2008  Beijing  volleyball       volleyball  TOUZINSKY, Scott  USA
# 1988  2008  Beijing   wrestling  wrestling free.     CEJUDO, Henry  USA
#
#      Gender                  Event Event Gender Medal
# 4       Men                   100m            M  Gold
# 14      Men           110m hurdles            M  Gold
# 28      Men        25m army pistol            M  Gold
# 34      Men                   400m            M  Gold
# 40      Men  50m pistol (60 shots)            M  Gold
# ...     ...                    ...          ...   ...
# 1885    Men             volleyball            M  Gold
# 1886    Men             volleyball            M  Gold
# 1887    Men             volleyball            M  Gold
# 1888    Men             volleyball            M  Gold
# 1988    Men                 - 55kg            M  Gold
#
# [2088 rows x 10 columns]

# %%
usa_gold.groupby(['Year', 'Gender']).size()
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/713144573.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size()
# Year  Gender
# 1896  Men        11
#       Women       0
# 1900  Men        26
#       Women       1
# 1904  Men       140
#       Women       6
# 1908  Men        34
#       Women       0
# 1912  Men        45
#       Women       0
# 1920  Men       103
#       Women       7
# 1924  Men        95
#       Women      15
# 1928  Men        34
#       Women       9
# 1932  Men        61
#       Women      17
# 1936  Men        44
#       Women       7
# 1948  Men        75
#       Women       8
# 1952  Men        72
#       Women       7
# 1956  Men        57
#       Women       4
# 1960  Men        51
#       Women      17
# 1964  Men        63
#       Women      15
# 1968  Men        59
#       Women      24
# 1972  Men        37
#       Women      16
# 1976  Men        56
#       Women       7
# 1984  Men       106
#       Women      62
# 1988  Men        49
#       Women      28
# 1992  Men        57
#       Women      32
# 1996  Men        59
#       Women     101
# 2000  Men        68
#       Women      62
# 2004  Men        51
#       Women      65
# 2008  Men        67
#       Women      58
# dtype: int64

# %%
usa_gold.groupby(['Year', 'Gender']).size().index
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3229960007.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().index
# MultiIndex([(1896,   'Men'),
#             (1896, 'Women'),
#             (1900,   'Men'),
#             (1900, 'Women'),
#             (1904,   'Men'),
#             (1904, 'Women'),
#             (1908,   'Men'),
#             (1908, 'Women'),
#             (1912,   'Men'),
#             (1912, 'Women'),
#             (1920,   'Men'),
#             (1920, 'Women'),
#             (1924,   'Men'),
#             (1924, 'Women'),
#             (1928,   'Men'),
#             (1928, 'Women'),
#             (1932,   'Men'),
#             (1932, 'Women'),
#             (1936,   'Men'),
#             (1936, 'Women'),
#             (1948,   'Men'),
#             (1948, 'Women'),
#             (1952,   'Men'),
#             (1952, 'Women'),
#             (1956,   'Men'),
#             (1956, 'Women'),
#             (1960,   'Men'),
#             (1960, 'Women'),
#             (1964,   'Men'),
#             (1964, 'Women'),
#             (1968,   'Men'),
#             (1968, 'Women'),
#             (1972,   'Men'),
#             (1972, 'Women'),
#             (1976,   'Men'),
#             (1976, 'Women'),
#             (1984,   'Men'),
#             (1984, 'Women'),
#             (1988,   'Men'),
#             (1988, 'Women'),
#             (1992,   'Men'),
#             (1992, 'Women'),
#             (1996,   'Men'),
#             (1996, 'Women'),
#             (2000,   'Men'),
#             (2000, 'Women'),
#             (2004,   'Men'),
#             (2004, 'Women'),
#             (2008,   'Men'),
#             (2008, 'Women')],
#            names=['Year', 'Gender'])

# %%
usa_gold.groupby(['Year', 'Gender']).size().plot(kind='line')
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3911645964.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().plot(kind='line')
# <Axes: xlabel='Year,Gender'>

# %%
usa_gold.groupby(['Year', 'Gender']).size()
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/713144573.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size()
# Year  Gender
# 1896  Men        11
#       Women       0
# 1900  Men        26
#       Women       1
# 1904  Men       140
#       Women       6
# 1908  Men        34
#       Women       0
# 1912  Men        45
#       Women       0
# 1920  Men       103
#       Women       7
# 1924  Men        95
#       Women      15
# 1928  Men        34
#       Women       9
# 1932  Men        61
#       Women      17
# 1936  Men        44
#       Women       7
# 1948  Men        75
#       Women       8
# 1952  Men        72
#       Women       7
# 1956  Men        57
#       Women       4
# 1960  Men        51
#       Women      17
# 1964  Men        63
#       Women      15
# 1968  Men        59
#       Women      24
# 1972  Men        37
#       Women      16
# 1976  Men        56
#       Women       7
# 1984  Men       106
#       Women      62
# 1988  Men        49
#       Women      28
# 1992  Men        57
#       Women      32
# 1996  Men        59
#       Women     101
# 2000  Men        68
#       Women      62
# 2004  Men        51
#       Women      65
# 2008  Men        67
#       Women      58
# dtype: int64

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender')
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/4014363675.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender')
# Gender  Men  Women
# Year
# 1896     11      0
# 1900     26      1
# 1904    140      6
# 1908     34      0
# 1912     45      0
# 1920    103      7
# 1924     95     15
# 1928     34      9
# 1932     61     17
# 1936     44      7
# 1948     75      8
# 1952     72      7
# 1956     57      4
# 1960     51     17
# 1964     63     15
# 1968     59     24
# 1972     37     16
# 1976     56      7
# 1984    106     62
# 1988     49     28
# 1992     57     32
# 1996     59    101
# 2000     68     62
# 2004     51     65
# 2008     67     58

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line')
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1970508800.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line')
# <Axes: xlabel='Year'>

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot?
# Out:
# Object `plot` not found.

# %%
pd.Series.plot?

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['blue', 'pink'])
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/4278425552.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['blue', 'pink'])
# <Axes: xlabel='Year'>

# %%
usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['pink', 'blue'])
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1281612549.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_gold.groupby(['Year', 'Gender']).size().unstack('Gender').plot(kind='line', color=['pink', 'blue'])
# <Axes: xlabel='Year'>

# %% [markdown]
# **Using a bar chart, plot the 5 Olympians who have won the most gold medals from the dataset (1896 to 2008). When there is a tie, consider the number of silver medals, then bronze medals.**

# %%
up.groupby(['Athlete Name','Medal']).size()
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1424106807.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   up.groupby(['Athlete Name','Medal']).size()
# Athlete Name           Medal
# AABYE, Edgar           Bronze    0
#                        Silver    0
#                        Gold      1
# AALTONEN, Arvo Ossian  Bronze    2
#                        Silver    0
#                                 ..
# ÖSTMO, Ole             Silver    2
#                        Gold      0
# ÖSTRAND, Per-Olof      Bronze    1
#                        Silver    0
#                        Gold      0
# Length: 64239, dtype: int64

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3389181119.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# Medal                      Bronze  Silver  Gold
# Athlete Name
# AABYE, Edgar                    0       0     1
# AALTONEN, Arvo Ossian           2       0     0
# AALTONEN, Paavo Johannes        2       0     3
# AAMODT, Ragnhild                0       0     1
# AANING, Alf Lied                0       1     0
# ...                           ...     ...   ...
# ÖSTERVOLD, Jan Olsen            0       0     1
# ÖSTERVOLD, Kristian Olsen       0       0     1
# ÖSTERVOLD, Ole Olsen            0       0     1
# ÖSTMO, Ole                      2       2     0
# ÖSTRAND, Per-Olof               1       0     0
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/2107258196.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# Medal                Bronze  Silver  Gold
# Athlete Name
# PHELPS, Michael           2       0    14
# LATYNINA, Larisa          4       5     9
# NURMI, Paavo              0       3     9
# SPITZ, Mark               1       1     9
# LEWIS, Carl               0       1     9
# ...                     ...     ...   ...
# ZYCH, Boguslaw            1       0     0
# ZÄHRINGER, Klaus          1       0     0
# ZÜHLKE, Steffen           1       0     0
# ÖRSTED, Hans-Henrik       1       0     0
# ÖSTRAND, Per-Olof         1       0     0
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/906453956.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# Medal                Gold  Silver  Bronze
# Athlete Name
# PHELPS, Michael        14       0       2
# LATYNINA, Larisa        9       5       4
# NURMI, Paavo            9       3       0
# SPITZ, Mark             9       1       1
# LEWIS, Carl             9       1       0
# ...                   ...     ...     ...
# ZYCH, Boguslaw          0       0       1
# ZÄHRINGER, Klaus        0       0       1
# ZÜHLKE, Steffen         0       0       1
# ÖRSTED, Hans-Henrik     0       0       1
# ÖSTRAND, Per-Olof       0       0       1
#
# [21413 rows x 3 columns]

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3341183033.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# Medal             Gold  Silver  Bronze
# Athlete Name
# PHELPS, Michael     14       0       2
# LATYNINA, Larisa     9       5       4
# NURMI, Paavo         9       3       0
# SPITZ, Mark          9       1       1
# LEWIS, Carl          9       1       0

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar')
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1922917556.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# <Axes: xlabel='Athlete Name'>

# %% [markdown]
# ## Creating your own colormaps

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year         City     Sport Discipline          Athlete Name  NOC  \
# 17371  1984  Los Angeles   fencing    fencing  KIRCHEIS-WESSEL, Ute  FRG
# 1244   1908       London  shooting   shooting    HAWKINS, Harold I.  GBR
# 23659  2000       Sydney      judo       judo        SCAPIN, Ylenia  ITA
#
#       Gender                                      Event Event Gender   Medal
# 17371  Women                                  foil team            W    Gold
# 1244     Men  25y small bore rifle, disappearing target            M  Silver
# 23659  Women                   63 - 70kg (middleweight)            W  Bronze

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar')
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1922917556.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# <Axes: xlabel='Athlete Name'>

# %%
from matplotlib.colors import ListedColormap

# %%
ListedColormap?
# Out:
# Init signature: ListedColormap(colors, name='from_list', N=None)
# Docstring:
# Colormap object generated from a list of colors.
#
# This may be most useful when indexing directly into a colormap,
# but it can also be used to generate special colormaps for ordinary
# mapping.
#
# Parameters
# ----------
# colors : list, array
#     Sequence of Matplotlib color specifications (color names or RGB(A)
#     values).
# name : str, optional
#     String to identify the colormap.
# N : int, optional
#     Number of entries in the map. The default is *None*, in which case
#     there is one colormap entry for each element in the list of colors.
#     If ::
#
#         N < len(colors)
#
#     the list will be truncated at *N*. If ::
#
#         N > len(colors)
#
#     the list will be extended by repetition.
# Init docstring:
# Parameters
# ----------
# name : str
#     The name of the colormap.
# N : int
#     The number of RGB quantization levels.
# File:           ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/matplotlib/colors.py
# Type:           type
# Subclasses:

# %%
gold_silver_bronze = ['#dbb40c','#c5c9c7','#a87900']

# %%
colormap = ListedColormap(gold_silver_bronze)
colormap

# %%
(up.groupby(['Athlete Name','Medal'])
.size()
.unstack('Medal', fill_value=0)
.sort_values(['Gold', 'Silver', 'Bronze'], ascending=False)[['Gold', 'Silver', 'Bronze']]
.head(5)
.plot(kind='bar', colormap=colormap)
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3418138111.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (up.groupby(['Athlete Name','Medal'])
# <Axes: xlabel='Athlete Name'>

# %% [markdown]
# ## Final Challenge

# %% [markdown]
# For each Olympic year present in the dataset, show the US Olympian (and their sport) who has won the highest number of medals in that particular year.
#
# - In the case of a tie, Gold > Silver > Bronze
# - Include only one Olympian for each Olympic year i.e. If there are 2 Olympians in one year who have won exactly the same number and type of medals, then show only the first one based on sorting the names alphabetically by surname.
#
# - You should show the the following columns for each Olympic year:
#   - Athlete Name
#   - Sport
#   - Total

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
pd.set_option("display.width", 100)

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year         City      Sport       Discipline         Athlete Name  \
# 21838  1996      Atlanta  wrestling  wrestling free.   KURTANIDZE, Eldari
# 23679  2000       Sydney  taekwondo        taekwondo  EBNOUTALIB, Faissal
# 16673  1984  Los Angeles   shooting         shooting    HEBERLE, Philippe
#
#        NOC Gender                          Event Event Gender   Medal
# 21838  GEO    Men  82 - 90kg (light-heavyweight)            M  Bronze
# 23679  GER    Men                     68 - 80 kg            M  Silver
# 16673  FRA    Men       10m air rifle (60 shots)            M    Gold

# %% [markdown]
# ##Solution

# %% [markdown]
# For each Olympic year present in the dataset, show the US Olympian (and their sport) who has won the highest number of medals in that particular year.
#
# - In the case of a tie, Gold > Silver > Bronze
# - Include only one Olympian for each Olympic year i.e. If there are 2 Olympians in one year who have won exactly the same number and type of medals, then show only the first one based on sorting the names alphabetically by surname.
#
# - You should show the the following columns for each Olympic year:
#   - Athlete Name
#   - Sport
#   - Total

# %%
# !pip install --quiet pandas==2.0.2

import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
pd.set_option("display.width", 100)

if not Path("olympics_1896_2004.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_1896_2004.csv
if not Path("olympics_2008.csv").exists():
  # !wget https://github.com/jonfernandes/pandas_essential/raw/main/olympics_2008.csv

filename = "olympics_1896_2004.csv"
print("Installed all of the necessary files for this section ...")

# %%
def preprocess(filename = "olympics_1896_2004.csv"):
  """Preparing and transforming dataframe"""
  print(f"Preprocessing {filename} ...\n")
  ordered_medals = pd.api.types.CategoricalDtype(categories=["Bronze", "Silver", "Gold"], ordered=True)
  dtype_mapper = {"Year": "int64",
                "City": "string",
                "Sport": "string",
                "Discipline": "string",
                "Athlete Name": "string",
                "NOC": "string",
                "Gender": "category",
                "Event": "string",
                "Event_gender": "category",
                "Medal": ordered_medals}
  df = pd.read_csv(filename, skiprows=5, dtype=dtype_mapper)
  df = df.drop('Position', axis=1)
  df["Event Gender"] = df["Event Gender"].astype("category")
  df.loc[24676, "Gender"] = "Women"
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  return df

def preprocess_2008(filename="olympics_2008.csv"):
  print(f"Preprocessing {filename} ...\n")
  df = pd.read_csv(filename)
  df.columns = ['City', 'Year', 'Sport', 'Discipline', 'Athlete Name', 'NOC',
       'Gender', 'Event', 'Event Gender', 'Medal', 'Result']
  df = df.drop("Result", axis=1)
  df.City = df.City.fillna(value="Beijing")
  df.Year = df.Year.fillna(value=2008)
  df = df.dropna(subset=['Sport', 'Discipline', 'Athlete Name', 'NOC', 'Gender',
       'Event', 'Event Gender', 'Medal'], how="all")
  df = df.drop_duplicates()
  df.Sport = df.Sport.str.lower()
  df.Discipline = df.Discipline.str.lower()
  df.Event = df.Event.str.lower()
  df.NOC = df.NOC.str.upper()
  df.Medal = df.Medal.str.capitalize()
  df.City = df.City.astype("string")
  df.Year = df.Year.astype(int)
  df.Sport = df.Sport.astype("string")
  df.Discipline = df.Discipline.astype("string")
  df["Athlete Name"] = df["Athlete Name"].astype("string")
  df.NOC = df.NOC.astype("string")
  df.Gender = df.Gender.astype("category")
  df.Event = df.Event.astype("string")
  df['Event Gender'] = df['Event Gender'].astype("category")
  medal_order = ["Bronze", "Silver", "Gold"]
  df.Medal = pd.Categorical(df.Medal, categories=medal_order, ordered=True)

  return df

oo = preprocess()
nw = preprocess_2008()
up = pd.concat([oo, nw])
up.sample(3)
# Out:
# Preprocessing olympics_1896_2004.csv ...
#
# Preprocessing olympics_2008.csv ...
#        Year     City       Sport  Discipline      Athlete Name  NOC Gender  \
# 25027  2000   Sydney  volleyball  volleyball   IAKOVLEV, Roman  RUS    Men
# 1703   2008  Beijing    shooting    shooting    TAN, Zongliang  CHN    Men
# 18673  1988    Seoul  basketball  basketball  PETROVIC, Drazen  YUG    Men
#
#                        Event Event Gender   Medal
# 25027             volleyball            M  Silver
# 1703   50m pistol (60 shots)            M  Silver
# 18673             basketball            M  Silver

# %%
usa_olympian = up[up.NOC == 'USA']
usa_olympian
# Out:
#       Year     City       Sport       Discipline     Athlete Name  NOC Gender  \
# 2     1896   Athens   athletics        athletics    LANE, Francis  USA    Men
# 4     1896   Athens   athletics        athletics    BURKE, Thomas  USA    Men
# 14    1896   Athens   athletics        athletics   CURTIS, Thomas  USA    Men
# 23    1896   Athens   athletics        athletics    BLAKE, Arthur  USA    Men
# 28    1896   Athens    shooting         shooting      PAINE, John  USA    Men
# ...    ...      ...         ...              ...              ...  ...    ...
# 1935  2008  Beijing  volleyball       volleyball       TOM, Logan  USA  Women
# 1936  2008  Beijing  volleyball       volleyball  WILLOUGHBY, Kim  USA  Women
# 1988  2008  Beijing   wrestling  wrestling free.    CEJUDO, Henry  USA    Men
# 1998  2008  Beijing   wrestling  wrestling free.    MILLER, Randi  USA  Women
# 2046  2008  Beijing   wrestling  wrestling gre-r    WHEELER, Adam  USA    Men
#
#                 Event Event Gender   Medal
# 2                100m            M  Bronze
# 4                100m            M    Gold
# 14       110m hurdles            M    Gold
# 23              1500m            M  Silver
# 28    25m army pistol            M    Gold
# ...               ...          ...     ...
# 1935       volleyball            W  Silver
# 1936       volleyball            W  Silver
# 1988           - 55kg            M    Gold
# 1998        55 - 63kg            W  Bronze
# 2046        84 - 96kg            M  Bronze
#
# [4335 rows x 10 columns]

# %%
usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport']).size()
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/794241134.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport']).size()
# Year  Athlete Name   Medal   Sport
# 1896  ABAS, Stephen  Bronze  aquatics         0
#                              archery          0
#                              athletics        0
#                              baseball         0
#                              basketball       0
#                                              ..
# 2008  ZORN, Zachary  Gold    triathlon        0
#                              tug of war       0
#                              volleyball       0
#                              weightlifting    0
#                              wrestling        0
# Length: 7680600, dtype: int64

# %%
(usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport'])
.size()
.unstack('Medal', fill_value=0)
)
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1876731407.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   (usa_olympian.groupby(['Year', 'Athlete Name', 'Medal', 'Sport'])
# Medal                             Bronze  Silver  Gold
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0
#                    archery             0       0     0
#                    athletics           0       0     0
#                    baseball            0       0     0
#                    basketball          0       0     0
# ...                                  ...     ...   ...
# 2008 ZORN, Zachary triathlon           0       0     0
#                    tug of war          0       0     0
#                    volleyball          0       0     0
#                    weightlifting       0       0     0
#                    wrestling           0       0     0
#
# [2560200 rows x 3 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
)
table
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3980595554.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
# Medal                             Bronze  Silver  Gold
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0
#                    archery             0       0     0
#                    athletics           0       0     0
#                    baseball            0       0     0
#                    basketball          0       0     0
# ...                                  ...     ...   ...
# 2008 ZORN, Zachary triathlon           0       0     0
#                    tug of war          0       0     0
#                    volleyball          0       0     0
#                    weightlifting       0       0     0
#                    wrestling           0       0     0
#
# [2560200 rows x 3 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
.assign(Total=table['Gold']+table['Silver']+table['Bronze'])
)
table
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/3892327202.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
# Medal                             Bronze  Silver  Gold  Total
# Year Athlete Name  Sport
# 1896 ABAS, Stephen aquatics            0       0     0      0
#                    archery             0       0     0      0
#                    athletics           0       0     0      0
#                    baseball            0       0     0      0
#                    basketball          0       0     0      0
# ...                                  ...     ...   ...    ...
# 2008 ZORN, Zachary triathlon           0       0     0      0
#                    tug of war          0       0     0      0
#                    volleyball          0       0     0      0
#                    weightlifting       0       0     0      0
#                    wrestling           0       0     0      0
#
# [2560200 rows x 4 columns]

# %%
table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
.size()
.unstack('Medal', fill_value=0)
.assign(Total=table['Gold']+table['Silver']+table['Bronze'])
.reset_index()
)
table
# Out:
# /var/folders/24/qxr9c06j19gcvdhrn3t51m000000gn/T/ipykernel_91196/1442986421.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   table = (usa_olympian.groupby(['Year', 'Athlete Name', 'Sport', 'Medal'])
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 0        1896  ABAS, Stephen       aquatics       0       0     0      0
# 1        1896  ABAS, Stephen        archery       0       0     0      0
# 2        1896  ABAS, Stephen      athletics       0       0     0      0
# 3        1896  ABAS, Stephen       baseball       0       0     0      0
# 4        1896  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2560195  2008  ZORN, Zachary      triathlon       0       0     0      0
# 2560196  2008  ZORN, Zachary     tug of war       0       0     0      0
# 2560197  2008  ZORN, Zachary     volleyball       0       0     0      0
# 2560198  2008  ZORN, Zachary  weightlifting       0       0     0      0
# 2560199  2008  ZORN, Zachary      wrestling       0       0     0      0
#
# [2560200 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group)
# Out:
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 0       1896  ABAS, Stephen       aquatics       0       0     0      0
# 1       1896  ABAS, Stephen        archery       0       0     0      0
# 2       1896  ABAS, Stephen      athletics       0       0     0      0
# 3       1896  ABAS, Stephen       baseball       0       0     0      0
# 4       1896  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 102403  1896  ZORN, Zachary      triathlon       0       0     0      0
# 102404  1896  ZORN, Zachary     tug of war       0       0     0      0
# 102405  1896  ZORN, Zachary     volleyball       0       0     0      0
# 102406  1896  ZORN, Zachary  weightlifting       0       0     0      0
# 102407  1896  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 102408  1900  ABAS, Stephen       aquatics       0       0     0      0
# 102409  1900  ABAS, Stephen        archery       0       0     0      0
# 102410  1900  ABAS, Stephen      athletics       0       0     0      0
# 102411  1900  ABAS, Stephen       baseball       0       0     0      0
# 102412  1900  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 204811  1900  ZORN, Zachary      triathlon       0       0     0      0
# 204812  1900  ZORN, Zachary     tug of war       0       0     0      0
# 204813  1900  ZORN, Zachary     volleyball       0       0     0      0
# 204814  1900  ZORN, Zachary  weightlifting       0       0     0      0
# 204815  1900  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 204816  1904  ABAS, Stephen       aquatics       0       0     0      0
# 204817  1904  ABAS, Stephen        archery       0       0     0      0
# 204818  1904  ABAS, Stephen      athletics       0       0     0      0
# 204819  1904  ABAS, Stephen       baseball       0       0     0      0
# 204820  1904  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 307219  1904  ZORN, Zachary      triathlon       0       0     0      0
# 307220  1904  ZORN, Zachary     tug of war       0       0     0      0
# 307221  1904  ZORN, Zachary     volleyball       0       0     0      0
# 307222  1904  ZORN, Zachary  weightlifting       0       0     0      0
# 307223  1904  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 307224  1908  ABAS, Stephen       aquatics       0       0     0      0
# 307225  1908  ABAS, Stephen        archery       0       0     0      0
# 307226  1908  ABAS, Stephen      athletics       0       0     0      0
# 307227  1908  ABAS, Stephen       baseball       0       0     0      0
# 307228  1908  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 409627  1908  ZORN, Zachary      triathlon       0       0     0      0
# 409628  1908  ZORN, Zachary     tug of war       0       0     0      0
# 409629  1908  ZORN, Zachary     volleyball       0       0     0      0
# 409630  1908  ZORN, Zachary  weightlifting       0       0     0      0
# 409631  1908  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 409632  1912  ABAS, Stephen       aquatics       0       0     0      0
# 409633  1912  ABAS, Stephen        archery       0       0     0      0
# 409634  1912  ABAS, Stephen      athletics       0       0     0      0
# 409635  1912  ABAS, Stephen       baseball       0       0     0      0
# 409636  1912  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 512035  1912  ZORN, Zachary      triathlon       0       0     0      0
# 512036  1912  ZORN, Zachary     tug of war       0       0     0      0
# 512037  1912  ZORN, Zachary     volleyball       0       0     0      0
# 512038  1912  ZORN, Zachary  weightlifting       0       0     0      0
# 512039  1912  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 512040  1920  ABAS, Stephen       aquatics       0       0     0      0
# 512041  1920  ABAS, Stephen        archery       0       0     0      0
# 512042  1920  ABAS, Stephen      athletics       0       0     0      0
# 512043  1920  ABAS, Stephen       baseball       0       0     0      0
# 512044  1920  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 614443  1920  ZORN, Zachary      triathlon       0       0     0      0
# 614444  1920  ZORN, Zachary     tug of war       0       0     0      0
# 614445  1920  ZORN, Zachary     volleyball       0       0     0      0
# 614446  1920  ZORN, Zachary  weightlifting       0       0     0      0
# 614447  1920  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 614448  1924  ABAS, Stephen       aquatics       0       0     0      0
# 614449  1924  ABAS, Stephen        archery       0       0     0      0
# 614450  1924  ABAS, Stephen      athletics       0       0     0      0
# 614451  1924  ABAS, Stephen       baseball       0       0     0      0
# 614452  1924  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 716851  1924  ZORN, Zachary      triathlon       0       0     0      0
# 716852  1924  ZORN, Zachary     tug of war       0       0     0      0
# 716853  1924  ZORN, Zachary     volleyball       0       0     0      0
# 716854  1924  ZORN, Zachary  weightlifting       0       0     0      0
# 716855  1924  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 716856  1928  ABAS, Stephen       aquatics       0       0     0      0
# 716857  1928  ABAS, Stephen        archery       0       0     0      0
# 716858  1928  ABAS, Stephen      athletics       0       0     0      0
# 716859  1928  ABAS, Stephen       baseball       0       0     0      0
# 716860  1928  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 819259  1928  ZORN, Zachary      triathlon       0       0     0      0
# 819260  1928  ZORN, Zachary     tug of war       0       0     0      0
# 819261  1928  ZORN, Zachary     volleyball       0       0     0      0
# 819262  1928  ZORN, Zachary  weightlifting       0       0     0      0
# 819263  1928  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 819264  1932  ABAS, Stephen       aquatics       0       0     0      0
# 819265  1932  ABAS, Stephen        archery       0       0     0      0
# 819266  1932  ABAS, Stephen      athletics       0       0     0      0
# 819267  1932  ABAS, Stephen       baseball       0       0     0      0
# 819268  1932  ABAS, Stephen     basketball       0       0     0      0
# ...      ...            ...            ...     ...     ...   ...    ...
# 921667  1932  ZORN, Zachary      triathlon       0       0     0      0
# 921668  1932  ZORN, Zachary     tug of war       0       0     0      0
# 921669  1932  ZORN, Zachary     volleyball       0       0     0      0
# 921670  1932  ZORN, Zachary  weightlifting       0       0     0      0
# 921671  1932  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 921672   1936  ABAS, Stephen       aquatics       0       0     0      0
# 921673   1936  ABAS, Stephen        archery       0       0     0      0
# 921674   1936  ABAS, Stephen      athletics       0       0     0      0
# 921675   1936  ABAS, Stephen       baseball       0       0     0      0
# 921676   1936  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1024075  1936  ZORN, Zachary      triathlon       0       0     0      0
# 1024076  1936  ZORN, Zachary     tug of war       0       0     0      0
# 1024077  1936  ZORN, Zachary     volleyball       0       0     0      0
# 1024078  1936  ZORN, Zachary  weightlifting       0       0     0      0
# 1024079  1936  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1024080  1948  ABAS, Stephen       aquatics       0       0     0      0
# 1024081  1948  ABAS, Stephen        archery       0       0     0      0
# 1024082  1948  ABAS, Stephen      athletics       0       0     0      0
# 1024083  1948  ABAS, Stephen       baseball       0       0     0      0
# 1024084  1948  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1126483  1948  ZORN, Zachary      triathlon       0       0     0      0
# 1126484  1948  ZORN, Zachary     tug of war       0       0     0      0
# 1126485  1948  ZORN, Zachary     volleyball       0       0     0      0
# 1126486  1948  ZORN, Zachary  weightlifting       0       0     0      0
# 1126487  1948  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1126488  1952  ABAS, Stephen       aquatics       0       0     0      0
# 1126489  1952  ABAS, Stephen        archery       0       0     0      0
# 1126490  1952  ABAS, Stephen      athletics       0       0     0      0
# 1126491  1952  ABAS, Stephen       baseball       0       0     0      0
# 1126492  1952  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1228891  1952  ZORN, Zachary      triathlon       0       0     0      0
# 1228892  1952  ZORN, Zachary     tug of war       0       0     0      0
# 1228893  1952  ZORN, Zachary     volleyball       0       0     0      0
# 1228894  1952  ZORN, Zachary  weightlifting       0       0     0      0
# 1228895  1952  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1228896  1956  ABAS, Stephen       aquatics       0       0     0      0
# 1228897  1956  ABAS, Stephen        archery       0       0     0      0
# 1228898  1956  ABAS, Stephen      athletics       0       0     0      0
# 1228899  1956  ABAS, Stephen       baseball       0       0     0      0
# 1228900  1956  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1331299  1956  ZORN, Zachary      triathlon       0       0     0      0
# 1331300  1956  ZORN, Zachary     tug of war       0       0     0      0
# 1331301  1956  ZORN, Zachary     volleyball       0       0     0      0
# 1331302  1956  ZORN, Zachary  weightlifting       0       0     0      0
# 1331303  1956  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1331304  1960  ABAS, Stephen       aquatics       0       0     0      0
# 1331305  1960  ABAS, Stephen        archery       0       0     0      0
# 1331306  1960  ABAS, Stephen      athletics       0       0     0      0
# 1331307  1960  ABAS, Stephen       baseball       0       0     0      0
# 1331308  1960  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1433707  1960  ZORN, Zachary      triathlon       0       0     0      0
# 1433708  1960  ZORN, Zachary     tug of war       0       0     0      0
# 1433709  1960  ZORN, Zachary     volleyball       0       0     0      0
# 1433710  1960  ZORN, Zachary  weightlifting       0       0     0      0
# 1433711  1960  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1433712  1964  ABAS, Stephen       aquatics       0       0     0      0
# 1433713  1964  ABAS, Stephen        archery       0       0     0      0
# 1433714  1964  ABAS, Stephen      athletics       0       0     0      0
# 1433715  1964  ABAS, Stephen       baseball       0       0     0      0
# 1433716  1964  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1536115  1964  ZORN, Zachary      triathlon       0       0     0      0
# 1536116  1964  ZORN, Zachary     tug of war       0       0     0      0
# 1536117  1964  ZORN, Zachary     volleyball       0       0     0      0
# 1536118  1964  ZORN, Zachary  weightlifting       0       0     0      0
# 1536119  1964  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1536120  1968  ABAS, Stephen       aquatics       0       0     0      0
# 1536121  1968  ABAS, Stephen        archery       0       0     0      0
# 1536122  1968  ABAS, Stephen      athletics       0       0     0      0
# 1536123  1968  ABAS, Stephen       baseball       0       0     0      0
# 1536124  1968  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1638523  1968  ZORN, Zachary      triathlon       0       0     0      0
# 1638524  1968  ZORN, Zachary     tug of war       0       0     0      0
# 1638525  1968  ZORN, Zachary     volleyball       0       0     0      0
# 1638526  1968  ZORN, Zachary  weightlifting       0       0     0      0
# 1638527  1968  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1638528  1972  ABAS, Stephen       aquatics       0       0     0      0
# 1638529  1972  ABAS, Stephen        archery       0       0     0      0
# 1638530  1972  ABAS, Stephen      athletics       0       0     0      0
# 1638531  1972  ABAS, Stephen       baseball       0       0     0      0
# 1638532  1972  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1740931  1972  ZORN, Zachary      triathlon       0       0     0      0
# 1740932  1972  ZORN, Zachary     tug of war       0       0     0      0
# 1740933  1972  ZORN, Zachary     volleyball       0       0     0      0
# 1740934  1972  ZORN, Zachary  weightlifting       0       0     0      0
# 1740935  1972  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1740936  1976  ABAS, Stephen       aquatics       0       0     0      0
# 1740937  1976  ABAS, Stephen        archery       0       0     0      0
# 1740938  1976  ABAS, Stephen      athletics       0       0     0      0
# 1740939  1976  ABAS, Stephen       baseball       0       0     0      0
# 1740940  1976  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1843339  1976  ZORN, Zachary      triathlon       0       0     0      0
# 1843340  1976  ZORN, Zachary     tug of war       0       0     0      0
# 1843341  1976  ZORN, Zachary     volleyball       0       0     0      0
# 1843342  1976  ZORN, Zachary  weightlifting       0       0     0      0
# 1843343  1976  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1843344  1984  ABAS, Stephen       aquatics       0       0     0      0
# 1843345  1984  ABAS, Stephen        archery       0       0     0      0
# 1843346  1984  ABAS, Stephen      athletics       0       0     0      0
# 1843347  1984  ABAS, Stephen       baseball       0       0     0      0
# 1843348  1984  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 1945747  1984  ZORN, Zachary      triathlon       0       0     0      0
# 1945748  1984  ZORN, Zachary     tug of war       0       0     0      0
# 1945749  1984  ZORN, Zachary     volleyball       0       0     0      0
# 1945750  1984  ZORN, Zachary  weightlifting       0       0     0      0
# 1945751  1984  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 1945752  1988  ABAS, Stephen       aquatics       0       0     0      0
# 1945753  1988  ABAS, Stephen        archery       0       0     0      0
# 1945754  1988  ABAS, Stephen      athletics       0       0     0      0
# 1945755  1988  ABAS, Stephen       baseball       0       0     0      0
# 1945756  1988  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2048155  1988  ZORN, Zachary      triathlon       0       0     0      0
# 2048156  1988  ZORN, Zachary     tug of war       0       0     0      0
# 2048157  1988  ZORN, Zachary     volleyball       0       0     0      0
# 2048158  1988  ZORN, Zachary  weightlifting       0       0     0      0
# 2048159  1988  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2048160  1992  ABAS, Stephen       aquatics       0       0     0      0
# 2048161  1992  ABAS, Stephen        archery       0       0     0      0
# 2048162  1992  ABAS, Stephen      athletics       0       0     0      0
# 2048163  1992  ABAS, Stephen       baseball       0       0     0      0
# 2048164  1992  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2150563  1992  ZORN, Zachary      triathlon       0       0     0      0
# 2150564  1992  ZORN, Zachary     tug of war       0       0     0      0
# 2150565  1992  ZORN, Zachary     volleyball       0       0     0      0
# 2150566  1992  ZORN, Zachary  weightlifting       0       0     0      0
# 2150567  1992  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2150568  1996  ABAS, Stephen       aquatics       0       0     0      0
# 2150569  1996  ABAS, Stephen        archery       0       0     0      0
# 2150570  1996  ABAS, Stephen      athletics       0       0     0      0
# 2150571  1996  ABAS, Stephen       baseball       0       0     0      0
# 2150572  1996  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2252971  1996  ZORN, Zachary      triathlon       0       0     0      0
# 2252972  1996  ZORN, Zachary     tug of war       0       0     0      0
# 2252973  1996  ZORN, Zachary     volleyball       0       0     0      0
# 2252974  1996  ZORN, Zachary  weightlifting       0       0     0      0
# 2252975  1996  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2252976  2000  ABAS, Stephen       aquatics       0       0     0      0
# 2252977  2000  ABAS, Stephen        archery       0       0     0      0
# 2252978  2000  ABAS, Stephen      athletics       0       0     0      0
# 2252979  2000  ABAS, Stephen       baseball       0       0     0      0
# 2252980  2000  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2355379  2000  ZORN, Zachary      triathlon       0       0     0      0
# 2355380  2000  ZORN, Zachary     tug of war       0       0     0      0
# 2355381  2000  ZORN, Zachary     volleyball       0       0     0      0
# 2355382  2000  ZORN, Zachary  weightlifting       0       0     0      0
# 2355383  2000  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2355384  2004  ABAS, Stephen       aquatics       0       0     0      0
# 2355385  2004  ABAS, Stephen        archery       0       0     0      0
# 2355386  2004  ABAS, Stephen      athletics       0       0     0      0
# 2355387  2004  ABAS, Stephen       baseball       0       0     0      0
# 2355388  2004  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2457787  2004  ZORN, Zachary      triathlon       0       0     0      0
# 2457788  2004  ZORN, Zachary     tug of war       0       0     0      0
# 2457789  2004  ZORN, Zachary     volleyball       0       0     0      0
# 2457790  2004  ZORN, Zachary  weightlifting       0       0     0      0
# 2457791  2004  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year   Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2457792  2008  ABAS, Stephen       aquatics       0       0     0      0
# 2457793  2008  ABAS, Stephen        archery       0       0     0      0
# 2457794  2008  ABAS, Stephen      athletics       0       0     0      0
# 2457795  2008  ABAS, Stephen       baseball       0       0     0      0
# 2457796  2008  ABAS, Stephen     basketball       0       0     0      0
# ...       ...            ...            ...     ...     ...   ...    ...
# 2560195  2008  ZORN, Zachary      triathlon       0       0     0      0
# 2560196  2008  ZORN, Zachary     tug of war       0       0     0      0
# 2560197  2008  ZORN, Zachary     volleyball       0       0     0      0
# 2560198  2008  ZORN, Zachary  weightlifting       0       0     0      0
# 2560199  2008  ZORN, Zachary      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values('Total', ascending=False))
# Out:
# Medal   Year     Athlete Name         Sport  Bronze  Silver  Gold  Total
# 32642   1896  GARRETT, Robert     athletics       0       2     2      4
# 17988   1896  CONNOLLY, James     athletics       1       1     1      3
# 71118   1896    PAINE, Sumner      shooting       0       1     1      2
# 16186   1896    CLARK, Ellery     athletics       0       0     2      2
# 12616   1896    BURKE, Thomas     athletics       0       0     2      2
# ...      ...              ...           ...     ...     ...   ...    ...
# 102387  1896    ZORN, Zachary        hockey       0       0     0      0
# 102388  1896    ZORN, Zachary    ice hockey       0       0     0      0
# 102389  1896    ZORN, Zachary  jeu de paume       0       0     0      0
# 102390  1896    ZORN, Zachary          judo       0       0     0      0
# 23      1896    ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year               Athlete Name         Sport  Bronze  Silver  Gold  \
# 107612  1900             BAXTER, Irving     athletics       0       3     2
# 193156  1900  TEWKSBURY, Walter B. John     athletics       1       2     2
# 154838  1900          KRAENZLEIN, Alvin     athletics       0       0     4
# 130154  1900                  EWRY, Ray     athletics       0       0     3
# 185472  1900           SHELDON, Richard     athletics       1       0     1
# ...      ...                        ...           ...     ...     ...   ...
# 204795  1900              ZORN, Zachary        hockey       0       0     0
# 204796  1900              ZORN, Zachary    ice hockey       0       0     0
# 204797  1900              ZORN, Zachary  jeu de paume       0       0     0
# 204798  1900              ZORN, Zachary          judo       0       0     0
# 102431  1900              ABAS, Stephen       sailing       0       0     0
#
# Medal   Total
# 107612      5
# 193156      5
# 154838      4
# 130154      3
# 185472      2
# ...       ...
# 204795      0
# 204796      0
# 204797      0
# 204798      0
# 102431      0
#
# [102408 rows x 7 columns]
# Medal   Year      Athlete Name         Sport  Bronze  Silver  Gold  Total
# 245424  1904      HEIDA, Anton    gymnastics       0       1     5      6
# 232640  1904     EYSER, George    gymnastics       1       2     3      6
# 229541  1904   DOWNING, Burton       cycling       1       3     2      6
# 249159  1904    HURLEY, Marcus       cycling       1       0     4      5
# 225454  1904  DANIELS, Charles      aquatics       1       1     3      5
# ...      ...               ...           ...     ...     ...   ...    ...
# 307203  1904     ZORN, Zachary        hockey       0       0     0      0
# 307204  1904     ZORN, Zachary    ice hockey       0       0     0      0
# 307205  1904     ZORN, Zachary  jeu de paume       0       0     0      0
# 307206  1904     ZORN, Zachary          judo       0       0     0      0
# 204839  1904     ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year                  Athlete Name         Sport  Bronze  Silver  \
# 390458  1908              SHERIDAN, Martin     athletics       1       0
# 390390  1908              SHEPPARD, Melvin     athletics       0       0
# 322016  1908      CARTMELL, John Nathaniel     athletics       1       0
# 322140  1908  CASEY, Kellog Kennon Venable      shooting       0       1
# 327862  1908              DANIELS, Charles      aquatics       1       0
# ...      ...                           ...           ...     ...     ...
# 409611  1908                 ZORN, Zachary        hockey       0       0
# 409612  1908                 ZORN, Zachary    ice hockey       0       0
# 409613  1908                 ZORN, Zachary  jeu de paume       0       0
# 409614  1908                 ZORN, Zachary          judo       0       0
# 307247  1908                 ABAS, Stephen       sailing       0       0
#
# Medal   Gold  Total
# 390458     2      3
# 390390     3      3
# 322016     1      2
# 322140     1      2
# 327862     1      2
# ...      ...    ...
# 409611     0      0
# 409612     0      0
# 409613     0      0
# 409614     0      0
# 307247     0      0
#
# [102408 rows x 7 columns]
# Medal   Year           Athlete Name         Sport  Bronze  Silver  Gold  Total
# 480240  1912  OSBURN, Carl Townsend      shooting       1       2     1      4
# 463342  1912        LANE, Alfred P.      shooting       0       0     3      3
# 496186  1912      SPROUT, Warren A.      shooting       2       0     1      3
# 451884  1912     HIRD, Frederick S.      shooting       2       0     1      3
# 464974  1912   LEUSHNER, William F.      shooting       2       1     0      3
# ...      ...                    ...           ...     ...     ...   ...    ...
# 512019  1912          ZORN, Zachary        hockey       0       0     0      0
# 512020  1912          ZORN, Zachary    ice hockey       0       0     0      0
# 512021  1912          ZORN, Zachary  jeu de paume       0       0     0      0
# 512022  1912          ZORN, Zachary          judo       0       0     0      0
# 409655  1912          ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name         Sport  Bronze  Silver  Gold  \
# 566940  1920               LEE, Willis      shooting       1       1     5
# 598424  1920    SPOONER, Lloyd Spencer      shooting       2       1     4
# 582648  1920     OSBURN, Carl Townsend      shooting       1       1     4
# 581186  1920  NUESSLEIN, Lawrence Adam      shooting       2       1     2
# 540522  1920            FENTON, Dennis      shooting       1       0     3
# ...      ...                       ...           ...     ...     ...   ...
# 614427  1920             ZORN, Zachary        hockey       0       0     0
# 614428  1920             ZORN, Zachary    ice hockey       0       0     0
# 614429  1920             ZORN, Zachary  jeu de paume       0       0     0
# 614430  1920             ZORN, Zachary          judo       0       0     0
# 512063  1920             ABAS, Stephen       sailing       0       0     0
#
# Medal   Total
# 566940      7
# 598424      7
# 582648      6
# 581186      5
# 540522      4
# ...       ...
# 614427      0
# 614428      0
# 614429      0
# 614430      0
# 512063      0
#
# [102408 rows x 7 columns]
# Medal   Year                Athlete Name         Sport  Bronze  Silver  Gold  \
# 710940  1924         WEISSMULLER, Johnny      aquatics       1       0     3
# 640662  1924            EDERLE, Gertrude      aquatics       2       0     1
# 690602  1924           RICHARDS, Vincent        tennis       0       1     2
# 620228  1924  BECKER-PINKSTON, Elizabeth      aquatics       0       1     1
# 623006  1924           BOLES, John Keith      shooting       1       0     1
# ...      ...                         ...           ...     ...     ...   ...
# 716835  1924               ZORN, Zachary        hockey       0       0     0
# 716836  1924               ZORN, Zachary    ice hockey       0       0     0
# 716837  1924               ZORN, Zachary  jeu de paume       0       0     0
# 716838  1924               ZORN, Zachary          judo       0       0     0
# 614471  1924               ABAS, Stephen       sailing       0       0     0
#
# Medal   Total
# 710940      4
# 640662      3
# 690602      3
# 620228      2
# 623006      2
# ...       ...
# 716835      0
# 716836      0
# 716837      0
# 716838      0
# 614471      0
#
# [102408 rows x 7 columns]
# Medal   Year                      Athlete Name         Sport  Bronze  Silver  \
# 720836  1928            BARBUTI, Raymond James     athletics       0       0
# 734230  1928               COLEMAN, Georgia V.      aquatics       1       1
# 739704  1928  DESJARDINS, Ulise Joseph "Peter"      aquatics       0       0
# 749088  1928           GALITZEN, Michael Riley      aquatics       1       1
# 813348  1928               WEISSMULLER, Johnny      aquatics       0       0
# ...      ...                               ...           ...     ...     ...
# 819243  1928                     ZORN, Zachary        hockey       0       0
# 819244  1928                     ZORN, Zachary    ice hockey       0       0
# 819245  1928                     ZORN, Zachary  jeu de paume       0       0
# 819246  1928                     ZORN, Zachary          judo       0       0
# 716879  1928                     ABAS, Stephen       sailing       0       0
#
# Medal   Gold  Total
# 720836     2      2
# 734230     0      2
# 739704     2      2
# 749088     0      2
# 813348     2      2
# ...      ...    ...
# 819243     0      0
# 819244     0      0
# 819245     0      0
# 819246     0      0
# 716879     0      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name         Sport  Bronze  Silver  Gold  \
# 842454  1932        DIDRIKSON, Mildred     athletics       0       1     2
# 877370  1932           MADISON, Helene      aquatics       0       0     3
# 832737  1932    CALNAN, George Charles       fencing       2       0     0
# 833818  1932      CARR, William Arthur     athletics       0       0     2
# 834674  1932  CHAMBERLIN, Harry Dwight    equestrian       0       1     1
# ...      ...                       ...           ...     ...     ...   ...
# 921651  1932             ZORN, Zachary        hockey       0       0     0
# 921652  1932             ZORN, Zachary    ice hockey       0       0     0
# 921653  1932             ZORN, Zachary  jeu de paume       0       0     0
# 921654  1932             ZORN, Zachary          judo       0       0     0
# 819287  1932             ABAS, Stephen       sailing       0       0     0
#
# Medal   Total
# 842454      3
# 877370      3
# 832737      2
# 833818      2
# 834674      2
# ...       ...
# 921651      0
# 921652      0
# 921653      0
# 921654      0
# 819287      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name         Sport  Bronze  Silver  Gold  \
# 992530   1936             OWENS, Jesse     athletics       0       0     4
# 984674   1936          MEDICA, Jack C.      aquatics       0       2     1
# 985322   1936          METCALFE, Ralph     athletics       0       1     1
# 995724   1936    POYNTON-HILL, Dorothy      aquatics       1       0     1
# 996710   1936  RAWLS, Katherine Louise      aquatics       1       1     0
# ...       ...                      ...           ...     ...     ...   ...
# 1024059  1936            ZORN, Zachary        hockey       0       0     0
# 1024060  1936            ZORN, Zachary    ice hockey       0       0     0
# 1024061  1936            ZORN, Zachary  jeu de paume       0       0     0
# 1024062  1936            ZORN, Zachary          judo       0       0     0
# 921695   1936            ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 992530       4
# 984674       3
# 985322       2
# 995724       2
# 996710       2
# ...        ...
# 1024059      0
# 1024060      0
# 1024061      0
# 1024062      0
# 921695       0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name         Sport  Bronze  Silver  Gold  \
# 1044310  1948      CURTIS, Ann Elisabeth      aquatics       0       1     2
# 1051724  1948      EWELL, Harold Norwood     athletics       0       2     1
# 1121560  1948  WHITFIELD, Malvin Groston     athletics       1       0     2
# 1065364  1948       HENRY, Frank Sherman    equestrian       0       2     1
# 1086402  1948    MCLANE, James Price Jr.      aquatics       0       1     2
# ...       ...                        ...           ...     ...     ...   ...
# 1126467  1948              ZORN, Zachary        hockey       0       0     0
# 1126468  1948              ZORN, Zachary    ice hockey       0       0     0
# 1126469  1948              ZORN, Zachary  jeu de paume       0       0     0
# 1126470  1948              ZORN, Zachary          judo       0       0     0
# 1024103  1948              ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1044310      3
# 1051724      3
# 1121560      3
# 1065364      3
# 1086402      3
# ...        ...
# 1126467      0
# 1126468      0
# 1126469      0
# 1126470      0
# 1024103      0
#
# [102408 rows x 7 columns]
# Medal    Year            Athlete Name         Sport  Bronze  Silver  Gold  \
# 1178576  1952     KONNO, Ford Hiroshi      aquatics       0       1     2
# 1149882  1952       DILLARD, Harrison     athletics       0       0     2
# 1176094  1952  KAWAMOTO, Evelyn Tokue      aquatics       2       0     0
# 1186228  1952   MATSON, Oliver Adrian     athletics       1       1     0
# 1187450  1952     MCCORMICK, Patricia      aquatics       0       0     2
# ...       ...                     ...           ...     ...     ...   ...
# 1228875  1952           ZORN, Zachary        hockey       0       0     0
# 1228876  1952           ZORN, Zachary    ice hockey       0       0     0
# 1228877  1952           ZORN, Zachary  jeu de paume       0       0     0
# 1228878  1952           ZORN, Zachary          judo       0       0     0
# 1126511  1952           ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1178576      3
# 1149882      2
# 1176094      2
# 1186228      2
# 1187450      2
# ...        ...
# 1228875      0
# 1228876      0
# 1228877      0
# 1228878      0
# 1126511      0
#
# [102408 rows x 7 columns]
# Medal    Year              Athlete Name         Sport  Bronze  Silver  Gold  \
# 1232536  1956       BAKER, Walter Thane     athletics       1       1     1
# 1239198  1956      BREEN, George Thomas      aquatics       2       1     0
# 1295504  1956     MORROW, Robert Joseph     athletics       0       0     3
# 1247836  1956  COURTNEY, Thomas William     athletics       0       0     2
# 1275410  1956   JENKINS, Charles Lamont     athletics       0       0     2
# ...       ...                       ...           ...     ...     ...   ...
# 1331283  1956             ZORN, Zachary        hockey       0       0     0
# 1331284  1956             ZORN, Zachary    ice hockey       0       0     0
# 1331285  1956             ZORN, Zachary  jeu de paume       0       0     0
# 1331286  1956             ZORN, Zachary          judo       0       0     0
# 1228919  1956             ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1232536      3
# 1239198      3
# 1295504      3
# 1247836      2
# 1275410      2
# ...        ...
# 1331283      0
# 1331284      0
# 1331285      0
# 1331286      0
# 1228919      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name              Sport  Bronze  Silver  \
# 1425994  1960  VON SALTZA, Susan Christina           aquatics       0       1
# 1409914  1960               RUDOLPH, Wilma          athletics       0       0
# 1336966  1960             BECK, Robert Lee  modern pentathlon       2       0
# 1343850  1960           BURKE, Lynn Edythe           aquatics       0       0
# 1352624  1960           DAVIS, Glenn Ashby          athletics       0       0
# ...       ...                          ...                ...     ...     ...
# 1433691  1960                ZORN, Zachary             hockey       0       0
# 1433692  1960                ZORN, Zachary         ice hockey       0       0
# 1433693  1960                ZORN, Zachary       jeu de paume       0       0
# 1433694  1960                ZORN, Zachary               judo       0       0
# 1331327  1960                ABAS, Stephen            sailing       0       0
#
# Medal    Gold  Total
# 1425994     3      4
# 1409914     3      3
# 1336966     0      2
# 1343850     2      2
# 1352624     2      2
# ...       ...    ...
# 1433691     0      0
# 1433692     0      0
# 1433693     0      0
# 1433694     0      0
# 1331327     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                Athlete Name         Sport  Bronze  Silver  Gold  \
# 1460232  1964             ELLIS, Kathleen      aquatics       2       0     2
# 1522282  1964       STOUDER, Sharon Marie      aquatics       0       1     3
# 1514564  1964  SCHOLLANDER, Donald Arthur      aquatics       0       0     4
# 1450100  1964       CLARK, Stephen Edward      aquatics       0       0     3
# 1495424  1964        MCGUIRE, Edith Marie     athletics       0       2     1
# ...       ...                         ...           ...     ...     ...   ...
# 1536099  1964               ZORN, Zachary        hockey       0       0     0
# 1536100  1964               ZORN, Zachary    ice hockey       0       0     0
# 1536101  1964               ZORN, Zachary  jeu de paume       0       0     0
# 1536102  1964               ZORN, Zachary          judo       0       0     0
# 1433735  1964               ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1460232      4
# 1522282      4
# 1514564      4
# 1450100      3
# 1495424      3
# ...        ...
# 1536099      0
# 1536100      0
# 1536101      0
# 1536102      0
# 1433735      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name         Sport  Bronze  Silver  Gold  \
# 1577294  1968          HENNE, Jane Margo      aquatics       1       1     2
# 1577804  1968  HICKCOX, Charles Buchanan      aquatics       0       1     3
# 1622412  1968                SPITZ, Mark      aquatics       1       1     2
# 1608234  1968       PEDERSEN, Susan Jane      aquatics       0       2     2
# 1556724  1968    DANIEL, Eleanor Suzanne      aquatics       1       1     1
# ...       ...                        ...           ...     ...     ...   ...
# 1638507  1968              ZORN, Zachary        hockey       0       0     0
# 1638508  1968              ZORN, Zachary    ice hockey       0       0     0
# 1638509  1968              ZORN, Zachary  jeu de paume       0       0     0
# 1638510  1968              ZORN, Zachary          judo       0       0     0
# 1536143  1968              ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1577294      4
# 1577804      4
# 1622412      4
# 1608234      4
# 1556724      3
# ...        ...
# 1638507      0
# 1638508      0
# 1638509      0
# 1638510      0
# 1536143      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name         Sport  Bronze  Silver  Gold  \
# 1724820  1972                SPITZ, Mark      aquatics       0       0     7
# 1679158  1972    HEIDENREICH, Jerry Alan      aquatics       1       1     2
# 1641656  1972  BABASHOFF, Shirley Farber      aquatics       0       2     1
# 1644818  1972     BELOTE, Melissa Louise      aquatics       0       0     3
# 1671576  1972      GENTER, Robert Steven      aquatics       0       2     1
# ...       ...                        ...           ...     ...     ...   ...
# 1740915  1972              ZORN, Zachary        hockey       0       0     0
# 1740916  1972              ZORN, Zachary    ice hockey       0       0     0
# 1740917  1972              ZORN, Zachary  jeu de paume       0       0     0
# 1740918  1972              ZORN, Zachary          judo       0       0     0
# 1638551  1972              ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1724820      7
# 1679158      4
# 1641656      3
# 1644818      3
# 1671576      3
# ...        ...
# 1740915      0
# 1740916      0
# 1740917      0
# 1740918      0
# 1638551      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name         Sport  Bronze  Silver  Gold  \
# 1744064  1976  BABASHOFF, Shirley Farber      aquatics       0       4     1
# 1808732  1976       NABER, John Phillips      aquatics       0       1     4
# 1806420  1976     MONTGOMERY, James Paul      aquatics       1       0     3
# 1781838  1976    HENCKEN, John Frederick      aquatics       0       1     2
# 1749368  1976   BOGLIOLI, Wendy Lansbach      aquatics       1       0     1
# ...       ...                        ...           ...     ...     ...   ...
# 1843323  1976              ZORN, Zachary        hockey       0       0     0
# 1843324  1976              ZORN, Zachary    ice hockey       0       0     0
# 1843325  1976              ZORN, Zachary  jeu de paume       0       0     0
# 1843326  1976              ZORN, Zachary          judo       0       0     0
# 1740959  1976              ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1744064      5
# 1808732      5
# 1806420      4
# 1781838      3
# 1749368      2
# ...        ...
# 1843323      0
# 1843324      0
# 1843325      0
# 1843326      0
# 1740959      0
#
# [102408 rows x 7 columns]
# Medal    Year           Athlete Name         Sport  Bronze  Silver  Gold  \
# 1919142  1984       RETTON, Mary-Lou    gymnastics       2       2     1
# 1898800  1984            LEWIS, Carl     athletics       0       0     4
# 1886014  1984   HOGSHEAD, Nancy Lynn      aquatics       0       1     3
# 1876234  1984  GAYLORD, Mitchell Jay    gymnastics       2       1     1
# 1937570  1984     VIDMAR, Peter Glen    gymnastics       0       1     2
# ...       ...                    ...           ...     ...     ...   ...
# 1945731  1984          ZORN, Zachary        hockey       0       0     0
# 1945732  1984          ZORN, Zachary    ice hockey       0       0     0
# 1945733  1984          ZORN, Zachary  jeu de paume       0       0     0
# 1945734  1984          ZORN, Zachary          judo       0       0     0
# 1843367  1984          ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 1919142      5
# 1898800      4
# 1886014      4
# 1876234      4
# 1937570      3
# ...        ...
# 1945731      0
# 1945732      0
# 1945733      0
# 1945734      0
# 1843367      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name         Sport  Bronze  Silver  \
# 1953334  1988              BIONDI, Matthew      aquatics       1       1
# 1982168  1988    GRIFFITH-JOYNER, Florence     athletics       0       1
# 1973088  1988                 EVANS, Janet      aquatics       0       0
# 1991142  1988  JACOBS, Christopher Charles      aquatics       0       1
# 2001208  1988                  LEWIS, Carl     athletics       0       1
# ...       ...                          ...           ...     ...     ...
# 2048139  1988                ZORN, Zachary        hockey       0       0
# 2048140  1988                ZORN, Zachary    ice hockey       0       0
# 2048141  1988                ZORN, Zachary  jeu de paume       0       0
# 2048142  1988                ZORN, Zachary          judo       0       0
# 1945775  1988                ABAS, Stephen       sailing       0       0
#
# Medal    Gold  Total
# 1953334     5      7
# 1982168     3      4
# 1973088     3      3
# 1991142     2      3
# 2001208     2      3
# ...       ...    ...
# 2048139     0      0
# 2048140     0      0
# 2048141     0      0
# 2048142     0      0
# 1945775     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                Athlete Name         Sport  Bronze  Silver  Gold  \
# 2112636  1992             MILLER, Shannon    gymnastics       3       2     0
# 2127856  1992             SANDERS, Summer      aquatics       1       1     2
# 2048840  1992  AHMANN-LEIGHTON, Christine      aquatics       0       1     2
# 2055742  1992             BIONDI, Matthew      aquatics       0       1     2
# 2085424  1992        HAISLETT, Nicole Lee      aquatics       0       0     3
# ...       ...                         ...           ...     ...     ...   ...
# 2150547  1992               ZORN, Zachary        hockey       0       0     0
# 2150548  1992               ZORN, Zachary    ice hockey       0       0     0
# 2150549  1992               ZORN, Zachary  jeu de paume       0       0     0
# 2150550  1992               ZORN, Zachary          judo       0       0     0
# 2048183  1992               ABAS, Stephen       sailing       0       0     0
#
# Medal    Total
# 2112636      5
# 2127856      4
# 2048840      3
# 2055742      3
# 2085424      3
# ...        ...
# 2150547      0
# 2150548      0
# 2150549      0
# 2150550      0
# 2048183      0
#
# [102408 rows x 7 columns]
# Medal    Year    Athlete Name         Sport  Bronze  Silver  Gold  Total
# 2188206  1996  HALL, Gary Jr.      aquatics       0       2     2      4
# 2244204  1996  VAN DYKEN, Amy      aquatics       0       0     4      4
# 2210068  1996  MARTINO, Angel      aquatics       2       0     2      4
# 2155940  1996   BEARD, Amanda      aquatics       0       2     1      3
# 2172022  1996     DAVIS, Josh      aquatics       0       0     3      3
# ...       ...             ...           ...     ...     ...   ...    ...
# 2252955  1996   ZORN, Zachary        hockey       0       0     0      0
# 2252956  1996   ZORN, Zachary    ice hockey       0       0     0      0
# 2252957  1996   ZORN, Zachary  jeu de paume       0       0     0      0
# 2252958  1996   ZORN, Zachary          judo       0       0     0      0
# 2150591  1996   ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year        Athlete Name         Sport  Bronze  Silver  Gold  Total
# 2345014  2000        TORRES, Dara      aquatics       3       0     2      5
# 2290614  2000      HALL, Gary Jr.      aquatics       1       1     2      4
# 2343994  2000     THOMPSON, Jenny      aquatics       1       0     3      4
# 2305540  2000  KRAYZELBURG, Lenny      aquatics       0       0     3      3
# 2259470  2000     BENNETT, Brooke      aquatics       0       0     2      2
# ...       ...                 ...           ...     ...     ...   ...    ...
# 2355363  2000       ZORN, Zachary        hockey       0       0     0      0
# 2355364  2000       ZORN, Zachary    ice hockey       0       0     0      0
# 2355365  2000       ZORN, Zachary  jeu de paume       0       0     0      0
# 2355366  2000       ZORN, Zachary          judo       0       0     0      0
# 2252999  2000       ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name         Sport  Bronze  Silver  Gold  Total
# 2428246  2004    PHELPS, Michael      aquatics       2       0     6      8
# 2374220  2004  COUGHLIN, Natalie      aquatics       1       2     2      5
# 2434944  2004   SANDENO, Kaitlin      aquatics       1       1     1      3
# 2360756  2004      BEARD, Amanda      aquatics       0       2     1      3
# 2427566  2004     PEIRSOL, Aaron      aquatics       0       0     3      3
# ...       ...                ...           ...     ...     ...   ...    ...
# 2457771  2004      ZORN, Zachary        hockey       0       0     0      0
# 2457772  2004      ZORN, Zachary    ice hockey       0       0     0      0
# 2457773  2004      ZORN, Zachary  jeu de paume       0       0     0      0
# 2457774  2004      ZORN, Zachary          judo       0       0     0      0
# 2355407  2004      ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name         Sport  Bronze  Silver  Gold  Total
# 2530654  2008    PHELPS, Michael      aquatics       0       0     8      8
# 2476628  2008  COUGHLIN, Natalie      aquatics       3       2     1      6
# 2514142  2008     LIUKIN, Nastia    gymnastics       1       3     1      5
# 2505642  2008     JOHNSON, Shawn    gymnastics       0       3     1      4
# 2514368  2008       LOCHTE, Ryan      aquatics       2       0     2      4
# ...       ...                ...           ...     ...     ...   ...    ...
# 2560179  2008      ZORN, Zachary        hockey       0       0     0      0
# 2560180  2008      ZORN, Zachary    ice hockey       0       0     0      0
# 2560181  2008      ZORN, Zachary  jeu de paume       0       0     0      0
# 2560182  2008      ZORN, Zachary          judo       0       0     0      0
# 2457815  2008      ABAS, Stephen       sailing       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False))
# Out:
# Medal  Year     Athlete Name          Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert      athletics       0       2     2      4
# 17988  1896  CONNOLLY, James      athletics       1       1     1      3
# 16186  1896    CLARK, Ellery      athletics       0       0     2      2
# 12616  1896    BURKE, Thomas      athletics       0       0     2      2
# 71118  1896    PAINE, Sumner       shooting       0       1     1      2
# ...     ...              ...            ...     ...     ...   ...    ...
# 29     1896    ABAS, Stephen      triathlon       0       0     0      0
# 30     1896    ABAS, Stephen     tug of war       0       0     0      0
# 31     1896    ABAS, Stephen     volleyball       0       0     0      0
# 32     1896    ABAS, Stephen  weightlifting       0       0     0      0
# 33     1896    ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year               Athlete Name          Sport  Bronze  Silver  Gold  \
# 107612  1900             BAXTER, Irving      athletics       0       3     2
# 193156  1900  TEWKSBURY, Walter B. John      athletics       1       2     2
# 154838  1900          KRAENZLEIN, Alvin      athletics       0       0     4
# 130154  1900                  EWRY, Ray      athletics       0       0     3
# 176700  1900           PRINSTEIN, Meyer      athletics       0       1     1
# ...      ...                        ...            ...     ...     ...   ...
# 102437  1900              ABAS, Stephen      triathlon       0       0     0
# 102438  1900              ABAS, Stephen     tug of war       0       0     0
# 102439  1900              ABAS, Stephen     volleyball       0       0     0
# 102440  1900              ABAS, Stephen  weightlifting       0       0     0
# 102441  1900              ABAS, Stephen      wrestling       0       0     0
#
# Medal   Total
# 107612      5
# 193156      5
# 154838      4
# 130154      3
# 176700      2
# ...       ...
# 102437      0
# 102438      0
# 102439      0
# 102440      0
# 102441      0
#
# [102408 rows x 7 columns]
# Medal   Year      Athlete Name          Sport  Bronze  Silver  Gold  Total
# 245424  1904      HEIDA, Anton     gymnastics       0       1     5      6
# 232640  1904     EYSER, George     gymnastics       1       2     3      6
# 229541  1904   DOWNING, Burton        cycling       1       3     2      6
# 249159  1904    HURLEY, Marcus        cycling       1       0     4      5
# 225454  1904  DANIELS, Charles       aquatics       1       1     3      5
# ...      ...               ...            ...     ...     ...   ...    ...
# 204845  1904     ABAS, Stephen      triathlon       0       0     0      0
# 204846  1904     ABAS, Stephen     tug of war       0       0     0      0
# 204847  1904     ABAS, Stephen     volleyball       0       0     0      0
# 204848  1904     ABAS, Stephen  weightlifting       0       0     0      0
# 204849  1904     ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal   Year                  Athlete Name          Sport  Bronze  Silver  \
# 390390  1908              SHEPPARD, Melvin      athletics       0       0
# 390458  1908              SHERIDAN, Martin      athletics       1       0
# 334970  1908                     EWRY, Ray      athletics       0       0
# 322140  1908  CASEY, Kellog Kennon Venable       shooting       0       1
# 342098  1908          GORMAN, James Edward       shooting       1       0
# ...      ...                           ...            ...     ...     ...
# 307253  1908                 ABAS, Stephen      triathlon       0       0
# 307254  1908                 ABAS, Stephen     tug of war       0       0
# 307255  1908                 ABAS, Stephen     volleyball       0       0
# 307256  1908                 ABAS, Stephen  weightlifting       0       0
# 307257  1908                 ABAS, Stephen      wrestling       0       0
#
# Medal   Gold  Total
# 390390     3      3
# 390458     2      3
# 334970     2      2
# 322140     1      2
# 342098     1      2
# ...      ...    ...
# 307253     0      0
# 307254     0      0
# 307255     0      0
# 307256     0      0
# 307257     0      0
#
# [102408 rows x 7 columns]
# Medal   Year           Athlete Name          Sport  Bronze  Silver  Gold  \
# 480240  1912  OSBURN, Carl Townsend       shooting       1       2     1
# 463342  1912        LANE, Alfred P.       shooting       0       0     3
# 496186  1912      SPROUT, Warren A.       shooting       2       0     1
# 451884  1912     HIRD, Frederick S.       shooting       2       0     1
# 464974  1912   LEUSHNER, William F.       shooting       2       1     0
# ...      ...                    ...            ...     ...     ...   ...
# 409661  1912          ABAS, Stephen      triathlon       0       0     0
# 409662  1912          ABAS, Stephen     tug of war       0       0     0
# 409663  1912          ABAS, Stephen     volleyball       0       0     0
# 409664  1912          ABAS, Stephen  weightlifting       0       0     0
# 409665  1912          ABAS, Stephen      wrestling       0       0     0
#
# Medal   Total
# 480240      4
# 463342      3
# 496186      3
# 451884      3
# 464974      3
# ...       ...
# 409661      0
# 409662      0
# 409663      0
# 409664      0
# 409665      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name          Sport  Bronze  Silver  Gold  \
# 566940  1920               LEE, Willis       shooting       1       1     5
# 598424  1920    SPOONER, Lloyd Spencer       shooting       2       1     4
# 582648  1920     OSBURN, Carl Townsend       shooting       1       1     4
# 581186  1920  NUESSLEIN, Lawrence Adam       shooting       2       1     2
# 540522  1920            FENTON, Dennis       shooting       1       0     3
# ...      ...                       ...            ...     ...     ...   ...
# 512069  1920             ABAS, Stephen      triathlon       0       0     0
# 512070  1920             ABAS, Stephen     tug of war       0       0     0
# 512071  1920             ABAS, Stephen     volleyball       0       0     0
# 512072  1920             ABAS, Stephen  weightlifting       0       0     0
# 512073  1920             ABAS, Stephen      wrestling       0       0     0
#
# Medal   Total
# 566940      7
# 598424      7
# 582648      6
# 581186      5
# 540522      4
# ...       ...
# 512069      0
# 512070      0
# 512071      0
# 512072      0
# 512073      0
#
# [102408 rows x 7 columns]
# Medal   Year              Athlete Name          Sport  Bronze  Silver  Gold  \
# 710940  1924       WEISSMULLER, Johnny       aquatics       1       0     3
# 690602  1924         RICHARDS, Vincent         tennis       0       1     2
# 640662  1924          EDERLE, Gertrude       aquatics       2       0     1
# 713858  1924        WILLS-MOODY, Helen         tennis       0       0     2
# 712362  1924  WIGHTMAN, Hazel Virginia         tennis       0       0     2
# ...      ...                       ...            ...     ...     ...   ...
# 614477  1924             ABAS, Stephen      triathlon       0       0     0
# 614478  1924             ABAS, Stephen     tug of war       0       0     0
# 614479  1924             ABAS, Stephen     volleyball       0       0     0
# 614480  1924             ABAS, Stephen  weightlifting       0       0     0
# 614481  1924             ABAS, Stephen      wrestling       0       0     0
#
# Medal   Total
# 710940      4
# 690602      3
# 640662      3
# 713858      2
# 712362      2
# ...       ...
# 614477      0
# 614478      0
# 614479      0
# 614480      0
# 614481      0
#
# [102408 rows x 7 columns]
# Medal   Year                      Athlete Name          Sport  Bronze  Silver  \
# 813348  1928               WEISSMULLER, Johnny       aquatics       0       0
# 787508  1928            OSIPOWICH, Albina Lucy       aquatics       0       0
# 785672  1928                  NORELIUS, Martha       aquatics       0       0
# 768774  1928              KOJAC, George Harold       aquatics       0       0
# 739704  1928  DESJARDINS, Ulise Joseph "Peter"       aquatics       0       0
# ...      ...                               ...            ...     ...     ...
# 716885  1928                     ABAS, Stephen      triathlon       0       0
# 716886  1928                     ABAS, Stephen     tug of war       0       0
# 716887  1928                     ABAS, Stephen     volleyball       0       0
# 716888  1928                     ABAS, Stephen  weightlifting       0       0
# 716889  1928                     ABAS, Stephen      wrestling       0       0
#
# Medal   Gold  Total
# 813348     2      2
# 787508     2      2
# 785672     2      2
# 768774     2      2
# 739704     2      2
# ...      ...    ...
# 716885     0      0
# 716886     0      0
# 716887     0      0
# 716888     0      0
# 716889     0      0
#
# [102408 rows x 7 columns]
# Medal   Year          Athlete Name          Sport  Bronze  Silver  Gold  Total
# 877370  1932       MADISON, Helene       aquatics       0       0     3      3
# 842454  1932    DIDRIKSON, Mildred      athletics       0       1     2      3
# 910964  1932          TOLAN, Eddie      athletics       0       0     2      2
# 833818  1932  CARR, William Arthur      athletics       0       0     2      2
# 910494  1932  THOMSON, Earl Foster     equestrian       0       1     1      2
# ...      ...                   ...            ...     ...     ...   ...    ...
# 819293  1932         ABAS, Stephen      triathlon       0       0     0      0
# 819294  1932         ABAS, Stephen     tug of war       0       0     0      0
# 819295  1932         ABAS, Stephen     volleyball       0       0     0      0
# 819296  1932         ABAS, Stephen  weightlifting       0       0     0      0
# 819297  1932         ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  \
# 992530   1936             OWENS, Jesse      athletics       0       0     4
# 984674   1936          MEDICA, Jack C.       aquatics       0       2     1
# 1009360  1936  STEPHENS, Helen Herring      athletics       0       0     2
# 1017484  1936          WAYNE, Marshall       aquatics       0       1     1
# 985322   1936          METCALFE, Ralph      athletics       0       1     1
# ...       ...                      ...            ...     ...     ...   ...
# 921701   1936            ABAS, Stephen      triathlon       0       0     0
# 921702   1936            ABAS, Stephen     tug of war       0       0     0
# 921703   1936            ABAS, Stephen     volleyball       0       0     0
# 921704   1936            ABAS, Stephen  weightlifting       0       0     0
# 921705   1936            ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 992530       4
# 984674       3
# 1009360      2
# 1017484      2
# 985322       2
# ...        ...
# 921701       0
# 921702       0
# 921703       0
# 921704       0
# 921705       0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  \
# 1086402  1948    MCLANE, James Price Jr.       aquatics       0       1     2
# 1044310  1948      CURTIS, Ann Elisabeth       aquatics       0       1     2
# 1121560  1948  WHITFIELD, Malvin Groston      athletics       1       0     2
# 1065364  1948       HENRY, Frank Sherman     equestrian       0       2     1
# 1051724  1948      EWELL, Harold Norwood      athletics       0       2     1
# ...       ...                        ...            ...     ...     ...   ...
# 1024109  1948              ABAS, Stephen      triathlon       0       0     0
# 1024110  1948              ABAS, Stephen     tug of war       0       0     0
# 1024111  1948              ABAS, Stephen     volleyball       0       0     0
# 1024112  1948              ABAS, Stephen  weightlifting       0       0     0
# 1024113  1948              ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1086402      3
# 1044310      3
# 1121560      3
# 1065364      3
# 1051724      3
# ...        ...
# 1024109      0
# 1024110      0
# 1024111      0
# 1024112      0
# 1024113      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  \
# 1178576  1952        KONNO, Ford Hiroshi       aquatics       0       1     2
# 1213428  1952  STANFIELD, Andrew William      athletics       0       0     2
# 1202174  1952            REMIGINO, Lindy      athletics       0       0     2
# 1187450  1952        MCCORMICK, Patricia       aquatics       0       0     2
# 1149882  1952          DILLARD, Harrison      athletics       0       0     2
# ...       ...                        ...            ...     ...     ...   ...
# 1126517  1952              ABAS, Stephen      triathlon       0       0     0
# 1126518  1952              ABAS, Stephen     tug of war       0       0     0
# 1126519  1952              ABAS, Stephen     volleyball       0       0     0
# 1126520  1952              ABAS, Stephen  weightlifting       0       0     0
# 1126521  1952              ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1178576      3
# 1213428      2
# 1202174      2
# 1187450      2
# 1149882      2
# ...        ...
# 1126517      0
# 1126518      0
# 1126519      0
# 1126520      0
# 1126521      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  \
# 1295504  1956    MORROW, Robert Joseph      athletics       0       0     3
# 1232536  1956      BAKER, Walter Thane      athletics       1       1     1
# 1239198  1956     BREEN, George Thomas       aquatics       2       1     0
# 1289858  1956      MCCORMICK, Patricia       aquatics       0       0     2
# 1275410  1956  JENKINS, Charles Lamont      athletics       0       0     2
# ...       ...                      ...            ...     ...     ...   ...
# 1228925  1956            ABAS, Stephen      triathlon       0       0     0
# 1228926  1956            ABAS, Stephen     tug of war       0       0     0
# 1228927  1956            ABAS, Stephen     volleyball       0       0     0
# 1228928  1956            ABAS, Stephen  weightlifting       0       0     0
# 1228929  1956            ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1295504      3
# 1232536      3
# 1239198      3
# 1289858      2
# 1275410      2
# ...        ...
# 1228925      0
# 1228926      0
# 1228927      0
# 1228928      0
# 1228929      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name          Sport  Bronze  Silver  \
# 1425994  1960  VON SALTZA, Susan Christina       aquatics       0       1
# 1409914  1960               RUDOLPH, Wilma      athletics       0       0
# 1423886  1960        TROY, Michael Francis       aquatics       0       0
# 1412564  1960        SCHULER, Carolyn Jane       aquatics       0       0
# 1359388  1960      FARRELL, Felix Geoffrey       aquatics       0       0
# ...       ...                          ...            ...     ...     ...
# 1331333  1960                ABAS, Stephen      triathlon       0       0
# 1331334  1960                ABAS, Stephen     tug of war       0       0
# 1331335  1960                ABAS, Stephen     volleyball       0       0
# 1331336  1960                ABAS, Stephen  weightlifting       0       0
# 1331337  1960                ABAS, Stephen      wrestling       0       0
#
# Medal    Gold  Total
# 1425994     3      4
# 1409914     3      3
# 1423886     2      2
# 1412564     2      2
# 1359388     2      2
# ...       ...    ...
# 1331333     0      0
# 1331334     0      0
# 1331335     0      0
# 1331336     0      0
# 1331337     0      0
#
# [102408 rows x 7 columns]
# Medal    Year                Athlete Name          Sport  Bronze  Silver  \
# 1514564  1964  SCHOLLANDER, Donald Arthur       aquatics       0       0
# 1522282  1964       STOUDER, Sharon Marie       aquatics       0       1
# 1460232  1964             ELLIS, Kathleen       aquatics       2       0
# 1450100  1964       CLARK, Stephen Edward       aquatics       0       0
# 1495424  1964        MCGUIRE, Edith Marie      athletics       0       2
# ...       ...                         ...            ...     ...     ...
# 1433741  1964               ABAS, Stephen      triathlon       0       0
# 1433742  1964               ABAS, Stephen     tug of war       0       0
# 1433743  1964               ABAS, Stephen     volleyball       0       0
# 1433744  1964               ABAS, Stephen  weightlifting       0       0
# 1433745  1964               ABAS, Stephen      wrestling       0       0
#
# Medal    Gold  Total
# 1514564     4      4
# 1522282     3      4
# 1460232     2      4
# 1450100     3      3
# 1495424     1      3
# ...       ...    ...
# 1433741     0      0
# 1433742     0      0
# 1433743     0      0
# 1433744     0      0
# 1433745     0      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  \
# 1577804  1968  HICKCOX, Charles Buchanan       aquatics       0       1     3
# 1608234  1968       PEDERSEN, Susan Jane       aquatics       0       2     2
# 1622412  1968                SPITZ, Mark       aquatics       1       1     2
# 1577294  1968          HENNE, Jane Margo       aquatics       1       1     2
# 1599802  1968             MEYER, Deborah       aquatics       0       0     3
# ...       ...                        ...            ...     ...     ...   ...
# 1536149  1968              ABAS, Stephen      triathlon       0       0     0
# 1536150  1968              ABAS, Stephen     tug of war       0       0     0
# 1536151  1968              ABAS, Stephen     volleyball       0       0     0
# 1536152  1968              ABAS, Stephen  weightlifting       0       0     0
# 1536153  1968              ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1577804      4
# 1608234      4
# 1622412      4
# 1577294      4
# 1599802      3
# ...        ...
# 1536149      0
# 1536150      0
# 1536151      0
# 1536152      0
# 1536153      0
#
# [102408 rows x 7 columns]
# Medal    Year             Athlete Name          Sport  Bronze  Silver  Gold  \
# 1724820  1972              SPITZ, Mark       aquatics       0       0     7
# 1679158  1972  HEIDENREICH, Jerry Alan       aquatics       1       1     2
# 1706562  1972  NEILSON, Alexandra Lynn       aquatics       0       0     3
# 1644818  1972   BELOTE, Melissa Louise       aquatics       0       0     3
# 1725398  1972    STAMM, Michael Eugene       aquatics       0       2     1
# ...       ...                      ...            ...     ...     ...   ...
# 1638557  1972            ABAS, Stephen      triathlon       0       0     0
# 1638558  1972            ABAS, Stephen     tug of war       0       0     0
# 1638559  1972            ABAS, Stephen     volleyball       0       0     0
# 1638560  1972            ABAS, Stephen  weightlifting       0       0     0
# 1638561  1972            ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1724820      7
# 1679158      4
# 1706562      3
# 1644818      3
# 1725398      3
# ...        ...
# 1638557      0
# 1638558      0
# 1638559      0
# 1638560      0
# 1638561      0
#
# [102408 rows x 7 columns]
# Medal    Year               Athlete Name          Sport  Bronze  Silver  Gold  \
# 1808732  1976       NABER, John Phillips       aquatics       0       1     4
# 1744064  1976  BABASHOFF, Shirley Farber       aquatics       0       4     1
# 1806420  1976     MONTGOMERY, James Paul       aquatics       1       0     3
# 1781838  1976    HENCKEN, John Frederick       aquatics       0       1     2
# 1835354  1976      VOGEL, Matthew Haynes       aquatics       0       0     2
# ...       ...                        ...            ...     ...     ...   ...
# 1740965  1976              ABAS, Stephen      triathlon       0       0     0
# 1740966  1976              ABAS, Stephen     tug of war       0       0     0
# 1740967  1976              ABAS, Stephen     volleyball       0       0     0
# 1740968  1976              ABAS, Stephen  weightlifting       0       0     0
# 1740969  1976              ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1808732      5
# 1744064      5
# 1806420      4
# 1781838      3
# 1835354      2
# ...        ...
# 1740965      0
# 1740966      0
# 1740967      0
# 1740968      0
# 1740969      0
#
# [102408 rows x 7 columns]
# Medal    Year           Athlete Name          Sport  Bronze  Silver  Gold  \
# 1919142  1984       RETTON, Mary-Lou     gymnastics       2       2     1
# 1898800  1984            LEWIS, Carl      athletics       0       0     4
# 1886014  1984   HOGSHEAD, Nancy Lynn       aquatics       0       1     3
# 1876234  1984  GAYLORD, Mitchell Jay     gymnastics       2       1     1
# 1906278  1984       MEAGHER, Mary T.       aquatics       0       0     3
# ...       ...                    ...            ...     ...     ...   ...
# 1843373  1984          ABAS, Stephen      triathlon       0       0     0
# 1843374  1984          ABAS, Stephen     tug of war       0       0     0
# 1843375  1984          ABAS, Stephen     volleyball       0       0     0
# 1843376  1984          ABAS, Stephen  weightlifting       0       0     0
# 1843377  1984          ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 1919142      5
# 1898800      4
# 1886014      4
# 1876234      4
# 1906278      3
# ...        ...
# 1843373      0
# 1843374      0
# 1843375      0
# 1843376      0
# 1843377      0
#
# [102408 rows x 7 columns]
# Medal    Year                 Athlete Name          Sport  Bronze  Silver  \
# 1953334  1988              BIONDI, Matthew       aquatics       1       1
# 1982168  1988    GRIFFITH-JOYNER, Florence      athletics       0       1
# 1973088  1988                 EVANS, Janet       aquatics       0       0
# 2001208  1988                  LEWIS, Carl      athletics       0       1
# 1991142  1988  JACOBS, Christopher Charles       aquatics       0       1
# ...       ...                          ...            ...     ...     ...
# 1945781  1988                ABAS, Stephen      triathlon       0       0
# 1945782  1988                ABAS, Stephen     tug of war       0       0
# 1945783  1988                ABAS, Stephen     volleyball       0       0
# 1945784  1988                ABAS, Stephen  weightlifting       0       0
# 1945785  1988                ABAS, Stephen      wrestling       0       0
#
# Medal    Gold  Total
# 1953334     5      7
# 1982168     3      4
# 1973088     3      3
# 2001208     2      3
# 1991142     2      3
# ...       ...    ...
# 1945781     0      0
# 1945782     0      0
# 1945783     0      0
# 1945784     0      0
# 1945785     0      0
#
# [102408 rows x 7 columns]
# Medal    Year          Athlete Name          Sport  Bronze  Silver  Gold  \
# 2112636  1992       MILLER, Shannon     gymnastics       3       2     0
# 2127856  1992       SANDERS, Summer       aquatics       1       1     2
# 2085424  1992  HAISLETT, Nicole Lee       aquatics       0       0     3
# 2140166  1992        TORRENCE, Gwen      athletics       0       1     2
# 2139178  1992       THOMPSON, Jenny       aquatics       0       1     2
# ...       ...                   ...            ...     ...     ...   ...
# 2048189  1992         ABAS, Stephen      triathlon       0       0     0
# 2048190  1992         ABAS, Stephen     tug of war       0       0     0
# 2048191  1992         ABAS, Stephen     volleyball       0       0     0
# 2048192  1992         ABAS, Stephen  weightlifting       0       0     0
# 2048193  1992         ABAS, Stephen      wrestling       0       0     0
#
# Medal    Total
# 2112636      5
# 2127856      4
# 2085424      3
# 2140166      3
# 2139178      3
# ...        ...
# 2048189      0
# 2048190      0
# 2048191      0
# 2048192      0
# 2048193      0
#
# [102408 rows x 7 columns]
# Medal    Year     Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2244204  1996   VAN DYKEN, Amy       aquatics       0       0     4      4
# 2188206  1996   HALL, Gary Jr.       aquatics       0       2     2      4
# 2210068  1996   MARTINO, Angel       aquatics       2       0     2      4
# 2241586  1996  THOMPSON, Jenny       aquatics       0       0     3      3
# 2172022  1996      DAVIS, Josh       aquatics       0       0     3      3
# ...       ...              ...            ...     ...     ...   ...    ...
# 2150597  1996    ABAS, Stephen      triathlon       0       0     0      0
# 2150598  1996    ABAS, Stephen     tug of war       0       0     0      0
# 2150599  1996    ABAS, Stephen     volleyball       0       0     0      0
# 2150600  1996    ABAS, Stephen  weightlifting       0       0     0      0
# 2150601  1996    ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year        Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2345014  2000        TORRES, Dara       aquatics       3       0     2      5
# 2343994  2000     THOMPSON, Jenny       aquatics       1       0     3      4
# 2290614  2000      HALL, Gary Jr.       aquatics       1       1     2      4
# 2305540  2000  KRAYZELBURG, Lenny       aquatics       0       0     3      3
# 2352250  2000     WILLIAMS, Venus         tennis       0       0     2      2
# ...       ...                 ...            ...     ...     ...   ...    ...
# 2253005  2000       ABAS, Stephen      triathlon       0       0     0      0
# 2253006  2000       ABAS, Stephen     tug of war       0       0     0      0
# 2253007  2000       ABAS, Stephen     volleyball       0       0     0      0
# 2253008  2000       ABAS, Stephen  weightlifting       0       0     0      0
# 2253009  2000       ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2428246  2004    PHELPS, Michael       aquatics       2       0     6      8
# 2374220  2004  COUGHLIN, Natalie       aquatics       1       2     2      5
# 2427566  2004     PEIRSOL, Aaron       aquatics       0       0     3      3
# 2427000  2004   PATTERSON, Carly     gymnastics       0       2     1      3
# 2393476  2004         HAMM, Paul     gymnastics       0       2     1      3
# ...       ...                ...            ...     ...     ...   ...    ...
# 2355412  2004      ABAS, Stephen         tennis       0       0     0      0
# 2355413  2004      ABAS, Stephen      triathlon       0       0     0      0
# 2355414  2004      ABAS, Stephen     tug of war       0       0     0      0
# 2355415  2004      ABAS, Stephen     volleyball       0       0     0      0
# 2355416  2004      ABAS, Stephen  weightlifting       0       0     0      0
#
# [102408 rows x 7 columns]
# Medal    Year       Athlete Name          Sport  Bronze  Silver  Gold  Total
# 2530654  2008    PHELPS, Michael       aquatics       0       0     8      8
# 2476628  2008  COUGHLIN, Natalie       aquatics       3       2     1      6
# 2514142  2008     LIUKIN, Nastia     gymnastics       1       3     1      5
# 2514368  2008       LOCHTE, Ryan       aquatics       2       0     2      4
# 2505642  2008     JOHNSON, Shawn     gymnastics       0       3     1      4
# ...       ...                ...            ...     ...     ...   ...    ...
# 2457821  2008      ABAS, Stephen      triathlon       0       0     0      0
# 2457822  2008      ABAS, Stephen     tug of war       0       0     0      0
# 2457823  2008      ABAS, Stephen     volleyball       0       0     0      0
# 2457824  2008      ABAS, Stephen  weightlifting       0       0     0      0
# 2457825  2008      ABAS, Stephen      wrestling       0       0     0      0
#
# [102408 rows x 7 columns]

# %%
for year, group in table.groupby('Year'):
  print(group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False).head(1))
# Out:
# Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert  athletics       0       2     2      4
# Medal   Year    Athlete Name      Sport  Bronze  Silver  Gold  Total
# 107612  1900  BAXTER, Irving  athletics       0       3     2      5
# Medal   Year  Athlete Name       Sport  Bronze  Silver  Gold  Total
# 245424  1904  HEIDA, Anton  gymnastics       0       1     5      6
# Medal   Year      Athlete Name      Sport  Bronze  Silver  Gold  Total
# 390390  1908  SHEPPARD, Melvin  athletics       0       0     3      3
# Medal   Year           Athlete Name     Sport  Bronze  Silver  Gold  Total
# 480240  1912  OSBURN, Carl Townsend  shooting       1       2     1      4
# Medal   Year Athlete Name     Sport  Bronze  Silver  Gold  Total
# 566940  1920  LEE, Willis  shooting       1       1     5      7
# Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 710940  1924  WEISSMULLER, Johnny  aquatics       1       0     3      4
# Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 813348  1928  WEISSMULLER, Johnny  aquatics       0       0     2      2
# Medal   Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 877370  1932  MADISON, Helene  aquatics       0       0     3      3
# Medal   Year  Athlete Name      Sport  Bronze  Silver  Gold  Total
# 992530  1936  OWENS, Jesse  athletics       0       0     4      4
# Medal    Year             Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1086402  1948  MCLANE, James Price Jr.  aquatics       0       1     2      3
# Medal    Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1178576  1952  KONNO, Ford Hiroshi  aquatics       0       1     2      3
# Medal    Year           Athlete Name      Sport  Bronze  Silver  Gold  Total
# 1295504  1956  MORROW, Robert Joseph  athletics       0       0     3      3
# Medal    Year                 Athlete Name     Sport  Bronze  Silver  Gold  \
# 1425994  1960  VON SALTZA, Susan Christina  aquatics       0       1     3
#
# Medal    Total
# 1425994      4
# Medal    Year                Athlete Name     Sport  Bronze  Silver  Gold  \
# 1514564  1964  SCHOLLANDER, Donald Arthur  aquatics       0       0     4
#
# Medal    Total
# 1514564      4
# Medal    Year               Athlete Name     Sport  Bronze  Silver  Gold  \
# 1577804  1968  HICKCOX, Charles Buchanan  aquatics       0       1     3
#
# Medal    Total
# 1577804      4
# Medal    Year Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1724820  1972  SPITZ, Mark  aquatics       0       0     7      7
# Medal    Year          Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1808732  1976  NABER, John Phillips  aquatics       0       1     4      5
# Medal    Year      Athlete Name       Sport  Bronze  Silver  Gold  Total
# 1919142  1984  RETTON, Mary-Lou  gymnastics       2       2     1      5
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 1953334  1988  BIONDI, Matthew  aquatics       1       1     5      7
# Medal    Year     Athlete Name       Sport  Bronze  Silver  Gold  Total
# 2112636  1992  MILLER, Shannon  gymnastics       3       2     0      5
# Medal    Year    Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2244204  1996  VAN DYKEN, Amy  aquatics       0       0     4      4
# Medal    Year  Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2345014  2000  TORRES, Dara  aquatics       3       0     2      5
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2428246  2004  PHELPS, Michael  aquatics       2       0     6      8
# Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
# 2530654  2008  PHELPS, Michael  aquatics       0       0     8      8

# %%
winners = [
    group.sort_values(['Total', 'Gold', 'Silver', 'Bronze', 'Athlete Name'], ascending=False).head(1)
    for year, group in table.groupby('Year')
]
winners
# Out:
# [Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
#  32642  1896  GARRETT, Robert  athletics       0       2     2      4,
#  Medal   Year    Athlete Name      Sport  Bronze  Silver  Gold  Total
#  107612  1900  BAXTER, Irving  athletics       0       3     2      5,
#  Medal   Year  Athlete Name       Sport  Bronze  Silver  Gold  Total
#  245424  1904  HEIDA, Anton  gymnastics       0       1     5      6,
#  Medal   Year      Athlete Name      Sport  Bronze  Silver  Gold  Total
#  390390  1908  SHEPPARD, Melvin  athletics       0       0     3      3,
#  Medal   Year           Athlete Name     Sport  Bronze  Silver  Gold  Total
#  480240  1912  OSBURN, Carl Townsend  shooting       1       2     1      4,
#  Medal   Year Athlete Name     Sport  Bronze  Silver  Gold  Total
#  566940  1920  LEE, Willis  shooting       1       1     5      7,
#  Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  710940  1924  WEISSMULLER, Johnny  aquatics       1       0     3      4,
#  Medal   Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  813348  1928  WEISSMULLER, Johnny  aquatics       0       0     2      2,
#  Medal   Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  877370  1932  MADISON, Helene  aquatics       0       0     3      3,
#  Medal   Year  Athlete Name      Sport  Bronze  Silver  Gold  Total
#  992530  1936  OWENS, Jesse  athletics       0       0     4      4,
#  Medal    Year             Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1086402  1948  MCLANE, James Price Jr.  aquatics       0       1     2      3,
#  Medal    Year         Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1178576  1952  KONNO, Ford Hiroshi  aquatics       0       1     2      3,
#  Medal    Year           Athlete Name      Sport  Bronze  Silver  Gold  Total
#  1295504  1956  MORROW, Robert Joseph  athletics       0       0     3      3,
#  Medal    Year                 Athlete Name     Sport  Bronze  Silver  Gold  \
#  1425994  1960  VON SALTZA, Susan Christina  aquatics       0       1     3
#
#  Medal    Total
#  1425994      4  ,
#  Medal    Year                Athlete Name     Sport  Bronze  Silver  Gold  \
#  1514564  1964  SCHOLLANDER, Donald Arthur  aquatics       0       0     4
#
#  Medal    Total
#  1514564      4  ,
#  Medal    Year               Athlete Name     Sport  Bronze  Silver  Gold  \
#  1577804  1968  HICKCOX, Charles Buchanan  aquatics       0       1     3
#
#  Medal    Total
#  1577804      4  ,
#  Medal    Year Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1724820  1972  SPITZ, Mark  aquatics       0       0     7      7,
#  Medal    Year          Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1808732  1976  NABER, John Phillips  aquatics       0       1     4      5,
#  Medal    Year      Athlete Name       Sport  Bronze  Silver  Gold  Total
#  1919142  1984  RETTON, Mary-Lou  gymnastics       2       2     1      5,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  1953334  1988  BIONDI, Matthew  aquatics       1       1     5      7,
#  Medal    Year     Athlete Name       Sport  Bronze  Silver  Gold  Total
#  2112636  1992  MILLER, Shannon  gymnastics       3       2     0      5,
#  Medal    Year    Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2244204  1996  VAN DYKEN, Amy  aquatics       0       0     4      4,
#  Medal    Year  Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2345014  2000  TORRES, Dara  aquatics       3       0     2      5,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2428246  2004  PHELPS, Michael  aquatics       2       0     6      8,
#  Medal    Year     Athlete Name     Sport  Bronze  Silver  Gold  Total
#  2530654  2008  PHELPS, Michael  aquatics       0       0     8      8]

# %%
winners[0]
# Out:
# Medal  Year     Athlete Name      Sport  Bronze  Silver  Gold  Total
# 32642  1896  GARRETT, Robert  athletics       0       2     2      4

# %%
type(winners[0])
# Out:
# pandas.core.frame.DataFrame

# %%
pd.concat(winners)
# Out:
# Medal    Year                 Athlete Name       Sport  Bronze  Silver  Gold  \
# 32642    1896              GARRETT, Robert   athletics       0       2     2
# 107612   1900               BAXTER, Irving   athletics       0       3     2
# 245424   1904                 HEIDA, Anton  gymnastics       0       1     5
# 390390   1908             SHEPPARD, Melvin   athletics       0       0     3
# 480240   1912        OSBURN, Carl Townsend    shooting       1       2     1
# 566940   1920                  LEE, Willis    shooting       1       1     5
# 710940   1924          WEISSMULLER, Johnny    aquatics       1       0     3
# 813348   1928          WEISSMULLER, Johnny    aquatics       0       0     2
# 877370   1932              MADISON, Helene    aquatics       0       0     3
# 992530   1936                 OWENS, Jesse   athletics       0       0     4
# 1086402  1948      MCLANE, James Price Jr.    aquatics       0       1     2
# 1178576  1952          KONNO, Ford Hiroshi    aquatics       0       1     2
# 1295504  1956        MORROW, Robert Joseph   athletics       0       0     3
# 1425994  1960  VON SALTZA, Susan Christina    aquatics       0       1     3
# 1514564  1964   SCHOLLANDER, Donald Arthur    aquatics       0       0     4
# 1577804  1968    HICKCOX, Charles Buchanan    aquatics       0       1     3
# 1724820  1972                  SPITZ, Mark    aquatics       0       0     7
# 1808732  1976         NABER, John Phillips    aquatics       0       1     4
# 1919142  1984             RETTON, Mary-Lou  gymnastics       2       2     1
# 1953334  1988              BIONDI, Matthew    aquatics       1       1     5
# 2112636  1992              MILLER, Shannon  gymnastics       3       2     0
# 2244204  1996               VAN DYKEN, Amy    aquatics       0       0     4
# 2345014  2000                 TORRES, Dara    aquatics       3       0     2
# 2428246  2004              PHELPS, Michael    aquatics       2       0     6
# 2530654  2008              PHELPS, Michael    aquatics       0       0     8
#
# Medal    Total
# 32642        4
# 107612       5
# 245424       6
# 390390       3
# 480240       4
# 566940       7
# 710940       4
# 813348       2
# 877370       3
# 992530       4
# 1086402      3
# 1178576      3
# 1295504      3
# 1425994      4
# 1514564      4
# 1577804      4
# 1724820      7
# 1808732      5
# 1919142      5
# 1953334      7
# 2112636      5
# 2244204      4
# 2345014      5
# 2428246      8
# 2530654      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]]
# Out:
# Medal    Year                 Athlete Name       Sport  Total
# 32642    1896              GARRETT, Robert   athletics      4
# 107612   1900               BAXTER, Irving   athletics      5
# 245424   1904                 HEIDA, Anton  gymnastics      6
# 390390   1908             SHEPPARD, Melvin   athletics      3
# 480240   1912        OSBURN, Carl Townsend    shooting      4
# 566940   1920                  LEE, Willis    shooting      7
# 710940   1924          WEISSMULLER, Johnny    aquatics      4
# 813348   1928          WEISSMULLER, Johnny    aquatics      2
# 877370   1932              MADISON, Helene    aquatics      3
# 992530   1936                 OWENS, Jesse   athletics      4
# 1086402  1948      MCLANE, James Price Jr.    aquatics      3
# 1178576  1952          KONNO, Ford Hiroshi    aquatics      3
# 1295504  1956        MORROW, Robert Joseph   athletics      3
# 1425994  1960  VON SALTZA, Susan Christina    aquatics      4
# 1514564  1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 1577804  1968    HICKCOX, Charles Buchanan    aquatics      4
# 1724820  1972                  SPITZ, Mark    aquatics      7
# 1808732  1976         NABER, John Phillips    aquatics      5
# 1919142  1984             RETTON, Mary-Lou  gymnastics      5
# 1953334  1988              BIONDI, Matthew    aquatics      7
# 2112636  1992              MILLER, Shannon  gymnastics      5
# 2244204  1996               VAN DYKEN, Amy    aquatics      4
# 2345014  2000                 TORRES, Dara    aquatics      5
# 2428246  2004              PHELPS, Michael    aquatics      8
# 2530654  2008              PHELPS, Michael    aquatics      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index()
# Out:
# Medal    index  Year                 Athlete Name       Sport  Total
# 0        32642  1896              GARRETT, Robert   athletics      4
# 1       107612  1900               BAXTER, Irving   athletics      5
# 2       245424  1904                 HEIDA, Anton  gymnastics      6
# 3       390390  1908             SHEPPARD, Melvin   athletics      3
# 4       480240  1912        OSBURN, Carl Townsend    shooting      4
# 5       566940  1920                  LEE, Willis    shooting      7
# 6       710940  1924          WEISSMULLER, Johnny    aquatics      4
# 7       813348  1928          WEISSMULLER, Johnny    aquatics      2
# 8       877370  1932              MADISON, Helene    aquatics      3
# 9       992530  1936                 OWENS, Jesse   athletics      4
# 10     1086402  1948      MCLANE, James Price Jr.    aquatics      3
# 11     1178576  1952          KONNO, Ford Hiroshi    aquatics      3
# 12     1295504  1956        MORROW, Robert Joseph   athletics      3
# 13     1425994  1960  VON SALTZA, Susan Christina    aquatics      4
# 14     1514564  1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 15     1577804  1968    HICKCOX, Charles Buchanan    aquatics      4
# 16     1724820  1972                  SPITZ, Mark    aquatics      7
# 17     1808732  1976         NABER, John Phillips    aquatics      5
# 18     1919142  1984             RETTON, Mary-Lou  gymnastics      5
# 19     1953334  1988              BIONDI, Matthew    aquatics      7
# 20     2112636  1992              MILLER, Shannon  gymnastics      5
# 21     2244204  1996               VAN DYKEN, Amy    aquatics      4
# 22     2345014  2000                 TORRES, Dara    aquatics      5
# 23     2428246  2004              PHELPS, Michael    aquatics      8
# 24     2530654  2008              PHELPS, Michael    aquatics      8

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index?
# Out:
# Object `reset_index` not found.

# %%
pd.DataFrame.reset_index?
# Out:
# Signature:
# pd.DataFrame.reset_index(
#     self,
#     level: 'IndexLabel | None' = None,
#     *,
#     drop: 'bool' = False,
#     inplace: 'bool' = False,
#     col_level: 'Hashable' = 0,
#     col_fill: 'Hashable' = '',
#     allow_duplicates: 'bool | lib.NoDefault' = <no_default>,
#     names: 'Hashable | Sequence[Hashable] | None' = None,
# ) -> 'DataFrame | None'
# Docstring:
# Reset the index, or a level of it.
#
# Reset the index of the DataFrame, and use the default one instead.
# If the DataFrame has a MultiIndex, this method can remove one or more
# levels.
#
# Parameters
# ----------
# level : int, str, tuple, or list, default None
#     Only remove the given levels from the index. Removes all levels by
#     default.
# drop : bool, default False
#     Do not try to insert index into dataframe columns. This resets
#     the index to the default integer index.
# inplace : bool, default False
#     Whether to modify the DataFrame rather than creating a new one.
# col_level : int or str, default 0
#     If the columns have multiple levels, determines which level the
#     labels are inserted into. By default it is inserted into the first
#     level.
# col_fill : object, default ''
#     If the columns have multiple levels, determines how the other
#     levels are named. If None then the index name is repeated.
# allow_duplicates : bool, optional, default lib.no_default
#     Allow duplicate column labels to be created.
#
#     .. versionadded:: 1.5.0
#
# names : int, str or 1-dimensional list, default None
#     Using the given string, rename the DataFrame column which contains the
#     index data. If the DataFrame has a MultiIndex, this has to be a list or
#     tuple with length equal to the number of levels.
#
#     .. versionadded:: 1.5.0
#
# Returns
# -------
# DataFrame or None
#     DataFrame with the new index or None if ``inplace=True``.
#
# See Also
# --------
# DataFrame.set_index : Opposite of reset_index.
# DataFrame.reindex : Change to new indices or expand indices.
# DataFrame.reindex_like : Change to same indices as other DataFrame.
#
# Examples
# --------
# >>> df = pd.DataFrame([('bird', 389.0),
# ...                    ('bird', 24.0),
# ...                    ('mammal', 80.5),
# ...                    ('mammal', np.nan)],
# ...                   index=['falcon', 'parrot', 'lion', 'monkey'],
# ...                   columns=('class', 'max_speed'))
# >>> df
#          class  max_speed
# falcon    bird      389.0
# parrot    bird       24.0
# lion    mammal       80.5
# monkey  mammal        NaN
#
# When we reset the index, the old index is added as a column, and a
# new sequential index is used:
#
# >>> df.reset_index()
#     index   class  max_speed
# 0  falcon    bird      389.0
# 1  parrot    bird       24.0
# 2    lion  mammal       80.5
# 3  monkey  mammal        NaN
#
# We can use the `drop` parameter to avoid the old index being added as
# a column:
#
# >>> df.reset_index(drop=True)
#     class  max_speed
# 0    bird      389.0
# 1    bird       24.0
# 2  mammal       80.5
# 3  mammal        NaN
#
# You can also use `reset_index` with `MultiIndex`.
#
# >>> index = pd.MultiIndex.from_tuples([('bird', 'falcon'),
# ...                                    ('bird', 'parrot'),
# ...                                    ('mammal', 'lion'),
# ...                                    ('mammal', 'monkey')],
# ...                                   names=['class', 'name'])
# >>> columns = pd.MultiIndex.from_tuples([('speed', 'max'),
# ...                                      ('species', 'type')])
# >>> df = pd.DataFrame([(389.0, 'fly'),
# ...                    (24.0, 'fly'),
# ...                    (80.5, 'run'),
# ...                    (np.nan, 'jump')],
# ...                   index=index,
# ...                   columns=columns)
# >>> df
#                speed species
#                  max    type
# class  name
# bird   falcon  389.0     fly
#        parrot   24.0     fly
# mammal lion     80.5     run
#        monkey    NaN    jump
#
# Using the `names` parameter, choose a name for the index column:
#
# >>> df.reset_index(names=['classes', 'names'])
#   classes   names  speed species
#                      max    type
# 0    bird  falcon  389.0     fly
# 1    bird  parrot   24.0     fly
# 2  mammal    lion   80.5     run
# 3  mammal  monkey    NaN    jump
#
# If the index has multiple levels, we can reset a subset of them:
#
# >>> df.reset_index(level='class')
#          class  speed species
#                   max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump
#
# If we are not dropping the index, by default, it is placed in the top
# level. We can place it in another level:
#
# >>> df.reset_index(level='class', col_level=1)
#                 speed species
#          class    max    type
# name
# falcon    bird  389.0     fly
# parrot    bird   24.0     fly
# lion    mammal   80.5     run
# monkey  mammal    NaN    jump
#
# When the index is inserted under another level, we can specify under
# which one with the parameter `col_fill`:
#
# >>> df.reset_index(level='class', col_level=1, col_fill='species')
#               species  speed species
#                 class    max    type
# name
# falcon           bird  389.0     fly
# parrot           bird   24.0     fly
# lion           mammal   80.5     run
# monkey         mammal    NaN    jump
#
# If we specify a nonexistent level for `col_fill`, it is created:
#
# >>> df.reset_index(level='class', col_level=1, col_fill='genus')
#                 genus  speed species
#                 class    max    type
# name
# falcon           bird  389.0     fly
# parrot           bird   24.0     fly
# lion           mammal   80.5     run
# monkey         mammal    NaN    jump
# File:      ~/code/pandas-esst/linkedin/lib/python3.9/site-packages/pandas/core/frame.py
# Type:      function

# %%
pd.concat(winners)[["Year",	"Athlete Name",	"Sport", "Total"]].reset_index(drop=True)
# Out:
# Medal  Year                 Athlete Name       Sport  Total
# 0      1896              GARRETT, Robert   athletics      4
# 1      1900               BAXTER, Irving   athletics      5
# 2      1904                 HEIDA, Anton  gymnastics      6
# 3      1908             SHEPPARD, Melvin   athletics      3
# 4      1912        OSBURN, Carl Townsend    shooting      4
# 5      1920                  LEE, Willis    shooting      7
# 6      1924          WEISSMULLER, Johnny    aquatics      4
# 7      1928          WEISSMULLER, Johnny    aquatics      2
# 8      1932              MADISON, Helene    aquatics      3
# 9      1936                 OWENS, Jesse   athletics      4
# 10     1948      MCLANE, James Price Jr.    aquatics      3
# 11     1952          KONNO, Ford Hiroshi    aquatics      3
# 12     1956        MORROW, Robert Joseph   athletics      3
# 13     1960  VON SALTZA, Susan Christina    aquatics      4
# 14     1964   SCHOLLANDER, Donald Arthur    aquatics      4
# 15     1968    HICKCOX, Charles Buchanan    aquatics      4
# 16     1972                  SPITZ, Mark    aquatics      7
# 17     1976         NABER, John Phillips    aquatics      5
# 18     1984             RETTON, Mary-Lou  gymnastics      5
# 19     1988              BIONDI, Matthew    aquatics      7
# 20     1992              MILLER, Shannon  gymnastics      5
# 21     1996               VAN DYKEN, Amy    aquatics      4
# 22     2000                 TORRES, Dara    aquatics      5
# 23     2004              PHELPS, Michael    aquatics      8
# 24     2008              PHELPS, Michael    aquatics      8

# %%
#SDG
