# %% [markdown]
# ### Global Jukebox Data
#
# The **Global Jukebox** (https://www.theglobaljukebox.org/) builds on the legacy of Alan Lomax's Cantometrics project. Anna Wood (Lomax's daughter and director of the GJ) has generously agreed to help us work with their data, and is very interested to include the results of student work in their publications.
#
# You will need to **create a login with GJ** for the best results
#
# Anna has suggested we work on **Lullabies**, which afford some interesting possibilities for study.  **Read her advice** here: 'https://docs.google.com/document/d/1S1M5p9Zfkdft5IQlTM0p-liNrNj83yh6UeQ1yL6TtfY/edit?usp=sharing'
#
# Read more about Cantometrics and the GJ here:  https://drive.google.com/file/d/1uY9jZ0dQd5Wmxg2zD-3bDFopFdzmW91h/view?usp=share_link
#
# The is also an important **print publication about the Cantometrics** method on reserve for Music 255 in the Harris Music Library

# %%
import os
# from decouple import AutoConfig # Install python-decouple
import requests # Install requests
import pandas as pd
import plotly as plt
from itertools import combinations
import numpy as np

# %% [markdown]
# ### GJ Data are on Github in a series of CSV files
#
# - **Canto** = the ratings for the individual songs, with about 40 different musical features in all
# - **Societies** = data about the ethnic and social groups represented in the survey.  These are linked to the Canto data via group ids
# - **Songs** = data about the songs themselves, also with data about the societies, but in addition information about the source recording and genres they represent
# - **Codes** = for each music feature, there are (at least) about a dozen possible ratings.  They are given as integers but really represent categories as explained in this dataset
# - **Raw Codes** = Since each song can in fact have more than one 'musical code' associated with it (as when it's slow at the start but fast at the end), the GJ team in fact uses a sophisticated system to encode more than one code with a single integer.  See below on this Power of 2 method.
# - **Lines Explained** = detailed explanation of the categories of musical features (texture, rhythm, melody, timbre, etc).  Read about these here: 'https://docs.google.com/document/d/1Ga7qxbWV1UaD8wPABYORpJc2_4WPwimIv-zQCbl_v0U/edit?usp=sharing'

# %%
# List of URLs to the data files
data_files_list = [
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/raw/data.csv',
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/raw/societies.csv',
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/raw/songs.csv',
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/etc/codes.csv',
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/etc/variables.csv',
    'https://raw.githubusercontent.com/theglobaljukebox/cantometrics/main/etc/raw_codes.csv'
]

# Short names for DataFrames
short_names = ['canto', 'societies', 'songs', 'codes', 'lines_explained', 'raw_codes']

# Initialize empty variables for each DataFrame
canto = None
societies = None
songs = None
codes = None
lines_explained = None
raw_codes = None

# Loop through the list of URLs and short names
for url, short_name in zip(data_files_list, short_names):
    # Read the CSV file from the URL into a DataFrame
    df = pd.read_csv(url)
    
    # Replace non-breaking spaces in column names with regular spaces
    df.columns = df.columns.str.replace('\xa0', ' ')
    
    # Iterate over each column to replace non-breaking spaces in cell values
    for col in df.columns:
        # Check if the column contains string values
        if df[col].dtype == 'object':
            df[col] = df[col].str.replace('\xa0', ' ')
    
    # Assign the modified DataFrame to the corresponding variable
    globals()[short_name] = df

# Now, you can access each DataFrame directly by its variable name
# print(canto.head())
# print(societies.head())
# print(songs.head())
# print(codes.head())
# print(lines_explained.head())
# print(raw_codes.head())

# %%
canto
# Out:
#       song_id          Preferred_name  society_id  line_1  line_2  line_3  \
# 0        4241                'Are'are       10000      64       2       2
# 1        4246                'Are'are       10000      64    4096    8192
# 2       30075                'Are'are       10000    8208       2       2
# 3       30120                'Are'are       10000    8208       2       2
# 4       30121                'Are'are       10000      32       2       2
# ...       ...                     ...         ...     ...     ...     ...
# 5771      364       Hokkaido Japanese       62554       4     256       4
# 5772      183          Eastern Ojibwa       62555       4       4       4
# 5773      180  Gayogo̱hó꞉nǫʼ (Cayuga)       62556     256       4      64
# 5774      181  Gayogo̱hó꞉nǫʼ (Cayuga)       62556     256       4       4
# 5775     1238  Gayogo̱hó꞉nǫʼ (Cayuga)       62556     256     256       4
#
#       line_4  line_5  line_6  line_7  ...  line_28  line_29  line_30  line_31  \
# 0       8192    1024    1024       2  ...      512      128       16     8192
# 1        128    8192    8192    8192  ...     8192        2     8192      128
# 2       8192    8192    1024       2  ...      512        2     1024     8192
# 3       8192    1024    1024       2  ...       32        2      128     8192
# 4       8192    1024    1024       2  ...       32      128      128     8192
# ...      ...     ...     ...     ...  ...      ...      ...      ...      ...
# 5771      16       2       2      16  ...      512        2        2        2
# 5772      16       2       2      16  ...     8192     8192        2      128
# 5773     128     128    1024     128  ...     8192     8192     1024        2
# 5774     128     128     128      16  ...       32     8192     1024      128
# 5775     128     128     128      16  ...      512      128     8192      128
#
#       line_32  line_33  line_34  line_35  line_36  line_37
# 0        1024     1024       16      128     1024      128
# 1        1024     8192       16     1024     1024     8192
# 2         144     1024     8192     8192     8192     8192
# 3         128      256     1024     8192     8192     1024
# 4         128      256     1024     8192     8192     1024
# ...       ...      ...      ...      ...      ...      ...
# 5771     1024        8       16     1024     1024      128
# 5772      128      256       16       16     1024      128
# 5773     1024       64      128       16        2     1024
# 5774     1024     1024       16      128        2      128
# 5775      128      256      128      128       16      128
#
# [5776 rows x 40 columns]

# %%
ordinals = lines_explained[lines_explained['type'] == 'Ordinal']
ordinals.drop(['units', 'source', 'changes', 'notes', 'short_title'], axis=1)
# Out:
#          id                category                                   title  \
# 4    line_5    Musical organization          Tonal blend of the vocal group
# 6    line_7    Musical organization   Musical organization of the orchestra
# 7    line_8    Musical organization            Tonal blend of the orchestra
# 8    line_9               Orchestra  Rhythmic coordination of the orchestra
# 15  line_16            Melodic form                            Melodic form
# 16  line_17        Metrical pattern                           Phrase length
# 17  line_18            Melodic form                       Number of phrases
# 18  line_19            Articulation                  Position of final tone
# 19  line_20  Musical characterstics                           Melodic range
# 20  line_21            Articulation                           Interval size
# 22  line_23                Ornament                           Embellishment
# 23  line_24                Dynamics                                   Tempo
# 24  line_25                Dynamics                                  Volume
# 25  line_26        Metrical pattern                           Rubato: vocal
# 26  line_27        Metrical pattern                       Rubato: orchestra
# 27  line_28                Ornament                               Glissando
# 28  line_29                Ornament                                 Melisma
# 29  line_30                Ornament                                 Tremolo
# 30  line_31                Ornament                                 Glottal
# 31  line_32                Dynamics                  Vocal pitch (register)
# 32  line_33             Vocal noise                             Vocal width
# 33  line_34             Vocal noise                                Nasality
# 34  line_35             Vocal noise                                    Rasp
# 35  line_36                Dynamics                                  Accent
# 36  line_37            Articulation                             Enunciation
#
#                                            definition     type
# 4   Both diffuse and cohesive sounds are pleasing ...  Ordinal
# 6   Overall musical coordination amongst members o...  Ordinal
# 7   The concept of tonal blend applies to orchestr...  Ordinal
# 8   Rates the degree of rhythmic coordination betw...  Ordinal
# 15  Line 16 is an attempt to deal succinctly with ...  Ordinal
# 16  A simple five-point scale is used to describe ...  Ordinal
# 17  Determine the number of melodic phrases that o...  Ordinal
# 18  The relation of the final note to the total ra...  Ordinal
# 19  This is a method of judging the total melodic ...  Ordinal
# 20  An interval is the distance in pitch between t...  Ordinal
# 22  Embellishment is one of several devices used b...  Ordinal
# 23  As employed in Cantometrics, tempo is based on...  Ordinal
# 24  Volume measures the relative degree of loudnes...  Ordinal
# 25  A judgment about how strictly tempo is maintai...  Ordinal
# 26  A judgment about how strictly tempo is maintai...  Ordinal
# 27  Glissando is the effect created when the voice...  Ordinal
# 28  The same syllable of text sung to two or more ...  Ordinal
# 29  Tremolo is a quavering or shaking in the voice...  Ordinal
# 30  Glottal articulation is the product of noticea...  Ordinal
# 31  Vocal pitch refers to the tonal height, or fre...  Ordinal
# 32  This measure concerns the contrast between voi...  Ordinal
# 33  A nasalized tone is a strong marker of some si...  Ordinal
# 34  Rasp is frequently associated with very marked...  Ordinal
# 35  Accent is heard as the dynamic attack on sung ...  Ordinal
# 36  Employing a scale of five degrees, this measur...  Ordinal

# %%
categoricals = lines_explained[lines_explained['type'] == 'Categorical']
categoricals.drop(['units', 'source', 'changes', 'notes', 'short_title'], axis=1)
# Out:
#          id                category  \
# 0    line_1     Social organization
# 1    line_2               Orchestra
# 2    line_3               Orchestra
# 3    line_4    Musical organization
# 5    line_6    Musical organization
# 9   line_10     Social organization
# 10  line_11        Metrical pattern
# 11  line_12   Rhythmic relationship
# 12  line_13        Metrical pattern
# 13  line_14   Rhythmic relationship
# 14  line_15            Melodic form
# 21  line_22  Musical characterstics
#
#                                            title  \
# 0     The social organization of the vocal group
# 1       Relationship of orchestra to vocal parts
# 2           Social organization of the orchestra
# 3         Musical organization of the vocal part
# 5       Rhythmic coordination of the vocal group
# 9                             Repetition of text
# 10                         Overall rhythm: vocal
# 11  Rhythmic relationship within the vocal group
# 12                     Overall rhythm: orchestra
# 13    Rhythmic relationship within the orchestra
# 14                                 Melodic shape
# 21                               Polyphonic type
#
#                                            definition         type
# 0   This line describes the social organization of...  Categorical
# 1   The term “orchestra” refers to the performers ...  Categorical
# 2   Line 3 and Line 1 (Social Organization of the ...  Categorical
# 3   The musical coordination amongst the singers i...  Categorical
# 5   The degree of rhythmic coordination between me...  Categorical
# 9   Listening to the text as it is performed, cons...  Categorical
# 10  In most musical styles, the performer or perfo...  Categorical
# 11  Singing groups establish their rhythmic activi...  Categorical
# 12  In most musical styles, the performer or perfo...  Categorical
# 13  The various types of relationships between the...  Categorical
# 14  The characteristic contours of the vocal line ...  Categorical
# 21  This measure considers the use of simultaneous...  Categorical

# %%
lines_explained['category'].unique().tolist()
# Out:
# ['Social organization',
#  'Orchestra',
#  'Musical organization',
#  'Metrical pattern',
#  'Rhythmic relationship',
#  'Melodic form',
#  'Articulation',
#  'Musical characterstics',
#  'Ornament',
#  'Dynamics',
#  'Vocal noise']

# %%
# cantometrics data contain the ratings for each item
# here we are making a 'short' df of the columns suggested by A Wood for the Lullaby project

# canto_df = pd.read_csv(canto)
canto.columns.to_list()

# canto songid is a number not string, so fix it
canto['song_id'] = canto['song_id'].astype('str')

# rename columns with real names of the categories
# dict to rename columns
canto_name_dict = {'line_1': 'Social_Org_Group', 
'line_10': 'Repetition',
'line_11': 'Vocal_Rhythm',
'line_16': 'Melodic_Form',
'line_18': 'Number_Phrases',
'line_20': 'Melodic_Range',
'line_24': 'Tempo',
'line_25': 'Volume',
'line_26': 'Vocal_Rubato',
'line_28': 'Glissando'}
canto_renamed = canto.rename(columns=canto_name_dict)

# Now we select only the columns (lines) that Anna suggests are relevant to the Lullaby Project

canto_short = canto_renamed.iloc[:,[0, 1, 2, 3, 12, 13, 20, 22, 26, 27, 28, 30]]
canto_lullaby_features = canto_short.drop(columns="society_id")
# canto_lullaby_features.iloc[0]['Vocal_Rhythm']
canto_lullaby_features.head()
# Out:
#   song_id Preferred_name  Social_Org_Group  Repetition  Vocal_Rhythm  \
# 0    4241       'Are'are                64          16          2048
# 1    4246       'Are'are                64        8192           512
# 2   30075       'Are'are              8208        1024            64
# 3   30120       'Are'are              8208         128            64
# 4   30121       'Are'are                32         128            64
#
#    Number_Phrases  Melodic_Range  Tempo  Volume  Vocal_Rubato  Glissando
# 0             512           1024    512       2           512        512
# 1            8192            128     32      16           512       8192
# 2            2048            128    512       2          8192        512
# 3            8192            128    512       2          8192         32
# 4             512           1024     32       2          8192         32

# %% [markdown]
# ### The Codes tell us what the ratings actually mean for each line (musical type)
#
# - Normally these are integer 'codes' for each line (feature), from 1-13.
# - Here are the codes for Line 1 (Social Organization of the Group)
# - The _meaning_ of the code changes from line to line.
#
# For ex:  in line 1, code 1 means 'no singer'.  But for line 2, it means no accompaniment
#
# As we see the codes move systematically through the kinds of roles and feature one might hear in a given piece--how many performing, what they are performing, how, when and where they are performing it; who is listening, etc.

# %%
# codes_df = pd.read_csv(codes)
# codes.head(25)

# %% [markdown]
# ### Combined Codes = Powers of 2.
#
# - But when we look at the canto data, we will often find integers other than 13!  What is going on?
#
# ```
# canto_lullaby_features.iloc[0]['Vocal_Rhythm']
# 2048
# ```
#
# - Since some songs might use two or more different aspects of a given musical feature (for instance, a slow introduction and a fast conclusion) the GJ data combine the 1>13 ratings according to a system they call **Powers of 2**.  In brief:
#     - use the original rating as a power of 2.  If the rating was "4", then 2 to the 4th power = 16.  That's the integer recorded in the canto data
#     - If there are TWO ratings, then use each as power of 2, then add them together!  Original ratings of 2 and 4 would be 2 to the 2nd (4) plus 2 to the 4th (16) = 20.
# - The "raw_codes" csv unpacks these combinations, which can involve up to three 'original' codes combined into a single Power of Two integer.
#
# ```
# raw_code_list = pd.read_csv(raw_codes)
# set_combined_codes = set(raw_code_list.code)
# raw_code_list
# ```

# %%
set_combined_codes = set(raw_codes['code'])
len(set_combined_codes)
# Out:
# 95

# %%
# There are in fact 27 of these combinations in the real data that are NOT in the raw list of possibles listed above!
canto_data_set_values = set(canto.iloc[:, 3:].stack().unique())
diff = canto_data_set_values - set_combined_codes
len(diff)
# Out:
# 27

# %%
len(set(canto.iloc[:, 3:].stack().unique()))
# Out:
# 122

# %% [markdown]
# ### Checking the Powers and Combinations
#
# - Here we build out all the possible values for powers of 2 from 1 to 13
# - And also build out all the unique sums of combinations of 1, 2, or 3 of these integers
# - This in turn will allow us to retrieve the original codes from the combined numbers found in the canto data set

# %%
powers = [2**n for n in range(1, 14)]
combo_list = list(combinations(powers, 1)) + list(combinations(powers, 2)) + list(combinations(powers, 3))
sums = [{"sum" : sum(t), "full_tuple": t} for t in combo_list]
sums_df = pd.DataFrame(sums)
sums_df['sorted_original_values'] = sums_df.full_tuple.apply(lambda x: tuple(sorted([np.log2(value) for value in x], reverse=True)))
sums_df.sort_values(by="sum")
# Out:
#        sum          full_tuple sorted_original_values
# 0        2                (2,)                 (1.0,)
# 1        4                (4,)                 (2.0,)
# 13       6              (2, 4)             (2.0, 1.0)
# 2        8                (8,)                 (3.0,)
# 14      10              (2, 8)             (3.0, 1.0)
# ..     ...                 ...                    ...
# 356  12416   (128, 4096, 8192)      (13.0, 12.0, 7.0)
# 366  12544   (256, 4096, 8192)      (13.0, 12.0, 8.0)
# 372  12800   (512, 4096, 8192)      (13.0, 12.0, 9.0)
# 375  13312  (1024, 4096, 8192)     (13.0, 12.0, 10.0)
# 376  14336  (2048, 4096, 8192)     (13.0, 12.0, 11.0)
#
# [377 rows x 3 columns]

# %%
codes
# Out:
#       var_id  code                                        description  \
# 0     line_1     1                                         No singers
# 1     line_1     2  One solo singer, whether or not accompanied by...
# 2     line_1     3  One singer with an audience whose dancing, sho...
# 3     line_1     4  Two or more singers alternate in singing a mel...
# 4     line_1     5  A single predominant voice—a leader— stands ou...
# ..       ...   ...                                                ...
# 211  line_37     1  Very precise enunciation. Highly articulated c...
# 212  line_37     4  Precise enunciation. Clearly articulated conso...
# 213  line_37     7  Moderate enunciation. A moderate degree of enu...
# 214  line_37    10  Softened enunciation. Consonants are hard to d...
# 215  line_37    13  Very softened enunciation. Situations in which...
#
#                         name
# 0                   NoSinger
# 1                 SoloSinger
# 2         SoloSingerAudience
# 3      SoloSingerConsecutive
# 4    UnisonPredominantLeader
# ..                       ...
# 211   VeryPreciseEnunciation
# 212       PreciseEnunciation
# 213      ModerateEnunciation
# 214      SoftenedEnunciation
# 215  VerySoftenedEnunciation
#
# [216 rows x 4 columns]

# %% [markdown]
# ###  A Dictionary of Summed Values and the Original Values
#
# - This will allow us to translate from the summed powers of 2 back to the component ratings.

# %%
dictionary_of_value_sets = dict(zip(sums_df["sum"], sums_df["sorted_original_values"]))

# %%
lullaby_feature_workbook = canto_lullaby_features
transformed_lullaby_features = lullaby_feature_workbook.iloc[:, 3:].applymap(lambda x : dictionary_of_value_sets.get(x, 0))
lullabies_unpacked = pd.concat([lullaby_feature_workbook.iloc[:, :3], transformed_lullaby_features], axis="columns")
lullabies_unpacked.sample(50)
# Out:
#      song_id                Preferred_name  Social_Org_Group Repetition  \
# 5313   30547                          Ayta               256    (10.0,)
# 2467      92                        Tuluun                64     (1.0,)
# 818     3907                       Guaraní                32     (7.0,)
# 3285     242                         Nandi                 4     (4.0,)
# 1075    3945                          Cluj                64     (1.0,)
# 1034    1242              Minnesota Ojibwa                 4    (13.0,)
# 5069   30074                          Aari              8192    (13.0,)
# 3567   30390                        Paiwan              2048     (7.0,)
# 2096      79                        Ifaluk                 4     (1.0,)
# 1518    2201                           Fon                 4     (4.0,)
# 2089    2331                          Iban                 4     (1.0,)
# 1516    2199                           Fon              4352    (10.0,)
# 1632    2527                         Kottu                64     (4.0,)
# 3128      59                  Middle Wahgi                64    (13.0,)
# 3145    9622                   Minangkabau                 4     (1.0,)
# 3735    3375                      Ch'unchu                64     (7.0,)
# 3115    4085                Meshkwahkihaki                 4    (10.0,)
# 3178    9353                       Mongols                 4    (13.0,)
# 5207     378                       Shikoku               256     (1.0,)
# 4263    3088                     Purépecha                64     (4.0,)
# 2808    3200                         Lunda              1280     (4.0,)
# 843      586                   Nova Scotia                 4     (1.0,)
# 5429   30249                          Tsou               256     (7.0,)
# 4622     259               Great Lakes Twa              4096     (1.0,)
# 4990    4174                       Zaghawa              1280     (7.0,)
# 5309   30274                       Mungiki               256     (7.0,)
# 2348    9341                  Israeli Jews                 4     (4.0,)
# 5435   30316                          Tsou                64     (1.0,)
# 3887    3381                  Coast Salish                 4    (10.0,)
# 4286    1470                        Temiar                64     (4.0,)
# 692     2435                   Bora Witoto                 4    (10.0,)
# 1536    9173                      Auvergne                 4    (10.0,)
# 2973    3455                        Maring                64    (13.0,)
# 1486    9233                          Fiji              2304    (10.0,)
# 5381    2812                        Seediq                 4     (4.0,)
# 534      658               Spanish Basques                64     (1.0,)
# 5773     180        Gayogo̱hó꞉nǫʼ (Cayuga)               256    (10.0,)
# 4335    9211                Tonga (Malawi)               256     (7.0,)
# 1618    2542                       Galicia                64     (4.0,)
# 4352    9258                      Tibetans              3072    (10.0,)
# 5745    2827  S Italian American/ Calabria                32     (7.0,)
# 2102   30490                        Ifugao               256     (1.0,)
# 4817    4030                         Warao                 4     (7.0,)
# 5190     396                 Monastic Lama                 4     (1.0,)
# 2718    2190                       W Sáami                32    (13.0,)
# 1442    2145                  Ekonda Mongo              5120     (7.0,)
# 2886    3177                       Malinke                64     (7.0,)
# 133     9989                       Koorete              1024          0
# 5377   30542                      Saisiyat               256     (7.0,)
# 2031    2754                    Wixáritari                 4    (10.0,)
#
#      Vocal_Rhythm Number_Phrases Melodic_Range    Tempo      Volume  \
# 5774  (10.0,)   (7.0,)     (10.0,)  (10.0,)   (4.0,)   (7.0,)   (1.0,)
# 5775  (13.0,)   (7.0,)      (7.0,)   (8.0,)   (7.0,)   (7.0,)   (4.0,)
#
#       line_37
# 0      (7.0,)
# 1     (13.0,)
# 2     (13.0,)
# 3     (10.0,)
# 4     (10.0,)
# ...       ...
# 5771   (7.0,)
# 5772   (7.0,)
# 5773  (10.0,)
# 5774   (7.0,)
# 5775   (7.0,)
#
# [5776 rows x 40 columns]

# %%
for col in canto.columns[3:]:
    canto[col] = canto[col].apply(lambda x: int(x[0]) if isinstance(x, tuple) else x)

# %%
lullabies_unpacked
# Out:
#      song_id          Preferred_name  Social_Org_Group  Repetition  \
# 0       4241                'Are'are                64           4
# 1       4246                'Are'are                64          13
# 2      30075                'Are'are              8208          10
# 3      30120                'Are'are              8208           7
# 4      30121                'Are'are                32           7
# ...      ...                     ...               ...         ...
# 5771     364       Hokkaido Japanese                 4           1
# 5772     183          Eastern Ojibwa                 4           1
# 5773     180  Gayogo̱hó꞉nǫʼ (Cayuga)               256          10
# 5774     181  Gayogo̱hó꞉nǫʼ (Cayuga)               256          10
# 5775    1238  Gayogo̱hó꞉nǫʼ (Cayuga)               256          13
#
#       Vocal_Rhythm  Number_Phrases  Melodic_Range  Tempo  Volume  \
# 0               11               9             10      9       1
# 1                9              13              7      5       4
# 2                6              11              7      9       1
# 3                6              13              7      9       1
# 4                6               9             10      5       1
# ...            ...             ...            ...    ...     ...
# 5771            13               5             10      3       7
# 5772            11               9              7      9       1
# 5773            11               3             10     11      13
# 5774            11               3              7      9      10
# 5775             6               6              7      3      10
#
#       Vocal_Rubato  Glissando
# 0                9          9
# 1                9         13
# 2               13          9
# 3               13          5
# 4               13          5
# ...            ...        ...
# 5771             1          9
# 5772            13         13
# 5773            13         13
# 5774             9          5
# 5775             9          9
#
# [5776 rows x 11 columns]

# %%
# data about the social groups
societies_df = pd.read_csv(societies)
societies_df.head()
# Out:
#   Society_latitude  Society_longitude  Homeland_latitude_of_diasporic_peoples  \
# 0             1.55              28.44                                     NaN
# 1             2.36              31.01                                     NaN
# 2            -2.27              14.44                                     NaN
# 3            -5.12              18.04                                     NaN
# 4             3.96              16.59                                     NaN
#
#    Homeland_longitude_of_diasporic_peoples  Area_latitude  Area_longitude  \
# 0                                      NaN           1.83           29.50
# 1                                      NaN           2.79           30.86
# 2                                      NaN          -2.07           15.37
# 3                                      NaN          -5.13           15.69
# 4                                      NaN           5.34           23.13
#
#    Region        Division                  Subregion  \
# 0  Africa  Central Africa  Equatorial Central Africa
# 1  Africa  Central Africa  Equatorial Central Africa
# 2  Africa  Central Africa  Equatorial Central Africa
# 3  Africa  Central Africa  Equatorial Central Africa
# 4  Africa  Central Africa           N Central Africa
#
#                                                 Area  ...  \
# 0                           Ituri Prov, N E DR Congo  ...
# 1                           N E DR Congo/ N W Uganda  ...
# 2                             Plateaux Dept, C Congo  ...
# 3                                       S W DR Congo  ...
# 4  Cameroon/ Central African Rep/ DR Congo/ South...  ...
#
#   eHRAF_soc_w_xd_id_2? eHRAF_OWC.1 eHRAF_OWC_Name.1 eHRAF_SubOWC_in_DPLACE.1  \
# 0                 NONE        NONE             NONE                     NONE
# 1                 NONE        NONE             NONE                     NONE
# 2                  NaN         NaN              NaN                      NaN
# 3                 NONE        NONE             NONE                     NONE
# 4                 NONE        NONE             NONE                     NONE
#
#   eHRAF_SubOWC_Name_in_DPLACE.1 eHRAF_subOWC_FINAL_STATUS_2021.1  \
# 0                          NONE                             NONE
# 1                          NONE                             NONE
# 2                           NaN                              NaN
# 3                          NONE                             NONE
# 4                          NONE                             NONE
#
#                                  STATUS_JULY_31_2021  \
# 0      D-PLACE_GJB_society_names_AND_languages_match
# 1      D-PLACE_GJB_society_names_AND_languages_match
# 2                                  NOT_CHECKED_BY_KK
# 3      D-PLACE_GJB_society_names_AND_languages_match
# 4  D-PLACE_GJB_society_names_match; language_assi...
#
#   language match checked by KK D-PLACE match checked by KK KK_ISSUE
# 0                         DONE                        DONE      NaN
# 1                         DONE                        DONE      NaN
# 2            NOT_CHECKED_BY_KK           NOT_CHECKED_BY_KK      NaN
# 3                         DONE                        DONE      NaN
# 4                         DONE                        DONE      NaN
#
# [5 rows x 78 columns]

# %%
# now the data about the individual songs
song_df = pd.read_csv(songs)
song_df.columns.to_list()
song_cols = ["song_id", 
             "Local_latitude",
             "society_id",
             'Local_longitude',
             'Homeland_latitude',
             'Homeland_longitude',
             'Region',
             'Genre']
song_data_selected = song_df[song_cols].fillna('')
len(song_data_selected)
# Out:
# 6038

# %%
combined = pd.merge(lullabies_unpacked, song_data_selected,
how='left', on='song_id')
combined.fillna('')
# Out:
#      song_id          Preferred_name  Social_Org_Group Repetition  \
# 0       4241                'Are'are                64     (4.0,)
# 1       4246                'Are'are                64    (13.0,)
# 2      30075                'Are'are              8208    (10.0,)
# 3      30120                'Are'are              8208     (7.0,)
# 4      30121                'Are'are                32     (7.0,)
# ...      ...                     ...               ...        ...
# 5771     364       Hokkaido Japanese                 4     (1.0,)
# 5772     183          Eastern Ojibwa                 4     (1.0,)
# 5773     180  Gayogo̱hó꞉nǫʼ (Cayuga)               256    (10.0,)
# 5774     181  Gayogo̱hó꞉nǫʼ (Cayuga)               256    (10.0,)
# 5775    1238  Gayogo̱hó꞉nǫʼ (Cayuga)               256    (13.0,)
#
#      Vocal_Rhythm Number_Phrases Melodic_Range    Tempo   Volume Vocal_Rubato  \
# 0         (11.0,)         (9.0,)       (10.0,)   (9.0,)   (1.0,)       (9.0,)
# 1          (9.0,)        (13.0,)        (7.0,)   (5.0,)   (4.0,)       (9.0,)
# 2          (6.0,)        (11.0,)        (7.0,)   (9.0,)   (1.0,)      (13.0,)
# 3          (6.0,)        (13.0,)        (7.0,)   (9.0,)   (1.0,)      (13.0,)
# 4          (6.0,)         (9.0,)       (10.0,)   (5.0,)   (1.0,)      (13.0,)
# ...           ...            ...           ...      ...      ...          ...
# 5771      (13.0,)         (5.0,)       (10.0,)   (3.0,)   (7.0,)       (1.0,)
# 5772      (11.0,)         (9.0,)        (7.0,)   (9.0,)   (1.0,)      (13.0,)
# 5773      (11.0,)         (3.0,)       (10.0,)  (11.0,)  (13.0,)      (13.0,)
# 5774      (11.0,)         (3.0,)        (7.0,)   (9.0,)  (10.0,)       (9.0,)
# 5775       (6.0,)         (6.0,)        (7.0,)   (3.0,)  (10.0,)       (9.0,)
#
#      Glissando  Local_latitude  society_id  Local_longitude Homeland_latitude  \
# 0       (9.0,)           -9.57       10000           161.37
# 1      (13.0,)           -9.57       10000           161.37
# 2       (9.0,)           -9.21       10000           161.16
# 3       (5.0,)           -9.32       10000           161.33
# 4       (5.0,)           -9.32       10000           161.33
# ...        ...             ...         ...              ...               ...
# 5771    (9.0,)           41.86       62554           140.12
# 5772   (13.0,)           46.77       62555           -88.48
# 5773   (13.0,)           43.05       62556           -80.12
# 5774    (5.0,)           43.05       62556           -80.12
# 5775    (9.0,)           43.05       62556           -80.12
#
#      Homeland_longitude         Region  \
# 0                              Oceania
# 1                              Oceania
# 2                              Oceania
# 3                              Oceania
# 4                              Oceania
# ...                 ...            ...
# 5771                     North Eurasia
# 5772                     North America
# 5773                     North America
# 5774                     North America
# 5775                     North America
#
#                                                   Genre
# 0                                          Women's Song
# 1
# 2                                               Lullaby
# 3                                     Lullaby; Roromera
# 4                                     Lullaby; Roromera
# ...                                                 ...
# 5771          Fisherman's Song; Work Song; Fishing Song
# 5772    Animal Song; Spirit Song; Clan Song; Totem Song
# 5773                  Dance Song; Magic Song; Rain Song
# 5774  Thanksgiving Song; Dance Song; Chief's Song; C...
# 5775                           Social Dance; Dance Song
#
# [5776 rows x 18 columns]

# %% [markdown]
# ### Filter for Lullabies!
#
# ```
# lullabies = combined[combined['Genre'].str.contains('Lullaby')]
# ```

# %%
lullabies = combined[combined['Genre'].str.contains('Lullaby')]
# lullaby["Glissando"].value_counts()

# %%
# an initial exploratory grouping
grouped = lullabies.groupby(['Region', 'Melodic_Range'])['song_id'].count()
grouped
# Out:
# Region           Melodic_Range
# Africa           (4.0,)            1
#                  (7.0,)            2
#                  (10.0,)           2
#                  (13.0,)           1
# Australia        (7.0,)            1
# Central America  (4.0,)            5
#                  (7.0,)            9
#                  (10.0,)           1
# Central Asia     (7.0,)            1
# East Asia        (7.0,)            1
#                  (10.0,)           2
# Europe           (4.0,)            6
#                  (7.0,)           15
#                  (10.0,)           2
# North America    (4.0,)            4
#                  (7.0,)            3
#                  (10.0,)           3
#                  (13.0,)           1
# North Eurasia    (4.0,)            2
#                  (7.0,)            2
#                  (10.0,)           1
# Oceania          (1.0,)            2
#                  (4.0,)            4
#                  (4.0, 1.0)        1
#                  (7.0,)            5
#                  (10.0,)           4
# South America    (1.0,)            3
#                  (4.0,)            3
#                  (7.0,)            5
#                  (10.0,)           1
# South Asia       (4.0,)            1
#                  (7.0,)            2
#                  (13.0,)           1
# Southeast Asia   (10.0,)           1
# Western Asia     (7.0,)            1
# Name: song_id, dtype: int64
